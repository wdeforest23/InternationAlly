# %% [markdown]
# # Search Property Listings
# 1. Model Setting
# 2. Create API filter from user's query
# 3. Get Property Listings from Zillow API
# 4. Generate advice with the property listings

# %% [markdown]
# ## 1. Model Setting - Gemini pro 1.0

# %%
# %pip list | grep google-cloud-aiplatform
# %pip list | grep google-api-core

# %%
# %pip install google-cloud-aiplatform==1.43.0
# %pip install google-api-core==2.17.1

# %%
import vertexai
from vertexai.preview.generative_models import GenerativeModel, ChatSession, Part
import vertexai.preview.generative_models as generative_models
# Out:
# 2024-04-22 22:26:30.324400: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-22 22:26:31.436234: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2024-04-22 22:26:31.436360: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2024-04-22 22:26:31.436371: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
vertexai.init(project="adsp-capstone-property-pilot", location="us-central1")

# %%
model = GenerativeModel("gemini-1.0-pro")
chat = model.start_chat()

def get_chat_response(chat: ChatSession, prompt: str) -> str:
    text_response = []
    responses = chat.send_message(prompt, stream=True)
    for chunk in responses:
        text_response.append(chunk.text)
    return "".join(text_response)

# %% [markdown]
# ### Test

# %%
prompt = "Hello."
print(get_chat_response(chat, prompt))
# Out:
# Hello! It's a pleasure to meet you. What can I help you with today?

# %% [markdown]
# ## 2. Create API filter from user's query

# %%
def generate_prompt_apifilter(instruction, user_query):
    return instruction.replace("{USER_QUERY}", user_query)

# %%
instruction = """
### Instructions ###
I want you to act as a principal software engineer. You'll be given a task to determine the parameters of an API call based on the "User's query" below, 
please modify the conditions and create the appropriate API filter. Provide your answer only for the part within ‘{}’. 
Do not include any other explanations in your response. Read the below instructions.

— Filter Options (Optional, so not required if not specified in the User's query) —

1. location
Format: STRING(lowercase)
Example: santa monica, ca

*If not specifically mentioned, use 'chicago, il'.
*Do not alter the format from the above example. 
*If you want to search for a specific neighborhood like Chicago's West Loop, please specify it in the Filter option '16. keywords', not here.
Incorrect example: "location": "west loop, chicago, il"
Correct example: "location": "chicago, il", "keywords": "west loop"


2. status_type
For purchase or for rent
Format: STRING
Example:
ForSale
ForRent

3. home_type
Property type comma-separated or empty for all types
Format: STRING
Example(ForRent):
Townhomes
Houses
Apartments_Condos_Co-ops

Example(ForSale):
Multi-family
Apartments
Houses
Manufactured
Condos
LotsLand
Townhomes

*If it cannot be determined from the User's query, specification is not necessary.

4. minPrice
If status_type = ForSale you can filter by min price.
Format: NUMBER
Example: 200000

5. maxPrice
If status_type = ForSale you can filter by max price.
Format: NUMBER
Example: 900000

6. rentMinPrice
If status_type = ForRent you can filter by min rent price.
Format: NUMBER
Example: 2000

7. rentMaxPrice
If status_type = ForRent you can filter by max rent price.
Format: NUMBER
Example: 3000

8. bathsMin
Bathrooms min count
Format: NUMBER
Example: 2
* If a specific number of baths is specified, rather than a range, please enter the same number for both bathsMin and bathsMax.

9. bathsMax
Bathrooms max count
Format: NUMBER
Example: 3

10. bedsMin
Bedrooms min count
Format: NUMBER
Example: 1
* If a specific number of bedrooms is specified, rather than a range, please enter the same number for both bedsMin and bedsMax.

11. bedsMax
Bedrooms max count
Format: NUMBER
Example: 3

12. sqftMin
Square Feet min value
Format: NUMBER
Example: 600

13. sqftMax
Square Feet max value
Format: NUMBER
Example: 1500

14. buildYearMin
Year Built min value
Format: NUMBER
Example: 1980

15. buildYearMax
Year Built max value
Format: NUMBER
Example: 2023

16. keywords
Filter with keywords.
Format: STRING
Example1: ‘gym’
Example2: ‘West Loop’
Example3: ‘pet, pool, South Loop‘
*Not necessary if already specified in another filter or if there is no clear specification in user’s query. Specify conditions that cannot be specified in other filters by using keywords.

17. sort
Sorting criteria for the results
Always specify "Newest"


Now, use the following query to determine the appropriate parameters.

### Example query ###
I am looking for a one-bedroom.

### Example Output ###
{
"location":"chicago, il",
"bedsMin":"1",
"bedsMax":"1",
"sort":"Newest"
}

### Example query ###
I am looking for a rental in South Loop, Chicago, with at least one bedroom and a rent of $3000 or less per month.

### Example Output ###
{
"location": "chicago, il",
"status_type": "ForRent",
"rentMaxPrice": 3000,
"bedsMin": 1,
"keywords": "South Loop",
"sort":"Newest"
}

### Example query ###
I am looking for a rental in West Loop, Chicago, with one bedroom and a rent between $2000 and $2500.

### Example Output ###
{
"location": "chicago, il",
"status_type": "ForRent",
"rentMinPrice": 2500,
"rentMaxPrice": 3000,
"bedsMin": 1,
"bedsMax": 1,
"keywords": "West Loop",
"sort":"Newest"
}

### Example query ###
I want to buy a house in River North with at least two bedrooms.

### Example Output ###
{
"location":"chicago, il",
"status_type": "ForSale",
"keywords":"River North",
"bedsMin":"2",
"sort":"Newest"
}

### Example query ###
I am looking for a rental around Wicker Park in Chicago with a gym and a pool. It should be built within the last 10 years.

### Example Output ###
{
"location": "chicago, il",
"home_type": "Apartments_Condos_Co-ops",
"status_type": "ForRent",
"buildYearMin": 2014,
"keywords": "Wicker Park, gym, pool",
"sort":"Newest"
}

### Example query ###
I am looking for a rental with a balcony, over 700 sqft in size, and less than 5 years old, located near downtown.

### Example Output ###
{
"location": "chicago, il",
"status_type": "ForRent",
"sqftMin":"700",
"buildYearMin": 2019,
"keywords": "downtown, balcony",
"sort":"Newest"
}


### User’s query ###
{USER_QUERY}

### Output ###
"""

# %%
user_query = "I am looking for a two-bedroom."
print(generate_prompt_apifilter(instruction, user_query))
# Out:
# ### Instructions ###
# I want you to act as a principal software engineer. You'll be given a task to determine the parameters of an API call based on the "User's query" below,
# please modify the conditions and create the appropriate API filter. Provide your answer only for the part within ‘{}’.
# Do not include any other explanations in your response. Read the below instructions.
#
# — Filter Options (Optional, so not required if not specified in the User's query) —
#
# 1. location
# Format: STRING(lowercase)
# Example: santa monica, ca
#
# *If not specifically mentioned, use 'chicago, il'.
# *Do not alter the format from the above example.
# *If you want to search for a specific neighborhood like Chicago's West Loop, please specify it in the Filter option '16. keywords', not here.
# Incorrect example: "location": "west loop, chicago, il"
# Correct example: "location": "chicago, il", "keywords": "west loop"
#
#
# 2. status_type
# For purchase or for rent
# Format: STRING
# Example:
# ForSale
# ForRent
#
# 3. home_type
# Property type comma-separated or empty for all types
# Format: STRING
# Example(ForRent):
# Townhomes
# Houses
# Apartments_Condos_Co-ops
#
# Example(ForSale):
# Multi-family
# Apartments
# Houses
# Manufactured
# Condos
# LotsLand
# Townhomes
#
# *If it cannot be determined from the User's query, specification is not necessary.
#
# 4. minPrice
# If status_type = ForSale you can filter by min price.
# Format: NUMBER
# Example: 200000
#
# 5. maxPrice
# If status_type = ForSale you can filter by max price.
# Format: NUMBER
# Example: 900000
#
# 6. rentMinPrice
# If status_type = ForRent you can filter by min rent price.
# Format: NUMBER
# Example: 2000
#
# 7. rentMaxPrice
# If status_type = ForRent you can filter by max rent price.
# Format: NUMBER
# Example: 3000
#
# 8. bathsMin
# Bathrooms min count
# Format: NUMBER
# Example: 2
# * If a specific number of baths is specified, rather than a range, please enter the same number for both bathsMin and bathsMax.
#
# 9. bathsMax
# Bathrooms max count
# Format: NUMBER
# Example: 3
#
# 10. bedsMin
# Bedrooms min count
# Format: NUMBER
# Example: 1
# * If a specific number of bedrooms is specified, rather than a range, please enter the same number for both bedsMin and bedsMax.
#
# 11. bedsMax
# Bedrooms max count
# Format: NUMBER
# Example: 3
#
# 12. sqftMin
# Square Feet min value
# Format: NUMBER
# Example: 600
#
# 13. sqftMax
# Square Feet max value
# Format: NUMBER
# Example: 1500
#
# 14. buildYearMin
# Year Built min value
# Format: NUMBER
# Example: 1980
#
# 15. buildYearMax
# Year Built max value
# Format: NUMBER
# Example: 2023
#
# 16. keywords
# Filter with keywords.
# Format: STRING
# Example1: ‘gym’
# Example2: ‘West Loop’
# Example3: ‘pet, pool, South Loop‘
# *Not necessary if already specified in another filter or if there is no clear specification in user’s query. Specify conditions that cannot be specified in other filters by using keywords.
#
# 17. sort
# Sorting criteria for the results
# Always specify "Newest"
#
#
# Now, use the following query to determine the appropriate parameters.
#
# ### Example query ###
# I am looking for a one-bedroom.
#
# ### Example Output ###
# {
# "location":"chicago, il",
# "bedsMin":"1",
# "bedsMax":"1",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental in South Loop, Chicago, with at least one bedroom and a rent of $3000 or less per month.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "rentMaxPrice": 3000,
# "bedsMin": 1,
# "keywords": "South Loop",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental in West Loop, Chicago, with one bedroom and a rent between $2000 and $2500.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "rentMinPrice": 2500,
# "rentMaxPrice": 3000,
# "bedsMin": 1,
# "bedsMax": 1,
# "keywords": "West Loop",
# "sort":"Newest"
# }
#
# ### Example query ###
# I want to buy a house in River North with at least two bedrooms.
#
# ### Example Output ###
# {
# "location":"chicago, il",
# "status_type": "ForSale",
# "keywords":"River North",
# "bedsMin":"2",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental around Wicker Park in Chicago with a gym and a pool. It should be built within the last 10 years.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "home_type": "Apartments_Condos_Co-ops",
# "status_type": "ForRent",
# "buildYearMin": 2014,
# "keywords": "Wicker Park, gym, pool",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental with a balcony, over 700 sqft in size, and less than 5 years old, located near downtown.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "sqftMin":"700",
# "buildYearMin": 2019,
# "keywords": "downtown, balcony",
# "sort":"Newest"
# }
#
#
# ### User’s query ###
# I am looking for a two-bedroom.
#
# ### Output ###

# %% [markdown]
# ### Test

# %%
user_query = "I am looking for a two-bedroom."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "bedsMin":"2",
# "bedsMax":"2",
# "location":"chicago, il",
# "sort":"Newest"
# }

# %%
user_query = "I am looking for a rental in Fulton Market, Chicago, with at least one bedroom and a rent of $3500 or less per month."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "rentMaxPrice": 3500,
# "bedsMin": 1,
# "keywords": "Fulton Market",
# "sort":"Newest"
# }

# %%
user_query = "I want to buy a house in Chinatown, Chicago with a minimum of 2 bathrooms and 2 bedrooms."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location":"chicago, il",
# "status_type": "ForSale",
# "keywords":"Chinatown",
# "bedsMin":"2",
# "bathsMin":"2",
# "sort":"Newest"
# }

# %%
user_query = "I am looking for a rental around Hyde Park with a gym and a pool. It should be built within the last 15 years."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location":"chicago, il",
# "home_type": "Apartments_Condos_Co-ops",
# "status_type": "ForRent",
# "buildYearMin": 2008,
# "keywords":"Hyde Park, gym, pool",
# "sort":"Newest"
# }

# %%
user_query = "I am looking for a rental in the Old Town area of Chicago with a balcony and a pool."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "keywords": "Old Town, balcony, pool",
# "sort":"Newest"
# }

# %% [markdown]
# ## 3. Get Property Listings from Zillow API

# %% [markdown]
# ### Example

# %%
import requests

url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

headers = {
	"X-RapidAPI-Key": "YOUR_API_KEY",
	"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

# %%
querystring = {"location":"chicago, il", "status_type":"ForRent", "bathsMin":"1","bedsMin":"3", "keywords":"west", "sort":"Newest"}
response = requests.get(url, headers = headers, params = querystring)

# %%
response.json()
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2238 W Warren Blvd #1, Chicago, IL 60612',
#    'variableData': None,
#    'unit': '# 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4b4c0860a673eabc37cb35ff26c4bf5e-p_e.jpg',
#    'price': 3995,
#    'detailUrl': '/homedetails/2238-W-Warren-Blvd-1-Chicago-IL-60612/2077513878_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.68252,
#    'latitude': 41.88218,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2077513878',
#    'listingSubType': {},
#    'rentZestimate': 2997,
#    'daysOnZillow': 0,
#    'bathrooms': 2.5,
#    'livingArea': 2600,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$4,538+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.890324--87.650696',
#    'longitude': -87.650696,
#    'buildingName': None,
#    'address': '914 W Hubbard St, Chicago, IL',
#    'detailUrl': '/b/914-w-hubbard-st-chicago-il-9S4pZT/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2104482697,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ec34a5cef47e046b4f0c3828a958de05-p_e.jpg',
#    'latitude': 41.890324},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': '1939 N Sayre Ave, Elmwood Park, IL 60707',
#    'variableData': None,
#    'zestimate': 477000,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/db67a5e2ee1b20527eb8622f1ca7b2a1-p_e.jpg',
#    'price': 3115,
#    'detailUrl': '/homedetails/1939-N-Sayre-Ave-Elmwood-Park-IL-60707/2069907498_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.80036,
#    'latitude': 41.91444,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2069907498',
#    'listingSubType': {},
#    'rentZestimate': 3099,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 2074,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '204 S Leavitt St #402, Chicago, IL 60612',
#    'variableData': None,
#    'unit': '# 402',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3264238fcae072b528163979c3ff66f0-p_e.jpg',
#    'price': 3500,
#    'detailUrl': '/homedetails/204-S-Leavitt-St-402-Chicago-IL-60612/348333150_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.68147,
#    'latitude': 41.878567,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '348333150',
#    'listingSubType': {},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1450,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1651 N Francisco Ave #1R, Chicago, IL 60647',
#    'variableData': None,
#    'unit': '# 1R',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7a143350e4ba5246eff3873331c91fb2-p_e.jpg',
#    'price': 2200,
#    'detailUrl': '/homedetails/1651-N-Francisco-Ave-1R-Chicago-IL-60647/2078027822_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.6988,
#    'latitude': 41.91174,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2078027822',
#    'listingSubType': {},
#    'rentZestimate': 2950,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1600,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '501 W 60th Pl #3, Chicago, IL 60621',
#    'variableData': None,
#    'unit': '# 3',
#    'zestimate': 157600,
#    'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=41.78413391113281,-87.63783264160156&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=9ZCf4XkG_Obu71plMRIG1iiCQeY=',
#    'price': 1800,
#    'detailUrl': '/homedetails/501-W-60th-Pl-3-Chicago-IL-60621/70477864_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.63783,
#    'latitude': 41.784134,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '70477864',
#    'listingSubType': {},
#    'rentZestimate': 1984,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1240,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': None},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': None,
#    'address': '2417 W Fillmore St #1, Chicago, IL 60612',
#    'variableData': None,
#    'unit': '# 1',
#    'zestimate': 379500,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a86dd4a9362ae7097085b1fea3363862-p_e.jpg',
#    'price': 3250,
#    'detailUrl': '/homedetails/2417-W-Fillmore-St-1-Chicago-IL-60612/87698169_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.686806,
#    'latitude': 41.86816,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '87698169',
#    'listingSubType': {},
#    'rentZestimate': 3140,
#    'daysOnZillow': 0,
#    'bathrooms': 2.5,
#    'livingArea': 2600,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': '6141 S Throop St, Chicago, IL 60636',
#    'variableData': None,
#    'zestimate': 206600,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/208d4719a9b04a9c2cb6a83d798a24d6-p_e.jpg',
#    'price': 2900,
#    'detailUrl': '/homedetails/6141-S-Throop-St-Chicago-IL-60636/3992743_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.656746,
#    'latitude': 41.78201,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '3992743',
#    'listingSubType': {},
#    'rentZestimate': 2069,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1579,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1528 W Chestnut St APT 2, Chicago, IL 60642',
#    'variableData': None,
#    'unit': 'Apt 2',
#    'zestimate': 718700,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3a66d1455f1c5690300e41dfa8c572e0-p_e.jpg',
#    'price': 2680,
#    'detailUrl': '/homedetails/1528-W-Chestnut-St-APT-2-Chicago-IL-60642/2126778275_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.66596,
#    'latitude': 41.89817,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2126778275',
#    'listingSubType': {},
#    'rentZestimate': 2995,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1350,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$1,095+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.88085--87.74993',
#    'longitude': -87.74993,
#    'buildingName': '5100-04 W Madison St',
#    'address': '5100 W Madison St, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/5100.dash.04-w-madison-st/9S55MP/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2104513367,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3bcdb14b47768008832a4328cb4cf80e-p_e.jpg',
#    'latitude': 41.88085},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '5507-5509 S. Hyde Park Boulevard, 5507 S Hyde Park Blvd #5509-2S, Chicago, IL 60637',
#    'variableData': None,
#    'unit': '# 5509-2S',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/759c48229bb2e57d56e03f5a036b401f-p_e.jpg',
#    'price': 4099,
#    'detailUrl': '/apartments/chicago-il/5507.dash.5509-s.-hyde-park-boulevard/5Xg2sH/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.58351,
#    'latitude': 41.794918,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '348328590',
#    'listingSubType': {},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 1937,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2641-43 N. Fairfield Ave., 2641-43 Fairfield Avenue Gdn #2641, Chicago, IL 60647',
#    'variableData': None,
#    'unit': '# 2641',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/12b597cffbc6b05f2831ba27e54022ed-p_e.jpg',
#    'price': 3200,
#    'detailUrl': '/homedetails/2641-43-Fairfield-Avenue-Gdn-2641-Chicago-IL-60647/2064245115_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.69588,
#    'latitude': 41.914814,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2064245115',
#    'listingSubType': {},
#    'rentZestimate': 3185,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$2,495+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.882565--87.66961',
#    'longitude': -87.66961,
#    'buildingName': '38-44 N. Paulina St. / 1710-1714 W. Warren Blvd.',
#    'address': '38 N Paulina St, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/38.dash.44-n.-paulina-st.-1710.dash.1714-w.-warren-blvd./5XjCv2/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 1001452053,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/6f2e42fcfd1766e4c7b6f597c923b55c-p_e.jpg',
#    'latitude': 41.882565},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '6625 S Evans Ave #1, Chicago, IL 60637',
#    'variableData': None,
#    'unit': '# 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d847fa0c5fcdd683da75f1fe9b6016c8-p_e.jpg',
#    'price': 2550,
#    'detailUrl': '/homedetails/6625-S-Evans-Ave-1-Chicago-IL-60637/2053172778_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.6067,
#    'latitude': 41.774208,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2053172778',
#    'listingSubType': {},
#    'rentZestimate': 2081,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1700,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1457 N Washtenaw Ave APT 2F, Chicago, IL 60622',
#    'variableData': None,
#    'unit': 'Apt 2F',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ba4462822f8a2e5ba37756614699710d-p_e.jpg',
#    'price': 2800,
#    'detailUrl': '/homedetails/1457-N-Washtenaw-Ave-APT-2F-Chicago-IL-60622/2069876779_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.694145,
#    'latitude': 41.908295,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2069876779',
#    'listingSubType': {},
#    'rentZestimate': 2028,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1500,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': '1833 W Belle Plaine Ave UNIT 1, Chicago, IL 60613',
#    'variableData': None,
#    'unit': 'Unit 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e6da731fad33b2ecf2f5ff7242f73a19-p_e.jpg',
#    'price': 2600,
#    'detailUrl': '/homedetails/1833-W-Belle-Plaine-Ave-UNIT-1-Chicago-IL-60613/348322720_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.67555,
#    'latitude': 41.955772,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '348322720',
#    'listingSubType': {},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$6,249+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.886642--87.631195',
#    'longitude': -87.631195,
#    'buildingName': 'OneEleven',
#    'address': '111 W Wacker Dr, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/oneeleven/95x9pN/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2000051736,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/dbd4a01c412fca27073b7b8ef48eaeaf-p_e.jpg',
#    'latitude': 41.886642},
#   {'units': [{'roomForRent': False, 'beds': '4', 'price': '$2,200+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.90002--87.71804',
#    'longitude': -87.71804,
#    'buildingName': None,
#    'address': '1030 N Monticello Ave, Chicago, IL',
#    'detailUrl': '/b/1030-n-monticello-ave-chicago-il-5XfXGJ/',
#    'isBuilding': True,
#    'hasImage': None,
#    'lotId': 1001138369,
#    'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=41.900020599365234,-87.7180404663086&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=PgFQyBtsx82IOrSWLBw7MvLkenU=',
#    'latitude': 41.90002},
#   {'dateSold': None,
#    'propertyType': 'CONDO',
#    'lotAreaValue': None,
#    'address': '6425 W Touhy Ave UNIT 2D, Chicago, IL 60646',
#    'variableData': {'text': '3D Tour', 'type': '3D_HOME'},
#    'unit': 'Unit 2D',
#    'zestimate': 328800,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/623aba50ea418bef0810df5eb63ab1a1-p_e.jpg',
#    'price': 2500,
#    'detailUrl': '/homedetails/6425-W-Touhy-Ave-UNIT-2D-Chicago-IL-60646/89889881_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.78796,
#    'latitude': 42.011703,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '89889881',
#    'listingSubType': {},
#    'rentZestimate': 2133,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1600,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '4216 W Monroe St #2, Chicago, IL 60624',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/6ec4d7f7e2f542d119e8d00402213850-p_e.jpg',
#    'price': 2100,
#    'detailUrl': '/homedetails/4216-W-Monroe-St-2-Chicago-IL-60624/2079396213_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.73124,
#    'latitude': 41.879955,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2079396213',
#    'listingSubType': {},
#    'rentZestimate': 1800,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1277,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': '7532 S Parnell Ave, Chicago, IL 60620',
#    'variableData': None,
#    'zestimate': 255900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ee4dee592736f48e61b36551b8d8beec-p_e.jpg',
#    'price': 1300,
#    'detailUrl': '/homedetails/7532-S-Parnell-Ave-Chicago-IL-60620/4007083_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.63872,
#    'latitude': 41.75703,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '4007083',
#    'listingSubType': {},
#    'rentZestimate': 2675,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 2200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1512 W Jackson Blvd FLOOR 2, Chicago, IL 60607',
#    'variableData': None,
#    'unit': 'Floor 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/eef7be059e05740ea703b92f19eb8df5-p_e.jpg',
#    'price': 4600,
#    'detailUrl': '/homedetails/1512-W-Jackson-Blvd-FLOOR-2-Chicago-IL-60607/348313020_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.66495,
#    'latitude': 41.87792,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '348313020',
#    'listingSubType': {},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1500,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2546 W Haddon Ave #2, Chicago, IL 60622',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': 488200,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f6c81cdb5073276a9b852b2912e6cbbd-p_e.jpg',
#    'price': 3600,
#    'detailUrl': '/homedetails/2546-W-Haddon-Ave-2-Chicago-IL-60622/159466265_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.69133,
#    'latitude': 41.902245,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '159466265',
#    'listingSubType': {},
#    'rentZestimate': 3037,
#    'daysOnZillow': 0,
#    'bathrooms': 2.5,
#    'livingArea': 2000,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1719 N Western Ave APT 3, Chicago, IL 60647',
#    'variableData': None,
#    'unit': 'Apt 3',
#    'zestimate': 473700,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/af4afec3d00b4aa4cf699e6667cf1456-p_e.jpg',
#    'price': 3100,
#    'detailUrl': '/homedetails/1719-N-Western-Ave-APT-3-Chicago-IL-60647/89967607_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.6869,
#    'latitude': 41.912773,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '89967607',
#    'listingSubType': {},
#    'rentZestimate': 3675,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1600,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '816 S Loomis St, Chicago, IL 60607',
#    'variableData': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/489b6fe9061a692d135af8eb99b19773-p_e.jpg',
#    'price': 2800,
#    'detailUrl': '/homedetails/816-S-Loomis-St-Chicago-IL-60607/2079896027_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.66205,
#    'latitude': 41.871147,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2079896027',
#    'listingSubType': {},
#    'rentZestimate': 2670,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2300 W Warren Blvd APT 3, Chicago, IL 60612',
#    'variableData': None,
#    'unit': 'Apt 3',
#    'zestimate': 594300,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7fe3383fbbb3614683fac89f9c6bd546-p_e.jpg',
#    'price': 6500,
#    'detailUrl': '/homedetails/2300-W-Warren-Blvd-APT-3-Chicago-IL-60612/70465632_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.684296,
#    'latitude': 41.882374,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '70465632',
#    'listingSubType': {},
#    'rentZestimate': 3673,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 4400,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1722 W Ohio St #2, Chicago, IL 60622',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/56db14df7eae1ef6e119d04bcaa31494-p_e.jpg',
#    'price': 2850,
#    'detailUrl': '/homedetails/1722-W-Ohio-St-2-Chicago-IL-60622/2144203887_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.670616,
#    'latitude': 41.892593,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2144203887',
#    'listingSubType': {},
#    'rentZestimate': 3025,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1350,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '4911 N Washtenaw Ave #1, Chicago, IL 60625',
#    'variableData': None,
#    'unit': '# 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/726701979de49014d451a885d440f380-p_e.jpg',
#    'price': 2500,
#    'detailUrl': '/homedetails/4911-N-Washtenaw-Ave-1-Chicago-IL-60625/2088146903_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.69598,
#    'latitude': 41.971107,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2088146903',
#    'listingSubType': {},
#    'rentZestimate': 2388,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1800,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '747 N Sedgwick St APT 2S, Chicago, IL 60654',
#    'variableData': None,
#    'unit': 'Apt 2S',
#    'zestimate': 516000,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/377dee964e7fce171aee6189c1919656-p_e.jpg',
#    'price': 5200,
#    'detailUrl': '/homedetails/747-N-Sedgwick-St-APT-2S-Chicago-IL-60654/65565519_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.63836,
#    'latitude': 41.89624,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '65565519',
#    'listingSubType': {},
#    'rentZestimate': 4300,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1800,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2220 W Madison St UNIT C, Chicago, IL 60612',
#    'variableData': None,
#    'unit': 'Unit C',
#    'zestimate': 447800,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d8b88ffb4cabcc9fb4d0e3baefa496fe-p_e.jpg',
#    'price': 3500,
#    'detailUrl': '/homedetails/2220-W-Madison-St-UNIT-C-Chicago-IL-60612/113954335_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.68287,
#    'latitude': 41.881496,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '113954335',
#    'listingSubType': {},
#    'rentZestimate': 3099,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 2226,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2733 W Fullerton Ave, Chicago, IL 60647',
#    'variableData': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/cd27061a294882c0d15df0334b85f194-p_e.jpg',
#    'price': 2900,
#    'detailUrl': '/homedetails/2733-W-Fullerton-Ave-Chicago-IL-60647/2085646983_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.69632,
#    'latitude': 41.92451,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2085646983',
#    'listingSubType': {},
#    'rentZestimate': 3120,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 2000,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '4', 'price': '$5,495+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.919956--87.64153',
#    'longitude': -87.64153,
#    'buildingName': None,
#    'address': '2058 N Cleveland Ave, Chicago, IL',
#    'detailUrl': '/b/2056-n-cleveland-ave-chicago-il-DMKM/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 1218059,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/fc331b6a646f888f8ca02175bfcfb2a3-p_e.jpg',
#    'latitude': 41.919956},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$2,550+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.870323--87.66202',
#    'longitude': -87.66202,
#    'buildingName': '846 S Loomis',
#    'address': '846 S Loomis St, Chicago, IL',
#    'detailUrl': '/b/846-s-loomis-chicago-il-9Rx9m7/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2103818043,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4275c89e1936edf32e163a24130ce23f-p_e.jpg',
#    'latitude': 41.870323},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '7601 N Sheridan Rd APT 3S, Chicago, IL 60626',
#    'variableData': None,
#    'unit': 'Apt 3S',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/6c1c65baf826eecf696c057602610dad-p_e.jpg',
#    'price': 2125,
#    'detailUrl': '/homedetails/7601-N-Sheridan-Rd-APT-3S-Chicago-IL-60626/348262875_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.66563,
#    'latitude': 42.019382,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '348262875',
#    'listingSubType': {},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1600,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2631 W Chicago Ave APT 2, Chicago, IL 60622',
#    'variableData': None,
#    'unit': 'Apt 2',
#    'zestimate': 459300,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/9c2e098d780f2690b7299cbf66bf7d58-p_e.jpg',
#    'price': 2995,
#    'detailUrl': '/homedetails/2631-W-Chicago-Ave-APT-2-Chicago-IL-60622/87700309_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.69303,
#    'latitude': 41.8954,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '87700309',
#    'listingSubType': {},
#    'rentZestimate': 3099,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1700,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1910 W School St #2, Chicago, IL 60657',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/25321871ce645de7d1c31e87d2e43dca-p_e.jpg',
#    'price': 4995,
#    'detailUrl': '/homedetails/1910-W-School-St-2-Chicago-IL-60657/2076879674_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.6765,
#    'latitude': 41.94168,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2076879674',
#    'listingSubType': {},
#    'rentZestimate': 3750,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 2400,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$4,875+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.895344--87.650444',
#    'longitude': -87.650444,
#    'buildingName': 'Mondial River West',
#    'address': '910 W Huron St, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/mondial-river-west/5XjNQF/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 1001472497,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/cb8f21b15580a8ba7c5c03b4ebaf9633-p_e.jpg',
#    'latitude': 41.895344},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '5749 W Chicago, 5749 W Chicago Ave #5751-2E, Chicago, IL 60644',
#    'variableData': None,
#    'unit': '# 5751-2E',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ccbbe7094546d1a7bafca073fdb5ced6-p_e.jpg',
#    'price': 1525,
#    'detailUrl': '/b/5749-w-chicago-chicago-il-C2fQkg/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.76987,
#    'latitude': 41.894524,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2058148482',
#    'listingSubType': {},
#    'rentZestimate': 1770,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 991,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '5624 S. Wabash, 5606-24 S Wabash Ave #5622-113, Chicago, IL 60637',
#    'variableData': None,
#    'unit': '# 5622-113',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/0b06fe29a06cc284f31c0f76726e22c1-p_e.jpg',
#    'price': 1400,
#    'detailUrl': '/apartments/chicago-il/5624-s.-wabash/BfjdGT/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.624016,
#    'latitude': 41.792786,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '345978566',
#    'listingSubType': {},
#    'rentZestimate': 1569,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1080,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '5226 - 5228 S Michigan Ave, 5226 S Michigan Ave #5228, Chicago, IL 60615',
#    'variableData': None,
#    'unit': '# 5228',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ecb3d5e49e79c6793547f24402ef8159-p_e.jpg',
#    'price': 1895,
#    'detailUrl': '/b/5226-5228-s-michigan-ave-chicago-il-DnBK/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.623055,
#    'latitude': 41.799183,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '348251158',
#    'listingSubType': {},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2531 W Medill Ave #1, Chicago, IL 60647',
#    'variableData': None,
#    'unit': '# 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ce6a8f7d8d0d3c1c223df5e4ab76e723-p_e.jpg',
#    'price': 2595,
#    'detailUrl': '/homedetails/2531-W-Medill-Ave-1-Chicago-IL-60647/2110746365_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.69066,
#    'latitude': 41.923813,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2110746365',
#    'listingSubType': {},
#    'rentZestimate': 2485,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True}],
#  'resultsPerPage': 41,
#  'totalPages': 9,
#  'totalResultCount': 367,
#  'schools': {},
#  'currentPage': 1}

# %%
def extract_properties(response, n, fields):
    """
    Extracts and returns the top 'n' properties from a given API response
    based on the specified fields, appending the base URL to 'detailUrl'.
    
    Parameters:
    - response: The response object from an API call.
    - n: The number of top properties to extract.
    - fields: A list of strings representing the fields to extract from each property.
    
    Returns:
    - A list of dictionaries, each representing a property with only the specified fields.
    """
    base_url = "https://www.zillow.com"
    try:
        # Convert the response to JSON format if it's not already a dictionary
        if not isinstance(response, dict):
            response = response.json()

        # Extract the top 'n' properties based on the specified fields
        top_properties = []
        for prop in response['props'][:n]:
            extracted_prop = {field: (base_url + prop['detailUrl'] if field == 'detailUrl' else prop.get(field, None)) for field in fields}
            top_properties.append(extracted_prop)

        return top_properties

    except Exception as e:
        print("An error occurred:", e)
        return []  # Return an empty list in case of an error

# %%
# Define fields to extract
fields = ["propertyType", "address", "price", "bedrooms", "bathrooms", "detailUrl", "imgSrc"]

# %%
# Get top 3 properties with selected fields
top_properties = extract_properties(response, 3, fields)
top_properties
# Out:
# [{'propertyType': 'APARTMENT',
#   'address': '2238 W Warren Blvd #1, Chicago, IL 60612',
#   'price': 3995,
#   'bedrooms': 3,
#   'bathrooms': 2.5,
#   'detailUrl': 'https://www.zillow.com/homedetails/2238-W-Warren-Blvd-1-Chicago-IL-60612/2077513878_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/4b4c0860a673eabc37cb35ff26c4bf5e-p_e.jpg'},
#  {'propertyType': None,
#   'address': '914 W Hubbard St, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/b/914-w-hubbard-st-chicago-il-9S4pZT/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/ec34a5cef47e046b4f0c3828a958de05-p_e.jpg'},
#  {'propertyType': 'SINGLE_FAMILY',
#   'address': '1939 N Sayre Ave, Elmwood Park, IL 60707',
#   'price': 3115,
#   'bedrooms': 5,
#   'bathrooms': 3,
#   'detailUrl': 'https://www.zillow.com/homedetails/1939-N-Sayre-Ave-Elmwood-Park-IL-60707/2069907498_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/db67a5e2ee1b20527eb8622f1ca7b2a1-p_e.jpg'}]

# %% [markdown]
# ### For main use case

# %%
import json

# %%
user_query = "I am looking for a two-bedroom."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location":"chicago, il",
# "bedsMin":"2",
# "bedsMax":"2",
# "sort":"Newest"
# }

# %%
# get an api filter through Gemini
querystring = get_chat_response(chat, prompt)

# from str to dict
querystring = json.loads(querystring)

# get listings from zillow api
response = requests.get(url, headers = headers, params = querystring)

# %%
# Define fields to extract
fields = ["propertyType", "address", "price", "bedrooms", "bathrooms", "detailUrl", "imgSrc"]

# %%
# Get top 3 properties with selected fields
top_properties = extract_properties(response, 3, fields)
top_properties
# Out:
# [{'propertyType': 'CONDO',
#   'address': '1636 N Wells St APT 1701, Chicago, IL 60614',
#   'price': 415000,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/1636-N-Wells-St-APT-1701-Chicago-IL-60614/3742912_zpid/',
#   'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=41.91228103637695,-87.63545227050781&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=7MyonTamWEEQu5wP4FWCDoS6cXQ='},
#  {'propertyType': 'CONDO',
#   'address': '1132 W Farwell Ave APT 1S, Chicago, IL 60626',
#   'price': 345000,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/1132-W-Farwell-Ave-APT-1S-Chicago-IL-60626/70456818_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/f44840911f2d16fe2fc7ed04fd2a9fa7-p_e.jpg'},
#  {'propertyType': 'CONDO',
#   'address': '222 N Columbus Dr APT 409, Chicago, IL 60601',
#   'price': 365000,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/222-N-Columbus-Dr-APT-409-Chicago-IL-60601/80825413_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/3f5f52ff493120f7ad855a75ada130be-p_e.jpg'}]

# %% [markdown]
# ## 4. Generate advice with the property listings

# %%
def generate_prompt_property(instruction, user_query, property_info):
    updated_instruction = instruction.replace("{USER_QUERY}", user_query)
    updated_instruction = updated_instruction.replace("{PROPERTY_INFO}", property_info)
    return updated_instruction

# %%
instruction = """
### Instructions ###
I want you to act as a real estate advisor. Please recommend properties to the customer. 
'User’s query' represents the questions you are asked by the customer. 
'Real estate properties to present to the user' are the properties you will introduce to the customer.　Please include all the details provided, including links, in your response.

### User’s query ###
{USER_QUERY}

### Real estate properties to present to the user ###
{PROPERTY_INFO}

### Output ###
"""

# %%
def format_properties(properties, fields):
    formatted_properties = []
    for prop in properties:
        # Format and concatenate each field of each property
        formatted_prop = ', '.join(f"{field.capitalize().replace('_', ' ')}: {prop.get(field, 'N/A')}" for field in fields)
        formatted_properties.append(formatted_prop)
    return '\n\n'.join(formatted_properties)

# %%
# Change format
property_info = format_properties(top_properties, fields)
print(property_info)
# Out:
# Propertytype: CONDO, Address: 1636 N Wells St APT 1701, Chicago, IL 60614, Price: 415000, Bedrooms: 2, Bathrooms: 2, Detailurl: https://www.zillow.com/homedetails/1636-N-Wells-St-APT-1701-Chicago-IL-60614/3742912_zpid/, Imgsrc: https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=41.91228103637695,-87.63545227050781&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=7MyonTamWEEQu5wP4FWCDoS6cXQ=
#
# Propertytype: CONDO, Address: 1132 W Farwell Ave APT 1S, Chicago, IL 60626, Price: 345000, Bedrooms: 2, Bathrooms: 2, Detailurl: https://www.zillow.com/homedetails/1132-W-Farwell-Ave-APT-1S-Chicago-IL-60626/70456818_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/f44840911f2d16fe2fc7ed04fd2a9fa7-p_e.jpg
#
# Propertytype: CONDO, Address: 222 N Columbus Dr APT 409, Chicago, IL 60601, Price: 365000, Bedrooms: 2, Bathrooms: 2, Detailurl: https://www.zillow.com/homedetails/222-N-Columbus-Dr-APT-409-Chicago-IL-60601/80825413_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/3f5f52ff493120f7ad855a75ada130be-p_e.jpg

# %%
# generate prompt
prompt = generate_prompt_property(instruction, user_query, property_info)

# %%
print(prompt)
# Out:
# ### Instructions ###
# I want you to act as a real estate advisor. Please recommend properties to the customer.
# 'User’s query' represents the questions you are asked by the customer.
# 'Real estate properties to present to the user' are the properties you will introduce to the customer.　Please include all the details provided, including links, in your response.
#
# ### User’s query ###
# I am looking for a two-bedroom.
#
# ### Real estate properties to present to the user ###
# Propertytype: CONDO, Address: 1636 N Wells St APT 1701, Chicago, IL 60614, Price: 415000, Bedrooms: 2, Bathrooms: 2, Detailurl: https://www.zillow.com/homedetails/1636-N-Wells-St-APT-1701-Chicago-IL-60614/3742912_zpid/, Imgsrc: https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=41.91228103637695,-87.63545227050781&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=7MyonTamWEEQu5wP4FWCDoS6cXQ=
#
# Propertytype: CONDO, Address: 1132 W Farwell Ave APT 1S, Chicago, IL 60626, Price: 345000, Bedrooms: 2, Bathrooms: 2, Detailurl: https://www.zillow.com/homedetails/1132-W-Farwell-Ave-APT-1S-Chicago-IL-60626/70456818_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/f44840911f2d16fe2fc7ed04fd2a9fa7-p_e.jpg
#
# Propertytype: CONDO, Address: 222 N Columbus Dr APT 409, Chicago, IL 60601, Price: 365000, Bedrooms: 2, Bathrooms: 2, Detailurl: https://www.zillow.com/homedetails/222-N-Columbus-Dr-APT-409-Chicago-IL-60601/80825413_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/3f5f52ff493120f7ad855a75ada130be-p_e.jpg
#
# ### Output ###

# %%
# get final response from Gemini
print(get_chat_response(chat, prompt))
# Out:
# ## Two-Bedroom Condos in Chicago
#
# I understand you are looking for a two-bedroom condo. Here are three options that might be a good fit for you, based on your criteria:
#
# **1. 2 Bedroom Condo in Lincoln Park**
#
# * Address: 1636 N Wells St APT 1701, Chicago, IL 60614
# * Price: $415,000
# * Bedrooms: 2
# * Bathrooms: 2
# * Details: https://www.zillow.com/homedetails/1636-N-Wells-St-APT-1701-Chicago-IL-60614/3742912_zpid/
# * Image: https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=41.91228103637695,-87.63545227050781&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=7MyonTamWEEQu5wP4FWCDoS6cXQ=
#
# This spacious two-bedroom condo in Lincoln Park boasts two full bathrooms and a prime location near the lakefront. It features modern finishes, an open floor plan, and plenty of natural light.
#
# **2. 2 Bedroom Condo in Lakeview**
#
# * Address: 1132 W Farwell Ave APT 1S, Chicago, IL 60626
# * Price: $345,000
# * Bedrooms: 2
# * Bathrooms: 2
# * Details: https://www.zillow.com/homedetails/1132-W-Farwell-Ave-APT-1S-Chicago-IL-60626/70456818_zpid/
# * Image: https://photos.zillowstatic.com/fp/f44840911f2d16fe2fc7ed04fd2a9fa7-p_e.jpg
#
# This two-bedroom condo in Lakeview is perfect for those who want to be close to the action. It is located within walking distance of Wrigley Field and the Lakefront Trail. It features a private balcony, stainless steel appliances, and a spacious living area.
#
# **3. 2 Bedroom Condo in South Loop**
#
# * Address: 222 N Columbus Dr APT 409, Chicago, IL 60601
# * Price: $365,000
# * Bedrooms: 2
# * Bathrooms: 2
# * Details: https://www.zillow.com/homedetails/222-N-Columbus-Dr-APT-409-Chicago-IL-60601/80825413_zpid/
# * Image: https://photos.zillowstatic.com/fp/3f5f52ff493120f7ad855a75ada130be-p_e.jpg
#
# This two-bedroom condo in the South Loop offers stunning city views and is within walking distance to Grant Park and the Museum Campus. It features a modern kitchen, hardwood floors, and a building with amenities such as a fitness center and rooftop terrace.
#
# These are just a few examples of the many two-bedroom condos available in Chicago. I would be happy to help you narrow down your options and find the perfect place for you to call home.
#
# **Please let me know if you have any questions or would like to see more options.**

# %% [markdown]
# ## 5. Integrating all functions

# %%
## TBD
