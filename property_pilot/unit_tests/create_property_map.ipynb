# %% [markdown]
# # Mapping Properties
# ## Function: create_property_map

# %% [markdown]
# ## create_property_map

# %%
import folium

def create_property_map(properties):
    # Attribution for custom tileset
    attr = '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors'
    
    # Initialize the map centered around Chicago
    property_map = folium.Map(location=[41.881832, -87.623177], zoom_start=11, tiles='OpenStreetMap_Mapnik', attr=attr)

    # Loop through each property in the list
    for prop in properties:
        # Extract latitude and longitude
        latitude = prop['latitude']
        longitude = prop['longitude']
        detail_url = prop['detailUrl']
        address = prop['address']

        # Add a marker to the map
        folium.Marker(
            location=[latitude, longitude],
            popup=folium.Popup(f'<a href="{detail_url}" target="_blank">{address}</a>', max_width=250),
            tooltip="Click for Zillow Listing",
            icon=folium.Icon(icon = 'home', color="blue")
        ).add_to(property_map)

    # Return the map
    return property_map

# %% [markdown]
# ## Example Inputs

# %%
# Example top properties

top_properties = [{'propertyType': 'APARTMENT',
  'address': '2253 W Iowa St #3F, Chicago, IL 60622',
  'price': 2695,
  'bedrooms': 3,
  'bathrooms': 1,
  'detailUrl': 'https://www.zillow.com/homedetails/2253-W-Iowa-St-3F-Chicago-IL-60622/2069892388_zpid/',
  'imgSrc': 'https://photos.zillowstatic.com/fp/24cfac4e50b54ac036925874a4d4b395-p_e.jpg',
  'longitude': -87.68405,
  'latitude': 41.897385},
 {'propertyType': None,
  'address': '1210 S Indiana Ave, Chicago, IL',
  'price': None,
  'bedrooms': None,
  'bathrooms': None,
  'detailUrl': 'https://www.zillow.com/apartments/chicago-il/nema-chicago/9RwqTm/',
  'imgSrc': 'https://photos.zillowstatic.com/fp/35f6b1437825b0cf43201316158e8000-p_e.jpg',
  'longitude': -87.62358,
  'latitude': 41.86681},
 {'propertyType': 'APARTMENT',
  'address': '2065 N. Hoyne Ave., 2065 N Hoyne Ave #3R, Chicago, IL 60647',
  'price': 2295,
  'bedrooms': 3,
  'bathrooms': 2,
  'detailUrl': 'https://www.zillow.com/apartments/chicago-il/2065-n.-hoyne-ave./5XgKsR/',
  'imgSrc': 'https://photos.zillowstatic.com/fp/8094800d8257833f346cfb9030093cee-p_e.jpg',
  'longitude': -87.67988,
  'latitude': 41.91961}]

# %% [markdown]
# ## Example

# %%
# Create the map
property_map = create_property_map(top_properties)

display(property_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c36156cb625ba78e8790455d7861096a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c36156cb625ba78e8790455d7861096a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c36156cb625ba78e8790455d7861096a = L.map(
#                 &quot;map_c36156cb625ba78e8790455d7861096a&quot;,
#                 {
#                     center: [41.881832, -87.623177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6c95f6a0cf942b7b369bf4134e017d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a6c95f6a0cf942b7b369bf4134e017d1.addTo(map_c36156cb625ba78e8790455d7861096a);
#
#
#             var marker_1dd45cbf4b76dd4e5a436197dffaa0d2 = L.marker(
#                 [41.897385, -87.68405],
#                 {}
#             ).addTo(map_c36156cb625ba78e8790455d7861096a);
#
#
#             var icon_fa5022da8cf1b6692155718ca5f63326 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1dd45cbf4b76dd4e5a436197dffaa0d2.setIcon(icon_fa5022da8cf1b6692155718ca5f63326);
#
#
#         var popup_6f0a324bd991a67b34a9fd548c53c90c = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_47120ae1dd9e442ed25aacf31303bf90 = $(`&lt;div id=&quot;html_47120ae1dd9e442ed25aacf31303bf90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.zillow.com/homedetails/2253-W-Iowa-St-3F-Chicago-IL-60622/2069892388_zpid/&quot; target=&quot;_blank&quot;&gt;2253 W Iowa St #3F, Chicago, IL 60622&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_6f0a324bd991a67b34a9fd548c53c90c.setContent(html_47120ae1dd9e442ed25aacf31303bf90);
#
#
#
#         marker_1dd45cbf4b76dd4e5a436197dffaa0d2.bindPopup(popup_6f0a324bd991a67b34a9fd548c53c90c)
#         ;
#
#
#
#
#             marker_1dd45cbf4b76dd4e5a436197dffaa0d2.bindTooltip(
#                 `&lt;div&gt;
#                      Click for Zillow Listing
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6643ce48564b5772c20624535d34db8e = L.marker(
#                 [41.86681, -87.62358],
#                 {}
#             ).addTo(map_c36156cb625ba78e8790455d7861096a);
#
#
#             var icon_42551869b46e176fda81ae6bd206f986 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6643ce48564b5772c20624535d34db8e.setIcon(icon_42551869b46e176fda81ae6bd206f986);
#
#
#         var popup_5e33f4c61a45415eaeba51709bb54fd9 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_4e43ea0cdccc887e16a20e7af2c1126e = $(`&lt;div id=&quot;html_4e43ea0cdccc887e16a20e7af2c1126e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.zillow.com/apartments/chicago-il/nema-chicago/9RwqTm/&quot; target=&quot;_blank&quot;&gt;1210 S Indiana Ave, Chicago, IL&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_5e33f4c61a45415eaeba51709bb54fd9.setContent(html_4e43ea0cdccc887e16a20e7af2c1126e);
#
#
#
#         marker_6643ce48564b5772c20624535d34db8e.bindPopup(popup_5e33f4c61a45415eaeba51709bb54fd9)
#         ;
#
#
#
#
#             marker_6643ce48564b5772c20624535d34db8e.bindTooltip(
#                 `&lt;div&gt;
#                      Click for Zillow Listing
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_83efe1c9b1589aadadcfea83123a9656 = L.marker(
#                 [41.91961, -87.67988],
#                 {}
#             ).addTo(map_c36156cb625ba78e8790455d7861096a);
#
#
#             var icon_801350c7d93555c88a09e0867fac2e1c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_83efe1c9b1589aadadcfea83123a9656.setIcon(icon_801350c7d93555c88a09e0867fac2e1c);
#
#
#         var popup_83183dc5751353612fdaaf60175b6cab = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_cfea872c88ae0675959c1eb485b1003d = $(`&lt;div id=&quot;html_cfea872c88ae0675959c1eb485b1003d&quot; style=&quot;width: 100.0%; hei
