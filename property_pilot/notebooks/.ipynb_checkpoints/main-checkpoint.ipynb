# %% [markdown]
# ## GCP

# %%
# %pip list | grep google-cloud-aiplatform
# %pip list | grep google-api-core
# %pip install google-cloud-aiplatform==1.43.0
# %pip install google-api-core==2.17.1

# %%
import vertexai
from vertexai.preview.generative_models import GenerativeModel, ChatSession, Part
import vertexai.preview.generative_models as generative_models

import geopandas as gpd
from shapely.geometry import Point

import http.client
import json
import urllib.parse

# %%
vertexai.init(project = "adsp-capstone-property-pilot", location = "us-central1")

# %% [markdown]
# ## Model Setting - Gemini pro 1.0

# %%
model = GenerativeModel("gemini-1.0-pro")
chat = model.start_chat()

def get_chat_response(chat: ChatSession, prompt: str) -> str:
    text_response = []
    responses = chat.send_message(prompt, stream=True)
    for chunk in responses:
        text_response.append(chunk.text)
    return "".join(text_response)

# %%
# Test chat
prompt = "Hello."
print(get_chat_response(chat, prompt))
# Out:
# Hello! How can I assist you today?

# %% [markdown]
# ## Settings

# %%
import requests

url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

headers = {
	"X-RapidAPI-Key": "RAPID_API_KEY",
	"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

# %%
yelp_api_key = 'YELP_API_KEY'

# %% [markdown]
# ## Import functions

# %%
import os
# os.chdir('/home/jupyter/property_pilot/scripts')

# import generate_api_filter
# import fetch_property_info
# import chat_response
# import yelp_feature

# %%
# %run /home/jupyter/property_pilot/scripts/chat_response.py

# %%
# %run /home/jupyter/property_pilot/scripts/generate_api_filter.py

# %%
# %run /home/jupyter/property_pilot/scripts/fetch_property_info.py

# %%
# %run /home/jupyter/property_pilot/scripts/yelp_feature.py

# %% [markdown]
# ## Import prompts

# %%
os.chdir('/home/jupyter/property_pilot/prompts')

# prompt_classifier
file_path = 'instruction_classifier.txt'
try:
    with open(file_path, 'r') as file:
        instruction_prompt_classifier = file.read()
except FileNotFoundError:
    print("The file does not exist")
except Exception as e:
    print(f"An error occurred: {e}") 
    
# prompt_apifilter
file_path = 'generate_prompt_apifilter.txt'
try:
    with open(file_path, 'r') as file:
        instruction_prompt_apifilter = file.read()
except FileNotFoundError:
    print("The file does not exist")
except Exception as e:
    print(f"An error occurred: {e}")
    
# yelp_categories
file_path = 'yelp_categories.txt'
try:
    with open(file_path, 'r') as file:
        yelp_categories = file.read().splitlines()
except FileNotFoundError:
    print("The file does not exist")
except Exception as e:
    print(f"An error occurred: {e}")
    
# prompt_property(for final output)
file_path = 'generate_prompt_property.txt'
try:
    with open(file_path, 'r') as file:
        instruction_prompt_property = file.read()
except FileNotFoundError:
    print("The file does not exist")
except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# ## Property Plot main function

# %%
def pp_chatbot(user_query):
    
    # User's quety classify
    prompt_classifier = generate_prompt_classifier(instruction_prompt_classifier, user_query)
    response_int = int(get_chat_response(chat, prompt_classifier))
    
    # if the user is looking for a property     
    if response_int == 1:

        # get prompt for api filter 
        prompt_apifilter = generate_prompt_apifilter(instruction_prompt_apifilter, user_query)

        # get api filter
        apifilter = get_chat_response(chat, prompt_apifilter)
        apifilter = extract_json_to_dict(apifilter)

        # get listings from zillow
        response = requests.get(url, headers = headers, params = apifilter)

        # get top 3 listings(sorted by newest)
        # Define fields to extract
        fields = ["propertyType", "address", "price", "bedrooms", "bathrooms", "detailUrl", "imgSrc", "longitude", "latitude"]
        top_properties = extract_properties(response, 3, fields)

        # get description of the properties
        top_properties = fetch_descriptions(top_properties)

        # get resoFacts(detail) of the properties
        keys_to_fetch_resoFacts = [
            'hasGarage', 'hasPetsAllowed', 'heating', 'cooling', 'flooring', 'appliances',
            'laundryFeatures', 'associationFee',
            'livingArea', 'taxAnnualAmount', 'parkingFeatures', 'stories'
        ]
        top_properties = fetch_resoFacts(top_properties, headers, keys_to_fetch_resoFacts)

        # get school info of the properties
        top_properties = fetch_schools(top_properties, headers)
        
        # get restaurant info from yelp api
        yelp_results = fetch_top_businesses_near_properties(yelp_api_key, top_properties, user_query, yelp_categories, chat)
        
        # extract restaurant info
        yelp_fields = ['business_name', 'categories_titles', 'rating', 'latitude', 'longitude', 'display_address', 'url']
        top_restaurants = extract_business_info(yelp_results, 2, yelp_fields)
        
        # merge top_restaurants with top_properties
        top_properties = merge_property_and_restaurant_info(top_properties, top_restaurants)

        # neighborhood boundaries shapefile
        neighborhood_boundaries_path = '/home/jupyter/Kshitiz_Working/geo_export_825d7df4-a9cd-4cef-b3d7-2ec1adc30204.shp'
        # neighborhood description file
        neighborhood_info_path = '/home/jupyter/Kshitiz_Working/neighborhood_info_final.csv'

        # load the neighborhood boundaries and description file
        neighborhoods = load_neighborhood_boundaries(neighborhood_boundaries_path)
        neighborhoods_info = load_neighborhood_info(neighborhood_info_path)

        # get neighborhood details of the properties
        top_properties = fetch_neighborhood(top_properties, neighborhoods)
        top_properties = fetch_neighborhood_info(top_properties, neighborhoods_info)

        # create property map
        property_map = create_property_map(top_properties)
        
        # create property_restaurant map
        property_restaurant_map = create_property_restaurant_map(top_properties)

        # change format
        fields_desc = fields + ['description', 'resoFacts', 'schools', 'neighborhood', 'neighborhood_description', 'restaurant_1', 'restaurant_2']
        property_info = format_properties(top_properties, fields_desc)

        # prompt for final output from Gemini
        prompt_final = generate_prompt_property(instruction_prompt_property, user_query, property_info, str(fields))

        # get final response from Gemini
        print(get_chat_response(chat, prompt_final))
        display(property_restaurant_map)

        return top_properties

    elif response_int == 2:
        print('The query is about restaurant. I will answer by using Yelp API Filter')
        
    elif response_int == 3:
        print('The query is about neighborhood. I will answer by using RAG')

    else:
        print(get_chat_response(chat, user_query))

# %% [markdown]
# ## Use case 1
# ### property search - detail info

# %%
# For initial query, use pp_chatbot, not get_chat_response
user_query = "I am looking for a two-bedroom apartment in Chicago."
top_properties = pp_chatbot(user_query)
# Out:
# ## Great News! I found two amazing two-bedroom apartments that might be perfect for you in Chicago:
#
# **Option 1: Spacious Loft in the Heart of West Loop**
#
# **Address:** 728 W Jackson Blvd APT 703, Chicago, IL 60661
#
# **Price:** $434,900
#
# **Bedrooms:** 2
#
# **Bathrooms:** 2
#
# **Link:** https://www.zillow.com/homedetails/728-W-Jackson-Blvd-APT-703-Chicago-IL-60661/49911377_zpid/
#
# **Photos:** https://photos.zillowstatic.com/fp/1c80f961355d0953177c208a73b212e5-p_e.jpg
#
# **Details:**
#
# * Large, two-story condo with 1450 sq ft of living space
# * 12ft concrete ceilings and original hardwood floors
# * Open floor plan with kitchen and dining area ideal for entertaining
# * Master bedroom with walk-in closet and ensuite bathroom
# * Private balcony and shared building terrace with breathtaking city views
# * Modern appliances and HVAC system
# * Prime indoor parking included
# * Walk Score: 99, Transit Score: 92, Bike Score: 88
# * Close to public transportation, restaurants, shops, and parks
# * Amenities include 24-hour door staff, gym, in-unit laundry, and more
#
# **Resofacts:**
#
# * Has Garage: True
# * Pets Allowed: True
# * Heating: Natural Gas
# * Cooling: Central Air
# * Flooring: Hardwood
# * Appliances: Range, Microwave, Dishwasher, Refrigerator, Washer, Dryer, Disposal
# * Laundry Features: In Unit
# * Association Fee: $897 monthly
# * Living Area: 1,450 sqft
# * Parking Features: Garage - Attached
#
# **Schools:**
#
# * Skinner Elementary School (9/10) - 0.8 miles
# * Wells Community Academy High School (1/10) - 1.9 miles
#
# **Option 2: East-Facing Condo in Gold Coast**
#
# **Address:** 1325 N State Pkwy APT 18E, Chicago, IL 60610
#
# **Price:** $649,000
#
# **Bedrooms:** 2
#
# **Bathrooms:** 2
#
# **Link:** https://www.zillow.com/homedetails/1325-N-State-Pkwy-APT-18E-Chicago-IL-60610/3844226_zpid/
#
# **Photos:** https://photos.zillowstatic.com/fp/2e3b9acd7514c150aebf5e7c9d0953-p_e.jpg
#
# **Details:**
#
# * Beautiful 2-bedroom corner unit in Gold Coast's Ambassador House
# * 1600+ sq ft with elegant oak hardwood throughout
# * East-facing with ample natural light and city views
# * Scavolini cabinetry, Vicostone quartz countertops, breakfast bar
# * Large living room with additional storage and designer cabinetry
# * Separate dining area with full wall of cabinets/wet bar and wine fridge
# * King-sized bedrooms, primary with walk-in closet and custom blinds
# * Luxurious ensuite primary bath with heated floors, tiled shower, and modern cabinetry
# * Second bedroom is spacious with plenty of built-in closets
# * Renovated second bath with air tub and heated floors
# * New in-unit washer and dryer, heated garage parking available
# * Full-service building with rooftop deck and pool, common grills, doorstaff, building engineer, and manager
# * Fantastic location near restaurants, shops, transportation, farmers market, and lakefront
#
# **Resofacts:**
#
# * Has Garage: True
# * Heating: Natural Gas, Forced Air
# * Cooling: Central Air
# * Appliances: Range, Microwave, Dishwasher, Refrigerator, Freezer, Washer, Dryer
# * Laundry Features: In Unit
# * Association Fee: $1,547 monthly
# * Living Area: 1,650 sqft
# * Parking Features: Garage - Attached
#
# **Schools:**
#
# * Ogden Elementary School (5/10) - 0.4 miles
# * Lincoln Park High School (9/10) - 1.2 miles
#
# **Additional Information:**
#
# * Please note that these are just two options and there are many other great apartments available in Chicago.
# * I encourage you to look at all of your options and choose the one that best suits your needs.
# * If you have any questions about these specific apartments or other properties, please don't hesitate to ask!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61528cb10f04a230ab33330567192896 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61528cb10f04a230ab33330567192896&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61528cb10f04a230ab33330567192896 = L.map(
#                 &quot;map_61528cb10f04a230ab33330567192896&quot;,
#                 {
#                     center: [41.881832, -87.623177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3eb8b3ca683f3faa1210c34653834af3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3eb8b3ca683f3faa1210c34653834af3.addTo(map_61528cb10f04a230ab33330567192896);
#
#
#             var marker_273bb5e2267672da24f623c39309789f = L.marker(
#                 [41.87842, -87.64483],
#                 {}
#             ).addTo(map_61528cb10f04a230ab33330567192896);
#
#
#             var icon_e83a6bc5c9464dad600fc87302b49547 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_273bb5e2267672da24f623c39309789f.setIcon(icon_e83a6bc5c9464dad600fc87302b49547);
#
#
#         var popup_5c7667d1c6cbf75636c2fcdb0cee6338 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_8d5c70bc3fa9539e6daf07b221fa9631 = $(`&lt;div id=&quot;html_8d5c70bc3fa9539e6daf07b221fa9631&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.zillow.com/homedetails/728-W-Jackson-Blvd-APT-703-Chicago-IL-60661/49911377_zpid/&quot; target=&quot;_blank&quot;&gt;728 W Jackson Blvd APT 703, Chicago, IL 60661&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_5c7667d1c6cbf75636c2fcdb0cee6338.setContent(html_8d5c70bc3fa9539e6daf07b221fa9631);
#
#
#
#         marker_273bb5e2267672da24f623c39309789f.bindPopup(popup_5c7667d1c6cbf75636c2fcdb0cee6338)
#         ;
#
#
#
#
#             marker_273bb5e2267672da24f623c39309789f.bindTooltip(
#                 `&lt;div&gt;
#                      Click for property details
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_22e2a67fc3eef91f91c3a14d4af733b4 = L.marker(
#                 [41.895179, -87.6343],
#                 {}
#             ).addTo(map_61528cb10f04a230ab33330567192896);
#
#
#             var icon_f2956c9fa968f8fd10e05337ed6b1002 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_22e2a67fc3eef91f91c3a14d4af733b4.setIcon(icon_f2956c9fa968f8fd10e05337ed6b1002);
#
#
#         var popup_052bfb3a4f0b991ac6c215613c7cf0a6 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_45ec443ff161a5ce73ece9c67c564f02 = $(`&lt;div id=&quot;html_45ec443ff161a5ce73ece9c67c564f02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.yelp.com/biz/sushi-by-bou-river-north-chicago-2?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&amp;utm_campaign=yelp_api_v3&amp;utm_medium=api_v3_business_search&amp;utm_source=6Rl6qXMI6EN3VkijeNTf0A&quot; target=&quot;_blank&quot;&gt;Sushi By Bou - River North&lt;/a&gt;&lt;br/&gt;Sushi Bars, Japanese, Speakeasies&lt;br/&gt;Rating: 5.0&lt;/div&gt;`)[0];
#                 popup_052bfb3a4f0b991ac6c215613c7cf0a6.setContent(html_45ec443ff161a5ce73ece9c67c564f02);
#
#
#
#         marker_22e2a67fc3eef91f91c3a14d4af733b4.bindPopup(popup_052bfb3a4f0b991ac6c215613c7cf0a6)
#         ;
#
#
#
#
#             marker_22e2a67fc3eef91f91c3a14d4af733b4.bindTooltip(
#                 `&lt;div&gt;
#                      Click for details on Sushi By Bou - River North
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6ead003f17afd489dacabb81ff661b11 = L.marker(
#                 [41.8891862295013, -87.6492763290888],
#                 {}
#             ).addTo(map_61528cb10f04a230ab33330567192896);
#
#
#             var icon_cc3e174dc4104e6ed5b1f3eddcf3531e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6ead003f17afd489dacabb81ff661b11.setIcon(icon_cc3e174dc4104e6ed5b1f3eddcf3531e);
#
#
#         va

# %%
# For additional question, use get_chat_response, not pp_chatbot
user_query = "Could you tell me about the first property in detail?"
print(get_chat_response(chat, user_query))
# Out:
# ## Amazing 2-Bedroom Loft in the Heart of West Loop
#
# **Address:** 728 W Jackson Blvd APT 703, Chicago, IL 60661
#
# **Price:** $434,900
#
# **Bedrooms:** 2
#
# **Bathrooms:** 2
#
# **Link:** https://www.zillow.com/homedetails/728-W-Jackson-Blvd-APT-703-Chicago-IL-60661/49911377_zpid/
#
# **Photos:** https://photos.zillowstatic.com/fp/1c80f961355d0953177c208a73b212e5-p_e.jpg
#
# **Highlights:**
#
# * **Spacious loft:** This two-story condo boasts 1450 sq ft of living space, offering plenty of room to relax and entertain.
# * **High ceilings and hardwood floors:** The 12ft concrete ceilings and original hardwood floors throughout create a modern and airy atmosphere.
# * **Open floor plan:** The kitchen and dining area seamlessly flow into the living room, making it an ideal space for hosting gatherings.
# * **Large master suite:** The master bedroom features a spacious walk-in closet and ensuite bathroom with a soaking tub, perfect for relaxation.
# * **Private outdoor space:** Enjoy fresh air and sunshine on your private balcony or the shared building terrace offering stunning city views.
# * **Modern updates:** The property includes new appliances and an HVAC system for added convenience and energy efficiency.
# * **Indoor parking:** Secured indoor parking is available for a separate fee.
# * **Prime location:** Situated in the heart of West Loop, you'll have access to numerous restaurants, shops, and entertainment options.
# * **Easy transportation access:** The property boasts a Walk Score of 99, Transit Score of 92, and Bike Score of 88, making it ideal for commuters and those who prefer car-free living.
#
# **Additional Features:**
#
# * In-unit laundry
# * Full amenity building with 24-hour door staff, exercise room, hospitality room, outdoor grilling area, bike room, basketball court, and more
# * Close proximity to public transportation, parks, and green spaces
#
# **Resofacts:**
#
# * Has Garage: True
# * Pets Allowed: True
# * Heating: Natural Gas
# * Cooling: Central Air
# * Flooring: Hardwood
# * Appliances: Range, Microwave, Dishwasher, Refrigerator, Washer, Dryer, Disposal
# * Laundry Features: In Unit
# * Association Fee: $897 monthly
# * Living Area: 1,450 sqft
# * Parking Features: Garage - Attached
#
# **Schools:**
#
# * Skinner Elementary School (9/10) - 0.8 miles
# * Wells Community Academy High School (1/10) - 1.9 miles
#
# **Additional Notes:**
#
# * There are architectural drawings available for a full gut rehab of the unit if you'd like to customize the space to your liking.
# * Schedule a tour today to experience this exceptional urban oasis!
#
# I hope this detailed information provides a better understanding of the first property. If you have any further questions or would like to discuss other options, please don't hesitate to ask.

# %%
user_query = "Which neighborhood is the first property located in? Tell me more about that neighborhood."
print(get_chat_response(chat, user_query))
# Out:
# ## West Loop: A Vibrant Chicago Neighborhood
#
# The first property you asked about is located in the heart of West Loop, considered one of Chicago's most exciting and dynamic neighborhoods.
#
# **A Historic Transformation:**
#
# Once a bustling meatpacking district, West Loop has undergone a remarkable transformation in recent years. Industrial warehouses and factories have been converted into trendy restaurants, bars, and art galleries, attracting a young and energetic crowd. Today, the neighborhood offers a unique blend of industrial chic and modern sophistication.
#
# **Culinary Delights:**
#
# West Loop is renowned for its world-class dining scene. Many acclaimed restaurants call this neighborhood home, including Girl & the Goat by Stephanie Izard, Au Cheval (known for their legendary burgers), Monteverde (celebrated for its handmade pasta), and Green Street Smoked Meats (a haven for barbecue enthusiasts). With a diverse range of cuisines and innovative culinary experiences, West Loop is a haven for food lovers.
#
# **Arts and Culture:**
#
# West Loop isn't just about food; it embraces creativity in all its forms. Numerous art galleries exhibit works by local and international artists, while unique boutiques offer hand-crafted products and designer finds. The Second City, a legendary comedy club, is also located here, ensuring plenty of laughter and entertainment.
#
# **Accessibility and Convenience:**
#
# Getting around West Loop is a breeze. You'll find excellent access to public transportation, including the CTA Blue Line and Metra lines, providing an easy connection to other parts of the city. Additionally, the neighborhood boasts a high Walk Score and Bike Score, making it ideal for those who enjoy exploring on foot or on two wheels.
#
# **Urban Green Spaces:**
#
# Despite its urban setting, West Loop offers green havens for relaxation and recreation. Mary Bartelme Park provides a serene atmosphere with its walking paths and dog park, while Skinner West Park features a playground and fitness equipment. The proximity to the Chicago Riverwalk allows for scenic walks and enjoying the city's natural beauty.
#
# **Community Vibes:**
#
# West Loop is a vibrant community with a sense of identity and belonging. Residents enjoy frequent farmers markets, street festivals, and special events, fostering a strong sense of unity and neighborhood spirit. With its friendly atmosphere and welcoming locals, West Loop offers a warm and inclusive vibe.
#
# **In conclusion, West Loop is a perfect blend of urban amenities, cultural attractions, and community spirit. Its dynamic atmosphere, diverse offerings, and convenient location make it a highly desirable place to live for those seeking a modern and exciting lifestyle.**
#
# If you have any further questions about West Loop or would like recommendations for specific things to do in the area, please don't hesitate to ask.

# %%
user_query = "What are some good schools nearby the first property?"
print(get_chat_response(chat, user_query))
# Out:
# ## Excellent Schools Surrounding the First Property in West Loop
#
# Choosing the right neighborhood for your family often involves considering the available educational options. Fortunately, the West Loop neighborhood, where the first property is located, boasts several highly-rated public and private schools. Here are some excellent options nearby:
#
# **Public Schools:**
#
# * **Skinner Elementary School (Pre-K-8th grade):** Located only 0.8 miles away from the property, Skinner Elementary consistently receives high ratings and boasts a strong academic focus. The school is known for its dedicated teachers, innovative learning approaches, and diverse student body.
# * **Wells Community Academy High School (9th-12th grade):** Located around 1.9 miles away, Wells Community Academy is a public high school offering a rigorous college-preparatory curriculum. The school emphasizes personalized learning and career-focused programs, preparing students for success in higher education and future careers.
#
# **Private Schools:**
#
# * **The Latin School of Chicago (Pre-K-12th grade):** This highly-regarded private school emphasizes intellectual rigor, ethical leadership, and global citizenship. Located about 1.5 miles from the property, it offers a challenging academic environment and fosters a strong sense of community among its students.
# * **St. Ignatius College Prep (9th-12th grade):** Another excellent private school option, St. Ignatius College Prep is a Jesuit institution with a strong tradition of academic excellence and service to others. Situated approximately 2 miles from the first property, it provides a rigorous college preparatory program and emphasizes faith formation and social justice.
# * **Chicago French School (Pre-K-8th grade):** For families seeking a unique cultural and linguistic immersion experience, the Chicago French School might be the perfect fit. This bilingual school, located about 1.6 miles away, offers instruction in both French and English, fostering fluency and intercultural understanding.
#
# **Additional Resources:**
#
# * **GreatSchools:** https://www.greatschools.org/illinois/chicago/ This comprehensive website provides detailed information on schools throughout the Chicago area, including test scores, parent reviews, and student-teacher ratios.
# * **Chicago Public Schools:** https://www.cps.edu/ The official website of the Chicago Public School system offers information on enrollment, school programs, and transportation options.
#
# **Choosing the Right School:**
#
# Ultimately, the best school for your child depends on their individual needs, academic strengths, and learning style. It's advisable to visit the schools, speak with teachers and administrators, and consider factors like class size, extracurricular activities, and overall school culture.
#
# **I hope this information helps you make an informed decision about the educational landscape surrounding the first property.** Feel free to ask if you have any further questions or need additional details about specific schools.

# %%
user_query = "I am interested in the first property. Should I buy it or rent it ?"
print(get_chat_response(chat, user_query))
# Out:
# ## Making the Right Decision: Buying vs. Renting the First Property
#
# The decision to buy or rent the first property depends on your individual circumstances, financial goals, and long-term plans. Here's a comparison to help you weigh the pros and cons:
#
# **Buying:**
#
# **Pros:**
#
# * **Equity building:** As you pay down your mortgage, you build equity in the property, which can be a significant financial asset.
# * **Potential for appreciation:** Property values can increase over time, leading to a potential increase in your investment value.
# * **Customization:** owning the property allows you to make changes and personalize the space to your liking.
# * **Tax benefits:** Homeownership comes with tax benefits, such as deductions for mortgage interest and property taxes.
#
# **Cons:**
#
# * **Down payment:** Purchasing a property requires a significant down payment, which can be a financial hurdle for some.
# * **Financial responsibility:** Homeownership comes with ongoing costs, including mortgage payments, property taxes, insurance, and maintenance.
# * **Less flexibility:** Buying a property requires a longer-term commitment and may limit your flexibility to move if needed.
#
# **Renting:**
#
# **Pros:**
#
# * **Lower upfront costs:** Renting does not require a large down payment, making it more accessible for those with limited funds.
# * **Flexibility:** Renting offers more flexibility, allowing you to move more easily if your circumstances change.
# * **Less responsibility:** Landlords are responsible for major repairs and maintenance, reducing your financial burden.
# * **Predictable monthly costs:** Rent payments are typically fixed, making it easier to budget your expenses.
#
# **Cons:**
#
# * **No equity building:** Rent payments do not build equity, so you are not investing in an asset.
# * **Rent increases:** Landlords can increase rent over time, leading to unpredictable expenses.
# * **Limited customization:** You may have limited ability to personalize the rental space.
#
# **Factors to Consider:**
#
# * **Financial situation:** Can you afford the down payment and ongoing costs of ownership?
# * **Long-term plans:** Do you plan to stay in the area for several years?
# * **Lifestyle:** Do you value flexibility or stability?
# * **Investment goals:** Are you looking to build long-term wealth through real estate?
#
# **Recommendation:**
#
# Given your interest in the first property, I recommend considering the following:
#
# * **Financial analysis:** Calculate the potential costs of buying and renting the property, including down payment, mortgage payments, property taxes, insurance, maintenance, and potential rent increases.
# * **Long-term goals:** Determine if you plan to stay in the area for several years and if homeownership aligns with your long-term financial goals.
# * **Market conditions:** Research the current real estate market in West Loop and determine if buying or renting is a better investment option.
#
# Based on your individual circumstances and the factors mentioned above, you can make an informed decision about whether buying or renting the first property is the right choice for you.
#
# **Additional Resources:**
#
# * **Mortgage calculators:** https://www.nerdwallet.com/mortgages/mortgage-calculators
# * **Real estate market trends:** https://www.zillow.com/research/
# * **Financial advisors:** Consult with a financial advisor to discuss your options and create a personalized plan.
#
# I hope this comprehensive analysis helps you make the best decision for your future. If you have any further questions or need additional information, please don't hesitate to ask.

# %%
user_query = "What restaurants are nearby the first property? Please provide me with the yelp link"
print(get_chat_response(chat, user_query))
# Out:
# ## Delectable Dining Options Near the First Property in West Loop
#
# West Loop is a haven for food lovers, offering a diverse range of restaurants within walking distance of the first property. Here are some of the top-rated options with their corresponding Yelp links:
#
# **Fine Dining:**
#
# * **Monteverde:** https://www.yelp.com/biz/monteverde-chicago
# * **Au Cheval:** https://www.yelp.com/biz/au-cheval-chicago
# * **Girl & the Goat:** https://www.yelp.com/biz/girl-and-the-goat-chicago
# * **Green Street Smoked Meats:** https://www.yelp.com/biz/green-street-smoked-meats-chicago
#
# **Casual Eats:**
#
# * **Roister:** https://www.yelp.com/biz/roister-chicago
# * **The Loyalist:** https://www.yelp.com/biz/the-loyalist-chicago
# * **Little Goat Diner:** https://www.yelp.com/biz/little-goat-diner-chicago
# * **Beatrix:** https://www.yelp.com/biz/beatrix-chicago
#
# **International Flavors:**
#
# * **Parachute:** https://www.yelp.com/biz/parachute-chicago
# * **Aba:** https://www.yelp.com/biz/aba-chicago
# * **Monteverde Take-Away:** https://www.yelp.com/biz/monteverde-take-away-chicago
# * **Duck Duck Goat:** https://www.yelp.com/biz/duck-duck-goat-chicago
#
# **Late Night Bites:**
#
# * **Big Star:** https://www.yelp.com/biz/big-star-chicago
# * **West Town Bakery:** https://www.yelp.com/biz/west-town-bakery-chicago
# * **Three Aces:** https://www.yelp.com/biz/three-aces-chicago
#
# **Additional Resources:**
#
# * **Chicago Eater West Loop:** https://chicago.eater.com/maps/best-west-loop-restaurants-chicago
# * **Thrillist Best West Loop Restaurants:** https://www.thrillist.com/eat/chicago/best-west-loop-restaurants
#
# Feel free to explore these links and discover the culinary gems that await you in West Loop. Whether you're craving a gourmet meal or a casual bite, you're sure to find something to tantalize your taste buds. Enjoy your culinary adventures!

# %%
top_properties
# Out:
# [{'propertyType': 'CONDO',
#   'address': '728 W Jackson Blvd APT 703, Chicago, IL 60661',
#   'price': 434900,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/728-W-Jackson-Blvd-APT-703-Chicago-IL-60661/49911377_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/1c80f961355d0953177c208a73b212e5-p_e.jpg',
#   'longitude': -87.64483,
#   'latitude': 41.87842,
#   'description': "Discover the allure of this spacious 2-bedroom, 2-bath concrete loft at Haberdasher Square in the vibrant West Loop Gate community! Boasting an expansive 1450 SQFT of living space, this loft offers room for a full-size dining table, perfect for entertaining or enjoying cozy family dinners. With 12 ft concrete ceilings and original hardwood floors throughout, this home exudes character and charm.  Closets galore provide ample storage space for your belongings, ensuring the opportunity for a clutter-free living environment. The large kitchen, complete with an island, seamlessly opens to the living room, creating a welcoming atmosphere for cooking and entertaining. Floor-to-ceiling windows flood the space with natural light, offering breathtaking views of the skyline and allowing for a sunny, cheerful ambiance.  Retreat to the master bedroom, featuring a huge walk-in closet and a step-up bath with a soaking tub, providing the perfect sanctuary for relaxation and rejuvenation. Step outside to your private balcony or enjoy fresh air and sunshine on the shared building terrace and sun deck, where panoramic views of the city skyline await.  Recent upgrades include all new appliances and an HVAC system that are less than a year old, ensuring modern efficiency and peace of mind. For those with a vision, the owner has architectural drawings for a gut rehab of the unit, available to interested buyers.  Convenience is key with a prime indoor parking option - a tandem spot available for an additional $45k, ensuring hassle-free parking in the heart of the city. With a remarkable 99% Walk Score, 92% Transit Score, and 88% Bike Score, this location is a commuter's dream! Walk just 0.3 miles to reach the Blue Line & BNSF Northern Stop, providing easy access to public transportation. Enjoy seamless access to the L Train system, Chicago Union, and Metra stations.  West Loop Gate is renowned for its bustling nightlife, eclectic dining options, and rich cultural scene. You're mere minutes away from a plethora of dining options, grocery stores, coffee shops, and retail stores, all within a 5-minute stroll from your doorstep. For outdoor enthusiasts, both humans and furry friends alike, nearby parks such as Trio Apartments, West Wayman Street, D'Angelo Dog Park, Southbank Riverwalk, Fulton River Park, Mary Bartelme Park, Heritage Green Park, and Printers Row Park offer green spaces and recreational amenities for residents to enjoy.  Enjoy the perks of full amenity living with 24-hour door staff, an exercise room, in-unit laundry, a hospitality room, outdoor grilling area, bike room, basketball court, and more! This property is not just a home; it's a lifestyle.  Don't miss out on this rare opportunity to experience the best of city living. Schedule your tour today and make this urban oasis your new home sweet home!",
#   'resoFacts': {'hasGarage': True,
#    'hasPetsAllowed': True,
#    'heating': ['Natural Gas'],
#    'cooling': ['Central Air'],
#    'flooring': ['Hardwood'],
#    'appliances': ['Range',
#     'Microwave',
#     'Dishwasher',
#     'Refrigerator',
#     'Washer',
#     'Dryer',
#     'Disposal'],
#    'laundryFeatures': ['In Unit', 'Laundry Hook-Up in Unit'],
#    'associationFee': '$897 monthly',
#    'livingArea': '1,450 sqft',
#    'taxAnnualAmount': 8220,
#    'parkingFeatures': ['Garage - Attached'],
#    'stories': None},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1350-Skinner-Elementary-School/',
#     'rating': 9,
#     'totalCount': None,
#     'distance': 0.8,
#     'assigned': None,
#     'name': 'Skinner Elementary School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1425-Wells-Community-Academy-High-School/',
#     'rating': 1,
#     'totalCount': None,
#     'distance': 1.9,
#     'assigned': None,
#     'name': 'Wells Community Academy High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'High',
#     'grades': '9-12',
#     'type': 'Public'}],
#   'restaurant_1': {'business_name': 'Sushi By Bou - River North',
#    'categories_titles': ['Sushi Bars', 'Japanese', 'Speakeasies'],
#    'rating': 5.0,
#    'latitude': 41.895179,
#    'longitude': -87.6343,
#    'display_address': '712 N Wells St Chicago, IL 60654',
#    'url': 'https://www.yelp.com/biz/sushi-by-bou-river-north-chicago-2?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'restaurant_2': {'business_name': 'Bob’s Pizza',
#    'categories_titles': ['Pizza'],
#    'rating': 5.0,
#    'latitude': 41.8891862295013,
#    'longitude': -87.6492763290888,
#    'display_address': '838 W Kinzie St Chicago, IL 60642',
#    'url': 'https://www.yelp.com/biz/bob-s-pizza-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'neighborhood': 'West Loop',
#   'neighborhood_description': 'Neighborhood description is not found.'},
#  {'propertyType': 'CONDO',
#   'address': '1325 N State Pkwy APT 18E, Chicago, IL 60610',
#   'price': 649000,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/1325-N-State-Pkwy-APT-18E-Chicago-IL-60610/3844226_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/2e3b9acd7514c150aebf5e7c9d09b538-p_e.jpg',
#   'longitude': -87.628365,
#   'latitude': 41.906437,
#   'description': "Welcome to your luxurious East-facing 2 bed, 2 bath corner retreat in the highly sought out Ambassador House in the heart of the Gold Coast. This stunning unit boasts 1600+ sq feet of meticulously designed living space and rich oak hardwood throughout, offering both elegance and functionality at every turn. You are greeted by an inviting foyer that sets the tone for the rest of the home and then opens to the gorgeous kitchen, featuring Scavolini cabinetry, Vicostone quartz countertops, pantry and a breakfast bar, perfect for casual dining or entertaining guests. Grand living room is bathed in natural light streaming through the expansive windows with motorized blinds and includes additional contemporary cabinetry providing storage with a sophisticated element of design. Adjacent is a separate dining space, complete with a full wall of added cabinetry/dry bar with a wine fridge that adds convenience and style to this culinary haven. Both bedrooms are king-sized, with the primary boasting a wall of built-in cabinetry, a desk, custom motorized blinds, and a designer walk-in closet. En-suite primary bath is a spa-like oasis, featuring heated floors, a tiled shower, and modern cabinetry. Second bedroom is extra-large and offers a wall of built-out closets. Fully renovated 2nd bath is equally impressive, complete with an air tub, heated floors, and contemporary finishes. New in-unit washer and dryer + utility sink. Heated garage parking available. This full-service and amenity building features breathtaking skyline views from a recently updated rooftop deck and swimming pool with common grills, a receiving room, 24-hour doorstaff, full-time building engineer and on-site manager. Perfect location nestled in the heart of Gold Coast providing easy living just steps from wonderful restaurants, great shopping, transportation, farmer's market and Chicago's lakefront!",
#   'resoFacts': {'hasGarage': True,
#    'hasPetsAllowed': None,
#    'heating': ['Natural Gas', 'Forced Air'],
#    'cooling': ['Central Air'],
#    'flooring': None,
#    'appliances': ['Range',
#     'Microwave',
#     'Dishwasher',
#     'Refrigerator',
#     'Freezer',
#     'Washer',
#     'Dryer'],
#    'laundryFeatures': None,
#    'associationFee': '$1,547 monthly',
#    'livingArea': '1,650 sqft',
#    'taxAnnualAmount': 12266,
#    'parkingFeatures': ['Garage - Attached'],
#    'stories': None},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1270-Ogden-Elementary-School/',
#     'rating': 5,
#     'totalCount': None,
#     'distance': 0.4,
#     'assigned': None,
#     'name': 'Ogden Elementary School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1421-Lincoln-Park-High-School/',
#     'rating': 9,
#     'totalCount': None,
#     'distance': 1.2,
#     'assigned': None,
#     'name': 'Lincoln Park High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'High',
#     'grades': '9-12',
#     'type': 'Public'}],
#   'restaurant_1': {'business_name': 'Sushi By Bou - River North',
#    'categories_titles': ['Sushi Bars', 'Japanese', 'Speakeasies'],
#    'rating': 5.0,
#    'latitude': 41.895179,
#    'longitude': -87.6343,
#    'display_address': '712 N Wells St Chicago, IL 60654',
#    'url': 'https://www.yelp.com/biz/sushi-by-bou-river-north-chicago-2?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'restaurant_2': {'business_name': 'BULSHO restaurant',
#    'categories_titles': ['African', 'Somali'],
#    'rating': 5.0,
#    'latitude': 41.899569,
#    'longitude': -87.63488467,
#    'display_address': '211 W Walton St Chicago, IL 60610',
#    'url': 'https://www.yelp.com/biz/bulsho-restaurant-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'neighborhood': 'Gold Coast',
#   'neighborhood_description': 'Neighborhood description is not found.'},
#  {'propertyType': 'CONDO',
#   'address': '6253 N Greenview Ave #3, Chicago, IL 60660',
#   'price': 250000,
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/6253-N-Greenview-Ave-3-Chicago-IL-60660/3689544_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/5a18b632631fb2fa19903b98fb8f7cc9-p_e.jpg',
#   'longitude': -87.66755,
#   'latitude': 41.996136,
#   'description': "This is one you won't want to miss! Recently renovated 2BR/1BA top-floor condo in hot Edgewater with a beautiful private balcony overlooking tree-lined Greenview! This vintage unit showcases a popular split-bedroom floorplan with refinished hardwood floors, crown molding, and spacious room sizes. The large living room is highlighted by west facing windows and a gorgeous brick decorative fireplace surrounded by built-in cabinetry and shelving! The renovated kitchen boasts white cabinetry, stainless steel appliances, granite counter tops, and an island that's open/adjacent to the dining room with plenty of space for a large dining set. Additional features include a nicely tiled bathroom, in-unit laundry and separate basement storage. Fantastic location near Loyola University, the Granville red line, CVS, Whole Foods, Aldi, Lickity Split, shopping, restaurants and near the new Peterson/Ridge Metra stop!",
#   'resoFacts': {'hasGarage': False,
#    'hasPetsAllowed': None,
#    'heating': ['Steam', 'Radiator(s)'],
#    'cooling': ['Window/Wall Units - 2'],
#    'flooring': ['Hardwood'],
#    'appliances': ['Range',
#     'Microwave',
#     'Dishwasher',
#     'Refrigerator',
#     'Washer',
#     'Dryer',
#     'Stainless Steel Appliance(s)'],
#    'laundryFeatures': ['In Unit', 'Laundry Hook-Up in Unit'],
#    'associationFee': '$523 monthly',
#    'livingArea': None,
#    'taxAnnualAmount': 4725,
#    'parkingFeatures': {},
#    'stories': None},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1133-Hayt-Elementary-School/',
#     'rating': 5,
#     'totalCount': None,
#     'distance': 0.1,
#     'assigned': None,
#     'name': 'Hayt Elementary School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1366-Senn-High-School/',
#     'rating': 4,
#     'totalCount': None,
#     'distance': 0.5,
#     'assigned': None,
#     'name': 'Senn High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'High',
#     'grades': '9-12',
#     'type': 'Public'}],
#   'restaurant_1': {'business_name': 'Mella Cafe',
#    'categories_titles': ['Cafes', 'Eritrean', 'Ethiopian'],
#    'rating': 5.0,
#    'latitude': 41.9806,
#    'longitude': -87.66038,
#    'display_address': '5418 N Broadway St Chicago, IL 60640',
#    'url': 'https://www.yelp.com/biz/mella-cafe-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'restaurant_2': {'business_name': 'Misericordia Hearts & Flour Bakery & Cafe',
#    'categories_titles': ['Breakfast & Brunch', 'Coffee & Tea', 'Bakeries'],
#    'rating': 5.0,
#    'latitude': 41.99274959187099,
#    'longitude': -87.67558925706018,
#    'display_address': '6130 N Ravenswood Ave Chicago, IL 60660',
#    'url': 'https://www.yelp.com/biz/misericordia-hearts-and-flour-bakery-and-cafe-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'neighborhood': 'Edgewater',
#   'neighborhood_description': 'Neighborhood description is not found.'}]

# %% [markdown]
# ## Use case 2
# ### Initial query: Restaurant info

# %%
# For initial query, use pp_chatbot, not get_chat_response
user_query = "Could you recommend an Italian restaurant in Chicago?"
pp_chatbot(user_query)
# Out:
# The query is about restaurant. I will answer by using Yelp API Filter

# %%
# For additional question, use get_chat_response, not pp_chatbot
user_query = "Tell me more about the restaurant?"
print(get_chat_response(chat, user_query))

# %% [markdown]
# ## Use case 3
# ### Initial query: Neighborhood info

# %%
# For initial query, use pp_chatbot, not get_chat_response
user_query = "What is the West Loop neighborhood in Chicago like?"
pp_chatbot(user_query)
# Out:
# The query is about neighborhood. I will answer by using RAG

# %%
# For additional question, use get_chat_response, not pp_chatbot
user_query = "Tell me more about the neighborhood?"
print(get_chat_response(chat, user_query))
