# %%
# %run /home/jupyter/Property-Pilot/property_pilot/scripts/fetch_property_info.py
# Out:
# 2024-05-18 20:46:31.874475: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
top_properties = [{'propertyType': None,
  'address': '2749 N Sawyer Ave, Chicago, IL',
  'price': None,
  'bedrooms': None,
  'bathrooms': None,
  'detailUrl': 'https://www.zillow.com/apartments/chicago-il/3213.dash.23-w-diversey-ave/9S5Sq4/',
  'imgSrc': 'https://photos.zillowstatic.com/fp/56fdea17837f212bb574b96b2c3693e2-p_e.jpg',
  'longitude': -87.708466,
  'latitude': 41.93161,
  'description': 'No description available',
  'resoFacts': {'hasGarage': 'N/A',
   'hasPetsAllowed': 'N/A',
   'heating': 'N/A',
   'cooling': 'N/A',
   'flooring': 'N/A',
   'appliances': 'N/A',
   'laundryFeatures': 'N/A',
   'associationFee': 'N/A',
   'livingArea': 'N/A',
   'taxAnnualAmount': 'N/A',
   'parkingFeatures': 'N/A',
   'stories': 'N/A'},
  'schools': [],
  'restaurant_1': {'business_name': 'Taquero Mucho',
   'categories_titles': ['Mexican'],
   'rating': 5.0,
   'latitude': 41.94536,
   'longitude': -87.7094,
   'display_address': '3517 N Spaulding Ave Chicago, IL 60618',
   'url': 'https://www.yelp.com/biz/taquero-mucho-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
  'restaurant_2': {'business_name': 'Trogo Kitchen and Market',
   'categories_titles': ['Cafes', 'Specialty Food', 'Sandwiches'],
   'rating': 5.0,
   'latitude': 41.93163,
   'longitude': -87.69189,
   'display_address': '2545 W Diversey Ave Ste 220 Chicago, IL 60647',
   'url': 'https://www.yelp.com/biz/trogo-kitchen-and-market-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
  'neighborhood': 'Logan Square',
  'neighborhood_description': 'Neighborhood description is not found.'},
 {'propertyType': 'APARTMENT',
  'address': 'Logan Apartments, 2522 N Milwaukee Ave #432, Chicago, IL 60647',
  'price': 3950,
  'bedrooms': 2,
  'bathrooms': 2,
  'detailUrl': 'https://www.zillow.com/apartments/chicago-il/logan-apartments/Bdjk77/',
  'imgSrc': 'https://photos.zillowstatic.com/fp/d0c4759abf73ca98af7693843939af22-p_e.jpg',
  'longitude': -87.704384,
  'latitude': 41.927082,
  'description': 'No description available',
  'resoFacts': {'hasGarage': 'N/A',
   'hasPetsAllowed': 'N/A',
   'heating': 'N/A',
   'cooling': 'N/A',
   'flooring': 'N/A',
   'appliances': 'N/A',
   'laundryFeatures': 'N/A',
   'associationFee': 'N/A',
   'livingArea': 'N/A',
   'taxAnnualAmount': 'N/A',
   'parkingFeatures': 'N/A',
   'stories': 'N/A'},
  'schools': [],
  'restaurant_1': {'business_name': 'Trogo Kitchen and Market',
   'categories_titles': ['Cafes', 'Specialty Food', 'Sandwiches'],
   'rating': 5.0,
   'latitude': 41.93163,
   'longitude': -87.69189,
   'display_address': '2545 W Diversey Ave Ste 220 Chicago, IL 60647',
   'url': 'https://www.yelp.com/biz/trogo-kitchen-and-market-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
  'restaurant_2': {'business_name': 'Omarcitos Latin Cafe',
   'categories_titles': ['Latin American', 'Coffee & Tea', 'Sandwiches'],
   'rating': 5.0,
   'latitude': 41.924307209794115,
   'longitude': -87.72218126803637,
   'display_address': '3801 W Fullerton Ave Chicago, IL 60647',
   'url': 'https://www.yelp.com/biz/omarcitos-latin-cafe-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
  'neighborhood': 'Logan Square',
  'neighborhood_description': 'Neighborhood description is not found.'},
 {'propertyType': 'SINGLE_FAMILY',
  'address': '950 N Michigan Ave APT 2304, Chicago, IL 60611',
  'price': 5000,
  'bedrooms': 2,
  'bathrooms': 3.5,
  'detailUrl': 'https://www.zillow.com/homedetails/950-N-Michigan-Ave-APT-2304-Chicago-IL-60611/3848501_zpid/',
  'imgSrc': 'https://photos.zillowstatic.com/fp/317190fe4b4484729d094b113f55e290-p_e.jpg',
  'longitude': -87.62463,
  'latitude': 41.901016,
  'description': "Gorgeous views down Michigan Avenue from this updated 2 bed 3.5 bath. Ideal chef's kitchen opens up to a sprawling living and dining space with plenty of natural light. Primary bedroom has a large walk in closet, as well as dual en-suite bathrooms. Second bedroom also has en-suite bathroom, and could also serve as a home office or den. In unit laundry and premium window treatments round out this stunning unit. Full amenity building provides 24/7 door staff, state-of-the-art fitness center, indoor pool and spa, sauna, and sun deck with grills. With on-site management, and parking for rent in the building, this location is central to downtown and Chicago's beautiful Lake Michigan trail and beach. New photos coming soon.",
  'resoFacts': {'hasGarage': False,
   'hasPetsAllowed': False,
   'heating': ['Electric', 'Radiant', 'Zoned'],
   'cooling': ['Central Air'],
   'flooring': ['Hardwood'],
   'appliances': ['Dishwasher',
    'Double Oven',
    'Dryer',
    'Garbage Disposal',
    'Refrigerator',
    'Stove',
    'Washer'],
   'laundryFeatures': ['In Unit', 'Laundry Hook-Up in Unit'],
   'associationFee': None,
   'livingArea': '1,830 sqft',
   'taxAnnualAmount': 95,
   'parkingFeatures': ['Attached', 'Covered'],
   'stories': None},
  'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1270-Ogden-Elementary-School/',
    'rating': 5,
    'totalCount': None,
    'distance': 0.2,
    'assigned': None,
    'name': 'Ogden Elementary School',
    'studentsPerTeacher': None,
    'isAssigned': None,
    'size': None,
    'level': 'Primary',
    'grades': 'PK-8',
    'type': 'Public'},
   {'link': 'https://www.greatschools.org/illinois/chicago/1421-Lincoln-Park-High-School/',
    'rating': 9,
    'totalCount': None,
    'distance': 1.6,
    'assigned': None,
    'name': 'Lincoln Park High School',
    'studentsPerTeacher': None,
    'isAssigned': None,
    'size': None,
    'level': 'High',
    'grades': '9-12',
    'type': 'Public'}],
  'restaurant_1': {'business_name': 'Sushi By Bou - River North',
   'categories_titles': ['Sushi Bars', 'Japanese', 'Speakeasies'],
   'rating': 5.0,
   'latitude': 41.895179,
   'longitude': -87.6343,
   'display_address': '712 N Wells St Chicago, IL 60654',
   'url': 'https://www.yelp.com/biz/sushi-by-bou-river-north-chicago-2?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
  'restaurant_2': {'business_name': 'Gold Coast Market',
   'categories_titles': ['Tobacco Shops', 'Beer, Wine & Spirits', 'Delis'],
   'rating': 5.0,
   'latitude': 41.89651,
   'longitude': -87.630544,
   'display_address': '71 W Chicago Ave Chicago, IL 60654',
   'url': 'https://www.yelp.com/biz/gold-coast-market-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
  'neighborhood': 'Gold Coast',
  'neighborhood_description': 'Neighborhood description is not found.'}]

# %%
top_properties
# Out:
# [{'propertyType': None,
#   'address': '2749 N Sawyer Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/apartments/chicago-il/3213.dash.23-w-diversey-ave/9S5Sq4/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/56fdea17837f212bb574b96b2c3693e2-p_e.jpg',
#   'longitude': -87.708466,
#   'latitude': 41.93161,
#   'description': 'No description available',
#   'resoFacts': {'hasGarage': 'N/A',
#    'hasPetsAllowed': 'N/A',
#    'heating': 'N/A',
#    'cooling': 'N/A',
#    'flooring': 'N/A',
#    'appliances': 'N/A',
#    'laundryFeatures': 'N/A',
#    'associationFee': 'N/A',
#    'livingArea': 'N/A',
#    'taxAnnualAmount': 'N/A',
#    'parkingFeatures': 'N/A',
#    'stories': 'N/A'},
#   'schools': [],
#   'restaurant_1': {'business_name': 'Taquero Mucho',
#    'categories_titles': ['Mexican'],
#    'rating': 5.0,
#    'latitude': 41.94536,
#    'longitude': -87.7094,
# ...

# %%
# neighborhood boundaries shapefile
neighborhood_boundaries_path = '/home/jupyter/Property-Pilot/property_pilot/data/neighborhood_boundaries/geo_export_825d7df4-a9cd-4cef-b3d7-2ec1adc30204.shp'
# neighborhood description file
neighborhood_info_path = '/home/jupyter/Property-Pilot/property_pilot/data/neighborhood_info/neighborhood_info_final.csv'

# load the neighborhood boundaries and description file
neighborhoods = load_neighborhood_boundaries(neighborhood_boundaries_path)
neighborhoods_info = load_neighborhood_info(neighborhood_info_path)

# %%
neighborhoods_info
# Out:
#         neighborhood                           neighborhood_information  \
# 0         Ravenswood  Ravenswood in Chicago is celebrated for its ro...
# 1         South Loop  The South Loop is a vibrant Chicago neighborho...
# 2     Belmont Cragin  Belmont Cragin, a neighborhood rich in Hispani...
# 3           Avondale  Avondale is a neighborhood with a growing repu...
# 4          Englewood  Englewood is a vibrant community known for its...
# 5          West Town  West Town stands out for its artistic and dive...
# 6          West Loop  West Loop is a dynamic dining hub in Chicago, ...
# 7         Hyde Park   Hyde Park, known for its rich history, was the...
# 8     Garfield Park   Garfield Park is a standout neighborhood known...
# 9     Roscoe Village  Roscoe Village is described as a "village with...
# 10      Logan Square  Logan Square is celebrated for its vibrant art...
# 11        North Park  North Park, steeped in Swedish heritage, combi...
# ...

# %%
fetch_neighborhood_info(top_properties, neighborhoods_info)
# Out:
# [{'propertyType': None,
#   'address': '2749 N Sawyer Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/apartments/chicago-il/3213.dash.23-w-diversey-ave/9S5Sq4/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/56fdea17837f212bb574b96b2c3693e2-p_e.jpg',
#   'longitude': -87.708466,
#   'latitude': 41.93161,
#   'description': 'No description available',
#   'resoFacts': {'hasGarage': 'N/A',
#    'hasPetsAllowed': 'N/A',
#    'heating': 'N/A',
#    'cooling': 'N/A',
#    'flooring': 'N/A',
#    'appliances': 'N/A',
#    'laundryFeatures': 'N/A',
#    'associationFee': 'N/A',
#    'livingArea': 'N/A',
#    'taxAnnualAmount': 'N/A',
#    'parkingFeatures': 'N/A',
#    'stories': 'N/A'},
#   'schools': [],
#   'restaurant_1': {'business_name': 'Taquero Mucho',
#    'categories_titles': ['Mexican'],
#    'rating': 5.0,
#    'latitude': 41.94536,
#    'longitude': -87.7094,
# ...
