# %%
# %run /home/jupyter/property_pilot/scripts/fetch_property_info.py

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
top_properties = [{'propertyType': 'SINGLE_FAMILY',
  'address': '9349 S Woodlawn Ave, Chicago, IL 60619',
  'price': 119000,
  'bedrooms': 2,
  'bathrooms': 1,
  'detailUrl': 'https://www.zillow.com/homedetails/9349-S-Woodlawn-Ave-Chicago-IL-60619/4114945_zpid/',
  'imgSrc': 'https://photos.zillowstatic.com/fp/145c32a679f93e6424b7d87c747cb950-p_e.jpg',
  'longitude': -87.5945,
  'latitude': 41.724407,
  'description': "Welcome to your dream starter home or investment property! This charming 2 bedroom, 1 bathroom residence has been freshly painted and boasts large room sizes, an expansive lot, inviting yard and an unfinished basement, offering endless expansion possibilities.  As you step through the front door, you'll be greeted by a cozy and inviting living space, perfect for creating lasting memories with loved ones. The well-designed layout enhances the functionality of the home, providing a nice flow between the living and kitchen area. The layout creates a warm and welcoming atmosphere. The heart of this home is undoubtedly the inviting eat-in kitchen, where you can whip up delicious meals and enjoy them in a cozy dining area. The kitchen boasts ample cabinet space, making it a chef's delight.  Step outside to the generous backyard, a green oasis that invites you to indulge your gardening aspirations or simply relax in the open air. The expansive outdoor space is perfect for entertaining, offering endless possibilities for outdoor activities and gatherings with friends and family. Situated in a quiet neighborhood, this residence offers convenience and accessibility to local amenities, schools, and parks. The property's prime location also presents an excellent opportunity for investors seeking a reliable and attractive rental or rehab property. Whether you're embarking on the exciting journey of homeownership or expanding your investment portfolio, this 2 bedroom, 1 bathroom gem is a must-see. Don't miss the chance to make this property your own.  Schedule a showing today and envision the possibilities that await you in this charming home!",
  'resoFacts': {'hasGarage': True,
   'hasPetsAllowed': None,
   'heating': ['Natural Gas'],
   'cooling': ['None'],
   'flooring': ['Hardwood'],
   'appliances': None,
   'laundryFeatures': None,
   'associationFee': None,
   'livingArea': '864 sqft',
   'taxAnnualAmount': 2249,
   'parkingFeatures': ['Garage', 'Open'],
   'stories': 1},
  'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1293-Washington--H-Elementary-School/',
    'rating': 5,
    'totalCount': None,
    'distance': 0.3,
    'assigned': None,
    'name': 'Washington  H Elementary School',
    'studentsPerTeacher': None,
    'isAssigned': None,
    'size': None,
    'level': 'Primary',
    'grades': 'PK-8',
    'type': 'Public'},
   {'link': 'https://www.greatschools.org/illinois/chicago/1145-Harlan-Community-Academy-High-School/',
    'rating': 1,
    'totalCount': None,
    'distance': 1.5,
    'assigned': None,
    'name': 'Harlan Community Academy High School',
    'studentsPerTeacher': None,
    'isAssigned': None,
    'size': None,
    'level': 'High',
    'grades': '9-12',
    'type': 'Public'}],
  'restaurant_1': {'business_name': 'Wingz It Iz',
   'categories_titles': ['New American', 'Fish & Chips'],
   'rating': 4.0,
   'latitude': 41.7292404174805,
   'longitude': -87.5858688354492,
   'display_address': '9106 S Stony Island Ave Chicago, IL 60617',
   'url': 'https://www.yelp.com/biz/wingz-it-iz-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
  'restaurant_2': {'business_name': 'Flames Fish and Chicken',
   'categories_titles': ['Burgers', 'Chicken Wings', 'Sandwiches'],
   'rating': 5.0,
   'latitude': 41.7223550534145,
   'longitude': -87.6048295944929,
   'display_address': '9454 S Cottage Grove Ave Chicago, IL 60619',
   'url': 'https://www.yelp.com/biz/flames-fish-and-chicken-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
  'neighborhood': 'Burnside',
  'neighborhood_description': 'Neighborhood description is not found.'},
 {'propertyType': 'CONDO',
  'address': '6255 N Oakley Ave #G, Chicago, IL 60659',
  'price': 179900,
  'bedrooms': 2,
  'bathrooms': 2,
  'detailUrl': 'https://www.zillow.com/homedetails/6255-N-Oakley-Ave-G-Chicago-IL-60659/80826181_zpid/',
  'imgSrc': 'https://photos.zillowstatic.com/fp/025f0841158270d5ec9b3cd98f6c603e-p_e.jpg',
  'longitude': -87.68651,
  'latitude': 41.995792,
  'description': 'Location, location! Stunning and rarely seen 2 bedroom and 2 full bathroom garden apartment at an amazing value. Complete renovation in 2015. In unit laundry. New windows throughout. New finished wood floors. Stainless steal appliances, high efficiency furnace and central air. Spacious bedrooms with plenty of closet space. Tall ceilings. Very close to transportation (155 Bus to Red line and 49B to Brown line). Everything you need is near by. You can feel the quality as soon as you step inside.',
  'resoFacts': {'hasGarage': False,
   'hasPetsAllowed': None,
   'heating': ['Natural Gas'],
   'cooling': ['Central Air'],
   'flooring': None,
   'appliances': None,
   'laundryFeatures': None,
   'associationFee': '$202 monthly',
   'livingArea': '1,200 sqft',
   'taxAnnualAmount': 3400,
   'parkingFeatures': {},
   'stories': None},
  'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1133-Hayt-Elementary-School/',
    'rating': 5,
    'totalCount': None,
    'distance': 0.9,
    'assigned': None,
    'name': 'Hayt Elementary School',
    'studentsPerTeacher': None,
    'isAssigned': None,
    'size': None,
    'level': 'Primary',
    'grades': 'PK-8',
    'type': 'Public'},
   {'link': 'https://www.greatschools.org/illinois/chicago/1366-Senn-High-School/',
    'rating': 4,
    'totalCount': None,
    'distance': 1.1,
    'assigned': None,
    'name': 'Senn High School',
    'studentsPerTeacher': None,
    'isAssigned': None,
    'size': None,
    'level': 'High',
    'grades': '9-12',
    'type': 'Public'}],
  'restaurant_1': {'business_name': 'Biryani Corner',
   'categories_titles': ['Pakistani'],
   'rating': 5.0,
   'latitude': 41.998277041153514,
   'longitude': -87.69026700407265,
   'display_address': '6418 N Western Ave Chicago, IL 60645',
   'url': 'https://www.yelp.com/biz/biryani-corner-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
  'restaurant_2': {'business_name': 'Urban Morning Cozy Cafe',
   'categories_titles': ['Cafes'],
   'rating': 5.0,
   'latitude': 42.011441,
   'longitude': -87.689947,
   'display_address': '7113 N Western Ave Chicago, IL 60645',
   'url': 'https://www.yelp.com/biz/urban-morning-cozy-cafe-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
  'neighborhood': 'West Ridge',
  'neighborhood_description': 'Neighborhood description is not found.'},
 {'propertyType': 'CONDO',
  'address': '2305 W Chicago Ave APT 1, Chicago, IL 60622',
  'price': 440000,
  'bedrooms': 2,
  'bathrooms': 2,
  'detailUrl': 'https://www.zillow.com/homedetails/2305-W-Chicago-Ave-APT-1-Chicago-IL-60622/65550988_zpid/',
  'imgSrc': 'https://photos.zillowstatic.com/fp/ccf0f222cc99e8827426e8507247872b-p_e.jpg',
  'longitude': -87.68475,
  'latitude': 41.89559,
  'description': 'Spacious open floor plan with patio and gardens this two bedrm 2 two full bath condo is move in ready.  The desirable Ukrainian Village location is close to Star Bucks, Mariano\'s, and shopping. In unit laundry, one parking spot 6 feet from back entrance, 42" kitchen cabinets, beautiful bath tile, storage space under stairs, big closets, low HOA, fire place, granite counter tops, large bedrooms, hard wood floors, double sink in master bath, separate shower, stainless appliances, walk in closets, slider to brick patio, garden space off patio, private entrance, lots of windows, in beautiful brick building are some features you don\'t want to miss.  OPEN 5/19 at 11-1.  This property will move fast.',
  'resoFacts': {'hasGarage': False,
   'hasPetsAllowed': None,
   'heating': ['Natural Gas'],
   'cooling': ['Central Air'],
   'flooring': ['Hardwood', 'Some Carpeting'],
   'appliances': None,
   'laundryFeatures': ['In Unit', 'Laundry Hook-Up in Unit'],
   'associationFee': '$150 monthly',
   'livingArea': '1,450 sqft',
   'taxAnnualAmount': 8316,
   'parkingFeatures': {},
   'stories': None},
  'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1241-Mitchell-Elementary-School/',
    'rating': 8,
    'totalCount': None,
    'distance': 0.3,
    'assigned': None,
    'name': 'Mitchell Elementary School',
    'studentsPerTeacher': None,
    'isAssigned': None,
    'size': None,
    'level': 'Primary',
    'grades': 'PK-8',
    'type': 'Public'},
   {'link': 'https://www.greatschools.org/illinois/chicago/1425-Wells-Community-Academy-High-School/',
    'rating': 1,
    'totalCount': None,
    'distance': 0.9,
    'assigned': None,
    'name': 'Wells Community Academy High School',
    'studentsPerTeacher': None,
    'isAssigned': None,
    'size': None,
    'level': 'High',
    'grades': '9-12',
    'type': 'Public'}],
  'restaurant_1': {'business_name': 'Healthy Substance Cantina',
   'categories_titles': ['Vegan'],
   'rating': 5.0,
   'latitude': 41.908631,
   'longitude': -87.675257,
   'display_address': '1480 N Milwaukee Ave Chicago, IL 60622',
   'url': 'https://www.yelp.com/biz/healthy-substance-cantina-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
  'restaurant_2': {'business_name': 'Modern Relish',
   'categories_titles': ['Hot Dogs', 'Burgers', 'Sandwiches'],
   'rating': 5.0,
   'latitude': 41.8934627,
   'longitude': -87.6674949,
   'display_address': '632-636 N Ashland Ave Chicago, IL 60622',
   'url': 'https://www.yelp.com/biz/modern-relish-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
  'neighborhood': 'West Town',
  'neighborhood_description': 'West Town stands out for its artistic and diverse atmosphere. It features a wide range of cultural experiences, from avant-garde art galleries to traditional pierogi joints. The neighborhood boasts a rich tapestry of historic buildings and a vibrant social scene, including Michelin-starred restaurants and unique craft breweries. Local highlights include the Ukrainian National Museum and the eclectic food scene on Chicago Avenue.'}]

# %%
top_properties
# Out:
# [{'propertyType': 'SINGLE_FAMILY',
#   'address': '9349 S Woodlawn Ave, Chicago, IL 60619',
#   'price': 119000,
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/9349-S-Woodlawn-Ave-Chicago-IL-60619/4114945_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/145c32a679f93e6424b7d87c747cb950-p_e.jpg',
#   'longitude': -87.5945,
#   'latitude': 41.724407,
# ...

# %%
# neighborhood boundaries shapefile
neighborhood_boundaries_path = '/home/jupyter/property_pilot/data/neighborhood_boundaries/geo_export_825d7df4-a9cd-4cef-b3d7-2ec1adc30204.shp'
# neighborhood description file
neighborhood_info_path = '/home/jupyter/property_pilot/data/neighborhood_info/neighborhood_info_final.csv'

# load the neighborhood boundaries and description file
neighborhoods = load_neighborhood_boundaries(neighborhood_boundaries_path)
neighborhoods_info = load_neighborhood_info(neighborhood_info_path)

# %%
fetch_neighborhood_info(top_properties, neighborhoods_info)
# Out:
# [{'propertyType': 'SINGLE_FAMILY',
#   'address': '9349 S Woodlawn Ave, Chicago, IL 60619',
#   'price': 119000,
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/9349-S-Woodlawn-Ave-Chicago-IL-60619/4114945_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/145c32a679f93e6424b7d87c747cb950-p_e.jpg',
#   'longitude': -87.5945,
#   'latitude': 41.724407,
# ...
