# %% [markdown]
# ## PropertyPilot Demo
# ## Conversational AI Capstone I
# ## 21 May 2024

# %%
# %pip list | grep google-cloud-aiplatform
# %pip list | grep google-api-core
# %pip install google-cloud-aiplatform==1.43.0
# %pip install google-api-core==2.17.1

# %%
import vertexai
from vertexai.preview.generative_models import GenerativeModel, ChatSession, Part
import vertexai.preview.generative_models as generative_models

import geopandas as gpd
from shapely.geometry import Point

import http.client
import json
import urllib.parse
from typing import Dict, Any
import pandas as pd
import folium

# %%
vertexai.init(project = "adsp-capstone-property-pilot", location = "us-central1")

# %% [markdown]
# ## Model Setting - Gemini pro 1.0

# %%
model = GenerativeModel("gemini-1.0-pro")
chat = model.start_chat()

def get_chat_response(chat: ChatSession, prompt: str) -> str:
    text_response = []
    responses = chat.send_message(prompt, stream=True)
    for chunk in responses:
        text_response.append(chunk.text)
    return "".join(text_response)

# %%
# Test chat
prompt = "Hello."
print(get_chat_response(chat, prompt))
# Out:
# Hello! I'm happy to hear from you. What would you like to talk about today?

# %% [markdown]
# ## Settings

# %%
with open('/home/jupyter/zillow_api.txt', 'r') as file:
    zillow_api = file.read()

import requests

url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

headers = {
	"X-RapidAPI-Key": zillow_api,
	"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

with open('/home/jupyter/yelp_api.txt', 'r') as file:
    yelp_api = file.read()

yelp_api_key = yelp_api

# %% [markdown]
# ## Import functions

# %%
import os

# %%
# %run /home/jupyter/property_pilot/scripts/chat_response.py

# %%
# %run /home/jupyter/property_pilot/scripts/generate_api_filter.py

# %%
# %run /home/jupyter/property_pilot/scripts/fetch_property_info.py

# %%
# %run /home/jupyter/property_pilot/scripts/yelp_property.py

# %%
# %run /home/jupyter/property_pilot/scripts/neighborhood_rag.py

# %%
# %run /home/jupyter/property_pilot/scripts/yelp_advisor.py

# %% [markdown]
# ## Import data

# %%
# For RAG

# read csv
vector_store = pd.read_csv('/home/jupyter/property_pilot/data/vector_store.csv')
# embedding to numpy array
vector_store['embeddings'] = vector_store['embeddings'].apply(lambda x: np.array(list(map(float, x.split(',')))))

# %% [markdown]
# ## Import prompts

# %%
os.chdir('/home/jupyter/property_pilot/prompts')

# prompt_classifier
file_path = 'instruction_classifier.txt'
try:
    with open(file_path, 'r') as file:
        instruction_prompt_classifier = file.read()
except FileNotFoundError:
    print("The file does not exist")
except Exception as e:
    print(f"An error occurred: {e}") 
    
# prompt_apifilter
file_path = 'generate_prompt_apifilter.txt'
try:
    with open(file_path, 'r') as file:
        instruction_prompt_apifilter = file.read()
except FileNotFoundError:
    print("The file does not exist")
except Exception as e:
    print(f"An error occurred: {e}")
    
# yelp_categories
file_path = 'yelp_categories.txt'
try:
    with open(file_path, 'r') as file:
        yelp_categories = file.read().splitlines()
        categories_string = ','.join(yelp_categories)
except FileNotFoundError:
    print("The file does not exist")
except Exception as e:
    print(f"An error occurred: {e}")
    
# prompt_property(for final output)
file_path = 'generate_prompt_property.txt'
try:
    with open(file_path, 'r') as file:
        instruction_prompt_property = file.read()
except FileNotFoundError:
    print("The file does not exist")
except Exception as e:
    print(f"An error occurred: {e}")
    
# instruction_rag_neighborhood
file_path = 'instruction_rag_neighborhood.txt'
try:
    with open(file_path, 'r') as file:
        instruction_rag_neighborhood = file.read()
except FileNotFoundError:
    print("The file does not exist")
except Exception as e:
    print(f"An error occurred: {e}")
    
# yelp_advisor_instructions (for yelp local advisor)
file_path = 'yelp_advisor_instructions.txt'
try:
    with open(file_path, 'r') as file:
        yelp_advisor_instruction = file.read()
except FileNotFoundError:
    print("The file does not exist")
except Exception as e:
    print(f"An error occurred: {e}")
    
# yelp_output_instructions (for yelp local advisor)
file_path = 'yelp_output_instructions.txt'
try:
    with open(file_path, 'r') as file:
        yelp_output_instructions = file.read()
except FileNotFoundError:
    print("The file does not exist")
except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# ## Property Plot main function

# %%
def pp_chatbot(user_query):
    
    # User's quety classify
    prompt_classifier = generate_prompt_classifier(instruction_prompt_classifier, user_query)
    response_int = int(get_chat_response(chat, prompt_classifier))
    
    # if the user is looking for a property     
    if response_int == 1:

        # get prompt for api filter 
        prompt_apifilter = generate_prompt_apifilter(instruction_prompt_apifilter, user_query)

        # get api filter
        apifilter = get_chat_response(chat, prompt_apifilter)
        apifilter = extract_json_to_dict(apifilter)

        # get listings from zillow
        response = requests.get(url, headers = headers, params = apifilter)

        # get top 3 listings(sorted by newest)
        # Define fields to extract
        fields = ["propertyType", "address", "price", "bedrooms", "bathrooms", "detailUrl", "imgSrc", "longitude", "latitude"]
        top_properties = extract_properties(response, 3, fields)

        # get description of the properties
        top_properties = fetch_descriptions(top_properties)

        # get resoFacts(detail) of the properties
        keys_to_fetch_resoFacts = [
            'hasGarage', 'hasPetsAllowed', 'heating', 'cooling', 'flooring', 'appliances',
            'laundryFeatures', 'associationFee',
            'livingArea', 'taxAnnualAmount', 'parkingFeatures', 'stories'
        ]
        top_properties = fetch_resoFacts(top_properties, headers, keys_to_fetch_resoFacts)

        # get school info of the properties
        top_properties = fetch_schools(top_properties, headers)
        
        # get restaurant info from yelp api
        yelp_results = fetch_top_businesses_near_properties(yelp_api_key, top_properties, user_query, yelp_categories, chat)
        
        # extract restaurant info
        yelp_fields = ['business_name', 'categories_titles', 'rating', 'latitude', 'longitude', 'display_address', 'url']
        top_restaurants = extract_business_info(yelp_results, 2, yelp_fields)
        
        # merge top_restaurants with top_properties
        top_properties = merge_property_and_restaurant_info(top_properties, top_restaurants)

        # neighborhood boundaries shapefile
        neighborhood_boundaries_path = '/home/jupyter/property_pilot/data/neighborhood_boundaries/geo_export_825d7df4-a9cd-4cef-b3d7-2ec1adc30204.shp'
        # neighborhood description file
        neighborhood_info_path = '/home/jupyter/property_pilot/data/neighborhood_info/neighborhood_info_final.csv'

        # load the neighborhood boundaries and description file
        neighborhoods = load_neighborhood_boundaries(neighborhood_boundaries_path)
        neighborhoods_info = load_neighborhood_info(neighborhood_info_path)

        # get neighborhood details of the properties
        top_properties = fetch_neighborhood(top_properties, neighborhoods)
        top_properties = fetch_neighborhood_info(top_properties, neighborhoods_info)

        # create property map
        property_map = create_property_map(top_properties)
        
        # create property_restaurant map
        property_restaurant_map = create_property_restaurant_map(top_properties)

        # change format
        fields_desc = fields + ['description', 'resoFacts', 'schools', 'neighborhood', 'neighborhood_description', 'restaurant_1', 'restaurant_2']
        property_info = format_properties(top_properties, fields_desc)

        # prompt for final output from Gemini
        prompt_final = generate_prompt_property(instruction_prompt_property, user_query, property_info, str(fields))

        # get final response from Gemini
        print(get_chat_response(chat, prompt_final))
        display(property_restaurant_map)

        return top_properties

    elif response_int == 2:
        # print('The query is about restaurant. I will answer by using Yelp API Filter')
        yelp_prompt = generate_prompt_yelp_advisor(yelp_advisor_instruction, user_query, categories_string)
        
        # get yelp filter string
        yelp_filter_str = get_chat_response(chat, yelp_prompt)
        
        # get yelp filter in json format
        yelp_filter = extract_json_to_dict(yelp_filter_str)
        
        # get response from yelp api
        yelp_advisor_results = yelp_advisor(yelp_api_key, yelp_filter)
        
        # create yelp restaurant map
        restaurant_map = create_yelp_restaurant_map(yelp_advisor_results)
        
        # generate yelp output prompt
        yelp_output_prompt = final_output_yelp_advisor(yelp_output_instructions, user_query, yelp_advisor_results)
        
        # get final response from Gemini
        print(get_chat_response(chat, yelp_output_prompt))
        display(restaurant_map)
        
    elif response_int == 3:
        # print('The query is about neighborhood. I will answer by using RAG')
        context = get_context(question = user_query, vector_store=vector_store, num_docs=10)
        prompt_rag_neighborhood = generate_prompt_rag_neighborhood(instruction_rag_neighborhood, context, user_query)
        print(get_chat_response(chat, prompt_rag_neighborhood))
        # return context
    else:
        print(get_chat_response(chat, user_query))

# %% [markdown]
# ## Use case 1
# ### property search - detail info

# %%
# For initial query, use pp_chatbot, not get_chat_response
user_query = "I am looking to purchase a house in Chicago. I would like to have a minimum 2 bedrooms and 2 bathrooms. I want to pay between $700,000 and $900,000."
top_properties = pp_chatbot(user_query)
# Out:
# ## Here are 3 properties that fit your criteria:
#
# **1. Single-family home in Kenwood:**
#
# * **Address:** 4922P S Cornell Ave, Chicago, IL 60615
# * **Price:** $825,000
# * **Bedrooms:** 3
# * **Bathrooms:** 4
# * **Details:** This spacious single-family home has 3 bedrooms and 4 bathrooms. It features a sunken family room, a balcony, and a finished basement. The kitchen has plenty of counter space and a walk-in pantry. There is a two-car attached garage and guest parking available. The home is located near public transportation and the lakefront.
# * **Photos:** https://photos.zillowstatic.com/fp/6c85ab0c974c11627d33d83701c78839-p_e.jpg
# * **More information:** https://www.zillow.com/homedetails/4922P-S-Cornell-Ave-Chicago-IL-60615/350418760_zpid/
#
# **2. Modern condo in Wicker Park:**
#
# * **Address:** 1332 N Leavitt St, Chicago, IL 60622
# * **Price:** $725,000
# * **Bedrooms:** 3
# * **Bathrooms:** 3
# * **Details:** This modern condo has 3 bedrooms and 3 bathrooms. It features high ceilings, a spacious kitchen, and a finished basement. There is a two-car garage and a private balcony. The home is located near trendy restaurants, shops, and nightlife.
# * **Photos:** https://photos.zillowstatic.com/fp/dfe030e612f21ceefc9edc40d96d0847-p_e.jpg
# * **More information:** https://www.zillow.com/homedetails/1332-N-Leavitt-St-Chicago-IL-60622/87708188_zpid/
#
# **3. Luxury condo in Streeterville:**
#
# * **Address:** 159 E Walton Pl APT 12D, Chicago, IL 60611
# * **Price:** $749,000
# * **Bedrooms:** 2
# * **Bathrooms:** 3
# * **Details:** This luxurious condo has 2 bedrooms and 3 bathrooms. It features high-end finishes, a gourmet kitchen, and stunning city views. There is one valet parking spot included. The building has a 24-hour doorman, on-site staff, and a fitness center.
# * **Photos:** https://photos.zillowstatic.com/fp/5cc780c53579c196e8b7bf404c26514d-p_e.jpg
# * **More information:** https://www.zillow.com/homedetails/159-E-Walton-Pl-APT-12D-Chicago-IL-60611/80858288_zpid/
#
# These are just a few examples of properties that meet your criteria. Please let me know if you have any other questions or would like me to recommend additional properties.
#
# Would you like me to tell you more about the schools or restaurants near these properties?
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1013e5b7bf135f5723e97bc9b48b871a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1013e5b7bf135f5723e97bc9b48b871a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1013e5b7bf135f5723e97bc9b48b871a = L.map(
#                 &quot;map_1013e5b7bf135f5723e97bc9b48b871a&quot;,
#                 {
#                     center: [41.881832, -87.623177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_32a0eb21b2ddf2f0b546b0ce133c5ef7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_32a0eb21b2ddf2f0b546b0ce133c5ef7.addTo(map_1013e5b7bf135f5723e97bc9b48b871a);
#
#
#             var marker_1c7d113a3c25ee3e51b5d6c8be504d08 = L.marker(
#                 [41.806026, -87.5879],
#                 {}
#             ).addTo(map_1013e5b7bf135f5723e97bc9b48b871a);
#
#
#             var icon_6dfef984229317725d5602730b3f5ec8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1c7d113a3c25ee3e51b5d6c8be504d08.setIcon(icon_6dfef984229317725d5602730b3f5ec8);
#
#
#         var popup_e914e3876f28b6bdf717498a59a0d28c = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_f7d0bfe563e2aae7e02bf194a960e001 = $(`&lt;div id=&quot;html_f7d0bfe563e2aae7e02bf194a960e001&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.zillow.com/homedetails/4922P-S-Cornell-Ave-Chicago-IL-60615/350418760_zpid/&quot; target=&quot;_blank&quot;&gt;4922P S Cornell Ave, Chicago, IL 60615&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_e914e3876f28b6bdf717498a59a0d28c.setContent(html_f7d0bfe563e2aae7e02bf194a960e001);
#
#
#
#         marker_1c7d113a3c25ee3e51b5d6c8be504d08.bindPopup(popup_e914e3876f28b6bdf717498a59a0d28c)
#         ;
#
#
#
#
#             marker_1c7d113a3c25ee3e51b5d6c8be504d08.bindTooltip(
#                 `&lt;div&gt;
#                      Click for property details
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e24f61054db842d02146669b2df4ae07 = L.marker(
#                 [41.7994057, -87.5892372],
#                 {}
#             ).addTo(map_1013e5b7bf135f5723e97bc9b48b871a);
#
#
#             var icon_5f7ad718ea1583992de333c4d3b7eb2c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e24f61054db842d02146669b2df4ae07.setIcon(icon_5f7ad718ea1583992de333c4d3b7eb2c);
#
#
#         var popup_2b1845047f14727960707152d2a5b357 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_9c74cbdfb9be827ab786e3edde7780cc = $(`&lt;div id=&quot;html_9c74cbdfb9be827ab786e3edde7780cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.yelp.com/biz/capital-one-caf%C3%A9-chicago-6?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&amp;utm_campaign=yelp_api_v3&amp;utm_medium=api_v3_business_search&amp;utm_source=6Rl6qXMI6EN3VkijeNTf0A&quot; target=&quot;_blank&quot;&gt;Capital One Café&lt;/a&gt;&lt;br/&gt;Cafes&lt;br/&gt;Rating: 4.7&lt;/div&gt;`)[0];
#                 popup_2b1845047f14727960707152d2a5b357.setContent(html_9c74cbdfb9be827ab786e3edde7780cc);
#
#
#
#         marker_e24f61054db842d02146669b2df4ae07.bindPopup(popup_2b1845047f14727960707152d2a5b357)
#         ;
#
#
#
#
#             marker_e24f61054db842d02146669b2df4ae07.bindTooltip(
#                 `&lt;div&gt;
#                      Click for details on Capital One Café
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_53d81e269bfba06fb03183992198db9c = L.marker(
#                 [41.8097706381699, -87.59817392478504],
#                 {}
#             ).addTo(map_1013e5b7bf135f5723e97bc9b48b871a);
#
#
#             var icon_7ee3accd3fcdcacc824df606fdbd4c12 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_53d81e269bfba06fb03183992198db9c.setIcon(icon_7ee3accd3fcdcacc824df606fdbd4c12);
#
#
#         var popup_149c81ef7faf759a43857e1ea56e086e = L.popup({&quot;m

# %%
top_properties
# Out:
# [{'propertyType': 'SINGLE_FAMILY',
#   'address': '4922P S Cornell Ave, Chicago, IL 60615',
#   'price': 825000,
#   'bedrooms': 3,
#   'bathrooms': 4,
#   'detailUrl': 'https://www.zillow.com/homedetails/4922P-S-Cornell-Ave-Chicago-IL-60615/350418760_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/6c85ab0c974c11627d33d83701c78839-p_e.jpg',
#   'longitude': -87.5879,
#   'latitude': 41.806026,
#   'description': "Unit P, Welcome to one of Cornell Square's highly desired EXTRA wide single family home. Step into this stunning home's main level featuring a charming foyer and steps leading down to the sunken family room, perfect for cozy family movie nights or easily convertible to a 4th bedroom if needed. The foyer and family room boast rare heated flooring and built-in surround sound speakers, with additional speakers installed in every room throughout the home. A convenient half bath is located on this level, just before the two-car attached garage. Ascending to the 2nd floor, you'll experience the spaciousness with the home's width and light-filled ambiance of this home. High ceilings and abundant windows create a bright and open feel. The enormous living room features a gas fireplace and opens to the dining room. The kitchen is a chef's dream, with an abundance of maple cabinetry, granite countertops, and a walk-in pantry. Another half bath is conveniently located on this level along with an ideal balcony just off the kitchen perfect for grilling. The top floor offers 3 spacious bedrooms, 2 full baths, and a laundry area. Each room is flooded with sunlight and offers ample closet space. The primary suite boasts cathedral ceilings, adding a dramatic flair to the space. The primary bathroom has a separate shower and tub along with a double vanity and lovely natural light from the skylight. Many upgrades have been completed by these long time owners with a complete new roof installed in Oct/2023 with added attic insulation (2021), a new oven/microwave (2023), and replaced most other mechanicals. The entire home was JUST painted and ready for it's new owner! There is included guest parking available directly behind the garages for 2 cars perfect for guests! This home is ideally located with a very short walk down Cornell to the 51st St. Metra station, offering a quick trip downtown. Enjoy great bus access to the University of Chicago and express buses to downtown, as well as super easy walk/bike access to the lakefront and paths north and south. This is a VERY special home! *** Interior photos coming on Thursday, May 23rd and first showings will be Wednesday May 22nd. This one should go very quickly....",
#   'resoFacts': {'hasGarage': True,
#    'hasPetsAllowed': None,
#    'heating': ['Forced Air'],
#    'cooling': ['Central Air'],
#    'flooring': ['Hardwood'],
#    'appliances': ['Range',
#     'Microwave',
#     'Dishwasher',
#     'Refrigerator',
#     'Washer',
#     'Dryer',
#     'Stainless Steel Appliance(s)'],
#    'laundryFeatures': ['In Unit', 'Laundry Closet', 'Second Floor Laundry'],
#    'associationFee': '$295 monthly',
#    'livingArea': None,
#    'taxAnnualAmount': 15593,
#    'parkingFeatures': ['None'],
#    'stories': 3},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1348-Shoesmith-Elementary-School/',
#     'rating': 5,
#     'totalCount': None,
#     'distance': 0.3,
#     'assigned': None,
#     'name': 'Shoesmith Elementary School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Elementary',
#     'grades': 'K-6',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1205-Kenwood-Academy-High-School/',
#     'rating': 7,
#     'totalCount': None,
#     'distance': 0.2,
#     'assigned': None,
#     'name': 'Kenwood Academy High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Middle',
#     'grades': '7-12',
#     'type': 'Public'}],
#   'restaurant_1': {'business_name': 'Capital One Café',
#    'categories_titles': ['Cafes'],
#    'rating': 4.7,
#    'latitude': 41.7994057,
#    'longitude': -87.5892372,
#    'display_address': '1465 E 53rd St Chicago, IL 60615',
#    'url': 'https://www.yelp.com/biz/capital-one-caf%C3%A9-chicago-6?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'restaurant_2': {'business_name': 'Gorée Cuisine',
#    'categories_titles': ['Senegalese', 'Caterers'],
#    'rating': 4.6,
#    'latitude': 41.8097706381699,
#    'longitude': -87.59817392478504,
#    'display_address': '1126 E 47th St Chicago, IL 60653',
#    'url': 'https://www.yelp.com/biz/gor%C3%A9e-cuisine-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'neighborhood': 'Kenwood',
#   'neighborhood_description': "Kenwood is an architectural haven, boasting a unique mix of 19th-century mansions and contemporary homes, providing a suburban feel within an urban setting. It's known for its lush landscapes and historical significance with landmarks like the Powhatan Apartments and the Hyde Park–Kenwood Historic District. Formerly home to prominent figures like Muddy Waters and Barack Obama, Kenwood offers guided architecture tours, showcasing its rich history and stunning designs."},
#  {'propertyType': 'SINGLE_FAMILY',
#   'address': '1332 N Leavitt St, Chicago, IL 60622',
#   'price': 725000,
#   'bedrooms': 3,
#   'bathrooms': 3,
#   'detailUrl': 'https://www.zillow.com/homedetails/1332-N-Leavitt-St-Chicago-IL-60622/87708188_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/dfe030e612f21ceefc9edc40d96d0847-p_e.jpg',
#   'longitude': -87.68258,
#   'latitude': 41.905933,
#   'description': 'Located in the heart of Wicker Park, Ukrainian Village this modern and clean two story, all brick home offers a buyer seeking to get into the area tons of equity upside and should not be overlooked! The home is situated on a tree lined street and has tons of charm, as you enter you will fall in love with the higher ceilings and natural sun that flows into the formal living room. The kitchen is very spacious with room for a breakfast area/dining room, add an island with modern cabinets and watch your equity soar! The second floor features three great sized bedrooms nice clean bathroom, fresh paint and new carpet will make a world of difference again while creating more equity. The basement is finished with a family room and second bathroom, there is a 2 car garage and the location is hard to beat! Being in the middle of Division and North Ave, blocks from Milwaukee and minutes from the Dan Ryan, this home is truly centrally located! Value add oppertunity such as this does not arise often in the Wicker Park community  so we know this one will not last long!',
#   'resoFacts': {'hasGarage': True,
#    'hasPetsAllowed': None,
#    'heating': ['Natural Gas'],
#    'cooling': ['Central Air'],
#    'flooring': None,
#    'appliances': None,
#    'laundryFeatures': None,
#    'associationFee': None,
#    'livingArea': None,
#    'taxAnnualAmount': 13703,
#    'parkingFeatures': ['Garage'],
#    'stories': 2},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/986-De-Diego-Elementary-Community-Academy/',
#     'rating': 4,
#     'totalCount': None,
#     'distance': 0.1,
#     'assigned': None,
#     'name': 'De Diego Elementary Community Academy',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1342-Clemente-Community-Academy-High-School/',
#     'rating': 1,
#     'totalCount': None,
#     'distance': 0.3,
#     'assigned': None,
#     'name': 'Clemente Community Academy High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'High',
#     'grades': '9-12',
#     'type': 'Public'}],
#   'restaurant_1': {'business_name': 'Janellie’s Kitchen',
#    'categories_titles': ['Puerto Rican'],
#    'rating': 5.0,
#    'latitude': 41.90281613454157,
#    'longitude': -87.69265859457461,
#    'display_address': '2617 W Division St Chicago, IL 60622',
#    'url': 'https://www.yelp.com/biz/janellie-s-kitchen-chicago-2?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'restaurant_2': {'business_name': 'Healthy Substance Cantina',
#    'categories_titles': ['Vegan'],
#    'rating': 5.0,
#    'latitude': 41.908631,
#    'longitude': -87.675257,
#    'display_address': '1480 N Milwaukee Ave Chicago, IL 60622',
#    'url': 'https://www.yelp.com/biz/healthy-substance-cantina-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'neighborhood': 'Wicker Park',
#   'neighborhood_description': 'Wicker Park and Bucktown are lively, artsy neighborhoods known for their vibrant cultural scene. These areas are bustling with trendy restaurants, unique shops, cocktail bars, and indie music venues. Highlights include The Violet Hour, a pioneering craft cocktail bar, and Subterranean, a popular music venue. The neighborhoods are also famous for their "Six Corners" shopping district, filled with vintage stores, bookshops, and cafes. This area is a hub for creativity and nightlife, making it a favorite among locals and visitors alike.'},
#  {'propertyType': 'CONDO',
#   'address': '159 E Walton Pl APT 12D, Chicago, IL 60611',
#   'price': 749000,
#   'bedrooms': 2,
#   'bathrooms': 3,
#   'detailUrl': 'https://www.zillow.com/homedetails/159-E-Walton-Pl-APT-12D-Chicago-IL-60611/80858288_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/5cc780c53579c196e8b7bf404c26514d-p_e.jpg',
#   'longitude': -87.6235,
#   'latitude': 41.89977,
#   'description': 'Incredible southeast corner split 2 bedroom 2.5 bathroom at The Palmolive. Nearly 10 ft ceilings, gourmet kitchen with high end appliances such as Wolf, SubZero and Miele appliances. Incredible price and 1 valet parking spot included.  This tastefully decorated unit also has western exposures from the primary bedroom. Enter the double door entrance into a gracious foyer and you will feel like you are home the minute you walk in.  Hardwood floors throughout, Kalista water fixtures, freshly painted as well as wall coverings in other areas of the unit make this an enticing unit within the building. 24 hour door staff, on site engineer that lives in the building, on-site manager and concierge all here at your fingertips which makes this one of the best high end luxury builidings in the city! A must see.',
#   'resoFacts': {'hasGarage': True,
#    'hasPetsAllowed': True,
#    'heating': ['Forced Air'],
#    'cooling': ['Central Air'],
#    'flooring': ['Hardwood'],
#    'appliances': ['Range',
#     'Microwave',
#     'Dishwasher',
#     'Refrigerator',
#     'High End Refrigerator',
#     'Freezer',
#     'Washer',
#     'Dryer',
#     'Disposal',
#     'Wine Refrigerator'],
#    'laundryFeatures': ['In Unit',
#     'First Floor Laundry',
#     'Laundry Hook-Up in Unit'],
#    'associationFee': '$1,809 monthly',
#    'livingArea': '1,529 sqft',
#    'taxAnnualAmount': 14156,
#    'parkingFeatures': ['Garage - Attached'],
#    'stories': None},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1270-Ogden-Elementary-School/',
#     'rating': 5,
#     'totalCount': None,
#     'distance': 0.3,
#     'assigned': None,
#     'name': 'Ogden Elementary School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1425-Wells-Community-Academy-High-School/',
#     'rating': 1,
#     'totalCount': None,
#     'distance': 2.3,
#     'assigned': None,
#     'name': 'Wells Community Academy High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'High',
#     'grades': '9-12',
#     'type': 'Public'}],
#   'restaurant_1': {'business_name': 'Gold Coast Market',
#    'categories_titles': ['Tobacco Shops', 'Beer, Wine & Spirits', 'Delis'],
#    'rating': 5.0,
#    'latitude': 41.89651,
#    'longitude': -87.630544,
#    'display_address': '71 W Chicago Ave Chicago, IL 60654',
#    'url': 'https://www.yelp.com/biz/gold-coast-market-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'restaurant_2': {'business_name': 'FARE -Northwestern Memorial Hospital',
#    'categories_titles': ['New American',
#     'Breakfast & Brunch',
#     'Juice Bars & Smoothies'],
#    'rating': 5.0,
#    'latitude': 41.8948648,
#    'longitude': -87.62139719999999,
#    'display_address': '251 East Huron St Chicago, IL 60611',
#    'url': 'https://www.yelp.com/biz/fare-northwestern-memorial-hospital-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'neighborhood': 'Streeterville',
#   'neighborhood_description': 'Streeterville is a bustling area celebrated for its tourist attractions, including the famous Navy Pier, and cultural sites like the Museum of Contemporary Art. It’s known for its dynamic mix of shopping, dining, and entertainment options right by Lake Michigan. The neighborhood is also home to several prestigious hotels and institutions, offering vibrant nightlife and various recreational activities on the lakefront, making it a key destination for both visitors and locals.'}]

# %%
# For additional question, use get_chat_response, not pp_chatbot
user_query = "Can you tell me more about the house in Kenwood?"
print(get_chat_response(chat, user_query))
# Out:
# ## Unveiling the Details of the Kenwood Home: A Comprehensive Look
#
# The single-family home in Kenwood presents a perfect blend of modern elegance and cozy comfort, providing a welcoming retreat for residents. Let's delve into the details of this inviting abode:
#
# **Layout and Amenities:**
#
# * **Spaciousness:** The home boasts three bedrooms and four bathrooms, offering ample space for families or individuals who desire a spacious living environment.
# * **Sunken Family Room:** This unique feature adds a touch of whimsy and intimacy to the living area, creating a cozy space for movie nights or family gatherings.
# * **Balcony:** Enjoy the fresh air and stunning city views from your private balcony, perfect for relaxing evenings or morning coffee breaks.
# * **Finished Basement:** The finished basement adds valuable living space to the home, ideal for a home theater, playroom, or guest suite.
# * **Kitchen Delight:** The chef's dream kitchen features abundant maple cabinetry, granite countertops, a walk-in pantry, and high-end stainless steel appliances.
# * **Laundry Convenience:** Conveniently located on the second floor, the laundry area makes chores a breeze, eliminating the need to haul laundry up and down stairs.
# * **Garage and Parking:** Enjoy the security and convenience of a two-car attached garage along with guest parking, ensuring ample space for your vehicles.
# * **Guest Parking:** Extra parking available directly behind the garage for guests visiting your beautiful home.
# * **Central Air and Heating:** The home is equipped with central air conditioning and heating systems, ensuring year-round comfort regardless of the season.
# * **Forced Air and Natural Gas:** These efficient systems provide reliable heating and cooling for the home.
# * **Hardwood Flooring and High Ceilings:** These features add a touch of elegance and spaciousness to the living areas.
# * **Updated Appliances:** The kitchen and laundry room boast modern appliances for enhanced convenience and functionality.
#
# **Neighborhood Perks:**
#
# The Kenwood home is strategically located amidst a vibrant and diverse neighborhood offering a plethora of amenities and entertainment options:
#
# * **Public Transportation:** With the 51st St. Metra station just a quick walk away, commuting to downtown Chicago becomes a breeze.
# * **Lakefront Access:** Residents enjoy easy access to the lakefront and its scenic walking paths, perfect for leisurely strolls or invigorating bike rides.
# * **University of Chicago Proximity:** Located just a short commute away, the University of Chicago offers cultural events, educational opportunities, and access to its renowned campus.
# * **Kenwood Community:** The neighborhood's friendly and engaged community fosters a welcoming atmosphere for newcomers and longstanding residents alike.
#
# **Additional Information:**
#
# * **Price:** $825,000
# * **Property Type:** Single Family
# * **Address:** 4922P S Cornell Ave, Chicago, IL 60615
# * **Photos:** https://photos.zillowstatic.com/fp/6c85ab0c974c11627d33d83701c78839-p_e.jpg
# * **More Information:** https://www.zillow.com/homedetails/4922P-S-Cornell-Ave-Chicago-IL-60615/350418760_zpid/
#
# If you desire a spacious and stylish home in a vibrant Chicago neighborhood, this Kenwood single-family home stands as a compelling option worth exploring further. Let me know if you have any specific questions or if there's any additional information you would like to uncover about this property.

# %%
user_query = "Which neighborhood is the first property located in? Tell me more about that neighborhood."
print(get_chat_response(chat, user_query))
# Out:
# ## Kenwood: A Haven of History and Tranquility
#
# The first property you mentioned is located in the Kenwood neighborhood, a beautiful and historic enclave nestled alongside Lake Michigan in Chicago. Renowned for its architectural diversity and serene atmosphere, Kenwood presents a unique blend of urban convenience and suburban charm. Let's delve deeper into the essence of this captivating neighborhood:
#
# **A Tapestry of Architectural Gems:**
#
# Kenwood is a treasure trove for architecture enthusiasts, with an array of architectural styles gracing its streets. From stately mansions reminiscent of a bygone era to contemporary homes boasting modern designs, the neighborhood showcases a rich tapestry of architectural expressions. Among the notable structures are the impressive Powhatan Apartments, a testament to Art Deco elegance, and the Hyde Park–Kenwood Historic District, where history unfolds through its diverse collection of architectural marvels.
#
# **A Legacy of Prominent Residents:**
#
# Kenwood's allure goes beyond its architectural splendor. The neighborhood has long been associated with prominent figures who left an indelible mark on society. The legendary blues artist Muddy Waters once called Kenwood home, and former President Barack Obama chose this neighborhood as his residence during his tenure in the U.S. Senate. Their presence adds to the rich cultural tapestry of Kenwood, making it a place where history and contemporary life intertwine.
#
# **Guided Tours and Architectural Appreciation:**
#
# To further enhance your experience of Kenwood's architectural wonders, guided tours are available. These tours offer fascinating insights into the neighborhood's history, architectural styles, and iconic structures. By participating in these tours, you can gain a deeper appreciation for the neighborhood's unique character and architectural heritage.
#
# **A Short Walk to the Heart of Kenwood:**
#
# Conveniently located just a short walk from the first property, you'll find yourself immersed in the heart of Kenwood. Here, you can explore the vibrant shops, savor delectable culinary delights, and experience the neighborhood's cultural richness.
#
# **Additional Resources:**
#
# To further explore Kenwood, I recommend the following resources:
#
# * **Kenwood Historical Society:** https://kenwoodhistoricalsociety.org/
# * **Chicago Architecture Center:** https://www.architecture.org/
# * **Explore Chicago:** https://www.choosechicago.com/neighborhoods/kenwood/
#
# Kenwood awaits, offering a unique blend of history, architectural beauty, and urban convenience. I encourage you to visit and discover the charm that makes Kenwood a truly special place.

# %%
user_query = "What are some good schools nearby the first property?"
print(get_chat_response(chat, user_query))
# Out:
# ## Exploring Educational Opportunities near the First Property in Kenwood
#
# The neighborhood surrounding the first property is fortunate to have a variety of reputable educational options catering to different age groups and educational philosophies. Let's delve into some of the notable schools in close proximity:
#
# **Elementary Schools:**
#
# * **Shoesmith Elementary School:** Located just 0.3 miles from the property, Shoesmith Elementary School boasts an impressive GreatSchools rating of 5 stars. This high-performing public school is renowned for its nurturing learning environment and dedicated teachers who strive to ignite a passion for learning in their young students.
#
# **Middle Schools:**
#
# * **Kenwood Academy High School:** Nestled within a walking distance of 0.2 miles, Kenwood Academy High School is a public school consistently ranked among the top middle schools in the city. With its strong academic programs, diverse extracurricular activities, and emphasis on fostering well-rounded individuals, Kenwood Academy promises a stimulating and rewarding educational experience.
#
# **High Schools:**
#
# * **Kenwood Academy High School:** Continuing its excellence into the high school level, Kenwood Academy offers a challenging and engaging academic curriculum. With a focus on preparing its students for college success and global citizenship, Kenwood Academy is an outstanding option for high school education in the vicinity.
#
# **Private School Alternatives:**
#
# * **University of Chicago Laboratory Schools:** For parents seeking a private school environment, the University of Chicago Laboratory Schools provide an exceptional option. With campuses located within a convenient distance of the property, these renowned schools offer rigorous academics, diverse programs, and a commitment to fostering intellectual curiosity and growth in students.
#
# **Additional Resources for School Information:**
#
# * **GreatSchools:** https://www.greatschools.org/illinois/chicago/
# * **Chicago Public Schools:** https://www.cps.edu/
# * **University of Chicago Laboratory Schools:** https://laborschicago.org/
#
# Remember, selecting the "right" school depends largely on your individual needs and preferences. Consider factors like educational philosophy, curriculum offerings, extracurricular activities, and transportation access when choosing the ideal educational environment for your child.
#
# I hope this information proves helpful as you explore the educational landscape surrounding the first property. Feel free to ask if you have any further questions or require more specific details about any particular school.

# %%
user_query = "I am interested in the first property. Should I buy it or rent it ?"
print(get_chat_response(chat, user_query))
# Out:
# ## Assessing the Pros and Cons of Buying vs. Renting the First Property
#
# Deciding between buying and renting the first property involves careful consideration of numerous factors that align with your individual needs, financial circumstances, and future goals. Here's a breakdown of the potential advantages and disadvantages of both options to help guide your decision-making process:
#
# **Buying the First Property:**
#
# **Pros:**
#
# * **Building Equity:** As you pay down the mortgage, you accumulate equity in the property, increasing its value over time.
# * **Property Appreciation:** Over the long term, real estate values often appreciate, which could result in a significant financial gain when you sell the property.
# * **Sense of Ownership and Control:** Homeownership provides you with a sense of stability and control over your living environment. You can customize the property to your liking and make long-term improvements without constraints.
# * **Tax Benefits:** Homeowners enjoy certain tax advantages, such as deductions for mortgage interest and property taxes.
#
# **Cons:**
#
# * **Significant Upfront Investment:** A down payment is typically required for purchases, along with additional costs like closing fees and moving expenses.
# * **Financial Responsibility:** Homeowners are responsible for maintenance, repairs, property taxes, and insurance costs.
# * **Less Flexibility:** Homeownership implies less flexibility, making it more challenging to relocate on short notice.
# * **Potential Market Fluctuations:** Property values can fluctuate, presenting a risk of financial loss if you need to sell during a downturn.
#
# **Renting the First Property:**
#
# **Pros:**
#
# * **Lower Upfront Costs:** No down payment or large upfront investment is required when renting.
# * **Predictable Monthly Expenses:** Rent, utilities, and other living expenses are typically constant, simplifying budgeting.
# * **Greater Flexibility:** Renting offers more flexibility to relocate for work or life changes without needing to sell the property.
# * **Lower Maintenance Responsibility:** Renters are generally not responsible for significant repairs or major maintenance issues.
#
# **Cons:**
#
# * **No Equity Building:** Rent payments do not build equity, meaning you're essentially paying for temporary housing.
# * **Potential Rent Increases:** Landlords can raise rent over time, requiring adjustments to your budget.
# * **Less Control over Living Environment:** Renters typically have limited ability to customize the property or make lasting changes.
# * **Landlord-Tenant Dynamics:** Interactions with landlords and potential issues associated with property management must be factored in.
#
# Ultimately, the decision of whether to buy or rent depends on your individual circumstances and priorities. If you value long-term investment, stability, and customization, buying the first property emerges as a strong option. However, if flexibility, lower upfront costs, and convenience are your primary concerns, renting might be the better choice.
#
# Carefully weigh the pros and cons of both options, assess your financial standing and future plans, and don't hesitate to seek advice from financial professionals or real estate experts to reach a confident decision that aligns with your best interests.

# %%
user_query = "What restaurants are nearby the first property? Please provide me with the yelp link"
print(get_chat_response(chat, user_query))
# Out:
# ## Culinary Delights Await near the First Property
#
# The first property in Kenwood is fortunate to be surrounded by an array of diverse and delectable culinary experiences, offering a delightful range of flavors, cuisines, and ambiances. Here are some of the notable restaurants you'll find just a stone's throw away, along with their corresponding Yelp links for further exploration:
#
# **Capital One Café:**
#
# * Distance from property: Approximately 1.2 miles
# * Cuisine: Cafes
# * Yelp link: https://www.yelp.com/biz/capital-one-café-chicago-6?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A
# * This charming café, located within 15 minutes walking distance, offers a cozy atmosphere perfect for enjoying a cup of freshly brewed coffee, indulging in a delicious pastry, or savoring a light lunch.
#
# **Gorée Cuisine:**
#
# * Distance from property: Approximately 1.5 miles
# * Cuisine: Senegalese, Caterers
# * Yelp link: https://www.yelp.com/biz/gor%C3%A9e-cuisine-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A
# * For a taste of authentic Senegalese cuisine, Gorée Cuisine stands as a culinary gem within easy reach. Their flavorful dishes offer a unique cultural immersion, transporting you with every bite to the vibrant flavors of West Africa.
#
# Additional nearby restaurants worth considering include:
#
# 1. Cafe 53rd:** https://www.yelp.com/biz/cafe-53rd-chicago
# 2. Medici on 57th:** https://www.yelp.com/biz/medici-on-57th-chicago-5
# 3. Harper Court:** https://www.yelp.com/biz/harper-court-chicago
# 4. Kimski:** https://www.yelp.com/biz/kimski-chicago
# 5. The Promontory:** https://www.yelp.com/biz/the-promontory-chicago
#
# This array of diverse and enticing options ensures that your culinary cravings will always be satisfied when residing in the vicinity of the first property. From quick coffee stops to immersive cultural dining experiences, the neighborhood presents a delicious tapestry of flavors just waiting to be explored.
#
# Feel free to ask if you'd like recommendations for specific types of cuisine or a more in-depth dive into the offerings of any particular restaurant. Happy exploring!

# %%
top_properties
# Out:
# [{'propertyType': 'SINGLE_FAMILY',
#   'address': '4922P S Cornell Ave, Chicago, IL 60615',
#   'price': 825000,
#   'bedrooms': 3,
#   'bathrooms': 4,
#   'detailUrl': 'https://www.zillow.com/homedetails/4922P-S-Cornell-Ave-Chicago-IL-60615/350418760_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/6c85ab0c974c11627d33d83701c78839-p_e.jpg',
#   'longitude': -87.5879,
#   'latitude': 41.806026,
#   'description': "Unit P, Welcome to one of Cornell Square's highly desired EXTRA wide single family home. Step into this stunning home's main level featuring a charming foyer and steps leading down to the sunken family room, perfect for cozy family movie nights or easily convertible to a 4th bedroom if needed. The foyer and family room boast rare heated flooring and built-in surround sound speakers, with additional speakers installed in every room throughout the home. A convenient half bath is located on this level, just before the two-car attached garage. Ascending to the 2nd floor, you'll experience the spaciousness with the home's width and light-filled ambiance of this home. High ceilings and abundant windows create a bright and open feel. The enormous living room features a gas fireplace and opens to the dining room. The kitchen is a chef's dream, with an abundance of maple cabinetry, granite countertops, and a walk-in pantry. Another half bath is conveniently located on this level along with an ideal balcony just off the kitchen perfect for grilling. The top floor offers 3 spacious bedrooms, 2 full baths, and a laundry area. Each room is flooded with sunlight and offers ample closet space. The primary suite boasts cathedral ceilings, adding a dramatic flair to the space. The primary bathroom has a separate shower and tub along with a double vanity and lovely natural light from the skylight. Many upgrades have been completed by these long time owners with a complete new roof installed in Oct/2023 with added attic insulation (2021), a new oven/microwave (2023), and replaced most other mechanicals. The entire home was JUST painted and ready for it's new owner! There is included guest parking available directly behind the garages for 2 cars perfect for guests! This home is ideally located with a very short walk down Cornell to the 51st St. Metra station, offering a quick trip downtown. Enjoy great bus access to the University of Chicago and express buses to downtown, as well as super easy walk/bike access to the lakefront and paths north and south. This is a VERY special home! *** Interior photos coming on Thursday, May 23rd and first showings will be Wednesday May 22nd. This one should go very quickly....",
#   'resoFacts': {'hasGarage': True,
#    'hasPetsAllowed': None,
#    'heating': ['Forced Air'],
#    'cooling': ['Central Air'],
#    'flooring': ['Hardwood'],
#    'appliances': ['Range',
#     'Microwave',
#     'Dishwasher',
#     'Refrigerator',
#     'Washer',
#     'Dryer',
#     'Stainless Steel Appliance(s)'],
#    'laundryFeatures': ['In Unit', 'Laundry Closet', 'Second Floor Laundry'],
#    'associationFee': '$295 monthly',
#    'livingArea': None,
#    'taxAnnualAmount': 15593,
#    'parkingFeatures': ['None'],
#    'stories': 3},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1348-Shoesmith-Elementary-School/',
#     'rating': 5,
#     'totalCount': None,
#     'distance': 0.3,
#     'assigned': None,
#     'name': 'Shoesmith Elementary School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Elementary',
#     'grades': 'K-6',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1205-Kenwood-Academy-High-School/',
#     'rating': 7,
#     'totalCount': None,
#     'distance': 0.2,
#     'assigned': None,
#     'name': 'Kenwood Academy High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Middle',
#     'grades': '7-12',
#     'type': 'Public'}],
#   'restaurant_1': {'business_name': 'Capital One Café',
#    'categories_titles': ['Cafes'],
#    'rating': 4.7,
#    'latitude': 41.7994057,
#    'longitude': -87.5892372,
#    'display_address': '1465 E 53rd St Chicago, IL 60615',
#    'url': 'https://www.yelp.com/biz/capital-one-caf%C3%A9-chicago-6?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'restaurant_2': {'business_name': 'Gorée Cuisine',
#    'categories_titles': ['Senegalese', 'Caterers'],
#    'rating': 4.6,
#    'latitude': 41.8097706381699,
#    'longitude': -87.59817392478504,
#    'display_address': '1126 E 47th St Chicago, IL 60653',
#    'url': 'https://www.yelp.com/biz/gor%C3%A9e-cuisine-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'neighborhood': 'Kenwood',
#   'neighborhood_description': "Kenwood is an architectural haven, boasting a unique mix of 19th-century mansions and contemporary homes, providing a suburban feel within an urban setting. It's known for its lush landscapes and historical significance with landmarks like the Powhatan Apartments and the Hyde Park–Kenwood Historic District. Formerly home to prominent figures like Muddy Waters and Barack Obama, Kenwood offers guided architecture tours, showcasing its rich history and stunning designs."},
#  {'propertyType': 'SINGLE_FAMILY',
#   'address': '1332 N Leavitt St, Chicago, IL 60622',
#   'price': 725000,
#   'bedrooms': 3,
#   'bathrooms': 3,
#   'detailUrl': 'https://www.zillow.com/homedetails/1332-N-Leavitt-St-Chicago-IL-60622/87708188_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/dfe030e612f21ceefc9edc40d96d0847-p_e.jpg',
#   'longitude': -87.68258,
#   'latitude': 41.905933,
#   'description': 'Located in the heart of Wicker Park, Ukrainian Village this modern and clean two story, all brick home offers a buyer seeking to get into the area tons of equity upside and should not be overlooked! The home is situated on a tree lined street and has tons of charm, as you enter you will fall in love with the higher ceilings and natural sun that flows into the formal living room. The kitchen is very spacious with room for a breakfast area/dining room, add an island with modern cabinets and watch your equity soar! The second floor features three great sized bedrooms nice clean bathroom, fresh paint and new carpet will make a world of difference again while creating more equity. The basement is finished with a family room and second bathroom, there is a 2 car garage and the location is hard to beat! Being in the middle of Division and North Ave, blocks from Milwaukee and minutes from the Dan Ryan, this home is truly centrally located! Value add oppertunity such as this does not arise often in the Wicker Park community  so we know this one will not last long!',
#   'resoFacts': {'hasGarage': True,
#    'hasPetsAllowed': None,
#    'heating': ['Natural Gas'],
#    'cooling': ['Central Air'],
#    'flooring': None,
#    'appliances': None,
#    'laundryFeatures': None,
#    'associationFee': None,
#    'livingArea': None,
#    'taxAnnualAmount': 13703,
#    'parkingFeatures': ['Garage'],
#    'stories': 2},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/986-De-Diego-Elementary-Community-Academy/',
#     'rating': 4,
#     'totalCount': None,
#     'distance': 0.1,
#     'assigned': None,
#     'name': 'De Diego Elementary Community Academy',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1342-Clemente-Community-Academy-High-School/',
#     'rating': 1,
#     'totalCount': None,
#     'distance': 0.3,
#     'assigned': None,
#     'name': 'Clemente Community Academy High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'High',
#     'grades': '9-12',
#     'type': 'Public'}],
#   'restaurant_1': {'business_name': 'Janellie’s Kitchen',
#    'categories_titles': ['Puerto Rican'],
#    'rating': 5.0,
#    'latitude': 41.90281613454157,
#    'longitude': -87.69265859457461,
#    'display_address': '2617 W Division St Chicago, IL 60622',
#    'url': 'https://www.yelp.com/biz/janellie-s-kitchen-chicago-2?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'restaurant_2': {'business_name': 'Healthy Substance Cantina',
#    'categories_titles': ['Vegan'],
#    'rating': 5.0,
#    'latitude': 41.908631,
#    'longitude': -87.675257,
#    'display_address': '1480 N Milwaukee Ave Chicago, IL 60622',
#    'url': 'https://www.yelp.com/biz/healthy-substance-cantina-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'neighborhood': 'Wicker Park',
#   'neighborhood_description': 'Wicker Park and Bucktown are lively, artsy neighborhoods known for their vibrant cultural scene. These areas are bustling with trendy restaurants, unique shops, cocktail bars, and indie music venues. Highlights include The Violet Hour, a pioneering craft cocktail bar, and Subterranean, a popular music venue. The neighborhoods are also famous for their "Six Corners" shopping district, filled with vintage stores, bookshops, and cafes. This area is a hub for creativity and nightlife, making it a favorite among locals and visitors alike.'},
#  {'propertyType': 'CONDO',
#   'address': '159 E Walton Pl APT 12D, Chicago, IL 60611',
#   'price': 749000,
#   'bedrooms': 2,
#   'bathrooms': 3,
#   'detailUrl': 'https://www.zillow.com/homedetails/159-E-Walton-Pl-APT-12D-Chicago-IL-60611/80858288_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/5cc780c53579c196e8b7bf404c26514d-p_e.jpg',
#   'longitude': -87.6235,
#   'latitude': 41.89977,
#   'description': 'Incredible southeast corner split 2 bedroom 2.5 bathroom at The Palmolive. Nearly 10 ft ceilings, gourmet kitchen with high end appliances such as Wolf, SubZero and Miele appliances. Incredible price and 1 valet parking spot included.  This tastefully decorated unit also has western exposures from the primary bedroom. Enter the double door entrance into a gracious foyer and you will feel like you are home the minute you walk in.  Hardwood floors throughout, Kalista water fixtures, freshly painted as well as wall coverings in other areas of the unit make this an enticing unit within the building. 24 hour door staff, on site engineer that lives in the building, on-site manager and concierge all here at your fingertips which makes this one of the best high end luxury builidings in the city! A must see.',
#   'resoFacts': {'hasGarage': True,
#    'hasPetsAllowed': True,
#    'heating': ['Forced Air'],
#    'cooling': ['Central Air'],
#    'flooring': ['Hardwood'],
#    'appliances': ['Range',
#     'Microwave',
#     'Dishwasher',
#     'Refrigerator',
#     'High End Refrigerator',
#     'Freezer',
#     'Washer',
#     'Dryer',
#     'Disposal',
#     'Wine Refrigerator'],
#    'laundryFeatures': ['In Unit',
#     'First Floor Laundry',
#     'Laundry Hook-Up in Unit'],
#    'associationFee': '$1,809 monthly',
#    'livingArea': '1,529 sqft',
#    'taxAnnualAmount': 14156,
#    'parkingFeatures': ['Garage - Attached'],
#    'stories': None},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1270-Ogden-Elementary-School/',
#     'rating': 5,
#     'totalCount': None,
#     'distance': 0.3,
#     'assigned': None,
#     'name': 'Ogden Elementary School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1425-Wells-Community-Academy-High-School/',
#     'rating': 1,
#     'totalCount': None,
#     'distance': 2.3,
#     'assigned': None,
#     'name': 'Wells Community Academy High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'High',
#     'grades': '9-12',
#     'type': 'Public'}],
#   'restaurant_1': {'business_name': 'Gold Coast Market',
#    'categories_titles': ['Tobacco Shops', 'Beer, Wine & Spirits', 'Delis'],
#    'rating': 5.0,
#    'latitude': 41.89651,
#    'longitude': -87.630544,
#    'display_address': '71 W Chicago Ave Chicago, IL 60654',
#    'url': 'https://www.yelp.com/biz/gold-coast-market-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'restaurant_2': {'business_name': 'FARE -Northwestern Memorial Hospital',
#    'categories_titles': ['New American',
#     'Breakfast & Brunch',
#     'Juice Bars & Smoothies'],
#    'rating': 5.0,
#    'latitude': 41.8948648,
#    'longitude': -87.62139719999999,
#    'display_address': '251 East Huron St Chicago, IL 60611',
#    'url': 'https://www.yelp.com/biz/fare-northwestern-memorial-hospital-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6Rl6qXMI6EN3VkijeNTf0A'},
#   'neighborhood': 'Streeterville',
#   'neighborhood_description': 'Streeterville is a bustling area celebrated for its tourist attractions, including the famous Navy Pier, and cultural sites like the Museum of Contemporary Art. It’s known for its dynamic mix of shopping, dining, and entertainment options right by Lake Michigan. The neighborhood is also home to several prestigious hotels and institutions, offering vibrant nightlife and various recreational activities on the lakefront, making it a key destination for both visitors and locals.'}]

# %% [markdown]
# ## Use case 2
# ### Initial query: Restaurant info

# %%
chat = model.start_chat()
# Test chat
# prompt = "Hello."
# print(get_chat_response(chat, prompt))

# %%
# For initial query, use pp_chatbot, not get_chat_response
user_query = "What are the top rated Indian restaurants on the north side of chicago?"
pp_chatbot(user_query)
# Out:
# Absolutely! Based on your query, here are some of the top-rated Indian restaurants on the north side of Chicago:
#
# 1. **Art of Indian Cuisine (4.9 stars):** This highly-rated gem offers authentic Indian dishes with a focus on fresh, seasonal ingredients. Reviewers rave about the flavorful curries, delectable tandoori dishes, and friendly service.
#
# 2. **Bhoomi Modern Indian Grill (4.7 stars):** This modern eatery boasts a sophisticated atmosphere and a menu featuring innovative takes on classic Indian cuisine. Enjoy plates like black truffle naan, lamb chops, and creative vegetarian options.
#
# 3. **Krishna Lunch (4.7 stars):** This vegetarian lunch spot is a haven for those seeking flavorful and affordable Indian fare. The menu changes daily, offering a variety of curries, rice dishes, and fresh salads.
#
# 4. **Apna Indian Grill (4.6 stars):** This casual eatery offers a wide range of classic Indian dishes, from curries and biryanis to tandoori specialties. The portions are generous, and the prices are reasonable, making it a popular choice for locals and visitors alike.
#
# 5. **Indian Paradise (4.6 stars):** This family-owned restaurant serves up authentic North Indian cuisine in a warm and welcoming atmosphere. The menu features a variety of curries, kebabs, and vegetarian options, all prepared with fresh ingredients and traditional spices.
#
# These are just a few of the many fantastic Indian restaurants on the north side of Chicago. I recommend checking out online reviews and menus to find the perfect spot for your taste and budget.
#
# **Additional Tips:**
#
# * Consider the type of Indian cuisine you're in the mood for. Do you prefer North Indian, South Indian, or a fusion of styles?
# * Read online reviews to get insights into the atmosphere, service, and food quality.
# * Check for lunch specials or happy hour deals to save some money.
# * Make reservations if you're dining during peak hours, especially on weekends.
# * Don't be afraid to ask the staff for recommendations based on your preferences.
#
# I hope this helps you find the perfect Indian dining experience in Chicago!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa61cc977c12a02c9bd652c8ee2f6140 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa61cc977c12a02c9bd652c8ee2f6140&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa61cc977c12a02c9bd652c8ee2f6140 = L.map(
#                 &quot;map_fa61cc977c12a02c9bd652c8ee2f6140&quot;,
#                 {
#                     center: [41.881832, -87.623177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eec4fa82593eaddbc78518a9fc354632 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eec4fa82593eaddbc78518a9fc354632.addTo(map_fa61cc977c12a02c9bd652c8ee2f6140);
#
#
#             var marker_aac3adf5034326f4c56e5ff5f56e418e = L.marker(
#                 [41.93005710426521, -87.64369264864928],
#                 {}
#             ).addTo(map_fa61cc977c12a02c9bd652c8ee2f6140);
#
#
#             var icon_eab447d7b33888387b86ae31fbd3f521 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_aac3adf5034326f4c56e5ff5f56e418e.setIcon(icon_eab447d7b33888387b86ae31fbd3f521);
#
#
#         var popup_4b453800958cbb96c0f5ac74a50af9b3 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_ba0ee68d3dfaec966dd866feabe1d32a = $(`&lt;div id=&quot;html_ba0ee68d3dfaec966dd866feabe1d32a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.yelp.com/biz/art-of-indian-cuisine-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&amp;utm_campaign=yelp_api_v3&amp;utm_medium=api_v3_business_search&amp;utm_source=6Rl6qXMI6EN3VkijeNTf0A&quot; target=&quot;_blank&quot;&gt;Art of Indian Cuisine&lt;/a&gt;&lt;br/&gt;Indian&lt;br/&gt;Rating: 4.9&lt;br/&gt;2616 N Clark St, Chicago, IL 60614&lt;/div&gt;`)[0];
#                 popup_4b453800958cbb96c0f5ac74a50af9b3.setContent(html_ba0ee68d3dfaec966dd866feabe1d32a);
#
#
#
#         marker_aac3adf5034326f4c56e5ff5f56e418e.bindPopup(popup_4b453800958cbb96c0f5ac74a50af9b3)
#         ;
#
#
#
#
#             marker_aac3adf5034326f4c56e5ff5f56e418e.bindTooltip(
#                 `&lt;div&gt;
#                      Click for details on Art of Indian Cuisine
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_051853eb0214c96fef32dc133976c826 = L.marker(
#                 [41.8831, -87.62868],
#                 {}
#             ).addTo(map_fa61cc977c12a02c9bd652c8ee2f6140);
#
#
#             var icon_9c3e615aed205acc8ba1b33fde1aa932 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_051853eb0214c96fef32dc133976c826.setIcon(icon_9c3e615aed205acc8ba1b33fde1aa932);
#
#
#         var popup_966118682b8a86d8f7e14df6e6f7ca1e = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_1f38bf13763bbe7ff9924adf9cd8e6b4 = $(`&lt;div id=&quot;html_1f38bf13763bbe7ff9924adf9cd8e6b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.yelp.com/biz/bhoomi-modern-indian-grill-chicago?adjust_creative=6Rl6qXMI6EN3VkijeNTf0A&amp;utm_campaign=yelp_api_v3&amp;utm_medium=api_v3_business_search&amp;utm_source=6Rl6qXMI6EN3VkijeNTf0A&quot; target=&quot;_blank&quot;&gt;Bhoomi Modern Indian Grill&lt;/a&gt;&lt;br/&gt;Indian&lt;br/&gt;Rating: 4.7&lt;br/&gt;15 W Washington St, Chicago, IL 60602&lt;/div&gt;`)[0];
#                 popup_966118682b8a86d8f7e14df6e6f7ca1e.setContent(html_1f38bf13763bbe7ff9924adf9cd8e6b4);
#
#
#
#         marker_051853eb0214c96fef32dc133976c826.bindPopup(popup_966118682b8a86d8f7e14df6e6f7ca1e)
#         ;
#
#
#
#
#             marker_051853eb0214c96fef32dc133976c826.bindTooltip(
#                 `&lt;div&gt;
#                      Click for details on Bhoomi Modern Indian Grill
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d308351d0a3618027b3e275a6811dcc7 = L.marker(
#                 [41.8847802267723, -87.6199700908582],
#                 {}
#             ).addTo(map_fa61cc977c12a02c9bd652c8ee2f6140);
#
#
#             var icon_ce153df5ba539330fd40ec0d56d1526a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &qu

# %%
# For additional question, use get_chat_response, not pp_chatbot
user_query = "Which of these restaurants are budget-friendly?"
print(get_chat_response(chat, user_query))
# Out:
# ## Budget-Friendly Indian Restaurants on the North Side
#
# While all the restaurants I recommended have reasonable prices for their quality, here's a breakdown based on online information and reviews:
#
# **Most Budget-Friendly:**
#
# * **Krishna Lunch:** This vegetarian spot is known for its incredibly affordable lunch buffets, starting at around $10. You can also get individual dishes for under $10.
# * **Apna Indian Grill:** This casual eatery offers generous portions at reasonable prices. Most dishes are priced between $10-$15.
#
# **Moderately Priced:**
#
# * **Art of Indian Cuisine:** While offering high-quality ingredients, this restaurant has a slightly higher price range. Most entrees fall between $15-$25.
# * **Bhoomi Modern Indian Grill:** This modern restaurant has a contemporary atmosphere and slightly higher price point than the others. Entrees typically range from $20-$35.
# * **Indian Paradise:** This family-owned restaurant offers a good value for its authentic North Indian dishes. Most entrees fall between $15-$20.
#
# **Additional Tips for Finding Budget-Friendly Indian Restaurants:**
#
# * **Check online menus or restaurant websites:** Look for lunch specials, happy hour deals, or value sets.
# * **Read online reviews:** Look for comments mentioning affordability, value for money, or budget-friendly options.
# * **Consider smaller, less centrally located restaurants:** These can often offer lower prices while maintaining high quality.
# * **Ask about lunch specials and happy hour deals:** Many restaurants offer discounted prices during these times.
# * **Utilize delivery apps and websites:** They often have promotions and discounts for various restaurants.
#
# Remember, "budget-friendly" is relative and depends on your individual budget. I encourage you to research the menus and prices of these restaurants to determine which best suits your needs.

# %%
# For additional question, use get_chat_response, not pp_chatbot
user_query = "Could you provide me a link to Bhoomi Modern Indian Grill's menu?"
print(get_chat_response(chat, user_query))
# Out:
# ## Bhoomi Modern Indian Grill Menu
#
# Here's the link to Bhoomi Modern Indian Grill's menu: https://www.eatbhoomi.com/menu
#
# Please note that online menus may not always be completely up-to-date, so it's always a good idea to call the restaurant directly for the most accurate information.

# %% [markdown]
# ## Use case 3
# ### Initial query: Neighborhood info

# %%
chat = model.start_chat()

# %%
# For initial query, use pp_chatbot, not get_chat_response
user_query = "What is the Hyde Park in Chicago like?"
pp_chatbot(user_query)
# Out:
# ## Hyde Park in Chicago: A Detailed Look
#
# Hyde Park is a vibrant neighborhood on the south side of Chicago, offering a unique blend of history, culture, and natural beauty. Here's a breakdown of its key features:
#
# **Things to Do**:
#
# * **Museums & Culture:** Hyde Park is home to the renowned University of Chicago and its associated museums, including the Oriental Institute Museum and the Smart Museum of Art. The neighborhood also boasts the iconic Museum of Science and Industry, a family-friendly destination with interactive exhibits and educational programs.
# * **Green Spaces:** Relax and unwind in the expansive Jackson Park, offering stunning views of Lake Michigan, walking trails, and the beautiful landscaped gardens. The park also houses the Museum of Science and Industry and the Osaka Garden, a traditional Japanese garden.
# * **Diverse Dining:** Hyde Park caters to a variety of palates with its wide selection of restaurants. From casual eateries and cafes to upscale dining options, there's something for everyone. Explore international flavors, enjoy local favorites, or grab a coffee and pastry at a cozy cafe.
#
# **Neighborhood Vibe:**
#
# * **Quiet and Residential:** Hyde Park boasts a peaceful and family-friendly atmosphere. It's a primarily residential neighborhood, with tree-lined streets and a mix of apartments and single-family homes.
# * **University Influence:** The University of Chicago's presence shapes the neighborhood's identity. Students, faculty, and researchers contribute to a lively intellectual atmosphere and a diverse population.
# * **Strong Community:** Hyde Park fosters a strong sense of community with active resident associations, local events, and a commitment to social justice.
#
# **Additional Points:**
#
# * **Transportation:** The neighborhood is well-connected by public transportation, including the CTA bus and Metra train lines.
# * **Education:** Hyde Park is home to several top-rated schools, including the University of Chicago Laboratory Schools and Kenwood Academy High School.
# * **Cost of Living:** Housing costs in Hyde Park are relatively high compared to other Chicago neighborhoods, reflecting the area's desirable location and amenities.
#
# **Overall, Hyde Park offers a unique blend of urban living and natural beauty, with a vibrant cultural scene and a strong sense of community. It's an ideal neighborhood for those seeking a peaceful environment with easy access to amenities and diverse cultural offerings.**

# %%
# For additional question, use get_chat_response, not pp_chatbot
user_query = "Tell me more about the neighborhood?"
print(get_chat_response(chat, user_query))
# Out:
# ## Delving Deeper into Hyde Park:
#
# While I've covered the main highlights of Hyde Park, there's always more to explore in this dynamic neighborhood. Here are some additional details:
#
# **History:**
#
# * Founded in 1853, Hyde Park boasts a rich history. Its development as a planned community was envisioned by Paul Cornell, who aimed to create a picturesque suburb with spacious lots, tree-lined streets, and a commitment to education and culture.
# * The arrival of the University of Chicago in 1892 significantly shaped the neighborhood. Its iconic campus architecture and academic reputation attracted intellectuals, artists, and scholars, contributing to Hyde Park's vibrant intellectual atmosphere.
# * Throughout the 20th century, Hyde Park played a pivotal role in social movements like the Civil Rights movement. Its diverse population and progressive values fueled activism and social change initiatives.
#
# **Architecture:**
#
# * Hyde Park showcases a diverse array of architectural styles, reflecting its long history and cultural influences. From the Gothic Revival buildings of the University of Chicago to the stately mansions and charming bungalows found throughout the neighborhood, each architectural detail tells a story.
# * Notably, Hyde Park boasts the largest collection of Prairie School architecture in the world, designed by renowned architects Louis Sullivan and Frank Lloyd Wright. These buildings are characterized by their horizontal lines, open floor plans, and integration with nature.
#
# **Culture:**
#
# * Hyde Park's cultural scene is as diverse as its population. The neighborhood hosts numerous music venues, theaters, art galleries, and independent bookstores, providing entertainment for all interests.
# * Hyde Park is home to multiple festivals throughout the year, including the Hyde Park Summer Fest, a week-long celebration with music, food, and family fun. The neighborhood also hosts the Chicago Jazz Festival, showcasing both local and international talent.
#
# **Unique Features:**
#
# * The 57th Street Art Fair: This annual event gathers over 200 artists from across the country, showcasing diverse artistic styles and mediums. It's a unique opportunity to interact with artists and acquire artwork directly.
# * 57th Street Books: This iconic bookstore, owned by Barack Obama's former chief of staff, is a local gem with a curated selection of books and a cafe offering a cozy space for bibliophiles.
# * The Oriental Institute: Explore ancient civilizations at this museum housing artifacts from Mesopotamia, Egypt, and Persia. Its interactive exhibits and guided tours bring history to life.
#
# **Remember, these are just some of the highlights. Exploring Hyde Park in person will allow you to truly experience its unique charm and discover hidden gems.**
