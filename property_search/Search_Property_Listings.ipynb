# %% [markdown]
# # Search Property Listings
# 1. Model Setting
# 2. Create API filter from user's query
# 3. Get Property Listings from Zillow API
# 4. Generate advice with the property listings

# %% [markdown]
# ## 1. Model Setting - Gemini pro 1.0

# %%
# %pip list | grep google-cloud-aiplatform
# %pip list | grep google-api-core

# %%
# %pip install google-cloud-aiplatform==1.43.0
# %pip install google-api-core==2.17.1

# %%
import vertexai
from vertexai.preview.generative_models import GenerativeModel, ChatSession, Part
import vertexai.preview.generative_models as generative_models

# %%
vertexai.init(project="adsp-capstone-property-pilot", location="us-central1")

# %%
model = GenerativeModel("gemini-1.0-pro")
chat = model.start_chat()

def get_chat_response(chat: ChatSession, prompt: str) -> str:
    text_response = []
    responses = chat.send_message(prompt, stream=True)
    for chunk in responses:
        text_response.append(chunk.text)
    return "".join(text_response)

# %% [markdown]
# ### Test

# %%
prompt = "Hello."
print(get_chat_response(chat, prompt))
# Out:
# Hello! I'm glad you're here. What can I do for you today?

# %% [markdown]
# ## 2. Create API filter from user's query

# %%
def generate_prompt_apifilter(instruction, user_query):
    return instruction.replace("{USER_QUERY}", user_query)

# %%
instruction = """
### Instructions ###
I want you to act as a principal software engineer. You'll be given a task to determine the parameters of an API call based on the "User's query" below, 
please modify the conditions and create the appropriate API filter. Provide your answer only for the part within ‘{}’. 
Do not include any other explanations in your response. Read the below instructions.

— Filter Options (Optional, so not required if not specified in the User's query) —

1. location
Format: STRING(lowercase)
Example: santa monica, ca

*If not specifically mentioned, use 'chicago, il'.
*Do not alter the format from the above example. 
*If you want to search for a specific neighborhood like Chicago's West Loop, please specify it in the Filter option '16. keywords', not here.
Incorrect example: "location": "west loop, chicago, il"
Correct example: "location": "chicago, il", "keywords": "west loop"


2. status_type
For purchase or for rent
Format: STRING
Example:
ForSale
ForRent

3. home_type
Property type comma-separated or empty for all types
Format: STRING
Example(ForRent):
Townhomes
Houses
Apartments_Condos_Co-ops

Example(ForSale):
Multi-family
Apartments
Houses
Manufactured
Condos
LotsLand
Townhomes

*If it cannot be determined from the User's query, specification is not necessary.

4. minPrice
If status_type = ForSale you can filter by min price.
Format: NUMBER
Example: 200000

5. maxPrice
If status_type = ForSale you can filter by max price.
Format: NUMBER
Example: 900000

6. rentMinPrice
If status_type = ForRent you can filter by min rent price.
Format: NUMBER
Example: 2000

7. rentMaxPrice
If status_type = ForRent you can filter by max rent price.
Format: NUMBER
Example: 3000

8. bathsMin
Bathrooms min count
Format: NUMBER
Example: 2
* If a specific number of baths is specified, rather than a range, please enter the same number for both bathsMin and bathsMax.

9. bathsMax
Bathrooms max count
Format: NUMBER
Example: 3

10. bedsMin
Bedrooms min count
Format: NUMBER
Example: 1
* If a specific number of bedrooms is specified, rather than a range, please enter the same number for both bedsMin and bedsMax.

11. bedsMax
Bedrooms max count
Format: NUMBER
Example: 3

12. sqftMin
Square Feet min value
Format: NUMBER
Example: 600

13. sqftMax
Square Feet max value
Format: NUMBER
Example: 1500

14. buildYearMin
Year Built min value
Format: NUMBER
Example: 1980

15. buildYearMax
Year Built max value
Format: NUMBER
Example: 2023

16. keywords
Filter with keywords.
Format: STRING
Example1: ‘gym’
Example2: ‘West Loop’
Example3: ‘pet, pool, South Loop‘
*Not necessary if already specified in another filter or if there is no clear specification in user’s query. Specify conditions that cannot be specified in other filters by using keywords.

17. sort
Sorting criteria for the results
Always specify "Newest"


Now, use the following query to determine the appropriate parameters.

### Example query ###
I am looking for a one-bedroom.

### Example Output ###
{
"location":"chicago, il",
"bedsMin":"1",
"bedsMax":"1",
"sort":"Newest"
}

### Example query ###
I am looking for a rental in South Loop, Chicago, with at least one bedroom and a rent of $3000 or less per month.

### Example Output ###
{
"location": "chicago, il",
"status_type": "ForRent",
"rentMaxPrice": 3000,
"bedsMin": 1,
"keywords": "South Loop",
"sort":"Newest"
}

### Example query ###
I am looking for a rental in West Loop, Chicago, with one bedroom and a rent between $2000 and $2500.

### Example Output ###
{
"location": "chicago, il",
"status_type": "ForRent",
"rentMinPrice": 2500,
"rentMaxPrice": 3000,
"bedsMin": 1,
"bedsMax": 1,
"keywords": "West Loop",
"sort":"Newest"
}

### Example query ###
I want to buy a house in River North with at least two bedrooms.

### Example Output ###
{
"location":"chicago, il",
"status_type": "ForSale",
"keywords":"River North",
"bedsMin":"2",
"sort":"Newest"
}

### Example query ###
I am looking for a rental around Wicker Park in Chicago with a gym and a pool. It should be built within the last 10 years.

### Example Output ###
{
"location": "chicago, il",
"home_type": "Apartments_Condos_Co-ops",
"status_type": "ForRent",
"buildYearMin": 2014,
"keywords": "Wicker Park, gym, pool",
"sort":"Newest"
}

### Example query ###
I am looking for a rental with a balcony, over 700 sqft in size, and less than 5 years old, located near downtown.

### Example Output ###
{
"location": "chicago, il",
"status_type": "ForRent",
"sqftMin":"700",
"buildYearMin": 2019,
"keywords": "downtown, balcony",
"sort":"Newest"
}


### User’s query ###
{USER_QUERY}

### Output ###
"""

# %%
user_query = "I am looking for a two-bedroom."
print(generate_prompt_apifilter(instruction, user_query))
# Out:
# ### Instructions ###
# I want you to act as a principal software engineer. You'll be given a task to determine the parameters of an API call based on the "User's query" below,
# please modify the conditions and create the appropriate API filter. Provide your answer only for the part within ‘{}’.
# Do not include any other explanations in your response. Read the below instructions.
#
# — Filter Options (Optional, so not required if not specified in the User's query) —
#
# 1. location
# Format: STRING(lowercase)
# Example: santa monica, ca
#
# *If not specifically mentioned, use 'chicago, il'.
# *Do not alter the format from the above example.
# *If you want to search for a specific neighborhood like Chicago's West Loop, please specify it in the Filter option '16. keywords', not here.
# Incorrect example: "location": "west loop, chicago, il"
# Correct example: "location": "chicago, il", "keywords": "west loop"
#
#
# 2. status_type
# For purchase or for rent
# Format: STRING
# Example:
# ForSale
# ForRent
#
# 3. home_type
# Property type comma-separated or empty for all types
# Format: STRING
# Example(ForRent):
# Townhomes
# Houses
# Apartments_Condos_Co-ops
#
# Example(ForSale):
# Multi-family
# Apartments
# Houses
# Manufactured
# Condos
# LotsLand
# Townhomes
#
# *If it cannot be determined from the User's query, specification is not necessary.
#
# 4. minPrice
# If status_type = ForSale you can filter by min price.
# Format: NUMBER
# Example: 200000
#
# 5. maxPrice
# If status_type = ForSale you can filter by max price.
# Format: NUMBER
# Example: 900000
#
# 6. rentMinPrice
# If status_type = ForRent you can filter by min rent price.
# Format: NUMBER
# Example: 2000
#
# 7. rentMaxPrice
# If status_type = ForRent you can filter by max rent price.
# Format: NUMBER
# Example: 3000
#
# 8. bathsMin
# Bathrooms min count
# Format: NUMBER
# Example: 2
# * If a specific number of baths is specified, rather than a range, please enter the same number for both bathsMin and bathsMax.
#
# 9. bathsMax
# Bathrooms max count
# Format: NUMBER
# Example: 3
#
# 10. bedsMin
# Bedrooms min count
# Format: NUMBER
# Example: 1
# * If a specific number of bedrooms is specified, rather than a range, please enter the same number for both bedsMin and bedsMax.
#
# 11. bedsMax
# Bedrooms max count
# Format: NUMBER
# Example: 3
#
# 12. sqftMin
# Square Feet min value
# Format: NUMBER
# Example: 600
#
# 13. sqftMax
# Square Feet max value
# Format: NUMBER
# Example: 1500
#
# 14. buildYearMin
# Year Built min value
# Format: NUMBER
# Example: 1980
#
# 15. buildYearMax
# Year Built max value
# Format: NUMBER
# Example: 2023
#
# 16. keywords
# Filter with keywords.
# Format: STRING
# Example1: ‘gym’
# Example2: ‘West Loop’
# Example3: ‘pet, pool, South Loop‘
# *Not necessary if already specified in another filter or if there is no clear specification in user’s query. Specify conditions that cannot be specified in other filters by using keywords.
#
# 17. sort
# Sorting criteria for the results
# Always specify "Newest"
#
#
# Now, use the following query to determine the appropriate parameters.
#
# ### Example query ###
# I am looking for a one-bedroom.
#
# ### Example Output ###
# {
# "location":"chicago, il",
# "bedsMin":"1",
# "bedsMax":"1",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental in South Loop, Chicago, with at least one bedroom and a rent of $3000 or less per month.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "rentMaxPrice": 3000,
# "bedsMin": 1,
# "keywords": "South Loop",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental in West Loop, Chicago, with one bedroom and a rent between $2000 and $2500.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "rentMinPrice": 2500,
# "rentMaxPrice": 3000,
# "bedsMin": 1,
# "bedsMax": 1,
# "keywords": "West Loop",
# "sort":"Newest"
# }
#
# ### Example query ###
# I want to buy a house in River North with at least two bedrooms.
#
# ### Example Output ###
# {
# "location":"chicago, il",
# "status_type": "ForSale",
# "keywords":"River North",
# "bedsMin":"2",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental around Wicker Park in Chicago with a gym and a pool. It should be built within the last 10 years.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "home_type": "Apartments_Condos_Co-ops",
# "status_type": "ForRent",
# "buildYearMin": 2014,
# "keywords": "Wicker Park, gym, pool",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental with a balcony, over 700 sqft in size, and less than 5 years old, located near downtown.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "sqftMin":"700",
# "buildYearMin": 2019,
# "keywords": "downtown, balcony",
# "sort":"Newest"
# }
#
#
# ### User’s query ###
# I am looking for a two-bedroom.
#
# ### Output ###

# %% [markdown]
# ### Test

# %%
user_query = "I am looking for a two-bedroom."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "bedsMin": "2",
# "bedsMax": "2",
# "status_type": "ForRent",
# "location":"chicago, il",
# "sort":"Newest"
# }

# %%
user_query = "I am looking for a rental in Fulton Market, Chicago, with at least one bedroom and a rent of $3500 or less per month."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "rentMaxPrice": 3500,
# "bedsMin": 1,
# "keywords": "Fulton Market",
# "sort":"Newest"
# }

# %%
user_query = "I want to buy a house in Chinatown, Chicago with a minimum of 2 bathrooms and 2 bedrooms."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location":"chicago, il",
# "status_type": "ForSale",
# "keywords":"Chinatown",
# "bathsMin":"2",
# "bedsMin":"2",
# "sort":"Newest"
# }

# %%
user_query = "I am looking for a rental around Hyde Park with a gym and a pool. It should be built within the last 15 years."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location":"chicago, il",
# "status_type": "ForRent",
# "home_type": "Apartments_Condos_Co-ops",
# "buildYearMin": 2009,
# "keywords": "Hyde Park, gym, pool",
# "sort":"Newest"
# }

# %%
user_query = "I am looking for a rental in the Old Town area of Chicago with a balcony and a pool."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location": "chicago, il",
# "home_type": "Apartments_Condos_Co-ops",
# "status_type": "ForRent",
# "keywords": "Old Town, balcony, pool",
# "sort":"Newest"
# }

# %% [markdown]
# ## 3. Get Property Listings from Zillow API

# %% [markdown]
# ### Example - Extended Search endpoint

# %%
import requests

url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

headers = {
	"X-RapidAPI-Key": "YOUR_API_KEY",
	"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

# %%
querystring = {"location":"chicago, il", "status_type":"ForRent", "bathsMin":"1","bedsMin":"3", "keywords":"west", "sort":"Newest"}
response = requests.get(url, headers = headers, params = querystring)

# %%
response.json()
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '4734 S Kildare Ave #2, Chicago, IL 60632',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3e7358cce3b8100167e5293b511f0dc5-p_e.jpg',
#    'price': 1575,
#    'detailUrl': '/homedetails/4734-S-Kildare-Ave-2-Chicago-IL-60632/2058742577_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.73125,
#    'latitude': 41.806747,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2058742577',
#    'listingSubType': {},
#    'rentZestimate': 1634,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1100,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '6651 N Rockwell St #2, Chicago, IL 60645',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/15b92afe0366d891393d59a5866307b3-p_e.jpg',
#    'price': 2100,
#    'detailUrl': '/homedetails/6651-N-Rockwell-St-2-Chicago-IL-60645/2071905782_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.69452,
#    'latitude': 42.002796,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2071905782',
#    'listingSubType': {},
#    'rentZestimate': 1963,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1354,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '3826 W Monroe St, Chicago, IL 60624',
#    'variableData': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1628de89aa481ce8956c7328a1e016af-p_e.jpg',
#    'price': 1650,
#    'detailUrl': '/homedetails/3826-W-Monroe-St-Chicago-IL-60624/2076380588_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.72189,
#    'latitude': 41.88009,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2076380588',
#    'listingSubType': {},
#    'rentZestimate': 1462,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1100,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$4,250+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.89068--87.67218',
#    'longitude': -87.67218,
#    'buildingName': None,
#    'address': '1801 W Grand Ave, Chicago, IL',
#    'detailUrl': '/b/1801-w-grand-ave-chicago-il-9S23bN/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2104156205,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d83fc2d985236900f7d83f13e298c3d7-p_e.jpg',
#    'latitude': 41.89068},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2518 N Mozart St #1, Chicago, IL 60647',
#    'variableData': None,
#    'unit': '# 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1b8144f8975975537c57fda58d9f0468-p_e.jpg',
#    'price': 3300,
#    'detailUrl': '/homedetails/2518-N-Mozart-St-1-Chicago-IL-60647/2083528246_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.69906,
#    'latitude': 41.927223,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2083528246',
#    'listingSubType': {},
#    'rentZestimate': 3099,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2919 N Pine Grove Ave APT 2, Chicago, IL 60657',
#    'variableData': None,
#    'unit': 'Apt 2',
#    'zestimate': 547900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2d2800a5ec89a6197f972238a45e0f3b-p_e.jpg',
#    'price': 4295,
#    'detailUrl': '/homedetails/2919-N-Pine-Grove-Ave-APT-2-Chicago-IL-60657/3720979_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.641525,
#    'latitude': 41.93467,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '3720979',
#    'listingSubType': {},
#    'rentZestimate': 4450,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1900,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$2,395+'},
#     {'roomForRent': False, 'beds': '4', 'price': '$3,795+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.893543--87.6694',
#    'longitude': -87.6694,
#    'buildingName': None,
#    'address': '1656 W Erie St, Chicago, IL',
#    'detailUrl': '/b/1656-w-erie-st-chicago-il-9S22wC/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2104154579,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7a1c074bcf4bc10bf043123d925748a2-p_e.jpg',
#    'latitude': 41.893543},
#   {'units': [{'roomForRent': False, 'beds': '4', 'price': '$3,600+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.897114--87.65413',
#    'longitude': -87.65413,
#    'buildingName': None,
#    'address': '1059 W Fry St, Chicago, IL',
#    'detailUrl': '/b/1059-w-fry-st-chicago-il-5XjLzn/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 1001469094,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f3daa5f50cfe0d7855623a070e8e255d-p_e.jpg',
#    'latitude': 41.897114},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '35 S Racine Ave APT 4NW, Chicago, IL 60607',
#    'variableData': None,
#    'unit': 'Apt 4NW',
#    'zestimate': 709400,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a428249f6bb761dfddf8ac5ec5d0f2b6-p_e.jpg',
#    'price': 4200,
#    'detailUrl': '/homedetails/35-S-Racine-Ave-APT-4NW-Chicago-IL-60607/80842984_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.6569,
#    'latitude': 41.88057,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '80842984',
#    'listingSubType': {},
#    'rentZestimate': 3884,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1650,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '520 N Western Ave #3B, Chicago, IL 60612',
#    'variableData': None,
#    'unit': '# 3B',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2d00eccef063cf421d130d9b311f803f-p_e.jpg',
#    'price': 3250,
#    'detailUrl': '/homedetails/520-N-Western-Ave-3B-Chicago-IL-60612/2069236975_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.687096,
#    'latitude': 41.891293,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2069236975',
#    'listingSubType': {},
#    'rentZestimate': 2382,
#    'daysOnZillow': 0,
#    'bathrooms': 2.5,
#    'livingArea': 1700,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '3728 N Magnolia Ave #11, Chicago, IL 60613',
#    'variableData': None,
#    'unit': '# 11',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b63a6461f72e61d2674786d0782032c5-p_e.jpg',
#    'price': 5875,
#    'detailUrl': '/homedetails/3728-N-Magnolia-Ave-11-Chicago-IL-60613/347305376_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.660805,
#    'latitude': 41.949833,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '347305376',
#    'listingSubType': {},
#    'rentZestimate': 4500,
#    'daysOnZillow': 0,
#    'bathrooms': 4,
#    'livingArea': 2000,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$3,355+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.886066--87.656',
#    'longitude': -87.656,
#    'buildingName': None,
#    'address': '216 N May St, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/216-n-may-st/DZ7r/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 1244004,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e5171f5156e06eeb43afb37c0e1810e8-p_e.jpg',
#    'latitude': 41.886066},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': None,
#    'address': '238 S Ashland Ave, Chicago, IL 60607',
#    'variableData': None,
#    'zestimate': 573800,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/bc5d04cbc3034843a272f004212e561e-p_e.jpg',
#    'price': 3800,
#    'detailUrl': '/homedetails/238-S-Ashland-Ave-Chicago-IL-60607/2119049294_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.66707,
#    'latitude': 41.877735,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2119049294',
#    'listingSubType': {},
#    'rentZestimate': 3614,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1800,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1717 W Roscoe St #1, Chicago, IL 60657',
#    'variableData': None,
#    'unit': '# 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/03e22f82c0b577eea9878547c0b820e9-p_e.jpg',
#    'price': 4300,
#    'detailUrl': '/homedetails/1717-W-Roscoe-St-1-Chicago-IL-60657/2082717789_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.67195,
#    'latitude': 41.94304,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2082717789',
#    'listingSubType': {},
#    'rentZestimate': 3800,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 1750,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1324 W Grand Ave UNIT 1W, Chicago, IL 60642',
#    'variableData': None,
#    'unit': 'Unit 1W',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5f9f45c92675db7a6c15b08bd577589a-p_e.jpg',
#    'price': 5700,
#    'detailUrl': '/homedetails/1324-W-Grand-Ave-UNIT-1W-Chicago-IL-60642/2061181246_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.66003,
#    'latitude': 41.89134,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2061181246',
#    'listingSubType': {},
#    'rentZestimate': 4999,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 2800,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '7126 S University Ave #2, Chicago, IL 60619',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/c8f6b2e8c165762a4633ed618598cd1f-p_e.jpg',
#    'price': 1375,
#    'detailUrl': '/homedetails/7126-S-University-Ave-2-Chicago-IL-60619/2102520664_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.5974,
#    'latitude': 41.765125,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2102520664',
#    'listingSubType': {},
#    'rentZestimate': 1529,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '700 N Noble St APT 1, Chicago, IL 60642',
#    'variableData': None,
#    'unit': 'Apt 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/aa0d3b13416c48ff4a3ac6aceca19bf1-p_e.jpg',
#    'price': 3250,
#    'detailUrl': '/homedetails/700-N-Noble-St-APT-1-Chicago-IL-60642/2083935792_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.662674,
#    'latitude': 41.894455,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2083935792',
#    'listingSubType': {},
#    'rentZestimate': 3999,
#    'daysOnZillow': 0,
#    'bathrooms': 2.5,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '3040 N Ashland Ave #1R, Chicago, IL 60657',
#    'variableData': None,
#    'unit': '# 1R',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/91bf713de84ba15f53c8cbd7040e9d6e-p_e.jpg',
#    'price': 3975,
#    'detailUrl': '/homedetails/3040-N-Ashland-Ave-1R-Chicago-IL-60657/2083025613_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.66893,
#    'latitude': 41.937237,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2083025613',
#    'listingSubType': {},
#    'rentZestimate': 3300,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1800,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': 'The Lofts at Gin Alley, 120 N Green St UNIT 602, Chicago, IL 60607',
#    'variableData': None,
#    'unit': 'Unit 602',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e618a6c1bbe124245d7b5c0877508df6-p_e.jpg',
#    'price': 4730,
#    'detailUrl': '/apartments/chicago-il/the-lofts-at-gin-alley/DMyz/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.64886,
#    'latitude': 41.883957,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2081983585',
#    'listingSubType': {},
#    'rentZestimate': 6007,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1767,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': '1115 S Plymouth Ct APT 311, Chicago, IL 60605',
#    'variableData': None,
#    'unit': 'Apt 311',
#    'zestimate': 312700,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b6fd87bed7bec98cc36717208e430e62-p_e.jpg',
#    'price': 4200,
#    'detailUrl': '/homedetails/1115-S-Plymouth-Ct-APT-311-Chicago-IL-60605/3873244_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.62812,
#    'latitude': 41.871635,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '3873244',
#    'listingSubType': {},
#    'rentZestimate': 1964,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$4,795+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.895344--87.650444',
#    'longitude': -87.650444,
#    'buildingName': 'Mondial River West',
#    'address': '910 W Huron St, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/mondial-river-west/5XjNQF/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 1001472497,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/cb8f21b15580a8ba7c5c03b4ebaf9633-p_e.jpg',
#    'latitude': 41.895344},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$1,075+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.88085--87.74993',
#    'longitude': -87.74993,
#    'buildingName': '5100-04 W Madison St',
#    'address': '5100 W Madison St, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/5100.dash.04-w-madison-st/9S55MP/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2104513367,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3bcdb14b47768008832a4328cb4cf80e-p_e.jpg',
#    'latitude': 41.88085},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': '10038 S Normal Ave, Chicago, IL 60628',
#    'variableData': None,
#    'zestimate': 188600,
#    'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=41.71133804321289,-87.63601684570312&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=FgLkQpbkR4qz5mgB7mkUmNQDBqc=',
#    'price': 2700,
#    'detailUrl': '/homedetails/10038-S-Normal-Ave-Chicago-IL-60628/4131591_zpid/',
#    'bedrooms': 7,
#    'contingentListingType': None,
#    'longitude': -87.63602,
#    'latitude': 41.711338,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '4131591',
#    'listingSubType': {},
#    'rentZestimate': 2719,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 2900,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': None},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1400 W Taylor, 1400 W Taylor St #7, Chicago, IL 60607',
#    'variableData': None,
#    'unit': '# 7',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f1d9bf02e6733c47a2fcca9a69b6454e-p_e.jpg',
#    'price': 3000,
#    'detailUrl': '/b/1400-w-taylor-chicago-il-9Rx5sP/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.6619,
#    'latitude': 41.8696,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2057304647',
#    'listingSubType': {},
#    'rentZestimate': 2700,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '725 S Loomis, 725 S Loomis St #101, Chicago, IL 60607',
#    'variableData': None,
#    'unit': '# 101',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/15ac328c47a3d026132bd2f596955390-p_e.jpg',
#    'price': 2500,
#    'detailUrl': '/b/725-s-loomis-chicago-il-9Rx8zw/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.66137,
#    'latitude': 41.8726,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2057307896',
#    'listingSubType': {},
#    'rentZestimate': 2039,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1100,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1336 W Ohio St APT 1F, Chicago, IL 60642',
#    'variableData': None,
#    'unit': 'Apt 1F',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/43d47754bd7b054a5c1f8b4d0b7d1660-p_e.jpg',
#    'price': 5995,
#    'detailUrl': '/homedetails/1336-W-Ohio-St-APT-1F-Chicago-IL-60642/2093690573_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.66098,
#    'latitude': 41.892735,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2093690573',
#    'listingSubType': {},
#    'rentZestimate': 4675,
#    'daysOnZillow': 0,
#    'bathrooms': 4,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1401 W Hubbard St STE 2, Chicago, IL 60642',
#    'variableData': None,
#    'unit': 'Ste 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ba6346b1814316632700fce1e785de58-p_e.jpg',
#    'price': 4800,
#    'detailUrl': '/homedetails/1401-W-Hubbard-St-STE-2-Chicago-IL-60642/2097633723_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.66252,
#    'latitude': 41.889805,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2097633723',
#    'listingSubType': {},
#    'rentZestimate': 6249,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 3000,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '4', 'price': '$3,395+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.872406--87.65455',
#    'longitude': -87.65455,
#    'buildingName': '718 S. Aberdeen St',
#    'address': '718 S Aberdeen St, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/718-s.-aberdeen-st/9Rx8yD/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2103816137,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d6b0258bb616636c41a461aa03c0d929-p_e.jpg',
#    'latitude': 41.872406},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1249 W Winnemac Ave APT 1, Chicago, IL 60640',
#    'variableData': None,
#    'unit': 'Apt 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/466978de745ce54821f6daf9729efd7b-p_e.jpg',
#    'price': 3750,
#    'detailUrl': '/homedetails/1249-W-Winnemac-Ave-APT-1-Chicago-IL-60640/2109050883_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.66175,
#    'latitude': 41.973343,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2109050883',
#    'listingSubType': {},
#    'rentZestimate': 4337,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 3001,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2102 W Erie St #1, Chicago, IL 60612',
#    'variableData': None,
#    'unit': '# 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1aac8639037cbbd300ff4af92dcdb089-p_e.jpg',
#    'price': 2450,
#    'detailUrl': '/homedetails/2102-W-Erie-St-1-Chicago-IL-60612/2078867746_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.67968,
#    'latitude': 41.893303,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2078867746',
#    'listingSubType': {},
#    'rentZestimate': 2805,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '612 N May St #G, Chicago, IL 60642',
#    'variableData': None,
#    'unit': '# G',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ccafcc5a491e38681866b30e38c1a0d8-p_e.jpg',
#    'price': 2400,
#    'detailUrl': '/homedetails/612-N-May-St-G-Chicago-IL-60642/2109694949_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.656166,
#    'latitude': 41.89267,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2109694949',
#    'listingSubType': {},
#    'rentZestimate': 2674,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1500,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1953 W. Dickens, 1953 W Dickens Ave APT 2, Chicago, IL 60614',
#    'variableData': None,
#    'unit': 'Apt 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/df640ed45e14e5d16c814623b1a81067-p_e.jpg',
#    'price': 3700,
#    'detailUrl': '/b/1953-w.-dickens-chicago-il-5XdZHb/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.67733,
#    'latitude': 41.919353,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2067796420',
#    'listingSubType': {},
#    'rentZestimate': 3021,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '617 N Racine Ave APT 3, Chicago, IL 60642',
#    'variableData': None,
#    'unit': 'Apt 3',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/da9eda2883a9f1a4102a84e68826f94c-p_e.jpg',
#    'price': 2875,
#    'detailUrl': '/homedetails/617-N-Racine-Ave-APT-3-Chicago-IL-60642/2119662466_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.65709,
#    'latitude': 41.892727,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2119662466',
#    'listingSubType': {},
#    'rentZestimate': 4412,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1600,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2233 W Cullerton St #3, Chicago, IL 60608',
#    'variableData': None,
#    'unit': '# 3',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d4621914b6905c7eb83c3669d5ff852b-p_e.jpg',
#    'price': 2200,
#    'detailUrl': '/homedetails/2233-W-Cullerton-St-3-Chicago-IL-60608/2058097553_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.68213,
#    'latitude': 41.854626,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2058097553',
#    'listingSubType': {},
#    'rentZestimate': 2334,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1600,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2141 W Ainslie St #1, Chicago, IL 60625',
#    'variableData': None,
#    'unit': '# 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2817e6be9751743f04d3cf63ad4ea7f2-p_e.jpg',
#    'price': 3250,
#    'detailUrl': '/homedetails/2141-W-Ainslie-St-1-Chicago-IL-60625/2099501914_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.68334,
#    'latitude': 41.970375,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2099501914',
#    'listingSubType': {},
#    'rentZestimate': 3882,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1825,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': '2050 W Berwyn Ave #1, Chicago, IL 60625',
#    'variableData': None,
#    'unit': '# 1',
#    'zestimate': 786700,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ae352847ee03131011c7f3e75c04bb2a-p_e.jpg',
#    'price': 3800,
#    'detailUrl': '/homedetails/2050-W-Berwyn-Ave-1-Chicago-IL-60625/2113907611_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.6814,
#    'latitude': 41.978092,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2113907611',
#    'listingSubType': {},
#    'rentZestimate': 4762,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 2050,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1654 N Talman Ave, Chicago, IL 60647',
#    'variableData': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/85ced1eb95a573118dd45f39c7967c60-p_e.jpg',
#    'price': 1995,
#    'detailUrl': '/homedetails/1654-N-Talman-Ave-Chicago-IL-60647/2089595296_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.693665,
#    'latitude': 41.91189,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2089595296',
#    'listingSubType': {},
#    'rentZestimate': 4943,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1100,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '(undisclosed Address), Chicago, IL 60609',
#    'variableData': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b57f3c066e2b5003e581c62c91ef5058-p_e.jpg',
#    'price': 1725,
#    'detailUrl': '/homedetails/Chicago-IL-60609/2079851752_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': None,
#    'latitude': None,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2079851752',
#    'listingSubType': {},
#    'rentZestimate': 1650,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1100,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'CONDO',
#    'lotAreaValue': None,
#    'address': '1039 S Racine Ave APT 1F, Chicago, IL 60607',
#    'variableData': None,
#    'unit': 'Apt 1F',
#    'zestimate': 674600,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/517ce4fb0a4997f706f6f74a717be9a9-p_e.jpg',
#    'price': 2695,
#    'detailUrl': '/homedetails/1039-S-Racine-Ave-APT-1F-Chicago-IL-60607/2098150565_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.6563,
#    'latitude': 41.86827,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2098150565',
#    'listingSubType': {},
#    'rentZestimate': 2184,
#    'daysOnZillow': 0,
#    'bathrooms': 1.5,
#    'livingArea': 1280,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '3341 N Seminary, 3341 N Seminary Ave, Chicago, IL 60657',
#    'variableData': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a834a5b7920e22a4fe7d182463ee7e8d-p_e.jpg',
#    'price': 3000,
#    'detailUrl': '/homedetails/3341-N-Seminary-Ave-Chicago-IL-60657/2106865096_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.65626,
#    'latitude': 41.942936,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2106865096',
#    'listingSubType': {},
#    'rentZestimate': 3663,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1740 W Huron St UNIT F4, Chicago, IL 60622',
#    'variableData': None,
#    'unit': 'Unit F4',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/554c2d9f6d291f638204d3efaa4b62c5-p_e.jpg',
#    'price': 3100,
#    'detailUrl': '/homedetails/1740-W-Huron-St-UNIT-F4-Chicago-IL-60622/2057287909_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.67131,
#    'latitude': 41.894382,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2057287909',
#    'listingSubType': {},
#    'rentZestimate': 2334,
#    'daysOnZillow': 0,
#    'bathrooms': 1.5,
#    'livingArea': 1500,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True}],
#  'resultsPerPage': 41,
#  'totalPages': 9,
#  'totalResultCount': 364,
#  'schools': {},
#  'currentPage': 1}

# %%
def extract_properties(response, n, fields):
    """
    Extracts and returns the top 'n' properties from a given API response
    based on the specified fields, appending the base URL to 'detailUrl'.
    
    Parameters:
    - response: The response object from an API call.
    - n: The number of top properties to extract.
    - fields: A list of strings representing the fields to extract from each property.
    
    Returns:
    - A list of dictionaries, each representing a property with only the specified fields.
    """
    base_url = "https://www.zillow.com"
    try:
        # Convert the response to JSON format if it's not already a dictionary
        if not isinstance(response, dict):
            response = response.json()

        # Extract the top 'n' properties based on the specified fields
        top_properties = []
        for prop in response['props'][:n]:
            extracted_prop = {field: (base_url + prop['detailUrl'] if field == 'detailUrl' else prop.get(field, None)) for field in fields}
            top_properties.append(extracted_prop)

        return top_properties

    except Exception as e:
        print("An error occurred:", e)
        return []  # Return an empty list in case of an error

# %%
# Define fields to extract
fields = ["propertyType", "address", "price", "bedrooms", "bathrooms", "detailUrl", "imgSrc"]

# %%
# Get top 3 properties with selected fields
top_properties = extract_properties(response, 3, fields)
top_properties
# Out:
# [{'propertyType': 'APARTMENT',
#   'address': '4734 S Kildare Ave #2, Chicago, IL 60632',
#   'price': 1575,
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/4734-S-Kildare-Ave-2-Chicago-IL-60632/2058742577_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/3e7358cce3b8100167e5293b511f0dc5-p_e.jpg'},
#  {'propertyType': 'APARTMENT',
#   'address': '6651 N Rockwell St #2, Chicago, IL 60645',
#   'price': 2100,
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/6651-N-Rockwell-St-2-Chicago-IL-60645/2071905782_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/15b92afe0366d891393d59a5866307b3-p_e.jpg'},
#  {'propertyType': 'APARTMENT',
#   'address': '3826 W Monroe St, Chicago, IL 60624',
#   'price': 1650,
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/3826-W-Monroe-St-Chicago-IL-60624/2076380588_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/1628de89aa481ce8956c7328a1e016af-p_e.jpg'}]

# %% [markdown]
# ### Example - Property details endpoint

# %%
top_properties[0]['detailUrl']
# Out:
# 'https://www.zillow.com/homedetails/10500-S-Church-St-Chicago-IL-60643/4143638_zpid/'

# %%
# Endpoint
url_details = "https://zillow-com1.p.rapidapi.com/property"

# URL example
property_url = top_properties[0]['detailUrl']

querystring = {"property_url":property_url}
response = requests.get(url_details, headers = headers, params = querystring)

# %%
response = response.json()
response['description']
# Out:
# 'Location, Location, Location! Make this huge corner bungalow your dream home in the Beverly area.  Step inside and be engulfed by the entryway, that leads to a unique living room with a custom full wall book shelf, that flows into an elegant dining area with a beautiful chandelier and complemented by a huge bay window. Then move to the completely remodeled kitchen that will blow you away.  The bath has been updated with ceramic tile and vanity.  The lower level  features a possible 3rd bedroom, an office, storage or exercise room, and a roughed-in bath.  The attic is ready for your creative ideas for a master suite or two additional bedrooms and a bath.  Walk out  to the huge deck that is great for entertaining.   Proceed to a newer two car garage.from the large yard enclosed by a wrought iron fence. Near Metra, bus line and expressway.  Beautiful, quiet block with nice neighbors. This beauty will not last.'

# %%
def fetch_descriptions(properties):
    """
    Fetches the descriptions of each property and appends them to the list.

    Parameters:
    - properties: A list of dictionaries representing properties.

    Returns:
    - A list of dictionaries(the same format as input).
    """
    url_details = "https://zillow-com1.p.rapidapi.com/property"

    for prop in properties:
        # Fetch detailed information using detailUrl
        querystring = {"property_url": prop['detailUrl']}
        response = requests.get(url_details, headers=headers, params=querystring)

        # Convert to JSON and fetch description
        detail_data = response.json()
        prop['description'] = detail_data.get('description', 'No description available')

    return properties

# %%
fetch_descriptions(top_properties)
# Out:
# [{'propertyType': 'SINGLE_FAMILY',
#   'address': '10500 S Church St, Chicago, IL 60643',
#   'price': 244900,
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/10500-S-Church-St-Chicago-IL-60643/4143638_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/a5a3f713652b246545f67e89d17d0ed0-p_e.jpg',
#   'description': 'Location, Location, Location! Make this huge corner bungalow your dream home in the Beverly area.  Step inside and be engulfed by the entryway, that leads to a unique living room with a custom full wall book shelf, that flows into an elegant dining area with a beautiful chandelier and complemented by a huge bay window. Then move to the completely remodeled kitchen that will blow you away.  The bath has been updated with ceramic tile and vanity.  The lower level  features a possible 3rd bedroom, an office, storage or exercise room, and a roughed-in bath.  The attic is ready for your creative ideas for a master suite or two additional bedrooms and a bath.  Walk out  to the huge deck that is great for entertaining.   Proceed to a newer two car garage.from the large yard enclosed by a wrought iron fence. Near Metra, bus line and expressway.  Beautiful, quiet block with nice neighbors. This beauty will not last.'},
#  {'propertyType': 'CONDO',
#   'address': '1660 N La Salle St #1302, Chicago, IL 60614',
#   'price': 465000,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/1660-N-La-Salle-St-1302-Chicago-IL-60614/348746300_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/5b24f7400972354118c83732038a7aeb-p_e.jpg',
#   'description': "Old Town's most coveted high rise in prime location!  Rarely available 2bed/2bath Corner Unit with Fabulous South Facing City Views. Immediately as you enter the unit, you will be enchanted with the entire condo.  From the beautiful upgrades including Hardwood Flooring - Elegant Kitchen - Customized Built Ins - Large Balcony - Floor To Ceiling Windows - Storage Galore, this condo has it all.  Saturated with sunlight enjoy picturesque views of the skyline, sunsets and views of the Lake from your private balcony. Full amenity building including 24 hour doorstaff, fitness center, outdoor pool, amazing rooftop deck, laundry room, etc. Rental parking options available in attached garage starting at $121. Very healthy building with $12 million in reserves as of 2/29/2024. Rentals allowed with lease minimum of 12 months.  No rental cap.  Highly desired Old Town location right across from the lake, parks, baseball and soccer fields, trails, etc. Exit through the back of the building and you are in the heart of all the Wells Street action surrounded by restaurants, night life, shopping and entertainment. CTA - the 156 bus stops directly in front of the building and the 22 bus is across the street. Brown and Red lines are a short walk. Additional annual neighborhood highlights include the Wells Street and Old Town Art Fairs as well as front row seats to the spectacular Air and Water Show. Although we love our furry pets, 1660 unfortunately is not a dog friendly building (of course, service and ESA animals are welcome)."},
#  {'propertyType': 'MULTI_FAMILY',
#   'address': '7801 W Summerdale Ave, Chicago, IL 60656',
#   'price': 325500,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/7801-W-Summerdale-Ave-Chicago-IL-60656/3583976_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/3d472df8b68f814af810007e481987fd-p_e.jpg',
#   'description': "Oriole Park Gem! This Impressive 2-story Duplex features gleaming hardwood floors throughout, a gorgeous living room with custom bay window. Modern kitchen with dining area, recessed lighting, newer stainless steel appliances and granite counters. The beautiful 2nd level is filled with natural light and offers two spacious bedrooms and closets, updated full bath and linen closet. The lower level basement has a cozy finished family room, a full bath with walk-in shower, separate laundry room and tons of storage space. Step outside to a large deck that overlooks an amazing landscaped yard filled with perennials, trees and shrubs. The beautiful stone walkway leads to your oversized two car garage. This home has been  meticulously maintained and offers many recent updates:(2023) New roof, chimney copper flashing and crown sealer. (2022) basement hopper windows, (2021) new fence, attic fan. (2020) Carrier furnace. (2020) Clean check backwater valve installed. (2019) Larson storm doors, overhead garage door & opener. Several other improvements were made along the way. Excellent location! Walking distance to Blue Line Station, highly-rated schools and parks. Easy access to the expressway, O'Hare Airport, and downtown. This is a MUST SEE!"}]

# %% [markdown]
# ### For main use case

# %%
import json

# %%
user_query = "I am looking for a two-bedroom."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location":"chicago, il",
# "bedsMin": "2",
# "bedsMax": "2",
# "sort":"Newest"
# }

# %%
# get an api filter through Gemini
querystring = get_chat_response(chat, prompt)

# from str to dict
querystring = json.loads(querystring)

# get listings from zillow api
response = requests.get(url, headers = headers, params = querystring)

# %%
# Define fields to extract
fields = ["propertyType", "address", "price", "bedrooms", "bathrooms", "detailUrl", "imgSrc"]

# %%
# Get top 3 properties with selected fields
top_properties = extract_properties(response, 3, fields)
top_properties
# Out:
# [{'propertyType': 'SINGLE_FAMILY',
#   'address': '10500 S Church St, Chicago, IL 60643',
#   'price': 244900,
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/10500-S-Church-St-Chicago-IL-60643/4143638_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/a5a3f713652b246545f67e89d17d0ed0-p_e.jpg'},
#  {'propertyType': 'CONDO',
#   'address': '1660 N La Salle St #1302, Chicago, IL 60614',
#   'price': 465000,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/1660-N-La-Salle-St-1302-Chicago-IL-60614/348746300_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/5b24f7400972354118c83732038a7aeb-p_e.jpg'},
#  {'propertyType': 'MULTI_FAMILY',
#   'address': '7801 W Summerdale Ave, Chicago, IL 60656',
#   'price': 325500,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/7801-W-Summerdale-Ave-Chicago-IL-60656/3583976_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/3d472df8b68f814af810007e481987fd-p_e.jpg'}]

# %%
top_properties = fetch_descriptions(top_properties)
top_properties
# Out:
# [{'propertyType': 'SINGLE_FAMILY',
#   'address': '10500 S Church St, Chicago, IL 60643',
#   'price': 244900,
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/10500-S-Church-St-Chicago-IL-60643/4143638_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/a5a3f713652b246545f67e89d17d0ed0-p_e.jpg',
#   'description': 'Location, Location, Location! Make this huge corner bungalow your dream home in the Beverly area.  Step inside and be engulfed by the entryway, that leads to a unique living room with a custom full wall book shelf, that flows into an elegant dining area with a beautiful chandelier and complemented by a huge bay window. Then move to the completely remodeled kitchen that will blow you away.  The bath has been updated with ceramic tile and vanity.  The lower level  features a possible 3rd bedroom, an office, storage or exercise room, and a roughed-in bath.  The attic is ready for your creative ideas for a master suite or two additional bedrooms and a bath.  Walk out  to the huge deck that is great for entertaining.   Proceed to a newer two car garage.from the large yard enclosed by a wrought iron fence. Near Metra, bus line and expressway.  Beautiful, quiet block with nice neighbors. This beauty will not last.'},
#  {'propertyType': 'CONDO',
#   'address': '1660 N La Salle St #1302, Chicago, IL 60614',
#   'price': 465000,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/1660-N-La-Salle-St-1302-Chicago-IL-60614/348746300_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/5b24f7400972354118c83732038a7aeb-p_e.jpg',
#   'description': "Old Town's most coveted high rise in prime location!  Rarely available 2bed/2bath Corner Unit with Fabulous South Facing City Views. Immediately as you enter the unit, you will be enchanted with the entire condo.  From the beautiful upgrades including Hardwood Flooring - Elegant Kitchen - Customized Built Ins - Large Balcony - Floor To Ceiling Windows - Storage Galore, this condo has it all.  Saturated with sunlight enjoy picturesque views of the skyline, sunsets and views of the Lake from your private balcony. Full amenity building including 24 hour doorstaff, fitness center, outdoor pool, amazing rooftop deck, laundry room, etc. Rental parking options available in attached garage starting at $121. Very healthy building with $12 million in reserves as of 2/29/2024. Rentals allowed with lease minimum of 12 months.  No rental cap.  Highly desired Old Town location right across from the lake, parks, baseball and soccer fields, trails, etc. Exit through the back of the building and you are in the heart of all the Wells Street action surrounded by restaurants, night life, shopping and entertainment. CTA - the 156 bus stops directly in front of the building and the 22 bus is across the street. Brown and Red lines are a short walk. Additional annual neighborhood highlights include the Wells Street and Old Town Art Fairs as well as front row seats to the spectacular Air and Water Show. Although we love our furry pets, 1660 unfortunately is not a dog friendly building (of course, service and ESA animals are welcome)."},
#  {'propertyType': 'MULTI_FAMILY',
#   'address': '7801 W Summerdale Ave, Chicago, IL 60656',
#   'price': 325500,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/7801-W-Summerdale-Ave-Chicago-IL-60656/3583976_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/3d472df8b68f814af810007e481987fd-p_e.jpg',
#   'description': "Oriole Park Gem! This Impressive 2-story Duplex features gleaming hardwood floors throughout, a gorgeous living room with custom bay window. Modern kitchen with dining area, recessed lighting, newer stainless steel appliances and granite counters. The beautiful 2nd level is filled with natural light and offers two spacious bedrooms and closets, updated full bath and linen closet. The lower level basement has a cozy finished family room, a full bath with walk-in shower, separate laundry room and tons of storage space. Step outside to a large deck that overlooks an amazing landscaped yard filled with perennials, trees and shrubs. The beautiful stone walkway leads to your oversized two car garage. This home has been  meticulously maintained and offers many recent updates:(2023) New roof, chimney copper flashing and crown sealer. (2022) basement hopper windows, (2021) new fence, attic fan. (2020) Carrier furnace. (2020) Clean check backwater valve installed. (2019) Larson storm doors, overhead garage door & opener. Several other improvements were made along the way. Excellent location! Walking distance to Blue Line Station, highly-rated schools and parks. Easy access to the expressway, O'Hare Airport, and downtown. This is a MUST SEE!"}]

# %% [markdown]
# ## 4. Generate advice with the property listings

# %%
def generate_prompt_property(instruction, user_query, property_info):
    updated_instruction = instruction.replace("{USER_QUERY}", user_query)
    updated_instruction = updated_instruction.replace("{PROPERTY_INFO}", property_info)
    return updated_instruction

# %%
instruction = """
### Instructions ###
I want you to act as a real estate advisor. Please recommend properties to the customer. 
'User’s query' represents the questions you are asked by the customer. 
'Real estate properties to present to the user' are the properties you will introduce to the customer. Please include all the details provided, including links, in your response.

### User’s query ###
{USER_QUERY}

### Real estate properties to present to the user ###
{PROPERTY_INFO}

### Output ###
"""

# %%
def format_properties(properties, fields):
    formatted_properties = []
    for prop in properties:
        # Format and concatenate each field of each property
        formatted_prop = ', '.join(f"{field.capitalize().replace('_', ' ')}: {prop.get(field, 'N/A')}" for field in fields)
        formatted_properties.append(formatted_prop)
    return '\n\n'.join(formatted_properties)

# %%
# Change format
fields_desc = fields + ['description']
property_info = format_properties(top_properties, fields_desc)
print(property_info)
# Out:
# Propertytype: SINGLE_FAMILY, Address: 10500 S Church St, Chicago, IL 60643, Price: 244900, Bedrooms: 2, Bathrooms: 1, Detailurl: https://www.zillow.com/homedetails/10500-S-Church-St-Chicago-IL-60643/4143638_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/a5a3f713652b246545f67e89d17d0ed0-p_e.jpg, Description: Location, Location, Location! Make this huge corner bungalow your dream home in the Beverly area.  Step inside and be engulfed by the entryway, that leads to a unique living room with a custom full wall book shelf, that flows into an elegant dining area with a beautiful chandelier and complemented by a huge bay window. Then move to the completely remodeled kitchen that will blow you away.  The bath has been updated with ceramic tile and vanity.  The lower level  features a possible 3rd bedroom, an office, storage or exercise room, and a roughed-in bath.  The attic is ready for your creative ideas for a master suite or two additional bedrooms and a bath.  Walk out  to the huge deck that is great for entertaining.   Proceed to a newer two car garage.from the large yard enclosed by a wrought iron fence. Near Metra, bus line and expressway.  Beautiful, quiet block with nice neighbors. This beauty will not last.
#
# Propertytype: CONDO, Address: 1660 N La Salle St #1302, Chicago, IL 60614, Price: 465000, Bedrooms: 2, Bathrooms: 2, Detailurl: https://www.zillow.com/homedetails/1660-N-La-Salle-St-1302-Chicago-IL-60614/348746300_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/5b24f7400972354118c83732038a7aeb-p_e.jpg, Description: Old Town's most coveted high rise in prime location!  Rarely available 2bed/2bath Corner Unit with Fabulous South Facing City Views. Immediately as you enter the unit, you will be enchanted with the entire condo.  From the beautiful upgrades including Hardwood Flooring - Elegant Kitchen - Customized Built Ins - Large Balcony - Floor To Ceiling Windows - Storage Galore, this condo has it all.  Saturated with sunlight enjoy picturesque views of the skyline, sunsets and views of the Lake from your private balcony. Full amenity building including 24 hour doorstaff, fitness center, outdoor pool, amazing rooftop deck, laundry room, etc. Rental parking options available in attached garage starting at $121. Very healthy building with $12 million in reserves as of 2/29/2024. Rentals allowed with lease minimum of 12 months.  No rental cap.  Highly desired Old Town location right across from the lake, parks, baseball and soccer fields, trails, etc. Exit through the back of the building and you are in the heart of all the Wells Street action surrounded by restaurants, night life, shopping and entertainment. CTA - the 156 bus stops directly in front of the building and the 22 bus is across the street. Brown and Red lines are a short walk. Additional annual neighborhood highlights include the Wells Street and Old Town Art Fairs as well as front row seats to the spectacular Air and Water Show. Although we love our furry pets, 1660 unfortunately is not a dog friendly building (of course, service and ESA animals are welcome).
#
# Propertytype: MULTI_FAMILY, Address: 7801 W Summerdale Ave, Chicago, IL 60656, Price: 325500, Bedrooms: 2, Bathrooms: 2, Detailurl: https://www.zillow.com/homedetails/7801-W-Summerdale-Ave-Chicago-IL-60656/3583976_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/3d472df8b68f814af810007e481987fd-p_e.jpg, Description: Oriole Park Gem! This Impressive 2-story Duplex features gleaming hardwood floors throughout, a gorgeous living room with custom bay window. Modern kitchen with dining area, recessed lighting, newer stainless steel appliances and granite counters. The beautiful 2nd level is filled with natural light and offers two spacious bedrooms and closets, updated full bath and linen closet. The lower level basement has a cozy finished family room, a full bath with walk-in shower, separate laundry room and tons of storage space. Step outside to a large deck that overlooks an amazing landscaped yard filled with perennials, trees and shrubs. The beautiful stone walkway leads to your oversized two car garage. This home has been  meticulously maintained and offers many recent updates:(2023) New roof, chimney copper flashing and crown sealer. (2022) basement hopper windows, (2021) new fence, attic fan. (2020) Carrier furnace. (2020) Clean check backwater valve installed. (2019) Larson storm doors, overhead garage door & opener. Several other improvements were made along the way. Excellent location! Walking distance to Blue Line Station, highly-rated schools and parks. Easy access to the expressway, O'Hare Airport, and downtown. This is a MUST SEE!

# %%
# generate prompt
prompt = generate_prompt_property(instruction, user_query, property_info)

# %%
print(prompt)
# Out:
# ### Instructions ###
# I want you to act as a real estate advisor. Please recommend properties to the customer.
# 'User’s query' represents the questions you are asked by the customer.
# 'Real estate properties to present to the user' are the properties you will introduce to the customer.　Please include all the details provided, including links, in your response.
#
# ### User’s query ###
# I am looking for a two-bedroom.
#
# ### Real estate properties to present to the user ###
# Propertytype: SINGLE_FAMILY, Address: 10500 S Church St, Chicago, IL 60643, Price: 244900, Bedrooms: 2, Bathrooms: 1, Detailurl: https://www.zillow.com/homedetails/10500-S-Church-St-Chicago-IL-60643/4143638_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/a5a3f713652b246545f67e89d17d0ed0-p_e.jpg, Description: Location, Location, Location! Make this huge corner bungalow your dream home in the Beverly area.  Step inside and be engulfed by the entryway, that leads to a unique living room with a custom full wall book shelf, that flows into an elegant dining area with a beautiful chandelier and complemented by a huge bay window. Then move to the completely remodeled kitchen that will blow you away.  The bath has been updated with ceramic tile and vanity.  The lower level  features a possible 3rd bedroom, an office, storage or exercise room, and a roughed-in bath.  The attic is ready for your creative ideas for a master suite or two additional bedrooms and a bath.  Walk out  to the huge deck that is great for entertaining.   Proceed to a newer two car garage.from the large yard enclosed by a wrought iron fence. Near Metra, bus line and expressway.  Beautiful, quiet block with nice neighbors. This beauty will not last.
#
# Propertytype: CONDO, Address: 1660 N La Salle St #1302, Chicago, IL 60614, Price: 465000, Bedrooms: 2, Bathrooms: 2, Detailurl: https://www.zillow.com/homedetails/1660-N-La-Salle-St-1302-Chicago-IL-60614/348746300_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/5b24f7400972354118c83732038a7aeb-p_e.jpg, Description: Old Town's most coveted high rise in prime location!  Rarely available 2bed/2bath Corner Unit with Fabulous South Facing City Views. Immediately as you enter the unit, you will be enchanted with the entire condo.  From the beautiful upgrades including Hardwood Flooring - Elegant Kitchen - Customized Built Ins - Large Balcony - Floor To Ceiling Windows - Storage Galore, this condo has it all.  Saturated with sunlight enjoy picturesque views of the skyline, sunsets and views of the Lake from your private balcony. Full amenity building including 24 hour doorstaff, fitness center, outdoor pool, amazing rooftop deck, laundry room, etc. Rental parking options available in attached garage starting at $121. Very healthy building with $12 million in reserves as of 2/29/2024. Rentals allowed with lease minimum of 12 months.  No rental cap.  Highly desired Old Town location right across from the lake, parks, baseball and soccer fields, trails, etc. Exit through the back of the building and you are in the heart of all the Wells Street action surrounded by restaurants, night life, shopping and entertainment. CTA - the 156 bus stops directly in front of the building and the 22 bus is across the street. Brown and Red lines are a short walk. Additional annual neighborhood highlights include the Wells Street and Old Town Art Fairs as well as front row seats to the spectacular Air and Water Show. Although we love our furry pets, 1660 unfortunately is not a dog friendly building (of course, service and ESA animals are welcome).
#
# Propertytype: MULTI_FAMILY, Address: 7801 W Summerdale Ave, Chicago, IL 60656, Price: 325500, Bedrooms: 2, Bathrooms: 2, Detailurl: https://www.zillow.com/homedetails/7801-W-Summerdale-Ave-Chicago-IL-60656/3583976_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/3d472df8b68f814af810007e481987fd-p_e.jpg, Description: Oriole Park Gem! This Impressive 2-story Duplex features gleaming hardwood floors throughout, a gorgeous living room with custom bay window. Modern kitchen with dining area, recessed lighting, newer stainless steel appliances and granite counters. The beautiful 2nd level is filled with natural light and offers two spacious bedrooms and closets, updated full bath and linen closet. The lower level basement has a cozy finished family room, a full bath with walk-in shower, separate laundry room and tons of storage space. Step outside to a large deck that overlooks an amazing landscaped yard filled with perennials, trees and shrubs. The beautiful stone walkway leads to your oversized two car garage. This home has been  meticulously maintained and offers many recent updates:(2023) New roof, chimney copper flashing and crown sealer. (2022) basement hopper windows, (2021) new fence, attic fan. (2020) Carrier furnace. (2020) Clean check backwater valve installed. (2019) Larson storm doors, overhead garage door & opener. Several other improvements were made along the way. Excellent location! Walking distance to Blue Line Station, highly-rated schools and parks. Easy access to the expressway, O'Hare Airport, and downtown. This is a MUST SEE!
#
# ### Output ###

# %%
# get final response from Gemini
print(get_chat_response(chat, prompt))
# Out:
# ## Two-Bedroom Recommendations for You:
#
# Based on your interest in two-bedroom properties, here are three options that might be a good fit for you:
#
# **1. Spacious Bungalow in Beverly (Single Family):**
#
# * **Address:** 10500 S Church St, Chicago, IL 60643
# * **Price:** $244,900
# * **Bedrooms:** 2
# * **Bathrooms:** 1
# * **Details:** https://www.zillow.com/homedetails/10500-S-Church-St-Chicago-IL-60643/4143638_zpid/
# * **Image:** https://photos.zillowstatic.com/fp/a5a3f713652b246545f67e89d17d0ed0-p_e.jpg
# * **Description:** This charming corner bungalow boasts a spacious living room with a custom bookshelf, an elegant dining area with a bay window, and a completely remodeled kitchen. It also features a finished basement with a possible third bedroom, an office, and storage space. The attic is perfect for creating a master suite or two additional bedrooms and a bathroom. Enjoy the outdoors on the large deck and fenced-in yard. This home is near Metra, the bus line, and the expressway, making it an ideal location for commuters.
#
# **2. Corner Unit with City Views in Old Town (Condo):**
#
# * **Address:** 1660 N La Salle St #1302, Chicago, IL 60614
# * **Price:** $465,000
# * **Bedrooms:** 2
# * **Bathrooms:** 2
# * **Details:** https://www.zillow.com/homedetails/1660-N-La-Salle-St-1302-Chicago-IL-60614/348746300_zpid/
# * **Image:** https://photos.zillowstatic.com/fp/5b24f7400972354118c83732038a7aeb-p_e.jpg
# * **Description:** This stunning corner unit offers incredible south-facing city views. The condo is filled with natural light and features hardwood floors, a customized kitchen, built-ins, a large balcony, and floor-to-ceiling windows. Enjoy the amenities of the building, including a 24-hour doorman, a fitness center, an outdoor pool, a rooftop deck, and laundry facilities. Rental parking is available in the attached garage. This condo is located in a highly desirable area steps away from the lake, parks, and entertainment options. Public transportation is easily accessible, making it easy to get around the city.
#
# **3. Oriole Park Gem (Multi-Family):**
#
# * **Address:** 7801 W Summerdale Ave, Chicago, IL 60656
# * **Price:** $325,500
# * **Bedrooms:** 2
# * **Bathrooms:** 2
# * **Details:** https://www.zillow.com/homedetails/7801-W-Summerdale-Ave-Chicago-IL-60656/3583976_zpid/
# * **Image:** https://photos.zillowstatic.com/fp/3d472df8b68f814af81007e481987fd-p_e.jpg
# * **Description:** This beautifully maintained duplex features gleaming hardwood floors throughout, a charming living room, and a modern kitchen with stainless steel appliances and granite counters. The second level offers two spacious bedrooms with ample closet space and an updated bathroom. The finished basement includes a family room, a full bath, and a laundry room. Enjoy the outdoors on the large deck overlooking the landscaped yard. This home is conveniently located near the Blue Line Station, schools, parks, and major expressways.
#
# **Please note:** This is just a small sample of two-bedroom properties available in Chicago. I encourage you to explore other options and find the one that best suits your needs and preferences.

# %% [markdown]
# ## 5. Integrating all functions

# %%
## TBD
