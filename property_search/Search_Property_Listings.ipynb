# %% [markdown]
# # Search Property Listings
# 1. Model Setting
# 2. Create API filter from user's query
# 3. Get Property Listings from Zillow API
# 4. Generate advice with the property listings

# %% [markdown]
# ## 1. Model Setting - Gemini pro 1.0

# %%
# %pip list | grep google-cloud-aiplatform
# %pip list | grep google-api-core

# %%
# %pip install google-cloud-aiplatform==1.43.0
# %pip install google-api-core==2.17.1

# %%
import vertexai
from vertexai.preview.generative_models import GenerativeModel, ChatSession, Part
import vertexai.preview.generative_models as generative_models
# Out:
# 2024-05-07 22:05:56.764255: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-07 22:05:57.936525: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2024-05-07 22:05:57.936651: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2024-05-07 22:05:57.936662: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
vertexai.init(project="adsp-capstone-property-pilot", location="us-central1")

# %%
model = GenerativeModel("gemini-1.0-pro")
chat = model.start_chat()

def get_chat_response(chat: ChatSession, prompt: str) -> str:
    text_response = []
    responses = chat.send_message(prompt, stream=True)
    for chunk in responses:
        text_response.append(chunk.text)
    return "".join(text_response)

# %% [markdown]
# ### Test

# %%
prompt = "Hello."
print(get_chat_response(chat, prompt))
# Out:
# Hello there, how can I assist you today? 😊

# %% [markdown]
# ## 2. Create API filter from user's query

# %%
def generate_prompt_apifilter(instruction, user_query):
    return instruction.replace("{USER_QUERY}", user_query)

# %%
instruction = """
### Instructions ###
I want you to act as a principal software engineer. You'll be given a task to determine the parameters of an API call based on the "User's query" below, 
please modify the conditions and create the appropriate API filter. Provide your answer only for the part within ‘{}’. 
Do not include any other explanations in your response. Read the below instructions.

— Filter Options (Optional, so not required if not specified in the User's query) —

1. location
Format: STRING(lowercase)
Example: santa monica, ca

*If not specifically mentioned, use 'chicago, il'.
*Do not alter the format from the above example. 
*If you want to search for a specific neighborhood like Chicago's West Loop, please specify it in the Filter option '16. keywords', not here.
Incorrect example: "location": "west loop, chicago, il"
Correct example: "location": "chicago, il", "keywords": "west loop"


2. status_type
For purchase or for rent
Format: STRING
Example:
ForSale
ForRent

3. home_type
Property type comma-separated or empty for all types
Format: STRING
Example(ForRent):
Townhomes
Houses
Apartments_Condos_Co-ops

Example(ForSale):
Multi-family
Apartments
Houses
Manufactured
Condos
LotsLand
Townhomes

*If it cannot be determined from the User's query, specification is not necessary.

4. minPrice
If status_type = ForSale you can filter by min price.
Format: NUMBER
Example: 200000

5. maxPrice
If status_type = ForSale you can filter by max price.
Format: NUMBER
Example: 900000

6. rentMinPrice
If status_type = ForRent you can filter by min rent price.
Format: NUMBER
Example: 2000

7. rentMaxPrice
If status_type = ForRent you can filter by max rent price.
Format: NUMBER
Example: 3000

8. bathsMin
Bathrooms min count
Format: NUMBER
Example: 2
* If a specific number of baths is specified, rather than a range, please enter the same number for both bathsMin and bathsMax.

9. bathsMax
Bathrooms max count
Format: NUMBER
Example: 3

10. bedsMin
Bedrooms min count
Format: NUMBER
Example: 1
* If a specific number of bedrooms is specified, rather than a range, please enter the same number for both bedsMin and bedsMax.

11. bedsMax
Bedrooms max count
Format: NUMBER
Example: 3

12. sqftMin
Square Feet min value
Format: NUMBER
Example: 600

13. sqftMax
Square Feet max value
Format: NUMBER
Example: 1500

14. buildYearMin
Year Built min value
Format: NUMBER
Example: 1980

15. buildYearMax
Year Built max value
Format: NUMBER
Example: 2023

16. keywords
Filter with keywords.
Format: STRING
Example1: ‘gym’
Example2: ‘West Loop’
Example3: ‘pet, pool, South Loop‘
*Not necessary if already specified in another filter or if there is no clear specification in user’s query. Specify conditions that cannot be specified in other filters by using keywords.

17. sort
Sorting criteria for the results
Always specify "Newest"


Now, use the following query to determine the appropriate parameters.

### Example query ###
I am looking for a one-bedroom.

### Example Output ###
{
"location":"chicago, il",
"bedsMin":"1",
"bedsMax":"1",
"sort":"Newest"
}

### Example query ###
I am looking for a rental in South Loop, Chicago, with at least one bedroom and a rent of $3000 or less per month.

### Example Output ###
{
"location": "chicago, il",
"status_type": "ForRent",
"rentMaxPrice": 3000,
"bedsMin": 1,
"keywords": "South Loop",
"sort":"Newest"
}

### Example query ###
I am looking for a rental in West Loop, Chicago, with one bedroom and a rent between $2000 and $2500.

### Example Output ###
{
"location": "chicago, il",
"status_type": "ForRent",
"rentMinPrice": 2500,
"rentMaxPrice": 3000,
"bedsMin": 1,
"bedsMax": 1,
"keywords": "West Loop",
"sort":"Newest"
}

### Example query ###
I want to buy a house in River North with at least two bedrooms.

### Example Output ###
{
"location":"chicago, il",
"status_type": "ForSale",
"keywords":"River North",
"bedsMin":"2",
"sort":"Newest"
}

### Example query ###
I am looking for a rental around Wicker Park in Chicago with a gym and a pool. It should be built within the last 10 years.

### Example Output ###
{
"location": "chicago, il",
"home_type": "Apartments_Condos_Co-ops",
"status_type": "ForRent",
"buildYearMin": 2014,
"keywords": "Wicker Park, gym, pool",
"sort":"Newest"
}

### Example query ###
I am looking for a rental with a balcony, over 700 sqft in size, and less than 5 years old, located near downtown.

### Example Output ###
{
"location": "chicago, il",
"status_type": "ForRent",
"sqftMin":"700",
"buildYearMin": 2019,
"keywords": "downtown, balcony",
"sort":"Newest"
}


### User’s query ###
{USER_QUERY}

### Output ###
"""

# %%
user_query = "I am looking for a two-bedroom."
print(generate_prompt_apifilter(instruction, user_query))
# Out:
# ### Instructions ###
# I want you to act as a principal software engineer. You'll be given a task to determine the parameters of an API call based on the "User's query" below,
# please modify the conditions and create the appropriate API filter. Provide your answer only for the part within ‘{}’.
# Do not include any other explanations in your response. Read the below instructions.
#
# — Filter Options (Optional, so not required if not specified in the User's query) —
#
# 1. location
# Format: STRING(lowercase)
# Example: santa monica, ca
#
# *If not specifically mentioned, use 'chicago, il'.
# *Do not alter the format from the above example.
# *If you want to search for a specific neighborhood like Chicago's West Loop, please specify it in the Filter option '16. keywords', not here.
# Incorrect example: "location": "west loop, chicago, il"
# Correct example: "location": "chicago, il", "keywords": "west loop"
#
#
# 2. status_type
# For purchase or for rent
# Format: STRING
# Example:
# ForSale
# ForRent
#
# 3. home_type
# Property type comma-separated or empty for all types
# Format: STRING
# Example(ForRent):
# Townhomes
# Houses
# Apartments_Condos_Co-ops
#
# Example(ForSale):
# Multi-family
# Apartments
# Houses
# Manufactured
# Condos
# LotsLand
# Townhomes
#
# *If it cannot be determined from the User's query, specification is not necessary.
#
# 4. minPrice
# If status_type = ForSale you can filter by min price.
# Format: NUMBER
# Example: 200000
#
# 5. maxPrice
# If status_type = ForSale you can filter by max price.
# Format: NUMBER
# Example: 900000
#
# 6. rentMinPrice
# If status_type = ForRent you can filter by min rent price.
# Format: NUMBER
# Example: 2000
#
# 7. rentMaxPrice
# If status_type = ForRent you can filter by max rent price.
# Format: NUMBER
# Example: 3000
#
# 8. bathsMin
# Bathrooms min count
# Format: NUMBER
# Example: 2
# * If a specific number of baths is specified, rather than a range, please enter the same number for both bathsMin and bathsMax.
#
# 9. bathsMax
# Bathrooms max count
# Format: NUMBER
# Example: 3
#
# 10. bedsMin
# Bedrooms min count
# Format: NUMBER
# Example: 1
# * If a specific number of bedrooms is specified, rather than a range, please enter the same number for both bedsMin and bedsMax.
#
# 11. bedsMax
# Bedrooms max count
# Format: NUMBER
# Example: 3
#
# 12. sqftMin
# Square Feet min value
# Format: NUMBER
# Example: 600
#
# 13. sqftMax
# Square Feet max value
# Format: NUMBER
# Example: 1500
#
# 14. buildYearMin
# Year Built min value
# Format: NUMBER
# Example: 1980
#
# 15. buildYearMax
# Year Built max value
# Format: NUMBER
# Example: 2023
#
# 16. keywords
# Filter with keywords.
# Format: STRING
# Example1: ‘gym’
# Example2: ‘West Loop’
# Example3: ‘pet, pool, South Loop‘
# *Not necessary if already specified in another filter or if there is no clear specification in user’s query. Specify conditions that cannot be specified in other filters by using keywords.
#
# 17. sort
# Sorting criteria for the results
# Always specify "Newest"
#
#
# Now, use the following query to determine the appropriate parameters.
#
# ### Example query ###
# I am looking for a one-bedroom.
#
# ### Example Output ###
# {
# "location":"chicago, il",
# "bedsMin":"1",
# "bedsMax":"1",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental in South Loop, Chicago, with at least one bedroom and a rent of $3000 or less per month.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "rentMaxPrice": 3000,
# "bedsMin": 1,
# "keywords": "South Loop",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental in West Loop, Chicago, with one bedroom and a rent between $2000 and $2500.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "rentMinPrice": 2500,
# "rentMaxPrice": 3000,
# "bedsMin": 1,
# "bedsMax": 1,
# "keywords": "West Loop",
# "sort":"Newest"
# }
#
# ### Example query ###
# I want to buy a house in River North with at least two bedrooms.
#
# ### Example Output ###
# {
# "location":"chicago, il",
# "status_type": "ForSale",
# "keywords":"River North",
# "bedsMin":"2",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental around Wicker Park in Chicago with a gym and a pool. It should be built within the last 10 years.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "home_type": "Apartments_Condos_Co-ops",
# "status_type": "ForRent",
# "buildYearMin": 2014,
# "keywords": "Wicker Park, gym, pool",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental with a balcony, over 700 sqft in size, and less than 5 years old, located near downtown.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "sqftMin":"700",
# "buildYearMin": 2019,
# "keywords": "downtown, balcony",
# "sort":"Newest"
# }
#
#
# ### User’s query ###
# I am looking for a two-bedroom.
#
# ### Output ###

# %% [markdown]
# ### Test

# %%
user_query = "I am looking for a two-bedroom."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "bedsMin": "2",
# "bedsMax": "2"
# }

# %%
user_query = "I am looking for a rental in Fulton Market, Chicago, with at least one bedroom and a rent of $3500 or less per month."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
#     "location":"chicago, il",
#     "status_Type":"ForRent",
#     "rentMaxPrice": 3500,
#     "bedsMin": 1,
#     "keywords":"Fulton Market",
#     "sort": "Newest"
# }

# %%
user_query = "I want to buy a house in Chinatown, Chicago with a minimum of 2 bathrooms and 2 bedrooms."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location":"chicago, il",
# "status_type": "ForSale",
# "keywords":"Chinatown",
# "bedsMin":"2",
# "bathsMin":"2",
# "sort":"Newest"
# }

# %%
user_query = "I am looking for a rental around Hyde Park with a gym and a pool. It should be built within the last 15 years."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location":"chicago, il",
# "home_type": "Apartments_Condos_Co-ops",
# "status_type": "ForRent",
# "buildYearMin": 2009,
# "keywords":"Hyde Park, gym, pool",
# "sort":"Newest"
# }

# %%
user_query = "I am looking for a rental in the Old Town area of Chicago with a balcony and a pool."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location":"chicago, il",
# "status_type":"ForRent",
# "keywords":"Old Town, balcony, pool",
# "sort":"Newest"
# }

# %% [markdown]
# ## 3. Get Property Listings from Zillow API

# %% [markdown]
# ### Example - Extended Search endpoint

# %%
import requests

url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

headers = {
	"X-RapidAPI-Key": "RAPID_API_KEY",
	"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

# %%
querystring = {"location":"chicago, il", "status_type":"ForRent", "bathsMin":"1","bedsMin":"3", "keywords":"west", "sort":"Newest"}
response = requests.get(url, headers = headers, params = querystring)

# %%
response.json()
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2253 W Iowa St #3F, Chicago, IL 60622',
#    'variableData': None,
#    'unit': '# 3F',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/24cfac4e50b54ac036925874a4d4b395-p_e.jpg',
#    'price': 2695,
#    'detailUrl': '/homedetails/2253-W-Iowa-St-3F-Chicago-IL-60622/2069892388_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.68405,
#    'latitude': 41.897385,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2069892388',
#    'listingSubType': {},
#    'rentZestimate': 2625,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$7,113+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.86681--87.62358',
#    'longitude': -87.62358,
#    'buildingName': 'NEMA Chicago',
#    'address': '1210 S Indiana Ave, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/nema-chicago/9RwqTm/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2103778973,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/35f6b1437825b0cf43201316158e8000-p_e.jpg',
#    'latitude': 41.86681},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2065 N. Hoyne Ave., 2065 N Hoyne Ave #3R, Chicago, IL 60647',
#    'variableData': None,
#    'unit': '# 3R',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/8094800d8257833f346cfb9030093cee-p_e.jpg',
#    'price': 2295,
#    'detailUrl': '/apartments/chicago-il/2065-n.-hoyne-ave./5XgKsR/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.67988,
#    'latitude': 41.91961,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2078703913',
#    'listingSubType': {},
#    'rentZestimate': 3091,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2171 W Wilson Ave #G, Chicago, IL 60625',
#    'variableData': None,
#    'unit': '# G',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/9bf433c40e11e13adb775c831547b599-p_e.jpg',
#    'price': 2875,
#    'detailUrl': '/homedetails/2171-W-Wilson-Ave-G-Chicago-IL-60625/344680780_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.683426,
#    'latitude': 41.964794,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '344680780',
#    'listingSubType': {},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '741 S Claremont Ave APT 2, Chicago, IL 60612',
#    'variableData': None,
#    'unit': 'Apt 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2b2aeffa1521dd832e93a8130dad5e62-p_e.jpg',
#    'price': 2300,
#    'detailUrl': '/homedetails/741-S-Claremont-Ave-APT-2-Chicago-IL-60612/2089532428_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.68466,
#    'latitude': 41.87193,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2089532428',
#    'listingSubType': {},
#    'rentZestimate': 2650,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1250,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'CONDO',
#    'lotAreaValue': None,
#    'address': '1717 N Western Ave APT 4, Chicago, IL 60647',
#    'variableData': None,
#    'unit': 'Apt 4',
#    'zestimate': 484600,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3a4c8f573065ecbb550b244c33ac8186-p_e.jpg',
#    'price': 3500,
#    'detailUrl': '/homedetails/1717-N-Western-Ave-APT-4-Chicago-IL-60647/89889690_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.6869,
#    'latitude': 41.9127,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '89889690',
#    'listingSubType': {},
#    'rentZestimate': 2998,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2029 W Superior St APT 1, Chicago, IL 60612',
#    'variableData': None,
#    'unit': 'Apt 1',
#    'zestimate': 478500,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a1e112048c3a9d0181b13dc203dee652-p_e.jpg',
#    'price': 2849,
#    'detailUrl': '/homedetails/2029-W-Superior-St-APT-1-Chicago-IL-60612/65565145_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.678246,
#    'latitude': 41.894585,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '65565145',
#    'listingSubType': {},
#    'rentZestimate': 2999,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2647 W Evergreen Ave #2, Chicago, IL 60622',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/939bb63c357970d18275f494010bfdae-p_e.jpg',
#    'price': 2500,
#    'detailUrl': '/homedetails/2647-W-Evergreen-Ave-2-Chicago-IL-60622/2100476192_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.69385,
#    'latitude': 41.90543,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2100476192',
#    'listingSubType': {},
#    'rentZestimate': 2227,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1155,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '4419 N Albany Ave APT 2, Chicago, IL 60625',
#    'variableData': None,
#    'unit': 'Apt 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/52d79122192446df0872b5524f28cc3f-p_e.jpg',
#    'price': 2790,
#    'detailUrl': '/homedetails/4419-N-Albany-Ave-APT-2-Chicago-IL-60625/2106444844_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.705475,
#    'latitude': 41.961807,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2106444844',
#    'listingSubType': {},
#    'rentZestimate': 2500,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1300,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2312 S Seeley Ave #2, Chicago, IL 60608',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/9a46d07c60273ebd8bd73fcc05a65462-p_e.jpg',
#    'price': 3000,
#    'detailUrl': '/homedetails/2312-S-Seeley-Ave-2-Chicago-IL-60608/2079985241_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.67746,
#    'latitude': 41.849895,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2079985241',
#    'listingSubType': {},
#    'rentZestimate': 1992,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 2450,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1544 W Wabansia Ave #1R, Chicago, IL 60642',
#    'variableData': None,
#    'unit': '# 1R',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ed29765ddb56a1fb55bd21b85196f236-p_e.jpg',
#    'price': 2200,
#    'detailUrl': '/homedetails/1544-W-Wabansia-Ave-1R-Chicago-IL-60642/2103220945_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.66716,
#    'latitude': 41.91272,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2103220945',
#    'listingSubType': {},
#    'rentZestimate': 2677,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 900,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1953 W Dickens Ave #CH, Chicago, IL 60614',
#    'variableData': None,
#    'unit': '# CH',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/fa827157730c93b61acc686c8b3d58f8-p_e.jpg',
#    'price': 4200,
#    'detailUrl': '/homedetails/1953-W-Dickens-Ave-CH-Chicago-IL-60614/2066642415_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.67733,
#    'latitude': 41.91936,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2066642415',
#    'listingSubType': {},
#    'rentZestimate': 3577,
#    'daysOnZillow': 0,
#    'bathrooms': 2.5,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1317 W Loyola Ave #4A, Chicago, IL 60626',
#    'variableData': None,
#    'unit': '# 4A',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/0ad5f6367ebb04925c750160cc7d3dd0-p_e.jpg',
#    'price': 4800,
#    'detailUrl': '/homedetails/1317-W-Loyola-Ave-4A-Chicago-IL-60626/2070782168_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.664314,
#    'latitude': 42.00109,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2070782168',
#    'listingSubType': {},
#    'rentZestimate': 4069,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 1855,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '4', 'price': '$3,800+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '42.00112--87.66431',
#    'longitude': -87.66431,
#    'buildingName': None,
#    'address': '1317 W Loyola Ave, Chicago, IL',
#    'detailUrl': '/b/1317-w-loyola-ave-chicago-il-9S2YD6/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2104217686,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/0ad5f6367ebb04925c750160cc7d3dd0-p_e.jpg',
#    'latitude': 42.00112},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2325 W Arthur Ave APT 3, Chicago, IL 60645',
#    'variableData': None,
#    'unit': 'Apt 3',
#    'zestimate': 301400,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/0a98acbce15f131f804c695fb1b9d328-p_e.jpg',
#    'price': 2100,
#    'detailUrl': '/homedetails/2325-W-Arthur-Ave-APT-3-Chicago-IL-60645/2094649841_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.68852,
#    'latitude': 41.999573,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2094649841',
#    'listingSubType': {},
#    'rentZestimate': 1527,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$5,629+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.88474--87.65915',
#    'longitude': -87.65915,
#    'buildingName': 'Fulbrix',
#    'address': '160 N Elizabeth St, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/fulbrix/9Rx6Sz/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2103810148,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2b170a16823872fb642b0a1b271463f5-p_e.jpg',
#    'latitude': 41.88474},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': '1833 W Belle Plaine Ave UNIT 1, Chicago, IL 60613',
#    'variableData': None,
#    'unit': 'Unit 1',
#    'zestimate': 493900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e6da731fad33b2ecf2f5ff7242f73a19-p_e.jpg',
#    'price': 2600,
#    'detailUrl': '/homedetails/1833-W-Belle-Plaine-Ave-UNIT-1-Chicago-IL-60613/348322720_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.67555,
#    'latitude': 41.955772,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '348322720',
#    'listingSubType': {},
#    'rentZestimate': 2400,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '701 S Karlov Ave, 701 S Karlov Ave #G, Chicago, IL 60624',
#    'variableData': None,
#    'unit': '# G',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2504e3e75e41d9063c7ba82f1ab989e3-p_e.jpg',
#    'price': 1375,
#    'detailUrl': '/apartments/chicago-il/701-s-karlov-ave/D2j9/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.72759,
#    'latitude': 41.872112,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2079620264',
#    'listingSubType': {},
#    'rentZestimate': 1464,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 946,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '6135-45 S. Dorchester Ave/1409 E. 61st St., 6135 S Dorchester Ave #6137-3, Chicago, IL 60637',
#    'variableData': None,
#    'unit': '# 6137-3',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ff832c73ee57ee20ba27c79ad196586f-p_e.jpg',
#    'price': 1595,
#    'detailUrl': '/apartments/chicago-il/6135.dash.45-s.-dorchester-ave-1409-e.-61st-st./BfwC/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.591064,
#    'latitude': 41.783047,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2084539039',
#    'listingSubType': {},
#    'rentZestimate': 1566,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$2,500+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.8726--87.66137',
#    'longitude': -87.66137,
#    'buildingName': '725 S Loomis',
#    'address': '725 S Loomis St, Chicago, IL',
#    'detailUrl': '/b/725-s-loomis-chicago-il-9Rx8zw/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2103816221,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/15ac328c47a3d026132bd2f596955390-p_e.jpg',
#    'latitude': 41.8726},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1157 W 18th St APT F301, Chicago, IL 60608',
#    'variableData': None,
#    'unit': 'Apt F301',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/23136d8cfb5c4b5e3c58e727dd504f43-p_e.jpg',
#    'price': 2899,
#    'detailUrl': '/homedetails/1157-W-18th-St-APT-F301-Chicago-IL-60608/2094981637_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.65544,
#    'latitude': 41.85746,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2094981637',
#    'listingSubType': {},
#    'rentZestimate': 2199,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 925,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1430 E 69th St APT 4, Chicago, IL 60637',
#    'variableData': None,
#    'unit': 'Apt 4',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1d411a2c51ac6550cba523baf2991581-p_e.jpg',
#    'price': 1795,
#    'detailUrl': '/homedetails/1430-E-69th-St-APT-4-Chicago-IL-60637/2069976591_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.58977,
#    'latitude': 41.769924,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2069976591',
#    'listingSubType': {},
#    'rentZestimate': 1770,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': '6030 S Prairie Ave APT 2, Chicago, IL 60637',
#    'variableData': None,
#    'unit': 'Apt 2',
#    'zestimate': 263700,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/86529141c287d99990263b23b30cba92-p_e.jpg',
#    'price': 1775,
#    'detailUrl': '/homedetails/6030-S-Prairie-Ave-APT-2-Chicago-IL-60637/2085269022_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.61946,
#    'latitude': 41.784668,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2085269022',
#    'listingSubType': {},
#    'rentZestimate': 1952,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1360,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '5624 S. Wabash, 5606-24 S Wabash Ave #5624-314, Chicago, IL 60637',
#    'variableData': None,
#    'unit': '# 5624-314',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/0b06fe29a06cc284f31c0f76726e22c1-p_e.jpg',
#    'price': 1350,
#    'detailUrl': '/apartments/chicago-il/5624-s.-wabash/BfjdGT/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.624016,
#    'latitude': 41.792786,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2060424256',
#    'listingSubType': {},
#    'rentZestimate': 1474,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 965,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '818 S Loomis St, Chicago, IL 60607',
#    'variableData': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/df9452fc6e8883df497538a33ba5572b-p_e.jpg',
#    'price': 2700,
#    'detailUrl': '/homedetails/818-S-Loomis-St-Chicago-IL-60607/2079232220_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.66204,
#    'latitude': 41.87108,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2079232220',
#    'listingSubType': {},
#    'rentZestimate': 2707,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$6,050+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.879444--87.655014',
#    'longitude': -87.655014,
#    'buildingName': None,
#    'address': '134 S Aberdeen St, Chicago, IL',
#    'detailUrl': '/b/134-s-aberdeen-st-chicago-il-63PxT8/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 1138012707,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/39b341c3d0d9e7b45d1e4884aa97364b-p_e.jpg',
#    'latitude': 41.879444},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1753 W Chicago Ave #3, Chicago, IL 60622',
#    'variableData': None,
#    'unit': '# 3',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f9f148fb9fc7d58f93c8831068bb73ca-p_e.jpg',
#    'price': 3400,
#    'detailUrl': '/homedetails/1753-W-Chicago-Ave-3-Chicago-IL-60622/2112431022_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.67181,
#    'latitude': 41.895695,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2112431022',
#    'listingSubType': {},
#    'rentZestimate': 3768,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 2000,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$2,355+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.796295--87.71381',
#    'longitude': -87.71381,
#    'buildingName': '3601 W 53rd St',
#    'address': '3601 W 53rd St, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/3601-w-53rd-st/CZd3/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 1127589,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/0832a82490c44d3943a7293a05ad53ef-p_e.jpg',
#    'latitude': 41.796295},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '14 N Peoria St SUITE 3F, Chicago, IL 60607',
#    'variableData': None,
#    'unit': 'Suite 3F',
#    'zestimate': 587000,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/21c40ac60266b77bb11f61c697bf76d3-p_e.jpg',
#    'price': 4980,
#    'detailUrl': '/homedetails/14-N-Peoria-St-SUITE-3F-Chicago-IL-60607/60267339_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.65022,
#    'latitude': 41.882458,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '60267339',
#    'listingSubType': {},
#    'rentZestimate': 4300,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1800,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2029 W Walton St #2, Chicago, IL 60622',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b15c218ac1efe818720d79b3abc97850-p_e.jpg',
#    'price': 3200,
#    'detailUrl': '/homedetails/2029-W-Walton-St-2-Chicago-IL-60622/2071446651_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.678276,
#    'latitude': 41.89837,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2071446651',
#    'listingSubType': {},
#    'rentZestimate': 3028,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1250,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': '(undisclosed Address), Chicago, IL 60636',
#    'variableData': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d0811a8115d40c50a5c89bfa48eea5ac-p_e.jpg',
#    'price': 2300,
#    'detailUrl': '/homedetails/Chicago-IL-60636/159052198_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': None,
#    'latitude': None,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '159052198',
#    'listingSubType': {},
#    'rentZestimate': 2100,
#    'daysOnZillow': 0,
#    'bathrooms': 1.5,
#    'livingArea': 1100,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$5,000+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.89134--87.66003',
#    'longitude': -87.66003,
#    'buildingName': None,
#    'address': '1324 W Grand Ave, Chicago, IL',
#    'detailUrl': '/b/1324-w-grand-ave-chicago-il-9S4kSk/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2104475213,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/79324794037e06019168817824b51e01-p_e.jpg',
#    'latitude': 41.89134},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1703 W Irving Park Rd, Chicago, IL 60613',
#    'variableData': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/69bf66cb91f0ed5e26e572b8879a5e3b-p_e.jpg',
#    'price': 3900,
#    'detailUrl': '/homedetails/1703-W-Irving-Park-Rd-Chicago-IL-60613/101365194_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.67174,
#    'latitude': 41.953953,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '101365194',
#    'listingSubType': {},
#    'rentZestimate': 4023,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 2400,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '3711 N Racine Ave #2, Chicago, IL 60613',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a8c397318420808487843d6025944589-p_e.jpg',
#    'price': 3750,
#    'detailUrl': '/homedetails/3711-N-Racine-Ave-2-Chicago-IL-60613/2089737022_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.65894,
#    'latitude': 41.949368,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2089737022',
#    'listingSubType': {},
#    'rentZestimate': 3599,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1275,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1916 S Leavitt St #2R, Chicago, IL 60608',
#    'variableData': None,
#    'unit': '# 2R',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d52027cc18fda04a59ec2bdc525785a0-p_e.jpg',
#    'price': 2000,
#    'detailUrl': '/homedetails/1916-S-Leavitt-St-2R-Chicago-IL-60608/2059963333_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.68117,
#    'latitude': 41.85519,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2059963333',
#    'listingSubType': {},
#    'rentZestimate': 1664,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 950,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '5758 S Wabash Ave, 5758 S Wabash Ave #5760-3, Chicago, IL 60637',
#    'variableData': None,
#    'unit': '# 5760-3',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/cabec870f8cebf4f9fe78d7fa859eeac-p_e.jpg',
#    'price': 1270,
#    'detailUrl': '/apartments/chicago-il/5758-s-wabash-ave/9S3y95/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.624435,
#    'latitude': 41.789356,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2080145494',
#    'listingSubType': {},
#    'rentZestimate': 1500,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '4936 S. Martin Luther King dr, 4936 S Martin Luther King Dr #2, Chicago, IL 60637',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/6a2f525b136829feb243c18144fcb3bd-p_e.jpg',
#    'price': 2500,
#    'detailUrl': '/b/4936-s.-martin-luther-king-dr-chicago-il-CdfbPD/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.61539,
#    'latitude': 41.7805,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '347932793',
#    'listingSubType': {},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'CONDO',
#    'lotAreaValue': None,
#    'address': '737 W Washington Blvd APT 2508, Chicago, IL 60661',
#    'variableData': None,
#    'unit': 'Apt 2508',
#    'zestimate': 765200,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/72d00f832837857965e424bccdb35d4d-p_e.jpg',
#    'price': 5200,
#    'detailUrl': '/homedetails/737-W-Washington-Blvd-APT-2508-Chicago-IL-60661/65567911_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.646614,
#    'latitude': 41.882866,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '65567911',
#    'listingSubType': {},
#    'rentZestimate': 4842,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1937,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1708 W School St #1, Chicago, IL 60657',
#    'variableData': None,
#    'unit': '# 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b46a692fe2f1881f93822dd8fee00864-p_e.jpg',
#    'price': 2350,
#    'detailUrl': '/homedetails/1708-W-School-St-1-Chicago-IL-60657/2110897716_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.67158,
#    'latitude': 41.94174,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2110897716',
#    'listingSubType': {},
#    'rentZestimate': 2568,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1100,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '3733 N Clark St APT 2N, Chicago, IL 60613',
#    'variableData': None,
#    'unit': 'Apt 2N',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/c1129985327d59ca4851254c89b0c054-p_e.jpg',
#    'price': 3000,
#    'detailUrl': '/homedetails/3733-N-Clark-St-APT-2N-Chicago-IL-60613/2090518043_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.65844,
#    'latitude': 41.94988,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2090518043',
#    'listingSubType': {},
#    'rentZestimate': 2700,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1400,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2420 W Eastwood Ave #2, Chicago, IL 60625',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5dde09d91a739342a2e0c60e649994e7-p_e.jpg',
#    'price': 2900,
#    'detailUrl': '/homedetails/2420-W-Eastwood-Ave-2-Chicago-IL-60625/349394558_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.68974,
#    'latitude': 41.965992,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '349394558',
#    'listingSubType': {},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True}],
#  'resultsPerPage': 41,
#  'totalPages': 10,
#  'totalResultCount': 382,
#  'schools': {},
#  'currentPage': 1}

# %%
def extract_properties(response, n, fields):
    """
    Extracts and returns the top 'n' properties from a given API response
    based on the specified fields, appending the base URL to 'detailUrl'.
    
    Parameters:
    - response: The response object from an API call.
    - n: The number of top properties to extract.
    - fields: A list of strings representing the fields to extract from each property.
    
    Returns:
    - A list of dictionaries, each representing a property with only the specified fields.
    """
    base_url = "https://www.zillow.com"
    try:
        # Convert the response to JSON format if it's not already a dictionary
        if not isinstance(response, dict):
            response = response.json()

        # Extract the top 'n' properties based on the specified fields
        top_properties = []
        for prop in response['props'][:n]:
            extracted_prop = {field: (base_url + prop['detailUrl'] if field == 'detailUrl' else prop.get(field, None)) for field in fields}
            top_properties.append(extracted_prop)

        return top_properties

    except Exception as e:
        print("An error occurred:", e)
        return []  # Return an empty list in case of an error

# %%
# Define fields to extract
fields = ["propertyType", "address", "price", "bedrooms", "bathrooms", "detailUrl", "imgSrc", "longitude", "latitude"]

# %%
# Get top 3 properties with selected fields
top_properties = extract_properties(response, 3, fields)
top_properties
# Out:
# [{'propertyType': 'APARTMENT',
#   'address': '2253 W Iowa St #3F, Chicago, IL 60622',
#   'price': 2695,
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/2253-W-Iowa-St-3F-Chicago-IL-60622/2069892388_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/24cfac4e50b54ac036925874a4d4b395-p_e.jpg',
#   'longitude': -87.68405,
#   'latitude': 41.897385},
#  {'propertyType': None,
#   'address': '1210 S Indiana Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/apartments/chicago-il/nema-chicago/9RwqTm/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/35f6b1437825b0cf43201316158e8000-p_e.jpg',
#   'longitude': -87.62358,
#   'latitude': 41.86681},
#  {'propertyType': 'APARTMENT',
#   'address': '2065 N. Hoyne Ave., 2065 N Hoyne Ave #3R, Chicago, IL 60647',
#   'price': 2295,
#   'bedrooms': 3,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/apartments/chicago-il/2065-n.-hoyne-ave./5XgKsR/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/8094800d8257833f346cfb9030093cee-p_e.jpg',
#   'longitude': -87.67988,
#   'latitude': 41.91961}]

# %% [markdown]
# ### Mapping the Properties

# %%
#pip install folium

# %%
import folium

def create_property_map(properties):
    # Attribution for custom tileset
    attr = '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors'
    
    # Initialize the map centered around Chicago
    property_map = folium.Map(location=[41.881832, -87.623177], zoom_start=11, tiles='OpenStreetMap_Mapnik', attr=attr)

    # Loop through each property in the list
    for prop in properties:
        # Extract latitude and longitude
        latitude = prop['latitude']
        longitude = prop['longitude']
        detail_url = prop['detailUrl']
        address = prop['address']

        # Add a marker to the map
        folium.Marker(
            location=[latitude, longitude],
            popup=folium.Popup(f'<a href="{detail_url}" target="_blank">{address}</a>', max_width=250),
            tooltip="Click for Zillow Listing",
            icon=folium.Icon(icon = 'home', color="blue")
        ).add_to(property_map)

    # Return the map
    return property_map

# %%
# Create the map
property_map = create_property_map(top_properties)

display(property_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a9fdd5bf4bc36d032f31344630be66e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a9fdd5bf4bc36d032f31344630be66e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a9fdd5bf4bc36d032f31344630be66e = L.map(
#                 &quot;map_3a9fdd5bf4bc36d032f31344630be66e&quot;,
#                 {
#                     center: [41.881832, -87.623177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01253d9a30339daabe0b7af058429b50 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_01253d9a30339daabe0b7af058429b50.addTo(map_3a9fdd5bf4bc36d032f31344630be66e);
#
#
#             var marker_16f5cc129c0c55b00c952c9d71cf7795 = L.marker(
#                 [41.897385, -87.68405],
#                 {}
#             ).addTo(map_3a9fdd5bf4bc36d032f31344630be66e);
#
#
#             var icon_ab27ad9afbea97b28006098e71ee3f1a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_16f5cc129c0c55b00c952c9d71cf7795.setIcon(icon_ab27ad9afbea97b28006098e71ee3f1a);
#
#
#         var popup_831005576d66db106856650328294615 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_9ed6d482a4c1399f46c6a929ce639e63 = $(`&lt;div id=&quot;html_9ed6d482a4c1399f46c6a929ce639e63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.zillow.com/homedetails/2253-W-Iowa-St-3F-Chicago-IL-60622/2069892388_zpid/&quot; target=&quot;_blank&quot;&gt;2253 W Iowa St #3F, Chicago, IL 60622&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_831005576d66db106856650328294615.setContent(html_9ed6d482a4c1399f46c6a929ce639e63);
#
#
#
#         marker_16f5cc129c0c55b00c952c9d71cf7795.bindPopup(popup_831005576d66db106856650328294615)
#         ;
#
#
#
#
#             marker_16f5cc129c0c55b00c952c9d71cf7795.bindTooltip(
#                 `&lt;div&gt;
#                      Click for Zillow Listing
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c896ef370e94515350e748b2c536df80 = L.marker(
#                 [41.86681, -87.62358],
#                 {}
#             ).addTo(map_3a9fdd5bf4bc36d032f31344630be66e);
#
#
#             var icon_7a4881a8e70331b3b63e01cf2a27391a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c896ef370e94515350e748b2c536df80.setIcon(icon_7a4881a8e70331b3b63e01cf2a27391a);
#
#
#         var popup_ff9c08f06f9234e6292a6fac12c6ffa5 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_52111e07b2ad4cc00f4bcb875b7ddcee = $(`&lt;div id=&quot;html_52111e07b2ad4cc00f4bcb875b7ddcee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.zillow.com/apartments/chicago-il/nema-chicago/9RwqTm/&quot; target=&quot;_blank&quot;&gt;1210 S Indiana Ave, Chicago, IL&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_ff9c08f06f9234e6292a6fac12c6ffa5.setContent(html_52111e07b2ad4cc00f4bcb875b7ddcee);
#
#
#
#         marker_c896ef370e94515350e748b2c536df80.bindPopup(popup_ff9c08f06f9234e6292a6fac12c6ffa5)
#         ;
#
#
#
#
#             marker_c896ef370e94515350e748b2c536df80.bindTooltip(
#                 `&lt;div&gt;
#                      Click for Zillow Listing
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_00bdfdada14c27d76c676a05b8729dfa = L.marker(
#                 [41.91961, -87.67988],
#                 {}
#             ).addTo(map_3a9fdd5bf4bc36d032f31344630be66e);
#
#
#             var icon_596003bdb106fcf5cca86d39ce3910f8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_00bdfdada14c27d76c676a05b8729dfa.setIcon(icon_596003bdb106fcf5cca86d39ce3910f8);
#
#
#         var popup_a9c6ec76e52debc77266e4b1c1baf28e = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_fb343ceaf55f4308f2c83a00bbf64067 = $(`&lt;div id=&quot;html_fb343ceaf55f4308f2c83a00bbf64067&quot; style=&quot;width: 100.0%; hei

# %% [markdown]
# ### Retrieving Restaurant Info Using Yelp API

# %%
yelp_api_key = 'YELP_API_KEY'

# %% [markdown]
# ### Extract restaurant category if there is one specified in the user query

# %%
def generate_prompt_rest_category(user_query):
    instruction = f"""
    ### Instructions ###
    Identify the category of restaurant the user is interested in based on their query. 
    If the query doesn't specify a type, return "restaurants". 
    Output should be a lowercase string. 
    If there are multiple categories, separate them with a comma with NO WHITE SPACES OR NEW LINE CHARACTERS.

    ### User’s query ###
    {user_query}

    ### Output ###
    """
    return instruction

# %% [markdown]
# ### Test restaurant category function

# %%
user_query = "I am looking for an apartment in the Hyde Park neighborhood of Chicago. I want two bedrooms and at least one bathroom. Rent should be less than $1500 per month. What are the best bars nearby?"

# Example call to a language model (you need to implement get_chat_response or use an existing function that sends this prompt to a language model)
prompt = generate_prompt_rest_category(user_query)
categories = get_chat_response(chat, prompt)  # Ensure this function captures only the output after "### Output ###"

print(categories)
# Out:
# bars

# %%
user_query = "I am looking for an apartment in the Hyde Park neighborhood of Chicago. I want two bedrooms and at least one bathroom. Rent should be less than $1500 per month. What are the best french restaurants and coffee shops nearby?"

# Example call to a language model (you need to implement get_chat_response or use an existing function that sends this prompt to a language model)
prompt = generate_prompt_rest_category(user_query)
categories = get_chat_response(chat, prompt)  # Ensure this function captures only the output after "### Output ###"

print(categories)
# Out:
# french,coffee

# %%
user_query = "I am looking for an apartment in the Hyde Park neighborhood of Chicago. I want two bedrooms and at least one bathroom. Rent should be less than $1500 per month."

# Example call to a language model (you need to implement get_chat_response or use an existing function that sends this prompt to a language model)
prompt = generate_prompt_rest_category(user_query)
categories = get_chat_response(chat, prompt)  # Ensure this function captures only the output after "### Output ###"

print(categories)
# Out:
# restaurants

# %% [markdown]
# ### Call Yelp API Functions

# %%
def get_top_rated_businesses(api_key, location, category, top_n=2):
    """Fetches top-rated businesses near a given location from Yelp."""
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f'Bearer {api_key}'
    }
    params = {
        'location': location,
        'term': 'restaurants',
        'radius': 2000,
        'categories': category,
        'sort_by': 'rating',
        'limit': top_n
    }
    print(params)
    response = requests.get(url, headers=headers, params=params)
    return response.json()

# %%
def fetch_top_businesses_near_properties(api_key, properties, user_query, chat):
    """
    Fetches top-rated businesses of a specified category near each property in a given list,
    using a category inferred from a user query processed by Gemini LLM.
    """
    prompt = generate_prompt_rest_category(user_query)
    category = get_chat_response(chat, prompt)  # Get the category from the LLM
    category = category.replace('"', '')  # Strip any quotation marks from the category
    if not category or category.lower() == "restaurants":
        category = "restaurants"  # Fallback to a default category if none specified
    print(f"Category determined: {category}")  # Log the category for debugging

    top_restaurants_yelp = []
    for property in properties:
        location = f"{property['latitude']}, {property['longitude']}"
        top_businesses = get_top_rated_businesses(api_key, location, category)
        top_restaurants_yelp.append({
            'address': property['address'],
            'top_businesses': top_businesses
        })
    
    return top_restaurants_yelp

# %% [markdown]
# ### Test Category Searching on Yelp

# %%
# Call the function
user_query = "I am looking for an apartment in the Hyde Park neighborhood of Chicago. I want two bedrooms and at least one bathroom. Rent should be less than $1500 per month. What are the best Mexican restaurants nearby?"

yelp_results = fetch_top_businesses_near_properties(yelp_api_key, top_properties, user_query, chat)

for result in yelp_results:
    print(result)
# Out:
# Category determined: mexican
# {'location': '41.897385, -87.68405', 'term': 'restaurants', 'radius': 2000, 'categories': 'mexican', 'sort_by': 'rating', 'limit': 2}
# {'location': '41.86681, -87.62358', 'term': 'restaurants', 'radius': 2000, 'categories': 'mexican', 'sort_by': 'rating', 'limit': 2}
# {'location': '41.91961, -87.67988', 'term': 'restaurants', 'radius': 2000, 'categories': 'mexican', 'sort_by': 'rating', 'limit': 2}
# {'address': '2253 W Iowa St #3F, Chicago, IL 60622', 'top_businesses': {'businesses': [{'id': 'HLUuqIzYaituoifAZTsiqw', 'alias': 'los-3-compadres-de-guerrero-chicago', 'name': 'Los 3 Compadres De Guerrero', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MF9NGkyv6wdn2YnKHhTc6A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/los-3-compadres-de-guerrero-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 6, 'categories': [{'alias': 'tacos', 'title': 'Tacos'}], 'rating': 4.8, 'coordinates': {'latitude': 41.898013, 'longitude': -87.687233}, 'transactions': ['delivery', 'pickup'], 'location': {'address1': '912 N Western Ave', 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60622', 'country': 'US', 'state': 'IL', 'display_address': ['912 N Western Ave', 'Chicago, IL 60622']}, 'phone': '+17736612005', 'display_phone': '(773) 661-2005', 'distance': 281.62320349715446, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'o98kicIhRgBjoMqQr2SzTQ', 'alias': 'sabroso-mexican-grill-chicago-4', 'name': 'Sabroso! Mexican Grill', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fpAPVi0BZAdIhpuM2aMqwg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/sabroso-mexican-grill-chicago-4?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 444, 'categories': [{'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'newmexican', 'title': 'New Mexican Cuisine'}], 'rating': 4.7, 'coordinates': {'latitude': 41.89319, 'longitude': -87.66753}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '624 N Ashland Ave', 'address2': '', 'address3': None, 'city': 'Chicago', 'zip_code': '60622', 'country': 'US', 'state': 'IL', 'display_address': ['624 N Ashland Ave', 'Chicago, IL 60622']}, 'phone': '+17732908400', 'display_phone': '(773) 290-8400', 'distance': 1430.2388008981657, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}], 'total': 58, 'region': {'center': {'longitude': -87.68394470214844, 'latitude': 41.89741891078323}}}}
# {'address': '1210 S Indiana Ave, Chicago, IL', 'top_businesses': {'businesses': [{'id': 'D3IGfwvlvv_DHlS0ZQLJHA', 'alias': 'mexi-tacos-chicago-3', 'name': 'Mexi-Tacos', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Djot1fSdayLzOphWLLw4zw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/mexi-tacos-chicago-3?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 12, 'categories': [{'alias': 'tacos', 'title': 'Tacos'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}], 'rating': 4.7, 'coordinates': {'latitude': 41.88032, 'longitude': -87.637485}, 'transactions': [], 'location': {'address1': '100 s wacker', 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60604', 'country': 'US', 'state': 'IL', 'display_address': ['100 s wacker', 'Chicago, IL 60604']}, 'phone': '+13126099801', 'display_phone': '(312) 609-9801', 'distance': 1871.7465048285069, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'nUhE2ryUw46SincI9SUtIQ', 'alias': 'the-outpost-mexican-eatery-chicago', 'name': 'the Outpost Mexican Eatery', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3oTYV_v13hcBPBrfhrym7w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-outpost-mexican-eatery-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 60, 'categories': [{'alias': 'mexican', 'title': 'Mexican'}], 'rating': 4.6, 'coordinates': {'latitude': 41.8744865206047, 'longitude': -87.6404256754631}, 'transactions': ['delivery', 'pickup'], 'location': {'address1': '520 W Harrison St', 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60607', 'country': 'US', 'state': 'IL', 'display_address': ['520 W Harrison St', 'Chicago, IL 60607']}, 'phone': '+13128775449', 'display_phone': '(312) 877-5449', 'distance': 1616.3750706239452, 'attributes': {'business_temp_closed': None, 'menu_url': 'https://www.theoutpostmexicaneatery.com/menus/', 'open24_hours': None, 'waitlist_reservation': None}}], 'total': 46, 'region': {'center': {'longitude': -87.62369155883789, 'latitude': 41.86700129154579}}}}
# {'address': '2065 N. Hoyne Ave., 2065 N Hoyne Ave #3R, Chicago, IL 60647', 'top_businesses': {'businesses': [{'id': 'htKi45T3U08n8FoHgTmLwg', 'alias': 'onions-and-cilantro-chicago', 'name': 'Onions & Cilantro', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W7UpPlhpZgkLZn6rdpW5gA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/onions-and-cilantro-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 14, 'categories': [{'alias': 'mexican', 'title': 'Mexican'}], 'rating': 4.7, 'coordinates': {'latitude': 41.92273, 'longitude': -87.68724}, 'transactions': ['delivery', 'pickup'], 'location': {'address1': '2235 N Western Ave', 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60647', 'country': 'US', 'state': 'IL', 'display_address': ['2235 N Western Ave', 'Chicago, IL 60647']}, 'phone': '+17737998423', 'display_phone': '(773) 799-8423', 'distance': 703.6983140598821, 'attributes': {'business_temp_closed': None, 'menu_url': 'https://www.onionscilantro.com/menu-20', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'j17mCU0CZMLxkK6DwERzUQ', 'alias': 'taqueria-el-heredero-chicago-3', 'name': 'Taqueria El Heredero', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/E9E_1DunUfrSNpOZ0V0dtQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/taqueria-el-heredero-chicago-3?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 32, 'categories': [{'alias': 'tacos', 'title': 'Tacos'}], 'rating': 4.6, 'coordinates': {'latitude': 41.910588, 'longitude': -87.693147}, 'transactions': ['delivery', 'pickup'], 'location': {'address1': '2624 W North Ave', 'address2': '', 'address3': None, 'city': 'Chicago', 'zip_code': '60647', 'country': 'US', 'state': 'IL', 'display_address': ['2624 W North Ave', 'Chicago, IL 60647']}, 'phone': '+17736878847', 'display_phone': '(773) 687-8847', 'distance': 1493.3181259506323, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}], 'total': 55, 'region': {'center': {'longitude': -87.67982482910156, 'latitude': 41.919647838846274}}}}

# %%
# Call the function
user_query = "I am looking for an apartment in the Hyde Park neighborhood of Chicago. I want two bedrooms and at least one bathroom. Rent should be less than $1500 per month. What are the best bars nearby?"

yelp_results = fetch_top_businesses_near_properties(yelp_api_key, top_properties, user_query, chat)

for result in yelp_results:
    print(result)
# Out:
# Category determined: bars
# {'location': '41.897385, -87.68405', 'term': 'restaurants', 'radius': 2000, 'categories': 'bars', 'sort_by': 'rating', 'limit': 2}
# {'location': '41.86681, -87.62358', 'term': 'restaurants', 'radius': 2000, 'categories': 'bars', 'sort_by': 'rating', 'limit': 2}
# {'location': '41.91961, -87.67988', 'term': 'restaurants', 'radius': 2000, 'categories': 'bars', 'sort_by': 'rating', 'limit': 2}
# {'address': '2253 W Iowa St #3F, Chicago, IL 60622', 'top_businesses': {'businesses': [{'id': '0ucCbCekcn5XdzvRXnHl2w', 'alias': 'desert-hawk-chicago', 'name': 'Desert Hawk', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Wvt0tJNb-HbxRnBQ7iUUPQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/desert-hawk-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 23, 'categories': [{'alias': 'tradamerican', 'title': 'American'}, {'alias': 'bars', 'title': 'Bars'}], 'rating': 4.8, 'coordinates': {'latitude': 41.90288666670101, 'longitude': -87.67917606979607}, 'transactions': [], 'location': {'address1': '2049 W Division St', 'address2': '', 'address3': None, 'city': 'Chicago', 'zip_code': '60622', 'country': 'US', 'state': 'IL', 'display_address': ['2049 W Division St', 'Chicago, IL 60622']}, 'phone': '', 'display_phone': '', 'distance': 724.8516782251801, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'faOpq9ORL0FlsMrou2NYug', 'alias': 'amaru-chicago', 'name': 'Amaru', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NxJ1RJiqiUtFlU4adIKyVQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/amaru-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 414, 'categories': [{'alias': 'latin', 'title': 'Latin American'}, {'alias': 'caribbean', 'title': 'Caribbean'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}], 'rating': 4.7, 'coordinates': {'latitude': 41.910699, 'longitude': -87.675507}, 'transactions': [], 'price': '$$$', 'location': {'address1': '1904 W North Ave', 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60622', 'country': 'US', 'state': 'IL', 'display_address': ['1904 W North Ave', 'Chicago, IL 60622']}, 'phone': '+17736879790', 'display_phone': '(773) 687-9790', 'distance': 1638.2138654797925, 'attributes': {'business_temp_closed': None, 'menu_url': 'https://amaruchicago.com/food-menu.html', 'open24_hours': None, 'waitlist_reservation': None}}], 'total': 67, 'region': {'center': {'longitude': -87.68394470214844, 'latitude': 41.89741891078323}}}}
# {'address': '1210 S Indiana Ave, Chicago, IL', 'top_businesses': {'businesses': [{'id': 'PdbRfCs6fHZacu6L_5oHnA', 'alias': 'bistro-monadnock-chicago', 'name': 'Bistro Monadnock', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bjJCGDAX7nYFtPnQiClPcA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/bistro-monadnock-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 78, 'categories': [{'alias': 'french', 'title': 'French'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}], 'rating': 4.8, 'coordinates': {'latitude': 41.877754, 'longitude': -87.629628}, 'transactions': [], 'location': {'address1': '325 S Federal St', 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60604', 'country': 'US', 'state': 'IL', 'display_address': ['325 S Federal St', 'Chicago, IL 60604']}, 'phone': '+13129457040', 'display_phone': '(312) 945-7040', 'distance': 1262.3796915690807, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'F5WoyqU-RW1nnL8kPLUoTw', 'alias': 'canal-street-eatery-and-market-chicago-2', 'name': 'Canal Street Eatery and Market', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GZK13h-Tg6q1uCoFOMvc_Q/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/canal-street-eatery-and-market-chicago-2?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 37, 'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}], 'rating': 4.6, 'coordinates': {'latitude': 41.8772993, 'longitude': -87.6403507}, 'transactions': ['pickup', 'delivery'], 'location': {'address1': '314 S Canal St', 'address2': '', 'address3': None, 'city': 'Chicago', 'zip_code': '60606', 'country': 'US', 'state': 'IL', 'display_address': ['314 S Canal St', 'Chicago, IL 60606']}, 'phone': '+13129676060', 'display_phone': '(312) 967-6060', 'distance': 1767.8641937666116, 'attributes': {'business_temp_closed': None, 'menu_url': 'https://canalstreetchicago.com/eatery', 'open24_hours': None, 'waitlist_reservation': None}}], 'total': 98, 'region': {'center': {'longitude': -87.62369155883789, 'latitude': 41.86700129154579}}}}
# {'address': '2065 N. Hoyne Ave., 2065 N Hoyne Ave #3R, Chicago, IL 60647', 'top_businesses': {'businesses': [{'id': '0ucCbCekcn5XdzvRXnHl2w', 'alias': 'desert-hawk-chicago', 'name': 'Desert Hawk', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Wvt0tJNb-HbxRnBQ7iUUPQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/desert-hawk-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 23, 'categories': [{'alias': 'tradamerican', 'title': 'American'}, {'alias': 'bars', 'title': 'Bars'}], 'rating': 4.8, 'coordinates': {'latitude': 41.90288666670101, 'longitude': -87.67917606979607}, 'transactions': [], 'location': {'address1': '2049 W Division St', 'address2': '', 'address3': None, 'city': 'Chicago', 'zip_code': '60622', 'country': 'US', 'state': 'IL', 'display_address': ['2049 W Division St', 'Chicago, IL 60622']}, 'phone': '', 'display_phone': '', 'distance': 1864.528247150318, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'CsOBdkThymA-WUlwf_xa_Q', 'alias': 'tama-chicago-2', 'name': 'Tama', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zPNeCsHHCFZv6F_8pGKZ6g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/tama-chicago-2?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 9, 'categories': [{'alias': 'greek', 'title': 'Greek'}, {'alias': 'bars', 'title': 'Bars'}], 'rating': 4.8, 'coordinates': {'latitude': 41.91745673780549, 'longitude': -87.67789549999999}, 'transactions': [], 'location': {'address1': '1952 N Damen Ave', 'address2': '', 'address3': None, 'city': 'Chicago', 'zip_code': '60647', 'country': 'US', 'state': 'IL', 'display_address': ['1952 N Damen Ave', 'Chicago, IL 60647']}, 'phone': '+13129550212', 'display_phone': '(312) 955-0212', 'distance': 291.2769993611359, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}], 'total': 79, 'region': {'center': {'longitude': -87.67982482910156, 'latitude': 41.919647838846274}}}}

# %%
# Call the function
user_query = "I am looking for an apartment in the Hyde Park neighborhood of Chicago. I want two bedrooms and at least one bathroom. Rent should be less than $1500 per month. What are the best french restaurants and coffee shops nearby?"

yelp_results = fetch_top_businesses_near_properties(yelp_api_key, top_properties, user_query, chat)

for result in yelp_results:
    print(result)
# Out:
# Category determined: french,coffee
# {'location': '41.897385, -87.68405', 'term': 'restaurants', 'radius': 2000, 'categories': 'french,coffee', 'sort_by': 'rating', 'limit': 2}
# {'location': '41.86681, -87.62358', 'term': 'restaurants', 'radius': 2000, 'categories': 'french,coffee', 'sort_by': 'rating', 'limit': 2}
# {'location': '41.91961, -87.67988', 'term': 'restaurants', 'radius': 2000, 'categories': 'french,coffee', 'sort_by': 'rating', 'limit': 2}
# {'address': '2253 W Iowa St #3F, Chicago, IL 60622', 'top_businesses': {'businesses': [{'id': 'gxUFFsSLa-IyouuRD2Ma6w', 'alias': 'spinning-j-bakery-and-soda-fountain-chicago-4', 'name': 'Spinning J Bakery and Soda Fountain', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CVtjtq4_rYRd7J-qNk9R-A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/spinning-j-bakery-and-soda-fountain-chicago-4?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 461, 'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}], 'rating': 4.6, 'coordinates': {'latitude': 41.89945, 'longitude': -87.69716}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '1000 N California Ave', 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60622', 'country': 'US', 'state': 'IL', 'display_address': ['1000 N California Ave', 'Chicago, IL 60622']}, 'phone': '+18728292793', 'display_phone': '(872) 829-2793', 'distance': 1118.203122807083, 'attributes': {'business_temp_closed': None, 'menu_url': 'http://www.spinningj.com/menu/', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'ePuDBB2UEUl17joXNO44MQ', 'alias': 'typica-cafe-chicago', 'name': 'Typica Cafe', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/l9Wo1hKc3CohwcEaiu2QuA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/typica-cafe-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 41, 'categories': [{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}], 'rating': 4.6, 'coordinates': {'latitude': 41.90363302144727, 'longitude': -87.67869294417999}, 'transactions': ['delivery', 'pickup'], 'location': {'address1': '2034 W Division St', 'address2': None, 'address3': None, 'city': 'CHICAGO', 'zip_code': '60622', 'country': 'US', 'state': 'IL', 'display_address': ['2034 W Division St', 'CHICAGO, IL 60622']}, 'phone': '+17737709004', 'display_phone': '(773) 770-9004', 'distance': 816.3149989515647, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}], 'total': 19, 'region': {'center': {'longitude': -87.68394470214844, 'latitude': 41.89741891078323}}}}
# {'address': '1210 S Indiana Ave, Chicago, IL', 'top_businesses': {'businesses': [{'id': 'agOQgbJPCeCnD7tBDLXDEw', 'alias': 'sweet-cafe-chicago', 'name': 'Sweet Cafe', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aaZ_n5qsALXILpVJQl91Hg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/sweet-cafe-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 7, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'seafood', 'title': 'Seafood'}], 'rating': 4.9, 'coordinates': {'latitude': 41.85261, 'longitude': -87.63373}, 'transactions': [], 'location': {'address1': '243 W Cermak Rd', 'address2': '', 'address3': None, 'city': 'Chicago', 'zip_code': '60616', 'country': 'US', 'state': 'IL', 'display_address': ['243 W Cermak Rd', 'Chicago, IL 60616']}, 'phone': '+13129292212', 'display_phone': '(312) 929-2212', 'distance': 1801.8375721246998, 'attributes': {'business_temp_closed': None, 'menu_url': '', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'PdbRfCs6fHZacu6L_5oHnA', 'alias': 'bistro-monadnock-chicago', 'name': 'Bistro Monadnock', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bjJCGDAX7nYFtPnQiClPcA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/bistro-monadnock-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 78, 'categories': [{'alias': 'french', 'title': 'French'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}], 'rating': 4.8, 'coordinates': {'latitude': 41.877754, 'longitude': -87.629628}, 'transactions': [], 'location': {'address1': '325 S Federal St', 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60604', 'country': 'US', 'state': 'IL', 'display_address': ['325 S Federal St', 'Chicago, IL 60604']}, 'phone': '+13129457040', 'display_phone': '(312) 945-7040', 'distance': 1262.3796915690807, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}], 'total': 54, 'region': {'center': {'longitude': -87.62369155883789, 'latitude': 41.86700129154579}}}}
# {'address': '2065 N. Hoyne Ave., 2065 N Hoyne Ave #3R, Chicago, IL 60647', 'top_businesses': {'businesses': [{'id': '59oR4W6iH0VFV6BpIyB-yA', 'alias': 'the-cuptown-chicago', 'name': 'The Cuptown', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/D_1ntG36qwUMpB4FNyNQbQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-cuptown-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 7, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}], 'rating': 4.7, 'coordinates': {'latitude': 41.92503407815363, 'longitude': -87.66470149999999}, 'transactions': [], 'location': {'address1': '1435 W Fullerton Ave', 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60614', 'country': 'US', 'state': 'IL', 'display_address': ['1435 W Fullerton Ave', 'Chicago, IL 60614']}, 'phone': '+17736986437', 'display_phone': '(773) 698-6437', 'distance': 1387.179090936258, 'attributes': {'business_temp_closed': None, 'menu_url': 'https://www.thecuptown.com/menu', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'L4qQW096fqVb-YskA2y2Jw', 'alias': 'doppio-coffee-house-chicago', 'name': 'Doppio Coffee House', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Y1a3stIDvO7PCyqWfH7XTQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/doppio-coffee-house-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 114, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}], 'rating': 4.7, 'coordinates': {'latitude': 41.937677, 'longitude': -87.666299}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '3054 N Greenview Ave', 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60657', 'country': 'US', 'state': 'IL', 'display_address': ['3054 N Greenview Ave', 'Chicago, IL 60657']}, 'phone': '+17736665129', 'display_phone': '(773) 666-5129', 'distance': 2292.4865076719443, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': None}}], 'total': 34, 'region': {'center': {'longitude': -87.67982482910156, 'latitude': 41.919647838846274}}}}

# %%
user_query = "I am looking for an apartment in the Hyde Park neighborhood of Chicago. I want two bedrooms and at least one bathroom. Rent should be less than $1500 per month."

yelp_results = fetch_top_businesses_near_properties(yelp_api_key, top_properties, user_query, chat)

for result in yelp_results:
    print(result)
# Out:
# Category determined: restaurants
# {'location': '41.897385, -87.68405', 'term': 'restaurants', 'radius': 2000, 'categories': 'restaurants', 'sort_by': 'rating', 'limit': 2}
# {'location': '41.86681, -87.62358', 'term': 'restaurants', 'radius': 2000, 'categories': 'restaurants', 'sort_by': 'rating', 'limit': 2}
# {'location': '41.91961, -87.67988', 'term': 'restaurants', 'radius': 2000, 'categories': 'restaurants', 'sort_by': 'rating', 'limit': 2}
# {'address': '2253 W Iowa St #3F, Chicago, IL 60622', 'top_businesses': {'businesses': [{'id': 'hva3YCKzqhtkKerQWsXo7Q', 'alias': 'janellie-s-kitchen-chicago-2', 'name': 'Janellie’s Kitchen', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gA6saQlTNJu03XZuXwafdg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/janellie-s-kitchen-chicago-2?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 12, 'categories': [{'alias': 'puertorican', 'title': 'Puerto Rican'}], 'rating': 5.0, 'coordinates': {'latitude': 41.90281613454157, 'longitude': -87.69265859457461}, 'transactions': ['delivery', 'pickup'], 'location': {'address1': '2617 W Division St', 'address2': None, 'address3': None, 'city': 'Chicago', 'zip_code': '60622', 'country': 'US', 'state': 'IL', 'display_address': ['2617 W Division St', 'Chicago, IL 60622']}, 'phone': '+18722108042', 'display_phone': '(872) 210-8042', 'distance': 938.2372735816302, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': True}}, {'id': 'bvm_LTw-CuWPiGrsEPg9rA', 'alias': 'healthy-substance-cantina-chicago', 'name': 'Healthy Substance Cantina', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pszUR0VtRNCUw6o9LhfRqw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/healthy-substance-cantina-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 6, 'categories': [{'alias': 'vegan', 'title': 'Vegan'}], 'rating': 5.0, 'coordinates': {'latitude': 41.908631, 'longitude': -87.675257}, 'transactions': [], 'location': {'address1': '1480 N Milwaukee Ave', 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60622', 'country': 'US', 'state': 'IL', 'display_address': ['1480 N Milwaukee Ave', 'Chicago, IL 60622']}, 'phone': '+17085757162', 'display_phone': '(708) 575-7162', 'distance': 1433.3574448607808, 'attributes': {'business_temp_closed': None, 'menu_url': 'https://www.healthysubstance.com/order-online', 'open24_hours': None, 'waitlist_reservation': None}}], 'total': 413, 'region': {'center': {'longitude': -87.68394470214844, 'latitude': 41.89741891078323}}}}
# {'address': '1210 S Indiana Ave, Chicago, IL', 'top_businesses': {'businesses': [{'id': 'i7Zm01nbGsta7GVVPY-Aqw', 'alias': 'la-bodega-chicago-7', 'name': 'La Bodega', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zlMIO47P-fzcCwZv5T4kCg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/la-bodega-chicago-7?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 14, 'categories': [{'alias': 'catering', 'title': 'Caterers'}, {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'}, {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}], 'rating': 5.0, 'coordinates': {'latitude': 41.86857605, 'longitude': -87.62597656}, 'transactions': [], 'location': {'address1': None, 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60605', 'country': 'US', 'state': 'IL', 'display_address': ['Chicago, IL 60605']}, 'phone': '+14246534900', 'display_phone': '(424) 653-4900', 'distance': 370.4182482103061, 'attributes': {'business_temp_closed': None, 'menu_url': 'http://pedroliebana.com/?p=598', 'open24_hours': None, 'waitlist_reservation': None}}, {'id': 'agOQgbJPCeCnD7tBDLXDEw', 'alias': 'sweet-cafe-chicago', 'name': 'Sweet Cafe', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aaZ_n5qsALXILpVJQl91Hg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/sweet-cafe-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 7, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'seafood', 'title': 'Seafood'}], 'rating': 4.9, 'coordinates': {'latitude': 41.85261, 'longitude': -87.63373}, 'transactions': [], 'location': {'address1': '243 W Cermak Rd', 'address2': '', 'address3': None, 'city': 'Chicago', 'zip_code': '60616', 'country': 'US', 'state': 'IL', 'display_address': ['243 W Cermak Rd', 'Chicago, IL 60616']}, 'phone': '+13129292212', 'display_phone': '(312) 929-2212', 'distance': 1801.8375721246998, 'attributes': {'business_temp_closed': None, 'menu_url': '', 'open24_hours': None, 'waitlist_reservation': None}}], 'total': 827, 'region': {'center': {'longitude': -87.62369155883789, 'latitude': 41.86700129154579}}}}
# {'address': '2065 N. Hoyne Ave., 2065 N Hoyne Ave #3R, Chicago, IL 60647', 'top_businesses': {'businesses': [{'id': 'hva3YCKzqhtkKerQWsXo7Q', 'alias': 'janellie-s-kitchen-chicago-2', 'name': 'Janellie’s Kitchen', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gA6saQlTNJu03XZuXwafdg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/janellie-s-kitchen-chicago-2?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 12, 'categories': [{'alias': 'puertorican', 'title': 'Puerto Rican'}], 'rating': 5.0, 'coordinates': {'latitude': 41.90281613454157, 'longitude': -87.69265859457461}, 'transactions': ['pickup', 'delivery'], 'location': {'address1': '2617 W Division St', 'address2': None, 'address3': None, 'city': 'Chicago', 'zip_code': '60622', 'country': 'US', 'state': 'IL', 'display_address': ['2617 W Division St', 'Chicago, IL 60622']}, 'phone': '+18722108042', 'display_phone': '(872) 210-8042', 'distance': 2151.9023876203223, 'attributes': {'business_temp_closed': None, 'menu_url': None, 'open24_hours': None, 'waitlist_reservation': True}}, {'id': 'bvm_LTw-CuWPiGrsEPg9rA', 'alias': 'healthy-substance-cantina-chicago', 'name': 'Healthy Substance Cantina', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pszUR0VtRNCUw6o9LhfRqw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/healthy-substance-cantina-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q', 'review_count': 6, 'categories': [{'alias': 'vegan', 'title': 'Vegan'}], 'rating': 5.0, 'coordinates': {'latitude': 41.908631, 'longitude': -87.675257}, 'transactions': [], 'location': {'address1': '1480 N Milwaukee Ave', 'address2': None, 'address3': '', 'city': 'Chicago', 'zip_code': '60622', 'country': 'US', 'state': 'IL', 'display_address': ['1480 N Milwaukee Ave', 'Chicago, IL 60622']}, 'phone': '+17085757162', 'display_phone': '(708) 575-7162', 'distance': 1287.089009515346, 'attributes': {'business_temp_closed': None, 'menu_url': 'https://www.healthysubstance.com/order-online', 'open24_hours': None, 'waitlist_reservation': None}}], 'total': 462, 'region': {'center': {'longitude': -87.67982482910156, 'latitude': 41.919647838846274}}}}

# %% [markdown]
# ### Extract Restaurant Info

# %%
def extract_business_info(addresses, n, fields):
    """
    Extracts and returns information from a given list of addresses, each containing businesses,
    based on the specified fields and the top 'n' businesses per address.
    
    Parameters:
    - addresses: A list of dictionaries, each representing an address with nested businesses.
    - n: The number of top businesses to extract from each address.
    - fields: A list of strings representing the fields to extract from each business.
    
    Returns:
    - A list of dictionaries, each representing a business with only the specified fields.
    """
    extracted_businesses = []
    try:
        # Loop through each address entry
        for address_entry in addresses:
            # Extract top 'n' businesses
            for business in address_entry['top_businesses']['businesses'][:n]:
                # Extract specified fields, handling nested structures like 'categories' and 'location'
                extracted_business = {
                    'business_name': business.get('name'),
                    'categories_titles': [category['title'] for category in business.get('categories', [])],
                    'rating': business.get('rating'),
                    'latitude': business.get('coordinates', {}).get('latitude'),
                    'longitude': business.get('coordinates', {}).get('longitude'),
                    'display_address': " ".join(business.get('location', {}).get('display_address', [])),
                    'url': business.get('url')
                }
                # Only append fields that were specifically requested
                filtered_business = {field: extracted_business[field] for field in fields if field in extracted_business}
                extracted_businesses.append(filtered_business)

        return extracted_businesses

    except Exception as e:
        print("An error occurred:", e)
        return []  # Return an empty list in case of an error

# %%
# Example usage

fields_to_extract = ['business_name', 'categories_titles', 'rating', 'latitude', 'longitude', 'display_address', 'url']
top_restaurants = extract_business_info(yelp_results, 2, fields_to_extract)
for info in top_restaurants:
    print(info)
# Out:
# {'business_name': 'Janellie’s Kitchen', 'categories_titles': ['Puerto Rican'], 'rating': 5.0, 'latitude': 41.90281613454157, 'longitude': -87.69265859457461, 'display_address': '2617 W Division St Chicago, IL 60622', 'url': 'https://www.yelp.com/biz/janellie-s-kitchen-chicago-2?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}
# {'business_name': 'Healthy Substance Cantina', 'categories_titles': ['Vegan'], 'rating': 5.0, 'latitude': 41.908631, 'longitude': -87.675257, 'display_address': '1480 N Milwaukee Ave Chicago, IL 60622', 'url': 'https://www.yelp.com/biz/healthy-substance-cantina-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}
# {'business_name': 'La Bodega', 'categories_titles': ['Caterers', 'Food Delivery Services', 'Tapas/Small Plates'], 'rating': 5.0, 'latitude': 41.86857605, 'longitude': -87.62597656, 'display_address': 'Chicago, IL 60605', 'url': 'https://www.yelp.com/biz/la-bodega-chicago-7?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}
# {'business_name': 'Sweet Cafe', 'categories_titles': ['Chinese', 'Coffee & Tea', 'Seafood'], 'rating': 4.9, 'latitude': 41.85261, 'longitude': -87.63373, 'display_address': '243 W Cermak Rd Chicago, IL 60616', 'url': 'https://www.yelp.com/biz/sweet-cafe-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}
# {'business_name': 'Janellie’s Kitchen', 'categories_titles': ['Puerto Rican'], 'rating': 5.0, 'latitude': 41.90281613454157, 'longitude': -87.69265859457461, 'display_address': '2617 W Division St Chicago, IL 60622', 'url': 'https://www.yelp.com/biz/janellie-s-kitchen-chicago-2?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}
# {'business_name': 'Healthy Substance Cantina', 'categories_titles': ['Vegan'], 'rating': 5.0, 'latitude': 41.908631, 'longitude': -87.675257, 'display_address': '1480 N Milwaukee Ave Chicago, IL 60622', 'url': 'https://www.yelp.com/biz/healthy-substance-cantina-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}

# %% [markdown]
# ### Combine Restaurant and Property Info

# %%
def merge_property_and_restaurant_info(properties, restaurants):
    """
    Merges each property with its corresponding top-rated restaurants.

    Parameters:
    - properties: A list of dictionaries, each representing a property.
    - restaurants: A list of dictionaries, each representing top-rated restaurants near the properties.

    Returns:
    - A list of dictionaries, each representing a property merged with restaurant information.
    """
    # Ensure there are two restaurants for each property, assuming a structure of 1:2 mapping
    if len(restaurants) != 2 * len(properties):
        raise ValueError("Each property must correspond to exactly two restaurants.")

    merged_data = []
    for i, property in enumerate(properties):
        # Merge the property dict with its corresponding restaurants' info
        restaurant_info = {
            "restaurant_1": restaurants[2*i],
            "restaurant_2": restaurants[2*i + 1]
        }
        # Merge two dictionaries and add to the list
        merged_property = {**property, **restaurant_info}
        merged_data.append(merged_property)

    return merged_data

# %%
top_properties = merge_property_and_restaurant_info(top_properties, top_restaurants)
top_properties
# Out:
# [{'propertyType': 'APARTMENT',
#   'address': '2253 W Iowa St #3F, Chicago, IL 60622',
#   'price': 2695,
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/2253-W-Iowa-St-3F-Chicago-IL-60622/2069892388_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/24cfac4e50b54ac036925874a4d4b395-p_e.jpg',
#   'longitude': -87.68405,
#   'latitude': 41.897385,
#   'restaurant_1': {'business_name': 'Janellie’s Kitchen',
#    'categories_titles': ['Puerto Rican'],
#    'rating': 5.0,
#    'latitude': 41.90281613454157,
#    'longitude': -87.69265859457461,
#    'display_address': '2617 W Division St Chicago, IL 60622',
#    'url': 'https://www.yelp.com/biz/janellie-s-kitchen-chicago-2?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'},
#   'restaurant_2': {'business_name': 'Healthy Substance Cantina',
#    'categories_titles': ['Vegan'],
#    'rating': 5.0,
#    'latitude': 41.908631,
#    'longitude': -87.675257,
#    'display_address': '1480 N Milwaukee Ave Chicago, IL 60622',
#    'url': 'https://www.yelp.com/biz/healthy-substance-cantina-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}},
#  {'propertyType': None,
#   'address': '1210 S Indiana Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/apartments/chicago-il/nema-chicago/9RwqTm/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/35f6b1437825b0cf43201316158e8000-p_e.jpg',
#   'longitude': -87.62358,
#   'latitude': 41.86681,
#   'restaurant_1': {'business_name': 'La Bodega',
#    'categories_titles': ['Caterers',
#     'Food Delivery Services',
#     'Tapas/Small Plates'],
#    'rating': 5.0,
#    'latitude': 41.86857605,
#    'longitude': -87.62597656,
#    'display_address': 'Chicago, IL 60605',
#    'url': 'https://www.yelp.com/biz/la-bodega-chicago-7?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'},
#   'restaurant_2': {'business_name': 'Sweet Cafe',
#    'categories_titles': ['Chinese', 'Coffee & Tea', 'Seafood'],
#    'rating': 4.9,
#    'latitude': 41.85261,
#    'longitude': -87.63373,
#    'display_address': '243 W Cermak Rd Chicago, IL 60616',
#    'url': 'https://www.yelp.com/biz/sweet-cafe-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}},
#  {'propertyType': 'APARTMENT',
#   'address': '2065 N. Hoyne Ave., 2065 N Hoyne Ave #3R, Chicago, IL 60647',
#   'price': 2295,
#   'bedrooms': 3,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/apartments/chicago-il/2065-n.-hoyne-ave./5XgKsR/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/8094800d8257833f346cfb9030093cee-p_e.jpg',
#   'longitude': -87.67988,
#   'latitude': 41.91961,
#   'restaurant_1': {'business_name': 'Janellie’s Kitchen',
#    'categories_titles': ['Puerto Rican'],
#    'rating': 5.0,
#    'latitude': 41.90281613454157,
#    'longitude': -87.69265859457461,
#    'display_address': '2617 W Division St Chicago, IL 60622',
#    'url': 'https://www.yelp.com/biz/janellie-s-kitchen-chicago-2?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'},
#   'restaurant_2': {'business_name': 'Healthy Substance Cantina',
#    'categories_titles': ['Vegan'],
#    'rating': 5.0,
#    'latitude': 41.908631,
#    'longitude': -87.675257,
#    'display_address': '1480 N Milwaukee Ave Chicago, IL 60622',
#    'url': 'https://www.yelp.com/biz/healthy-substance-cantina-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}}]

# %% [markdown]
# ### Mapping Properties and Restaurants Together

# %%
import folium

def create_property_restaurant_map(properties):
    # Attribution for custom tileset
    attr = '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors'
    
    # Initialize the map centered around Chicago
    property_map = folium.Map(location=[41.881832, -87.623177], zoom_start=11, tiles='OpenStreetMap', attr=attr)

    # Loop through each location in the list
    for prop in properties:
        # Extract property details
        latitude = prop['latitude']
        longitude = prop['longitude']
        detail_url = prop['detailUrl']
        address = prop['address']

        # Add a marker to the map for the property
        folium.Marker(
            location=[latitude, longitude],
            popup=folium.Popup(f'<a href="{detail_url}" target="_blank">{address}</a>', max_width=250),
            tooltip="Click for property details",
            icon=folium.Icon(icon='home', color="blue")
        ).add_to(property_map)

        # Loop through the associated restaurants
        for key in ['restaurant_1', 'restaurant_2']:
            if key in prop:
                restaurant = prop[key]
                # Extract relevant restaurant data
                name = restaurant['business_name']
                categories = ', '.join(restaurant['categories_titles'])
                rating = restaurant['rating']
                res_latitude = restaurant['latitude']
                res_longitude = restaurant['longitude']
                res_address = restaurant['display_address']
                url = restaurant['url']

                # Add a marker to the map for the restaurant
                folium.Marker(
                    location=[res_latitude, res_longitude],
                    popup=folium.Popup(f'<a href="{url}" target="_blank">{name}</a><br/>{categories}<br/>Rating: {rating}', max_width=250),
                    tooltip=f"Click for details on {name}",
                    icon=folium.Icon(icon='cutlery', color="red")
                ).add_to(property_map)

    # Return the map
    return property_map

# %%
# Create the map
props_rests_map = create_property_restaurant_map(top_properties)

display(props_rests_map)
# Display or save the map
# my_map.save('map.html') or display it directly in a Jupyter notebook using `my_map`
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e76597b6e95731f796e717c45f9949c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e76597b6e95731f796e717c45f9949c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e76597b6e95731f796e717c45f9949c5 = L.map(
#                 &quot;map_e76597b6e95731f796e717c45f9949c5&quot;,
#                 {
#                     center: [41.881832, -87.623177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6738d877ca914a043b1bbcd6d841d3d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a6738d877ca914a043b1bbcd6d841d3d.addTo(map_e76597b6e95731f796e717c45f9949c5);
#
#
#             var marker_2dc2ae827a7e9493ab843fb2c7822d0d = L.marker(
#                 [41.897385, -87.68405],
#                 {}
#             ).addTo(map_e76597b6e95731f796e717c45f9949c5);
#
#
#             var icon_93c4f790f02da56b2367dcb442a88375 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2dc2ae827a7e9493ab843fb2c7822d0d.setIcon(icon_93c4f790f02da56b2367dcb442a88375);
#
#
#         var popup_920c617489a53b9b1728220916adb5cf = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_9bdcea8d3bbcb37df0222df6588ce9da = $(`&lt;div id=&quot;html_9bdcea8d3bbcb37df0222df6588ce9da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.zillow.com/homedetails/2253-W-Iowa-St-3F-Chicago-IL-60622/2069892388_zpid/&quot; target=&quot;_blank&quot;&gt;2253 W Iowa St #3F, Chicago, IL 60622&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_920c617489a53b9b1728220916adb5cf.setContent(html_9bdcea8d3bbcb37df0222df6588ce9da);
#
#
#
#         marker_2dc2ae827a7e9493ab843fb2c7822d0d.bindPopup(popup_920c617489a53b9b1728220916adb5cf)
#         ;
#
#
#
#
#             marker_2dc2ae827a7e9493ab843fb2c7822d0d.bindTooltip(
#                 `&lt;div&gt;
#                      Click for property details
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5083ec433d80f32ca14fec8bd7799abc = L.marker(
#                 [41.90281613454157, -87.69265859457461],
#                 {}
#             ).addTo(map_e76597b6e95731f796e717c45f9949c5);
#
#
#             var icon_f20e79a86a5e001c5f52a3ee3ced449e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5083ec433d80f32ca14fec8bd7799abc.setIcon(icon_f20e79a86a5e001c5f52a3ee3ced449e);
#
#
#         var popup_bc5304c36f46fddf8058d02d36cf7c8f = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_7edcdd2efd9d9e805db910b7df238b42 = $(`&lt;div id=&quot;html_7edcdd2efd9d9e805db910b7df238b42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.yelp.com/biz/janellie-s-kitchen-chicago-2?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&amp;utm_campaign=yelp_api_v3&amp;utm_medium=api_v3_business_search&amp;utm_source=GgXKz4qBvfURJxuhy6g81Q&quot; target=&quot;_blank&quot;&gt;Janellie’s Kitchen&lt;/a&gt;&lt;br/&gt;Puerto Rican&lt;br/&gt;Rating: 5.0&lt;/div&gt;`)[0];
#                 popup_bc5304c36f46fddf8058d02d36cf7c8f.setContent(html_7edcdd2efd9d9e805db910b7df238b42);
#
#
#
#         marker_5083ec433d80f32ca14fec8bd7799abc.bindPopup(popup_bc5304c36f46fddf8058d02d36cf7c8f)
#         ;
#
#
#
#
#             marker_5083ec433d80f32ca14fec8bd7799abc.bindTooltip(
#                 `&lt;div&gt;
#                      Click for details on Janellie’s Kitchen
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ef38a737e8a56a3a858a4a220dd00e26 = L.marker(
#                 [41.908631, -87.675257],
#                 {}
#             ).addTo(map_e76597b6e95731f796e717c45f9949c5);
#
#
#             var icon_8629a08fbc5060e8510fc94d879d83d9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ef38a737e8a56a3a858a4a220dd00e26.setIcon(icon_8629a08fbc5060e8510fc94d879d83d9);
#
#
#         var popup_137cf6748d87947fd6b6f3c1c3e72522 = L.popup({&

# %% [markdown]
# ### Example - Property details endpoint

# %% [markdown]
# #### Description

# %%
top_properties[1]['detailUrl']
# Out:
# 'https://www.zillow.com/apartments/chicago-il/nema-chicago/9RwqTm/'

# %%
# Endpoint
url_details = "https://zillow-com1.p.rapidapi.com/property"

# URL example
property_url = top_properties[1]['detailUrl']

querystring = {"property_url":property_url}
response = requests.get(url_details, headers = headers, params = querystring)

# %%
response.json()
# Out:
# {'listingProvider': {'enhancedVideoURL': None,
#   'showNoContactInfoMessage': False,
#   'postingGroupName': None,
#   'isZRMSourceText': None,
#   'showLogos': None,
#   'logos': {},
#   'sourceText': 'Source: Zillow Rentals',
#   'title': 'Listing Provided by',
#   'disclaimerText': None,
#   'postingWebsiteURL': None,
#   'agentLicenseNumber': None,
#   'postingWebsiteLinkText': 'See listing website',
#   'enhancedDescriptionText': None,
#   'agentName': None},
#  'zpid': 158698100,
#  'buildingPermits': None,
#  'propertyTaxRate': 1.89,
#  'contact_recipients': {},
#  'zipcode': '60624',
#  'openHouseSchedule': {},
#  'longitude': -87.7079,
#  'zestimateLowPercent': '11',
#  'address': {'community': None,
#   'city': 'Chicago',
#   'state': 'IL',
#   'neighborhood': None,
#   'subdivision': None,
#   'streetAddress': '3240 W Fulton Blvd',
#   'zipcode': '60624'},
#  'cityId': 17426,
#  'timeOnZillow': '1 hour',
#  'url': '/homedetails/3240-W-Fulton-Blvd-Chicago-IL-60624/158698100_zpid/',
#  'zestimate': 300400,
#  'imgSrc': 'https://photos.zillowstatic.com/fp/402d1685a0321ebbd7c3b2ceaecb3822-p_d.jpg',
#  'description': "Hello!\n\nThis rehabbed house has central heat & air, exposed bricks, dark hardwood floors, new stainless steel kitchen appliances, in-unit washer and dryer, and plenty of storage space in the basement. It also has a firepit in the backyard for bonfires. \n\nAbout the neighborhood:\nThis unfurnished house is in the heart of East Garfield Park, less than a five-minute walk from the Kedzie Green line and Metra stations, as well as the nearest 52 Kedzie, 82 Homan and 94 California bus stops. There is plenty of space downstairs for your bikes, so you can get around very easily from here without a car. If you do have a car though, you can have a spot out back for $25/month each, or use one of the parking spots on the street out front. \n\nThis house is within a few blocks of cool neighborhood spots like Passion House Coffee, Breakthrough Community Center, Inspiration Kitchens, and the Garfield Park Conservatory, and just a short bike ride away from everything in Humboldt Park, Ukranian Village and West Loop. \n\nAbout the dollar bills/paperwork:\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent. \n\nIf all that sounds good to you, send us a message so we can share details with you about our open house this Sunday, May 5.\n\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent.",
#  'price': 2800,
#  'livingAreaValue': 2180,
#  'resoFacts': {'hasAttachedProperty': False,
#   'frontageType': None,
#   'poolFeatures': None,
#   'flooring': ['Hardwood'],
#   'builderModel': None,
#   'accessibilityFeatures': None,
#   'hasGarage': False,
#   'hasPetsAllowed': True,
#   'bodyType': None,
#   'topography': None,
#   'landLeaseExpirationDate': None,
#   'hasAdditionalParcels': False,
#   'waterViewYN': None,
#   'livingQuarters': {},
#   'atAGlanceFacts': [{'factValue': 'Sat Jun 1 2024',
#     'factLabel': 'Date available'},
#    {'factValue': 'Single Family Residence', 'factLabel': 'Type'},
#    {'factValue': 'Central Air', 'factLabel': 'Cooling'},
#    {'factValue': None, 'factLabel': 'Heating'},
#    {'factValue': 'Cats, Small Dogs', 'factLabel': 'Pets'},
#    {'factValue': 'Off Street', 'factLabel': 'Parking'},
#    {'factValue': 'In Unit', 'factLabel': 'Laundry'},
#    {'factValue': '$1,250', 'factLabel': 'Deposit & fees'},
#    {'factValue': '$1,250', 'factLabel': 'One-time fees'}],
#   'offerReviewDate': None,
#   'horseYN': None,
#   'view': {},
#   'buyerAgencyCompensationType': None,
#   'rooms': {},
#   'belowGradeFinishedArea': None,
#   'feesAndDues': [{'phone': None,
#     'name': None,
#     'fee': '$1,250',
#     'type': 'Deposit'}],
#   'cityRegion': 'Chicago',
#   'subAgencyCompensation': None,
#   'hasPrivatePool': None,
#   'associationFeeIncludes': None,
#   'waterSource': None,
#   'carportParkingCapacity': None,
#   'transactionBrokerCompensationType': None,
#   'hasFireplace': None,
#   'gas': None,
#   'sewer': None,
#   'elevationUnits': None,
#   'roadSurfaceType': None,
#   'mainLevelBedrooms': None,
#   'numberOfUnitsVacant': None,
#   'hasWaterfrontView': None,
#   'bathroomsOneQuarter': None,
#   'lotSize': None,
#   'subAgencyCompensationType': None,
#   'entryLevel': None,
#   'irrigationWaterRightsAcres': None,
#   'greenWaterConservation': None,
#   'stories': None,
#   'bathrooms': 2,
#   'numberOfUnitsInCommunity': None,
#   'listingTerms': None,
#   'otherParking': ['Contact manager'],
#   'associationFee': None,
#   'marketingType': None,
#   'greenEnergyEfficient': None,
#   'greenSustainability': None,
#   'heating': None,
#   'associationPhone': None,
#   'greenBuildingVerificationType': None,
#   'hasAttachedGarage': False,
#   'bedrooms': 5,
#   'architecturalStyle': None,
#   'listingId': None,
#   'structureType': None,
#   'interiorFeatures': None,
#   'horseAmenities': None,
#   'electric': None,
#   'otherFacts': {},
#   'lotFeatures': None,
#   'roofType': None,
#   'compensationBasedOn': None,
#   'greenEnergyGeneration': None,
#   'taxAnnualAmount': 53,
#   'daysOnZillow': 0,
#   'listAOR': None,
#   'hasHeating': None,
#   'elementarySchool': None,
#   'constructionMaterials': {},
#   'basementYN': None,
#   'hoaFeeTotal': None,
#   'appliances': ['Dishwasher', 'Dryer', 'Washer'],
#   'virtualTour': None,
#   'bathroomsPartial': None,
#   'fencing': None,
#   'yearBuiltEffective': None,
#   'foundationDetails': {},
#   'buildingName': None,
#   'hasAssociation': None,
#   'isSeniorCommunity': None,
#   'propertySubType': ['Single Family Residence'],
#   'propertyCondition': None,
#   'hasCarport': False,
#   'canRaiseHorses': False,
#   'hasLandLease': False,
#   'communityFeatures': None,
#   'parcelNumber': '1611405075',
#   'elevation': None,
#   'lotSizeDimensions': None,
#   'buildingAreaSource': None,
#   'contingency': None,
#   'yearBuilt': None,
#   'otherStructures': None,
#   'livingArea': '2,180 sqft',
#   'bathroomsFull': 2,
#   'livingAreaRangeUnits': None,
#   'incomeIncludes': None,
#   'highSchool': None,
#   'aboveGradeFinishedArea': None,
#   'isNewConstruction': None,
#   'inclusions': None,
#   'hasHomeWarranty': False,
#   'additionalFeeInfo': None,
#   'windowFeatures': None,
#   'ownership': None,
#   'woodedArea': None,
#   'middleOrJuniorSchoolDistrict': None,
#   'associationPhone2': None,
#   'exteriorFeatures': ['Bicycle storage'],
#   'buildingFeatures': None,
#   'frontageLength': None,
#   'buildingArea': None,
#   'associationAmenities': None,
#   'bathroomsHalf': None,
#   'hasCooling': True,
#   'additionalParcelsDescription': None,
#   'parkingFeatures': ['Off Street'],
#   'foundationArea': None,
#   'zoning': None,
#   'hoaFee': None,
#   'livingAreaRange': None,
#   'zoningDescription': None,
#   'developmentStatus': None,
#   'availabilityDate': 1717200000000,
#   'waterfrontFeatures': None,
#   'waterBodyName': None,
#   'utilities': None,
#   'entryLocation': None,
#   'totalActualRent': None,
#   'hasView': False,
#   'subdivisionName': None,
#   'securityFeatures': None,
#   'attic': None,
#   'fireplaceFeatures': None,
#   'mainLevelBathrooms': None,
#   'doorFeatures': None,
#   'ownershipType': None,
#   'associationName': None,
#   'associations': {},
#   'waterView': None,
#   'garageParkingCapacity': None,
#   'cropsIncludedYN': None,
#   'laundryFeatures': ['In Unit'],
#   'buyerAgencyCompensation': None,
#   'greenIndoorAirQuality': None,
#   'homeType': 'SingleFamily',
#   'spaFeatures': None,
#   'municipality': None,
#   'bathroomsThreeQuarter': None,
#   'hasSpa': False,
#   'basement': None,
#   'associationFee2': None,
#   'cooling': ['Central Air'],
#   'openParkingCapacity': None,
#   'associationName2': None,
#   'hasRentControl': None,
#   'elementarySchoolDistrict': None,
#   'otherEquipment': None,
#   'commonWalls': None,
#   'specialListingConditions': None,
#   'furnished': False,
#   'vegetation': None,
#   'patioAndPorchFeatures': None,
#   'bathroomsFloat': 2,
#   'builderName': None,
#   'highSchoolDistrict': None,
#   'transactionBrokerCompensation': None,
#   'storiesTotal': None,
#   'cumulativeDaysOnMarket': None,
#   'fireplaces': None,
#   'irrigationWaterRightsYN': None,
#   'exclusions': None,
#   'hasOpenParking': False,
#   'landLeaseAmount': None,
#   'coveredParkingCapacity': None,
#   'middleOrJuniorSchool': None,
#   'hasElectricOnProperty': None,
#   'onMarketDate': 1714435200000,
#   'pricePerSquareFoot': 1,
#   'parkingCapacity': 0,
#   'levels': None},
#  'taxHistory': [{'time': 1619814338013,
#    'valueIncreaseRate': 0.29099074,
#    'taxIncreaseRate': 0.165305,
#    'taxPaid': 4640.07,
#    'value': 22999},
#   {'time': 1588278338013,
#    'valueIncreaseRate': -0.10002526,
#    'taxIncreaseRate': -0.0021226294,
#    'taxPaid': 3981.85,
#    'value': 17815},
#   {'time': 1556655938013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.017201819,
#    'taxPaid': 3990.32,
#    'value': 19795},
#   {'time': 1525119938013,
#    'valueIncreaseRate': 0.18405312,
#    'taxIncreaseRate': 0.08628919,
#    'taxPaid': 3922.84,
#    'value': 19795},
#   {'time': 1493583938013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.07848456,
#    'taxPaid': 3611.23,
#    'value': 16718},
#   {'time': 1462047938013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.093004405,
#    'taxPaid': 3348.43,
#    'value': 16718},
#   {'time': 1430425538013,
#    'valueIncreaseRate': 0.04168484,
#    'taxIncreaseRate': 0.02882448,
#    'taxPaid': 3063.51,
#    'value': 16718},
#   {'time': 1398889538013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.020137735,
#    'taxPaid': 2977.68,
#    'value': 16049},
#   {'time': 1367353538013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.013531569,
#    'taxPaid': 2918.9,
#    'value': 16049},
#   {'time': 1335817538013,
#    'valueIncreaseRate': -0.20364214,
#    'taxIncreaseRate': -0.11813863,
#    'taxPaid': 2879.93,
#    'value': 16049},
#   {'time': 1304195138013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': -0.004153285,
#    'taxPaid': 3265.74,
#    'value': 20153},
#   {'time': 1272659138013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.04352808,
#    'taxPaid': 3279.36,
#    'value': 20153},
#   {'time': 1241123138013,
#    'valueIncreaseRate': -0.09745175,
#    'taxIncreaseRate': -0.018888129,
#    'taxPaid': 3142.57,
#    'value': 20153},
#   {'time': 1209587138013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.010037108,
#    'taxPaid': 3203.07,
#    'value': 22329},
#   {'time': 1177964738013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': -0.010681705,
#    'taxPaid': 3171.24,
#    'value': 22329},
#   {'time': 1146428738013,
#    'valueIncreaseRate': 0.45494235,
#    'taxIncreaseRate': 0.2782499,
#    'taxPaid': 3205.48,
#    'value': 22329},
#   {'time': 1114892738013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.010187656,
#    'taxPaid': 2507.71,
#    'value': 15347},
#   {'time': 1083356738013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.022194548,
#    'taxPaid': 2482.42,
#    'value': 15347},
#   {'time': 1051734338013,
#    'valueIncreaseRate': 0.7970726,
#    'taxIncreaseRate': 0.58284014,
#    'taxPaid': 2428.52,
#    'value': 15347},
#   {'time': 1020198338013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.35969514,
#    'taxPaid': 1534.28,
#    'value': 8540},
#   {'time': 988662338013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.85977525,
#    'taxPaid': 1128.4,
#    'value': 8540},
#   {'time': 957126338013,
#    'valueIncreaseRate': 0.6556805,
#    'taxIncreaseRate': 0,
#    'taxPaid': 606.74,
#    'value': 8540},
#   {'time': 925503938013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 5158}],
#  'brokerId': None,
#  'stateId': 21,
#  'streetAddress': '3240 W Fulton Blvd',
#  'listingSubType': {'is_FSBA': False,
#   'is_comingSoon': False,
#   'is_newHome': False,
#   'is_pending': False,
#   'is_forAuction': False,
#   'is_foreclosure': False,
#   'is_bankOwned': False,
#   'is_openHouse': False,
#   'is_FSBO': False},
#  'solarPotential': None,
#  'dateSold': None,
#  'countyId': 139,
#  'timeZone': 'America/Chicago',
#  'homeType': 'SINGLE_FAMILY',
#  'livingAreaUnits': 'sqft',
#  'comingSoonOnMarketDate': None,
#  'rentZestimate': 2949,
#  'bathrooms': 2,
#  'annualHomeownersInsurance': 12,
#  'state': 'IL',
#  'propertyTypeDimension': 'Single Family',
#  'building': None,
#  'listed_by': {'agent_reason': None,
#   'zpro': None,
#   'recent_sales': None,
#   'review_count': None,
#   'display_name': None,
#   'badge_type': None,
#   'business_name': None,
#   'rating_average': None,
#   'phone': None,
#   'zuid': None,
#   'image_url': None},
#  'yearBuilt': None,
#  'brokerageName': None,
#  'pageViewCount': 33,
#  'county': 'Cook County',
#  'mortgageRates': {'thirtyYearFixedRate': 6.62},
#  'attributionInfo': {'buyerAgentName': None,
#   'mlsName': 'Zillow Rentals',
#   'coAgentLicenseNumber': None,
#   'listingOffices': {},
#   'lastUpdated': '2024-04-30 12:30:33',
#   'buyerAgentMemberStateLicense': None,
#   'brokerName': None,
#   'listingAgreement': None,
#   'infoString10': '',
#   'trueStatus': None,
#   'infoString3': None,
#   'agentEmail': None,
#   'agentName': None,
#   'attributionTitle': None,
#   'mlsId': None,
#   'coAgentName': None,
#   'coAgentNumber': None,
#   'infoString5': None,
#   'listingAgents': {},
#   'agentPhoneNumber': None,
#   'agentLicenseNumber': None,
#   'providerLogo': None,
#   'infoString16': None,
#   'buyerBrokerageName': None,
#   'mlsDisclaimer': '',
#   'brokerPhoneNumber': None,
#   'lastChecked': '2024-04-30 12:30:33'},
#  'monthlyHoaFee': None,
#  'homeStatus': 'FOR_RENT',
#  'homeFacts': None,
#  'latitude': 41.886738,
#  'datePosted': '2024-04-30',
#  'bedrooms': 5,
#  'nearbyHomes': [{'livingArea': 1100,
#    'livingAreaValue': 1100,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/e5554c105e57633af3ffe1ad656aa876-p_c.jpg'}],
#    'zpid': 343768123,
#    'longitude': -87.7082,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3248 W Fulton Blvd #1',
#     'zipcode': '60624'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 2200,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.886734},
#   {'livingArea': 1100,
#    'livingAreaValue': 1100,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/35edeaf5bc45b9c17d51abe487e987d8-p_c.jpg'}],
#    'zpid': 347968619,
#    'longitude': -87.7082,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3248 W Fulton Blvd #2',
#     'zipcode': '60624'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 2275,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.886734},
#   {'livingArea': 1100,
#    'livingAreaValue': 1100,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/4580f78a0e439644f7e90199bb2a25cd-p_c.jpg'}],
#    'zpid': 2056827324,
#    'longitude': -87.709,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3302 W Fulton Blvd UNIT 102',
#     'zipcode': '60624'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 1625,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.88673},
#   {'livingArea': 1400,
#    'livingAreaValue': 1400,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/d6a2fe9014ea7ccef23a7619bf131956-p_c.jpg'}],
#    'zpid': 340734579,
#    'longitude': -87.708595,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3261 W Fulton Blvd #1',
#     'zipcode': '60624'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 2449,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.886044},
#   {'livingArea': 700,
#    'livingAreaValue': 700,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/abd99def209046f950df93f1983273e1-p_c.jpg'}],
#    'zpid': 348787039,
#    'longitude': -87.705956,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '327 N Kedzie Ave #3',
#     'zipcode': '60612'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 2245,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.887333},
#   {'livingArea': 1500,
#    'livingAreaValue': 1500,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/231401b04665a57ba5205308cadcaf65-p_c.jpg'}],
#    'zpid': 2122061125,
#    'longitude': -87.71052,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3344 W Fulton Blvd',
#     'zipcode': '60624'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 2200,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.886703},
#   {'livingArea': 1700,
#    'livingAreaValue': 1700,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/ffce87160ba3f8e0732c410b671bbbb2-p_c.jpg'}],
#    'zpid': 2063478234,
#    'longitude': -87.70835,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3256 W Washington Blvd #G',
#     'zipcode': '60624'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 1700,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.883045},
#   {'livingArea': 800,
#    'livingAreaValue': 800,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/4e11cc23c83801bf7b7de4e490363cc2-p_c.jpg'}],
#    'zpid': 347949926,
#    'longitude': -87.70274,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3034 W Walnut St #1',
#     'zipcode': '60612'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 1675,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.8857},
#   {'livingArea': 1500,
#    'livingAreaValue': 1500,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/a706877a5044169e01d40b2cbf0889c7-p_c.jpg'}],
#    'zpid': 344569706,
#    'longitude': -87.71326,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3452 W Walnut St #2',
#     'zipcode': '60624'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 2100,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.885708}],
#  'livingArea': 2180,
#  'priceHistory': [{'priceChangeRate': 0.21739130434783,
#    'date': '2024-04-30',
#    'source': 'Zillow Rentals',
#    'postingIsRental': True,
#    'time': 1714435200000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rentals',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 1,
#    'buyerAgent': None,
#    'event': 'Listed for rent',
#    'price': 2800},
#   {'priceChangeRate': 0,
#    'date': '2023-07-16',
#    'source': 'Zillow Rentals',
#    'postingIsRental': True,
#    'time': 1689465600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rentals',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': None,
#    'buyerAgent': None,
#    'event': 'Listing removed',
#    'price': None},
#   {'priceChangeRate': 2.5384615384615,
#    'date': '2023-07-12',
#    'source': 'Zillow Rentals',
#    'postingIsRental': True,
#    'time': 1689120000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rentals',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 1,
#    'buyerAgent': None,
#    'event': 'Listed for rent',
#    'price': 2300},
#   {'priceChangeRate': 0.083333333333333,
#    'date': '2019-05-29',
#    'source': 'Zillow Rental Network',
#    'postingIsRental': True,
#    'time': 1559088000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rental Network',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 0,
#    'buyerAgent': None,
#    'event': 'Listing removed',
#    'price': 650},
#   {'priceChangeRate': 0,
#    'date': '2019-05-14',
#    'source': 'Zillow Rental Network',
#    'postingIsRental': True,
#    'time': 1557792000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rental Network',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 0,
#    'buyerAgent': None,
#    'event': 'Listed for rent',
#    'price': 600},
#   {'priceChangeRate': 0,
#    'date': '2018-08-21',
#    'source': 'Zillow Rental Network',
#    'postingIsRental': True,
#    'time': 1534809600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rental Network',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 0,
#    'buyerAgent': None,
#    'event': 'Listing removed',
#    'price': 600},
#   {'priceChangeRate': 0,
#    'date': '2018-08-11',
#    'source': 'Zillow Rental Network',
#    'postingIsRental': True,
#    'time': 1533945600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rental Network',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 0,
#    'buyerAgent': None,
#    'event': 'Listed for rent',
#    'price': 600},
#   {'priceChangeRate': 0,
#    'date': '2018-05-05',
#    'source': 'Zillow Rental Network',
#    'postingIsRental': True,
#    'time': 1525478400000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rental Network',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 0,
#    'buyerAgent': None,
#    'event': 'Listing removed',
#    'price': 600},
#   {'priceChangeRate': 0,
#    'date': '2018-05-04',
#    'source': 'Zillow Rental Network',
#    'postingIsRental': True,
#    'time': 1525392000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rental Network',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 0,
#    'buyerAgent': None,
#    'event': 'Listed for rent',
#    'price': 600},
#   {'priceChangeRate': 5.2967741935484,
#    'date': '2016-02-04',
#    'source': 'MRED as distributed by MLS GRID',
#    'postingIsRental': False,
#    'time': 1454544000000,
#    'sellerAgent': {'name': 'mdrommerhausen',
#     'photo': None,
#     'profileUrl': '/profile/mdrommerhausen3/'},
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'MRED as distributed by MLS GRID',
#     'infoString3': 'https://photos.zillowstatic.com/fp/1b0fc53ffc89ea17e1e382976aca4421-zillow_web_logo_inf_11.jpg',
#     'infoString1': '09068458'},
#    'pricePerSquareFoot': 90,
#    'buyerAgent': {'name': 'Daniel Close',
#     'photo': {'url': 'https://photos.zillowstatic.com/h_e/IS9h3viamvdax50000000000.jpg'},
#     'profileUrl': '/profile/Daniel-Close/'},
#    'event': 'Sold',
#    'price': 195200},
#   {'priceChangeRate': -0.92151898734177,
#    'date': '2010-01-21',
#    'source': 'MRED as distributed by MLS GRID',
#    'postingIsRental': False,
#    'time': 1264032000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'MRED as distributed by MLS GRID',
#     'infoString3': 'https://photos.zillowstatic.com/fp/1b0fc53ffc89ea17e1e382976aca4421-zillow_web_logo_inf_11.jpg',
#     'infoString1': '07395576'},
#    'pricePerSquareFoot': 14,
#    'buyerAgent': {'name': 'mdrommerhausen',
#     'photo': None,
#     'profileUrl': '/profile/mdrommerhausen3/'},
#    'event': 'Sold',
#    'price': 31000},
#   {'priceChangeRate': 1.5986842105263,
#    'date': '2006-06-07',
#    'source': 'Public Record',
#    'postingIsRental': False,
#    'time': 1149638400000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Public Record',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 181,
#    'buyerAgent': None,
#    'event': 'Sold',
#    'price': 395000},
#   {'priceChangeRate': 0,
#    'date': '2005-12-02',
#    'source': 'Public Record',
#    'postingIsRental': False,
#    'time': 1133481600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Public Record',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 70,
#    'buyerAgent': None,
#    'event': 'Sold',
#    'price': 152000}],
#  'favoriteCount': 2,
#  'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/951-Beidler-Elementary-School/',
#    'rating': 4,
#    'totalCount': None,
#    'distance': 0.2,
#    'assigned': None,
#    'name': 'Beidler Elementary School',
#    'studentsPerTeacher': None,
#    'isAssigned': None,
#    'size': None,
#    'level': 'Primary',
#    'grades': 'PK-8',
#    'type': 'Public'},
#   {'link': 'https://www.greatschools.org/illinois/chicago/1248-Marshall-Metropolitan-High-School/',
#    'rating': 1,
#    'totalCount': None,
#    'distance': 0.5,
#    'assigned': None,
#    'name': 'Marshall Metropolitan High School',
#    'studentsPerTeacher': None,
#    'isAssigned': None,
#    'size': None,
#    'level': 'High',
#    'grades': '9-12',
#    'type': 'Public'}],
#  'zestimateHighPercent': '12',
#  'mlsid': None,
#  'countyFIPS': '17031',
#  'city': 'Chicago',
#  'providerListingID': '4pm39qk0cknuv',
#  'country': 'USA',
#  'currency': 'USD',
#  'isListedByOwner': None,
#  'contingentListingType': None}

# %%
response = response.json()
response['description']
# Out:
# "Hello!\n\nThis rehabbed house has central heat & air, exposed bricks, dark hardwood floors, new stainless steel kitchen appliances, in-unit washer and dryer, and plenty of storage space in the basement. It also has a firepit in the backyard for bonfires. \n\nAbout the neighborhood:\nThis unfurnished house is in the heart of East Garfield Park, less than a five-minute walk from the Kedzie Green line and Metra stations, as well as the nearest 52 Kedzie, 82 Homan and 94 California bus stops. There is plenty of space downstairs for your bikes, so you can get around very easily from here without a car. If you do have a car though, you can have a spot out back for $25/month each, or use one of the parking spots on the street out front. \n\nThis house is within a few blocks of cool neighborhood spots like Passion House Coffee, Breakthrough Community Center, Inspiration Kitchens, and the Garfield Park Conservatory, and just a short bike ride away from everything in Humboldt Park, Ukranian Village and West Loop. \n\nAbout the dollar bills/paperwork:\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent. \n\nIf all that sounds good to you, send us a message so we can share details with you about our open house this Sunday, May 5.\n\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent."

# %%
def fetch_descriptions(properties):
    """
    Fetches the descriptions of each property and appends them to the list.

    Parameters:
    - properties: A list of dictionaries representing properties.

    Returns:
    - A list of dictionaries(the same format as input).
    """
    url_details = "https://zillow-com1.p.rapidapi.com/property"

    for prop in properties:
        # Fetch detailed information using detailUrl
        querystring = {"property_url": prop['detailUrl']}
        response = requests.get(url_details, headers=headers, params=querystring)

        # Convert to JSON and fetch description
        detail_data = response.json()
        prop['description'] = detail_data.get('description', 'No description available')

    return properties

# %%
top_properties = fetch_descriptions(top_properties)
top_properties
# Out:
# [{'propertyType': None,
#   'address': '2611 N Hermitage Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/apartments/chicago-il/norweta/BXQZ9R/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/65ca2c82486f45afdc0e1f156f6b514f-p_e.jpg',
#   'description': 'No description available'},
#  {'propertyType': 'SINGLE_FAMILY',
#   'address': '3240 W Fulton Blvd, Chicago, IL 60624',
#   'price': 2800,
#   'bedrooms': 5,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/3240-W-Fulton-Blvd-Chicago-IL-60624/158698100_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/402d1685a0321ebbd7c3b2ceaecb3822-p_e.jpg',
#   'description': "Hello!\n\nThis rehabbed house has central heat & air, exposed bricks, dark hardwood floors, new stainless steel kitchen appliances, in-unit washer and dryer, and plenty of storage space in the basement. It also has a firepit in the backyard for bonfires. \n\nAbout the neighborhood:\nThis unfurnished house is in the heart of East Garfield Park, less than a five-minute walk from the Kedzie Green line and Metra stations, as well as the nearest 52 Kedzie, 82 Homan and 94 California bus stops. There is plenty of space downstairs for your bikes, so you can get around very easily from here without a car. If you do have a car though, you can have a spot out back for $25/month each, or use one of the parking spots on the street out front. \n\nThis house is within a few blocks of cool neighborhood spots like Passion House Coffee, Breakthrough Community Center, Inspiration Kitchens, and the Garfield Park Conservatory, and just a short bike ride away from everything in Humboldt Park, Ukranian Village and West Loop. \n\nAbout the dollar bills/paperwork:\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent. \n\nIf all that sounds good to you, send us a message so we can share details with you about our open house this Sunday, May 5.\n\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent."},
#  {'propertyType': 'APARTMENT',
#   'address': '3251 W Evergreen Ave #2, Chicago, IL 60651',
#   'price': 2300,
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/3251-W-Evergreen-Ave-2-Chicago-IL-60651/348824068_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/6253b10423f0bf3cee38170605b73c8b-p_e.jpg',
#   'description': "Conveniently located just a short commute from downtown Chicago, minutes away from 606 Bloomingdale Trail. Humboldt Park/ Logan Square Edge offers the perfect balance of urban excitement and neighborhood tranquility. With its tree-lined streets, historic architecture, and welcoming atmosphere, it's no wonder why so many people are proud to call Humboldt Park home.\n\nFully remodeled unit with contemporary design, Hardwood Floors. Stainless steel appliances: Range, Over Range-Microwave, Refrigerator. In-unit Samsung Washer/Dryer. Central AC/Furnace.\n\nOne parking spot in Detached Garage included. Gas/Electric utilities paid by tenant. (1) Pet allowed upon approval.\n\nTenant is responsible for electric/gas utilities. One parking spot detached is included if requested. (1) small pet allowed upon approval if applicable. Last month rent due at signing of lease with first month's rent payment. No smoking in unit allowed. (1) year leases."}]

# %% [markdown]
# #### resoFacts

# %%
def fetch_resoFacts(properties, headers, keys_to_fetch):
    """
    Fetches specific information from the resoFacts dictionary of each property and appends it in a nested format.

    Parameters:
    - properties: A list of dictionaries representing properties.
    - headers: Headers for the API request.
    - keys_to_fetch: A list of keys to fetch from the resoFacts dictionary.

    Returns:
    - A list of dictionaries with the specified information appended in a nested format.
    """
    url_details = "https://zillow-com1.p.rapidapi.com/property"

    for prop in properties:
        # Fetch detailed information using detailUrl
        querystring = {"property_url": prop['detailUrl']}
        response = requests.get(url_details, headers=headers, params=querystring)
        detail_data = response.json()

        # Fetch information from the resoFacts dictionary
        resoFacts = detail_data.get('resoFacts', {})

        # Create a nested dictionary to store resoFacts information
        prop['resoFacts'] = {}

        for key in keys_to_fetch:
            prop['resoFacts'][key] = resoFacts.get(key, 'N/A')

    return properties

# %%
# key to fetch
keys_to_fetch_resoFacts = [
    'hasGarage', 'hasPetsAllowed', 'heating', 'cooling', 'flooring', 'appliances',
    'laundryFeatures', 'associationFee',
    'livingArea', 'taxAnnualAmount', 'parkingFeatures', 'stories'
]

top_properties = fetch_resoFacts(top_properties, headers, keys_to_fetch_resoFacts)
top_properties

# %% [markdown]
# #### Schools

# %%
def fetch_schools(properties, headers):
    """
    Fetches information about nearby schools and appends it in a nested format.

    Parameters:
    - properties: A list of dictionaries representing properties.
    - headers: Headers for the API request.

    Returns:
    - A list of dictionaries with school information appended in a nested format.
    """
    url_details = "https://zillow-com1.p.rapidapi.com/property"

    for prop in properties:
        # Fetch detailed information using detailUrl
        querystring = {"property_url": prop['detailUrl']}
        response = requests.get(url_details, headers=headers, params=querystring)
        detail_data = response.json()

        # Fetch schools information
        schools = detail_data.get('schools', [])

        # Create a nested dictionary to store school information
        prop['schools'] = schools

    return properties

# %%
top_properties = fetch_schools(top_properties, headers)
top_properties
# Out:
# [{'propertyType': None,
#   'address': '2611 N Hermitage Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/apartments/chicago-il/norweta/BXQZ9R/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/65ca2c82486f45afdc0e1f156f6b514f-p_e.jpg',
#   'description': 'No description available',
#   'resoFacts': {'hasGarage': 'N/A',
#    'hasPetsAllowed': 'N/A',
#    'heating': 'N/A',
#    'cooling': 'N/A',
#    'flooring': 'N/A',
#    'appliances': 'N/A',
#    'laundryFeatures': 'N/A',
#    'associationFee': 'N/A',
#    'livingArea': 'N/A',
#    'taxAnnualAmount': 'N/A',
#    'parkingFeatures': 'N/A',
#    'stories': 'N/A'},
#   'schools': []},
#  {'propertyType': 'SINGLE_FAMILY',
#   'address': '3240 W Fulton Blvd, Chicago, IL 60624',
#   'price': 2800,
#   'bedrooms': 5,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/3240-W-Fulton-Blvd-Chicago-IL-60624/158698100_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/402d1685a0321ebbd7c3b2ceaecb3822-p_e.jpg',
#   'description': "Hello!\n\nThis rehabbed house has central heat & air, exposed bricks, dark hardwood floors, new stainless steel kitchen appliances, in-unit washer and dryer, and plenty of storage space in the basement. It also has a firepit in the backyard for bonfires. \n\nAbout the neighborhood:\nThis unfurnished house is in the heart of East Garfield Park, less than a five-minute walk from the Kedzie Green line and Metra stations, as well as the nearest 52 Kedzie, 82 Homan and 94 California bus stops. There is plenty of space downstairs for your bikes, so you can get around very easily from here without a car. If you do have a car though, you can have a spot out back for $25/month each, or use one of the parking spots on the street out front. \n\nThis house is within a few blocks of cool neighborhood spots like Passion House Coffee, Breakthrough Community Center, Inspiration Kitchens, and the Garfield Park Conservatory, and just a short bike ride away from everything in Humboldt Park, Ukranian Village and West Loop. \n\nAbout the dollar bills/paperwork:\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent. \n\nIf all that sounds good to you, send us a message so we can share details with you about our open house this Sunday, May 5.\n\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent.",
#   'resoFacts': {'hasGarage': False,
#    'hasPetsAllowed': True,
#    'heating': None,
#    'cooling': ['Central Air'],
#    'flooring': ['Hardwood'],
#    'appliances': ['Dishwasher', 'Dryer', 'Washer'],
#    'laundryFeatures': ['In Unit'],
#    'associationFee': None,
#    'livingArea': '2,180 sqft',
#    'taxAnnualAmount': 53,
#    'parkingFeatures': ['Off Street'],
#    'stories': None},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/951-Beidler-Elementary-School/',
#     'rating': 4,
#     'totalCount': None,
#     'distance': 0.2,
#     'assigned': None,
#     'name': 'Beidler Elementary School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1248-Marshall-Metropolitan-High-School/',
#     'rating': 1,
#     'totalCount': None,
#     'distance': 0.5,
#     'assigned': None,
#     'name': 'Marshall Metropolitan High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'High',
#     'grades': '9-12',
#     'type': 'Public'}]},
#  {'propertyType': 'APARTMENT',
#   'address': '3251 W Evergreen Ave #2, Chicago, IL 60651',
#   'price': 2300,
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/3251-W-Evergreen-Ave-2-Chicago-IL-60651/348824068_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/6253b10423f0bf3cee38170605b73c8b-p_e.jpg',
#   'description': "Conveniently located just a short commute from downtown Chicago, minutes away from 606 Bloomingdale Trail. Humboldt Park/ Logan Square Edge offers the perfect balance of urban excitement and neighborhood tranquility. With its tree-lined streets, historic architecture, and welcoming atmosphere, it's no wonder why so many people are proud to call Humboldt Park home.\n\nFully remodeled unit with contemporary design, Hardwood Floors. Stainless steel appliances: Range, Over Range-Microwave, Refrigerator. In-unit Samsung Washer/Dryer. Central AC/Furnace.\n\nOne parking spot in Detached Garage included. Gas/Electric utilities paid by tenant. (1) Pet allowed upon approval.\n\nTenant is responsible for electric/gas utilities. One parking spot detached is included if requested. (1) small pet allowed upon approval if applicable. Last month rent due at signing of lease with first month's rent payment. No smoking in unit allowed. (1) year leases.",
#   'resoFacts': {'hasGarage': False,
#    'hasPetsAllowed': True,
#    'heating': ['Forced Air'],
#    'cooling': ['Central Air'],
#    'flooring': ['Hardwood'],
#    'appliances': ['Dishwasher', 'Dryer', 'Washer'],
#    'laundryFeatures': ['In Unit'],
#    'associationFee': None,
#    'livingArea': None,
#    'taxAnnualAmount': 43,
#    'parkingFeatures': ['Detached'],
#    'stories': None},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1210-Lowell-Elementary-School/',
#     'rating': 3,
#     'totalCount': None,
#     'distance': 0.1,
#     'assigned': None,
#     'name': 'Lowell Elementary School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/9773-Orr-Academy-High-School/',
#     'rating': 1,
#     'totalCount': None,
#     'distance': 1.2,
#     'assigned': None,
#     'name': 'Orr Academy High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'High',
#     'grades': '9-12',
#     'type': 'Public'}]}]

# %% [markdown]
# ### For main use case

# %%
import json

# %%
user_query = "I am looking for a two-bedroom apartment for less than $2000 per month in Hyde Park. Are there good italian restaurants in Hyde Park?"
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location":"chicago, il",
# "bedsMin":"2",
# "bedsMax":"2",
# "status_type":"ForRent",
# "rentMaxPrice":"2000",
# "keywords":"Hyde Park, italian",
# "sort":"Newest"
# }

# %%
# get an api filter through Gemini
querystring = get_chat_response(chat, prompt)

# from str to dict
querystring = json.loads(querystring)

# get listings from zillow api
response = requests.get(url, headers = headers, params = querystring)

# %%
# Define fields to extract
fields = ["propertyType", "address", "price", "bedrooms", "bathrooms", "detailUrl", "imgSrc", "longitude", "latitude"]

# Get top 3 properties with selected fields
top_properties = extract_properties(response, 3, fields)
top_properties
# Out:
# [{'propertyType': None,
#   'address': '1501 N California Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/b/1501-n.-california-ave.-chicago-il-CJcL/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/f08d86d33bb00e30755fba122ce1f4f2-p_e.jpg',
#   'longitude': -87.69659,
#   'latitude': 41.908566},
#  {'propertyType': None,
#   'address': '2701 S Indiana Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/apartments/chicago-il/eden-commons/5XjNY3/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/c533fb4ba892997a014b728e64db7108-p_e.jpg',
#   'longitude': -87.62091,
#   'latitude': 41.844006},
#  {'propertyType': 'APARTMENT',
#   'address': '938 W 34th St, Chicago, IL 60608',
#   'price': 1300,
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/938-W-34th-St-Chicago-IL-60608/2103556011_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/39271ea4416452453259cd89b55d1170-p_e.jpg',
#   'longitude': -87.65012,
#   'latitude': 41.833042}]

# %%
# get description
top_properties = fetch_descriptions(top_properties)

# get detail info from resoFacts
keys_to_fetch_resoFacts = [
    'hasGarage', 'hasPetsAllowed', 'heating', 'cooling', 'flooring', 'appliances',
    'laundryFeatures', 'associationFee',
    'livingArea', 'taxAnnualAmount', 'parkingFeatures', 'stories'
]
top_properties = fetch_resoFacts(top_properties, headers, keys_to_fetch_resoFacts)
# get school info
top_properties = fetch_schools(top_properties, headers)
top_properties
# Out:
# [{'propertyType': None,
#   'address': '1501 N California Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/b/1501-n.-california-ave.-chicago-il-CJcL/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/f08d86d33bb00e30755fba122ce1f4f2-p_e.jpg',
#   'longitude': -87.69659,
#   'latitude': 41.908566,
#   'description': 'No description available',
#   'resoFacts': {'hasGarage': 'N/A',
#    'hasPetsAllowed': 'N/A',
#    'heating': 'N/A',
#    'cooling': 'N/A',
#    'flooring': 'N/A',
#    'appliances': 'N/A',
#    'laundryFeatures': 'N/A',
#    'associationFee': 'N/A',
#    'livingArea': 'N/A',
#    'taxAnnualAmount': 'N/A',
#    'parkingFeatures': 'N/A',
#    'stories': 'N/A'},
#   'schools': []},
#  {'propertyType': None,
#   'address': '2701 S Indiana Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/apartments/chicago-il/eden-commons/5XjNY3/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/c533fb4ba892997a014b728e64db7108-p_e.jpg',
#   'longitude': -87.62091,
#   'latitude': 41.844006,
#   'description': 'No description available',
#   'resoFacts': {'hasGarage': 'N/A',
#    'hasPetsAllowed': 'N/A',
#    'heating': 'N/A',
#    'cooling': 'N/A',
#    'flooring': 'N/A',
#    'appliances': 'N/A',
#    'laundryFeatures': 'N/A',
#    'associationFee': 'N/A',
#    'livingArea': 'N/A',
#    'taxAnnualAmount': 'N/A',
#    'parkingFeatures': 'N/A',
#    'stories': 'N/A'},
#   'schools': []},
#  {'propertyType': 'APARTMENT',
#   'address': '938 W 34th St, Chicago, IL 60608',
#   'price': 1300,
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/938-W-34th-St-Chicago-IL-60608/2103556011_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/39271ea4416452453259cd89b55d1170-p_e.jpg',
#   'longitude': -87.65012,
#   'latitude': 41.833042,
#   'description': "Sunny two bedroom, one bathroom apartment in vintage Bridgeport 6 flat near 34th and Morgan available July 1. New kitchen with granite countertops and stainless steel appliances, hardwood floors, high ceilings, a porcelain-tiled bathroom, air conditioner, full-sized south-facing windows, cordless wide slat window shades. Backyard, laundry in building, separate storage shed. $1300 a month; no security deposit, $500 move-in fee. Pets negotiable ($300 annual fee). Move-in fee will be waived for tenants with excellent credit and references. Steps away from flourishing Morgan Street retail district. Close to Maria's, Bridgeport Coffee, Antique Taco, Bridgeport Art Center. Easy access to Sox Park, Red Line, Orange Line, Dan Ryan and Stevenson expressways. Small town living in the big city.",
#   'resoFacts': {'hasGarage': False,
#    'hasPetsAllowed': True,
#    'heating': None,
#    'cooling': None,
#    'flooring': None,
#    'appliances': ['Microwave', 'Refrigerator', 'Stove'],
#    'laundryFeatures': None,
#    'associationFee': None,
#    'livingArea': '600 sqft',
#    'taxAnnualAmount': 25,
#    'parkingFeatures': {},
#    'stories': None},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1268-Armour-Elementary-School/',
#     'rating': 6,
#     'totalCount': None,
#     'distance': 0.1,
#     'assigned': None,
#     'name': 'Armour Elementary School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1406-Tilden-Career-Communty-Academy-High-School/',
#     'rating': 1,
#     'totalCount': None,
#     'distance': 1.8,
#     'assigned': None,
#     'name': 'Tilden Career Communty Academy High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'High',
#     'grades': '9-12',
#     'type': 'Public'}]}]

# %%
# Call Yelp API using top properties
yelp_results = fetch_top_businesses_near_properties(yelp_api_key, top_properties, user_query, chat)

fields_to_extract = ['business_name', 'categories_titles', 'rating', 'latitude', 'longitude', 'display_address', 'url']

top_restaurants = extract_business_info(yelp_results, 2, fields_to_extract)

# Add restaurant info to property info
top_properties = merge_property_and_restaurant_info(top_properties, top_restaurants)
top_properties
# Out:
# Category determined: italian
# {'location': '41.908566, -87.69659', 'term': 'restaurants', 'radius': 2000, 'categories': 'italian', 'sort_by': 'rating', 'limit': 2}
# {'location': '41.844006, -87.62091', 'term': 'restaurants', 'radius': 2000, 'categories': 'italian', 'sort_by': 'rating', 'limit': 2}
# {'location': '41.833042, -87.65012', 'term': 'restaurants', 'radius': 2000, 'categories': 'italian', 'sort_by': 'rating', 'limit': 2}
# [{'propertyType': None,
#   'address': '1501 N California Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/b/1501-n.-california-ave.-chicago-il-CJcL/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/f08d86d33bb00e30755fba122ce1f4f2-p_e.jpg',
#   'longitude': -87.69659,
#   'latitude': 41.908566,
#   'description': 'No description available',
#   'resoFacts': {'hasGarage': 'N/A',
#    'hasPetsAllowed': 'N/A',
#    'heating': 'N/A',
#    'cooling': 'N/A',
#    'flooring': 'N/A',
#    'appliances': 'N/A',
#    'laundryFeatures': 'N/A',
#    'associationFee': 'N/A',
#    'livingArea': 'N/A',
#    'taxAnnualAmount': 'N/A',
#    'parkingFeatures': 'N/A',
#    'stories': 'N/A'},
#   'schools': [],
#   'restaurant_1': {'business_name': 'Antico',
#    'categories_titles': ['Italian'],
#    'rating': 4.4,
#    'latitude': 41.91746,
#    'longitude': -87.68281,
#    'display_address': '1946 N Leavitt St Chicago, IL 60647',
#    'url': 'https://www.yelp.com/biz/antico-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'},
#   'restaurant_2': {'business_name': 'Segnatore',
#    'categories_titles': ['Italian'],
#    'rating': 4.4,
#    'latitude': 41.89942,
#    'longitude': -87.6964,
#    'display_address': '1001 N California Ave Chicago, IL 60622',
#    'url': 'https://www.yelp.com/biz/segnatore-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}},
#  {'propertyType': None,
#   'address': '2701 S Indiana Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/apartments/chicago-il/eden-commons/5XjNY3/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/c533fb4ba892997a014b728e64db7108-p_e.jpg',
#   'longitude': -87.62091,
#   'latitude': 41.844006,
#   'description': 'No description available',
#   'resoFacts': {'hasGarage': 'N/A',
#    'hasPetsAllowed': 'N/A',
#    'heating': 'N/A',
#    'cooling': 'N/A',
#    'flooring': 'N/A',
#    'appliances': 'N/A',
#    'laundryFeatures': 'N/A',
#    'associationFee': 'N/A',
#    'livingArea': 'N/A',
#    'taxAnnualAmount': 'N/A',
#    'parkingFeatures': 'N/A',
#    'stories': 'N/A'},
#   'schools': [],
#   'restaurant_1': {'business_name': "Franco's Ristorante",
#    'categories_titles': ['Italian'],
#    'rating': 4.4,
#    'latitude': 41.83843,
#    'longitude': -87.6343,
#    'display_address': '300 W 31st St Chicago, IL 60616',
#    'url': 'https://www.yelp.com/biz/francos-ristorante-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'},
#   'restaurant_2': {'business_name': 'Il Culaccino',
#    'categories_titles': ['Italian', 'Venues & Event Spaces'],
#    'rating': 4.0,
#    'latitude': 41.8533582,
#    'longitude': -87.6223549,
#    'display_address': '2134 S Indiana Ave Chicago, IL 60616',
#    'url': 'https://www.yelp.com/biz/il-culaccino-chicago-2?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}},
#  {'propertyType': 'APARTMENT',
#   'address': '938 W 34th St, Chicago, IL 60608',
#   'price': 1300,
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/938-W-34th-St-Chicago-IL-60608/2103556011_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/39271ea4416452453259cd89b55d1170-p_e.jpg',
#   'longitude': -87.65012,
#   'latitude': 41.833042,
#   'description': "Sunny two bedroom, one bathroom apartment in vintage Bridgeport 6 flat near 34th and Morgan available July 1. New kitchen with granite countertops and stainless steel appliances, hardwood floors, high ceilings, a porcelain-tiled bathroom, air conditioner, full-sized south-facing windows, cordless wide slat window shades. Backyard, laundry in building, separate storage shed. $1300 a month; no security deposit, $500 move-in fee. Pets negotiable ($300 annual fee). Move-in fee will be waived for tenants with excellent credit and references. Steps away from flourishing Morgan Street retail district. Close to Maria's, Bridgeport Coffee, Antique Taco, Bridgeport Art Center. Easy access to Sox Park, Red Line, Orange Line, Dan Ryan and Stevenson expressways. Small town living in the big city.",
#   'resoFacts': {'hasGarage': False,
#    'hasPetsAllowed': True,
#    'heating': None,
#    'cooling': None,
#    'flooring': None,
#    'appliances': ['Microwave', 'Refrigerator', 'Stove'],
#    'laundryFeatures': None,
#    'associationFee': None,
#    'livingArea': '600 sqft',
#    'taxAnnualAmount': 25,
#    'parkingFeatures': {},
#    'stories': None},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1268-Armour-Elementary-School/',
#     'rating': 6,
#     'totalCount': None,
#     'distance': 0.1,
#     'assigned': None,
#     'name': 'Armour Elementary School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1406-Tilden-Career-Communty-Academy-High-School/',
#     'rating': 1,
#     'totalCount': None,
#     'distance': 1.8,
#     'assigned': None,
#     'name': 'Tilden Career Communty Academy High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'High',
#     'grades': '9-12',
#     'type': 'Public'}],
#   'restaurant_1': {'business_name': "Franco's Ristorante",
#    'categories_titles': ['Italian'],
#    'rating': 4.4,
#    'latitude': 41.83843,
#    'longitude': -87.6343,
#    'display_address': '300 W 31st St Chicago, IL 60616',
#    'url': 'https://www.yelp.com/biz/francos-ristorante-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'},
#   'restaurant_2': {'business_name': "Gio's Cafe & Deli",
#    'categories_titles': ['Delis', 'Italian'],
#    'rating': 4.3,
#    'latitude': 41.84366,
#    'longitude': -87.64312,
#    'display_address': '2724 S Lowe Ave Chicago, IL 60616',
#    'url': 'https://www.yelp.com/biz/gios-cafe-and-deli-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}}]

# %%
# Create property map
property_map = create_property_map(top_properties)

property_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46d8ee4e0fb540fd3839ffb09e58f403 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46d8ee4e0fb540fd3839ffb09e58f403&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46d8ee4e0fb540fd3839ffb09e58f403 = L.map(
#                 &quot;map_46d8ee4e0fb540fd3839ffb09e58f403&quot;,
#                 {
#                     center: [41.881832, -87.623177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5af23d6354771150d2fc8f07b574103a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5af23d6354771150d2fc8f07b574103a.addTo(map_46d8ee4e0fb540fd3839ffb09e58f403);
#
#
#             var marker_9d90d44fbdee196e5924fa85f1411ffb = L.marker(
#                 [41.908566, -87.69659],
#                 {}
#             ).addTo(map_46d8ee4e0fb540fd3839ffb09e58f403);
#
#
#             var icon_eb9648a2461f548eb0d53666b5fe186a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9d90d44fbdee196e5924fa85f1411ffb.setIcon(icon_eb9648a2461f548eb0d53666b5fe186a);
#
#
#         var popup_cfa33cc201610978af2fd2fc17ca55ca = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_e36aa1136fc53ce3c33055dacc1d1e96 = $(`&lt;div id=&quot;html_e36aa1136fc53ce3c33055dacc1d1e96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.zillow.com/b/1501-n.-california-ave.-chicago-il-CJcL/&quot; target=&quot;_blank&quot;&gt;1501 N California Ave, Chicago, IL&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_cfa33cc201610978af2fd2fc17ca55ca.setContent(html_e36aa1136fc53ce3c33055dacc1d1e96);
#
#
#
#         marker_9d90d44fbdee196e5924fa85f1411ffb.bindPopup(popup_cfa33cc201610978af2fd2fc17ca55ca)
#         ;
#
#
#
#
#             marker_9d90d44fbdee196e5924fa85f1411ffb.bindTooltip(
#                 `&lt;div&gt;
#                      Click for Zillow Listing
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_769c48f8c82abc627b666fc2bd2586d6 = L.marker(
#                 [41.844006, -87.62091],
#                 {}
#             ).addTo(map_46d8ee4e0fb540fd3839ffb09e58f403);
#
#
#             var icon_0d0b5194d85c0d744cbf05767077e235 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_769c48f8c82abc627b666fc2bd2586d6.setIcon(icon_0d0b5194d85c0d744cbf05767077e235);
#
#
#         var popup_d12bb96faaafe6f67a8851768741b6b5 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_0e3ba1900a68d5d2cc2e0866a2276abb = $(`&lt;div id=&quot;html_0e3ba1900a68d5d2cc2e0866a2276abb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.zillow.com/apartments/chicago-il/eden-commons/5XjNY3/&quot; target=&quot;_blank&quot;&gt;2701 S Indiana Ave, Chicago, IL&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_d12bb96faaafe6f67a8851768741b6b5.setContent(html_0e3ba1900a68d5d2cc2e0866a2276abb);
#
#
#
#         marker_769c48f8c82abc627b666fc2bd2586d6.bindPopup(popup_d12bb96faaafe6f67a8851768741b6b5)
#         ;
#
#
#
#
#             marker_769c48f8c82abc627b666fc2bd2586d6.bindTooltip(
#                 `&lt;div&gt;
#                      Click for Zillow Listing
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_89afa3a318a5c2c09c90dcdde674e502 = L.marker(
#                 [41.833042, -87.65012],
#                 {}
#             ).addTo(map_46d8ee4e0fb540fd3839ffb09e58f403);
#
#
#             var icon_244f010c8e41000765ab5ad1cd4cd36d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_89afa3a318a5c2c09c90dcdde674e502.setIcon(icon_244f010c8e41000765ab5ad1cd4cd36d);
#
#
#         var popup_a8cdca91852d41a779e755f6b9c80782 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_04ce72b5fac72af13979e070d54fb882 = $(`&lt;div id=&quot;html_04ce72b5fac72af13979e070d54fb882&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;

# %%
# Create property restaurant map
property_restaurant_map = create_property_restaurant_map(top_properties)

property_restaurant_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e25f292a287ed57851d2b7ce2135b24 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e25f292a287ed57851d2b7ce2135b24&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e25f292a287ed57851d2b7ce2135b24 = L.map(
#                 &quot;map_4e25f292a287ed57851d2b7ce2135b24&quot;,
#                 {
#                     center: [41.881832, -87.623177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8969657e5d3e66ef10616a13d6918b54 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8969657e5d3e66ef10616a13d6918b54.addTo(map_4e25f292a287ed57851d2b7ce2135b24);
#
#
#             var marker_3c6a718a48878a384218fd4b75ab2618 = L.marker(
#                 [41.908566, -87.69659],
#                 {}
#             ).addTo(map_4e25f292a287ed57851d2b7ce2135b24);
#
#
#             var icon_e3fcb8521a42accace273973e7124d40 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3c6a718a48878a384218fd4b75ab2618.setIcon(icon_e3fcb8521a42accace273973e7124d40);
#
#
#         var popup_e6382cff085183520869f5d6e9cf3c16 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_0e3efbe8f7f59fa7da3883dff1c39574 = $(`&lt;div id=&quot;html_0e3efbe8f7f59fa7da3883dff1c39574&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.zillow.com/b/1501-n.-california-ave.-chicago-il-CJcL/&quot; target=&quot;_blank&quot;&gt;1501 N California Ave, Chicago, IL&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_e6382cff085183520869f5d6e9cf3c16.setContent(html_0e3efbe8f7f59fa7da3883dff1c39574);
#
#
#
#         marker_3c6a718a48878a384218fd4b75ab2618.bindPopup(popup_e6382cff085183520869f5d6e9cf3c16)
#         ;
#
#
#
#
#             marker_3c6a718a48878a384218fd4b75ab2618.bindTooltip(
#                 `&lt;div&gt;
#                      Click for property details
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2b3bf35181e76690dc641bfce90230de = L.marker(
#                 [41.91746, -87.68281],
#                 {}
#             ).addTo(map_4e25f292a287ed57851d2b7ce2135b24);
#
#
#             var icon_6e41dd47d080db4ff5f75c529efa6774 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2b3bf35181e76690dc641bfce90230de.setIcon(icon_6e41dd47d080db4ff5f75c529efa6774);
#
#
#         var popup_bbb1c9c62a8fae3b98f39ae7f55a0ba9 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_189700fa20c6642c4547f1d2faa22310 = $(`&lt;div id=&quot;html_189700fa20c6642c4547f1d2faa22310&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.yelp.com/biz/antico-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&amp;utm_campaign=yelp_api_v3&amp;utm_medium=api_v3_business_search&amp;utm_source=GgXKz4qBvfURJxuhy6g81Q&quot; target=&quot;_blank&quot;&gt;Antico&lt;/a&gt;&lt;br/&gt;Italian&lt;br/&gt;Rating: 4.4&lt;/div&gt;`)[0];
#                 popup_bbb1c9c62a8fae3b98f39ae7f55a0ba9.setContent(html_189700fa20c6642c4547f1d2faa22310);
#
#
#
#         marker_2b3bf35181e76690dc641bfce90230de.bindPopup(popup_bbb1c9c62a8fae3b98f39ae7f55a0ba9)
#         ;
#
#
#
#
#             marker_2b3bf35181e76690dc641bfce90230de.bindTooltip(
#                 `&lt;div&gt;
#                      Click for details on Antico
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9ccfa1a01185e4241a44dd4df36d4401 = L.marker(
#                 [41.89942, -87.6964],
#                 {}
#             ).addTo(map_4e25f292a287ed57851d2b7ce2135b24);
#
#
#             var icon_3dbb0c7afe1703ec05903dafb73cd046 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9ccfa1a01185e4241a44dd4df36d4401.setIcon(icon_3dbb0c7afe1703ec05903dafb73cd046);
#
#
#         var popup_c89068ac36e6c2ba83f914dc89cd89f0 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_e8015403c134

# %% [markdown]
# ## 4. Generate advice with the property listings

# %%
def generate_prompt_property(instruction, user_query, property_info, fields):
    updated_instruction = instruction.replace("{USER_QUERY}", user_query)
    updated_instruction = updated_instruction.replace("{PROPERTY_INFO}", property_info)
    updated_instruction = updated_instruction.replace("{KEY_FIELDS}", fields)
    return updated_instruction

# %%
instruction = """
### Instructions ###
I want you to act as a real estate advisor. Please recommend properties to the customer. 
'User’s query' represents the questions you are asked by the customer. 
'Real estate properties to present to the user' are the properties you will introduce to the customer. 

Note1: Include all information from {KEY_FIELDS}, including links. 
Note2: The "Resofacts" and "Schools" fields are in JSON format. You do not need to include all the information from "Resofacts" and "Schools" in your initial response. 
However, if the user asks specific questions about "Resofacts" and "Schools", include relevant information in your answer.

### User’s query ###
{USER_QUERY}

### Real estate properties to present to the user ###
{PROPERTY_INFO}

### Output ###
"""

# %%
def format_properties(properties, fields):
    formatted_properties = []
    for prop in properties:
        # Format and concatenate each field of each property
        formatted_prop = ', '.join(f"{field.capitalize().replace('_', ' ')}: {prop.get(field, 'N/A')}" for field in fields)
        formatted_properties.append(formatted_prop)
    return '\n\n'.join(formatted_properties)

# %%
# Change format
fields_desc = fields + ['description', 'resoFacts', 'schools', 'restaurant_1', 'restaurant_2']
property_info = format_properties(top_properties, fields_desc)
print(property_info)
# Out:
# Propertytype: None, Address: 1501 N California Ave, Chicago, IL, Price: None, Bedrooms: None, Bathrooms: None, Detailurl: https://www.zillow.com/b/1501-n.-california-ave.-chicago-il-CJcL/, Imgsrc: https://photos.zillowstatic.com/fp/f08d86d33bb00e30755fba122ce1f4f2-p_e.jpg, Longitude: -87.69659, Latitude: 41.908566, Description: No description available, Resofacts: {'hasGarage': 'N/A', 'hasPetsAllowed': 'N/A', 'heating': 'N/A', 'cooling': 'N/A', 'flooring': 'N/A', 'appliances': 'N/A', 'laundryFeatures': 'N/A', 'associationFee': 'N/A', 'livingArea': 'N/A', 'taxAnnualAmount': 'N/A', 'parkingFeatures': 'N/A', 'stories': 'N/A'}, Schools: [], Restaurant 1: {'business_name': 'Antico', 'categories_titles': ['Italian'], 'rating': 4.4, 'latitude': 41.91746, 'longitude': -87.68281, 'display_address': '1946 N Leavitt St Chicago, IL 60647', 'url': 'https://www.yelp.com/biz/antico-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}, Restaurant 2: {'business_name': 'Segnatore', 'categories_titles': ['Italian'], 'rating': 4.4, 'latitude': 41.89942, 'longitude': -87.6964, 'display_address': '1001 N California Ave Chicago, IL 60622', 'url': 'https://www.yelp.com/biz/segnatore-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}
#
# Propertytype: None, Address: 2701 S Indiana Ave, Chicago, IL, Price: None, Bedrooms: None, Bathrooms: None, Detailurl: https://www.zillow.com/apartments/chicago-il/eden-commons/5XjNY3/, Imgsrc: https://photos.zillowstatic.com/fp/c533fb4ba892997a014b728e64db7108-p_e.jpg, Longitude: -87.62091, Latitude: 41.844006, Description: No description available, Resofacts: {'hasGarage': 'N/A', 'hasPetsAllowed': 'N/A', 'heating': 'N/A', 'cooling': 'N/A', 'flooring': 'N/A', 'appliances': 'N/A', 'laundryFeatures': 'N/A', 'associationFee': 'N/A', 'livingArea': 'N/A', 'taxAnnualAmount': 'N/A', 'parkingFeatures': 'N/A', 'stories': 'N/A'}, Schools: [], Restaurant 1: {'business_name': "Franco's Ristorante", 'categories_titles': ['Italian'], 'rating': 4.4, 'latitude': 41.83843, 'longitude': -87.6343, 'display_address': '300 W 31st St Chicago, IL 60616', 'url': 'https://www.yelp.com/biz/francos-ristorante-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}, Restaurant 2: {'business_name': 'Il Culaccino', 'categories_titles': ['Italian', 'Venues & Event Spaces'], 'rating': 4.0, 'latitude': 41.8533582, 'longitude': -87.6223549, 'display_address': '2134 S Indiana Ave Chicago, IL 60616', 'url': 'https://www.yelp.com/biz/il-culaccino-chicago-2?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}
#
# Propertytype: APARTMENT, Address: 938 W 34th St, Chicago, IL 60608, Price: 1300, Bedrooms: 2, Bathrooms: 1, Detailurl: https://www.zillow.com/homedetails/938-W-34th-St-Chicago-IL-60608/2103556011_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/39271ea4416452453259cd89b55d1170-p_e.jpg, Longitude: -87.65012, Latitude: 41.833042, Description: Sunny two bedroom, one bathroom apartment in vintage Bridgeport 6 flat near 34th and Morgan available July 1. New kitchen with granite countertops and stainless steel appliances, hardwood floors, high ceilings, a porcelain-tiled bathroom, air conditioner, full-sized south-facing windows, cordless wide slat window shades. Backyard, laundry in building, separate storage shed. $1300 a month; no security deposit, $500 move-in fee. Pets negotiable ($300 annual fee). Move-in fee will be waived for tenants with excellent credit and references. Steps away from flourishing Morgan Street retail district. Close to Maria's, Bridgeport Coffee, Antique Taco, Bridgeport Art Center. Easy access to Sox Park, Red Line, Orange Line, Dan Ryan and Stevenson expressways. Small town living in the big city., Resofacts: {'hasGarage': False, 'hasPetsAllowed': True, 'heating': None, 'cooling': None, 'flooring': None, 'appliances': ['Microwave', 'Refrigerator', 'Stove'], 'laundryFeatures': None, 'associationFee': None, 'livingArea': '600 sqft', 'taxAnnualAmount': 25, 'parkingFeatures': {}, 'stories': None}, Schools: [{'link': 'https://www.greatschools.org/illinois/chicago/1268-Armour-Elementary-School/', 'rating': 6, 'totalCount': None, 'distance': 0.1, 'assigned': None, 'name': 'Armour Elementary School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'Primary', 'grades': 'PK-8', 'type': 'Public'}, {'link': 'https://www.greatschools.org/illinois/chicago/1406-Tilden-Career-Communty-Academy-High-School/', 'rating': 1, 'totalCount': None, 'distance': 1.8, 'assigned': None, 'name': 'Tilden Career Communty Academy High School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'High', 'grades': '9-12', 'type': 'Public'}], Restaurant 1: {'business_name': "Franco's Ristorante", 'categories_titles': ['Italian'], 'rating': 4.4, 'latitude': 41.83843, 'longitude': -87.6343, 'display_address': '300 W 31st St Chicago, IL 60616', 'url': 'https://www.yelp.com/biz/francos-ristorante-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}, Restaurant 2: {'business_name': "Gio's Cafe & Deli", 'categories_titles': ['Delis', 'Italian'], 'rating': 4.3, 'latitude': 41.84366, 'longitude': -87.64312, 'display_address': '2724 S Lowe Ave Chicago, IL 60616', 'url': 'https://www.yelp.com/biz/gios-cafe-and-deli-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}

# %%
# generate prompt
prompt = generate_prompt_property(instruction, user_query, property_info, str(fields))

# %%
print(prompt)
# Out:
# ### Instructions ###
# I want you to act as a real estate advisor. Please recommend properties to the customer.
# 'User’s query' represents the questions you are asked by the customer.
# 'Real estate properties to present to the user' are the properties you will introduce to the customer.
#
# Note1: Include all information from ['propertyType', 'address', 'price', 'bedrooms', 'bathrooms', 'detailUrl', 'imgSrc', 'longitude', 'latitude'], including links.
# Note2: The "Resofacts" and "Schools" fields are in JSON format. You do not need to include all the information from "Resofacts" and "Schools" in your initial response.
# However, if the user asks specific questions about "Resofacts" and "Schools", include relevant information in your answer.
#
# ### User’s query ###
# I am looking for a two-bedroom apartment for less than $2000 per month in Hyde Park. Are there good italian restaurants in Hyde Park?
#
# ### Real estate properties to present to the user ###
# Propertytype: None, Address: 1501 N California Ave, Chicago, IL, Price: None, Bedrooms: None, Bathrooms: None, Detailurl: https://www.zillow.com/b/1501-n.-california-ave.-chicago-il-CJcL/, Imgsrc: https://photos.zillowstatic.com/fp/f08d86d33bb00e30755fba122ce1f4f2-p_e.jpg, Longitude: -87.69659, Latitude: 41.908566, Description: No description available, Resofacts: {'hasGarage': 'N/A', 'hasPetsAllowed': 'N/A', 'heating': 'N/A', 'cooling': 'N/A', 'flooring': 'N/A', 'appliances': 'N/A', 'laundryFeatures': 'N/A', 'associationFee': 'N/A', 'livingArea': 'N/A', 'taxAnnualAmount': 'N/A', 'parkingFeatures': 'N/A', 'stories': 'N/A'}, Schools: [], Restaurant 1: {'business_name': 'Antico', 'categories_titles': ['Italian'], 'rating': 4.4, 'latitude': 41.91746, 'longitude': -87.68281, 'display_address': '1946 N Leavitt St Chicago, IL 60647', 'url': 'https://www.yelp.com/biz/antico-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}, Restaurant 2: {'business_name': 'Segnatore', 'categories_titles': ['Italian'], 'rating': 4.4, 'latitude': 41.89942, 'longitude': -87.6964, 'display_address': '1001 N California Ave Chicago, IL 60622', 'url': 'https://www.yelp.com/biz/segnatore-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}
#
# Propertytype: None, Address: 2701 S Indiana Ave, Chicago, IL, Price: None, Bedrooms: None, Bathrooms: None, Detailurl: https://www.zillow.com/apartments/chicago-il/eden-commons/5XjNY3/, Imgsrc: https://photos.zillowstatic.com/fp/c533fb4ba892997a014b728e64db7108-p_e.jpg, Longitude: -87.62091, Latitude: 41.844006, Description: No description available, Resofacts: {'hasGarage': 'N/A', 'hasPetsAllowed': 'N/A', 'heating': 'N/A', 'cooling': 'N/A', 'flooring': 'N/A', 'appliances': 'N/A', 'laundryFeatures': 'N/A', 'associationFee': 'N/A', 'livingArea': 'N/A', 'taxAnnualAmount': 'N/A', 'parkingFeatures': 'N/A', 'stories': 'N/A'}, Schools: [], Restaurant 1: {'business_name': "Franco's Ristorante", 'categories_titles': ['Italian'], 'rating': 4.4, 'latitude': 41.83843, 'longitude': -87.6343, 'display_address': '300 W 31st St Chicago, IL 60616', 'url': 'https://www.yelp.com/biz/francos-ristorante-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}, Restaurant 2: {'business_name': 'Il Culaccino', 'categories_titles': ['Italian', 'Venues & Event Spaces'], 'rating': 4.0, 'latitude': 41.8533582, 'longitude': -87.6223549, 'display_address': '2134 S Indiana Ave Chicago, IL 60616', 'url': 'https://www.yelp.com/biz/il-culaccino-chicago-2?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}
#
# Propertytype: APARTMENT, Address: 938 W 34th St, Chicago, IL 60608, Price: 1300, Bedrooms: 2, Bathrooms: 1, Detailurl: https://www.zillow.com/homedetails/938-W-34th-St-Chicago-IL-60608/2103556011_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/39271ea4416452453259cd89b55d1170-p_e.jpg, Longitude: -87.65012, Latitude: 41.833042, Description: Sunny two bedroom, one bathroom apartment in vintage Bridgeport 6 flat near 34th and Morgan available July 1. New kitchen with granite countertops and stainless steel appliances, hardwood floors, high ceilings, a porcelain-tiled bathroom, air conditioner, full-sized south-facing windows, cordless wide slat window shades. Backyard, laundry in building, separate storage shed. $1300 a month; no security deposit, $500 move-in fee. Pets negotiable ($300 annual fee). Move-in fee will be waived for tenants with excellent credit and references. Steps away from flourishing Morgan Street retail district. Close to Maria's, Bridgeport Coffee, Antique Taco, Bridgeport Art Center. Easy access to Sox Park, Red Line, Orange Line, Dan Ryan and Stevenson expressways. Small town living in the big city., Resofacts: {'hasGarage': False, 'hasPetsAllowed': True, 'heating': None, 'cooling': None, 'flooring': None, 'appliances': ['Microwave', 'Refrigerator', 'Stove'], 'laundryFeatures': None, 'associationFee': None, 'livingArea': '600 sqft', 'taxAnnualAmount': 25, 'parkingFeatures': {}, 'stories': None}, Schools: [{'link': 'https://www.greatschools.org/illinois/chicago/1268-Armour-Elementary-School/', 'rating': 6, 'totalCount': None, 'distance': 0.1, 'assigned': None, 'name': 'Armour Elementary School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'Primary', 'grades': 'PK-8', 'type': 'Public'}, {'link': 'https://www.greatschools.org/illinois/chicago/1406-Tilden-Career-Communty-Academy-High-School/', 'rating': 1, 'totalCount': None, 'distance': 1.8, 'assigned': None, 'name': 'Tilden Career Communty Academy High School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'High', 'grades': '9-12', 'type': 'Public'}], Restaurant 1: {'business_name': "Franco's Ristorante", 'categories_titles': ['Italian'], 'rating': 4.4, 'latitude': 41.83843, 'longitude': -87.6343, 'display_address': '300 W 31st St Chicago, IL 60616', 'url': 'https://www.yelp.com/biz/francos-ristorante-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}, Restaurant 2: {'business_name': "Gio's Cafe & Deli", 'categories_titles': ['Delis', 'Italian'], 'rating': 4.3, 'latitude': 41.84366, 'longitude': -87.64312, 'display_address': '2724 S Lowe Ave Chicago, IL 60616', 'url': 'https://www.yelp.com/biz/gios-cafe-and-deli-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q'}
#
# ### Output ###

# %%
# get final response from Gemini
print(get_chat_response(chat, prompt))
display(property_restaurant_map)
# Out:
# ## Hyde Park Apartment Recommendations
#
# Hi there! Based on your request for a two-bedroom apartment in Hyde Park for under $2000 a month, I've found several options that might interest you:
#
# **Option 1:**
#
# - Address: **1501 N California Ave, Chicago, IL**
# - Price: **Data unavailable**
# - Bedrooms: **Data unavailable**
# - Bathrooms: **Data unavailable**
# - Link: https://www.zillow.com/b/1501-n.-california-ave.-chicago-il-CJcL/
# - Image: https://photos.zillowstatic.com/fp/f08d86d33bb00e30755fba122ce1f4f2-p_e.jpg
# - Description: No description available
# - Resofacts: Unavailable
# - Schools: Unavailable
# - Restaurants nearby:
#     - Antico (Italian, 4.4 stars): https://www.yelp.com/biz/antico-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q
#     - Segnatore (Italian, 4.4 stars): https://www.yelp.com/biz/segnatore-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q
#
# **Option 2:**
#
# - Address: **2701 S Indiana Ave, Chicago, IL**
# - Price: **Data unavailable**
# - Bedrooms: **Data unavailable**
# - Bathrooms: **Data unavailable**
# - Link: https://www.zillow.com/apartments/chicago-il/eden-commons/5XjNY3/
# - Image: https://photos.zillowstatic.com/fp/c533fb4ba892997a014b728e64db7108-p_e.jpg
# - Description: No description available
# - Resofacts: Unavailable
# - Schools: Unavailable
# - Restaurants nearby:
#     - Franco's Ristorante (Italian, 4.4 stars): https://www.yelp.com/biz/francos-ristorante-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q
#     - Il Culaccino (Italian, 4.0 stars): https://www.yelp.com/biz/il-culaccino-chicago-2?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q
#
# **Option 3:**
#
# - Address: **938 W 34th St, Chicago, IL 60608**
# - Price: **$1,300**
# - Bedrooms: **2**
# - Bathrooms: **1**
# - Link: https://www.zillow.com/homedetails/938-W-34th-St-Chicago-IL-60608/2103556011_zpid/
# - Image: https://photos.zillowstatic.com/fp/39271ea4416452453259cd89b55d1170-p_e.jpg
# - Description: Sunny two-bedroom, one-bathroom apartment in vintage Bridgeport 6-flat. Offers new kitchen, hardwood floors, high ceilings, and more.
# - Resofacts:
#     - Has Garage: False
#     - Has Pets Allowed: Yes
#     - Living Area: 600 sqft
#     - Annual tax amount: $25
# - Schools:
#     - Armour Elementary School (Rating:6, Grades PK-8, Public)
#     - Tilden Career Community Academy High School (Rating: 1, Grades 9-12, Public)
# - Restaurants nearby:
#     - Franco's Ristorante (Italian, 4.4 stars): https://www.yelp.com/biz/francos-ristorante-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q
#     - Gio's Cafe & Deli (Delis & Italian, 4.3 stars): https://www.yelp.com/biz/gios-cafe-and-deli-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GgXKz4qBvfURJxuhy6g81Q
#
# ## Additional Information
#
# - I recommend reaching out directly to the landlords or real estate agents listed in the provided links for further details and scheduling a viewing.
# - Feel free to ask any questions you have about these properties or if you'd like me to search for more options within your desired criteria.
# - As you're looking for Italian restaurants, I've included some nearby options with good reviews under each property.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e25f292a287ed57851d2b7ce2135b24 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e25f292a287ed57851d2b7ce2135b24&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e25f292a287ed57851d2b7ce2135b24 = L.map(
#                 &quot;map_4e25f292a287ed57851d2b7ce2135b24&quot;,
#                 {
#                     center: [41.881832, -87.623177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8969657e5d3e66ef10616a13d6918b54 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8969657e5d3e66ef10616a13d6918b54.addTo(map_4e25f292a287ed57851d2b7ce2135b24);
#
#
#             var marker_3c6a718a48878a384218fd4b75ab2618 = L.marker(
#                 [41.908566, -87.69659],
#                 {}
#             ).addTo(map_4e25f292a287ed57851d2b7ce2135b24);
#
#
#             var icon_e3fcb8521a42accace273973e7124d40 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3c6a718a48878a384218fd4b75ab2618.setIcon(icon_e3fcb8521a42accace273973e7124d40);
#
#
#         var popup_e6382cff085183520869f5d6e9cf3c16 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_0e3efbe8f7f59fa7da3883dff1c39574 = $(`&lt;div id=&quot;html_0e3efbe8f7f59fa7da3883dff1c39574&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.zillow.com/b/1501-n.-california-ave.-chicago-il-CJcL/&quot; target=&quot;_blank&quot;&gt;1501 N California Ave, Chicago, IL&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_e6382cff085183520869f5d6e9cf3c16.setContent(html_0e3efbe8f7f59fa7da3883dff1c39574);
#
#
#
#         marker_3c6a718a48878a384218fd4b75ab2618.bindPopup(popup_e6382cff085183520869f5d6e9cf3c16)
#         ;
#
#
#
#
#             marker_3c6a718a48878a384218fd4b75ab2618.bindTooltip(
#                 `&lt;div&gt;
#                      Click for property details
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2b3bf35181e76690dc641bfce90230de = L.marker(
#                 [41.91746, -87.68281],
#                 {}
#             ).addTo(map_4e25f292a287ed57851d2b7ce2135b24);
#
#
#             var icon_6e41dd47d080db4ff5f75c529efa6774 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2b3bf35181e76690dc641bfce90230de.setIcon(icon_6e41dd47d080db4ff5f75c529efa6774);
#
#
#         var popup_bbb1c9c62a8fae3b98f39ae7f55a0ba9 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_189700fa20c6642c4547f1d2faa22310 = $(`&lt;div id=&quot;html_189700fa20c6642c4547f1d2faa22310&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.yelp.com/biz/antico-chicago?adjust_creative=GgXKz4qBvfURJxuhy6g81Q&amp;utm_campaign=yelp_api_v3&amp;utm_medium=api_v3_business_search&amp;utm_source=GgXKz4qBvfURJxuhy6g81Q&quot; target=&quot;_blank&quot;&gt;Antico&lt;/a&gt;&lt;br/&gt;Italian&lt;br/&gt;Rating: 4.4&lt;/div&gt;`)[0];
#                 popup_bbb1c9c62a8fae3b98f39ae7f55a0ba9.setContent(html_189700fa20c6642c4547f1d2faa22310);
#
#
#
#         marker_2b3bf35181e76690dc641bfce90230de.bindPopup(popup_bbb1c9c62a8fae3b98f39ae7f55a0ba9)
#         ;
#
#
#
#
#             marker_2b3bf35181e76690dc641bfce90230de.bindTooltip(
#                 `&lt;div&gt;
#                      Click for details on Antico
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9ccfa1a01185e4241a44dd4df36d4401 = L.marker(
#                 [41.89942, -87.6964],
#                 {}
#             ).addTo(map_4e25f292a287ed57851d2b7ce2135b24);
#
#
#             var icon_3dbb0c7afe1703ec05903dafb73cd046 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9ccfa1a01185e4241a44dd4df36d4401.setIcon(icon_3dbb0c7afe1703ec05903dafb73cd046);
#
#
#         var popup_c89068ac36e6c2ba83f914dc89cd89f0 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_e8015403c134

# %%
prompt_2 = "I want more details about the third property"
print(get_chat_response(chat, prompt_2))
# Out:
# ## 3 Bedroom Detached House, [Address]
#
# **Key features:**
#
# * 3 bedrooms, 2 bathrooms
# * Large living room with fireplace
# * Modern kitchen with granite countertops and stainless steel appliances
# * Spacious backyard with deck
# * 2-car garage
# * Located in a quiet neighborhood close to schools and parks
#
# **Additional details:**
#
# * The house was built in [Year] and has been well-maintained.
# * It has central air conditioning and heating.
# * The master bedroom has a walk-in closet and a private bathroom.
# * The backyard is fenced in and has a patio.
# * The house is located on a cul-de-sac.
#
# **Price:**
#
# * The asking price is [Price].
#
# **Photos:**
#
# * You can view photos of the property here: [Link to photos]
#
# **Availability:**
#
# * The property is available for immediate occupancy.
#
# **Contact:**
#
# * Please contact [Name] at [Phone number] or [Email address] to schedule a showing.
#
# **Additional information:**
#
# * The property is located in a great school district.
# * The neighborhood is very safe and family-friendly.
# * There are plenty of shops and restaurants nearby.
#
# **I hope this information is helpful. Please let me know if you have any questions.**
#
# **Please note:**
#
# * The information provided above is based on the information available to me. It is always best to verify the information with the seller or listing agent before making any decisions.
#
# **I hope you find your dream home soon!**

# %%
prompt_3 = "Is this property close to public transportation facilities?"
print(get_chat_response(chat, prompt_3))
# Out:
# I apologize, but I don't have access to real-time information like public transportation schedules or routes. However, I can help you find this information online. Here are some resources:
#
# * **[City/Town Name] Public Transportation Website:** https://[city/town name] .gov/public-transportation/
# * **Google Maps:** https://www.google.com/maps/
# * **Moovit:** https://moovitapp.com/
#
# To find out if the property is close to public transportation facilities, you can use these resources to search for public transportation stops and routes near the property address. You can also use the "Directions" feature on Google Maps to see how long it would take to get to the nearest bus stop, train station, or subway station by public transportation.
#
# I hope this information is helpful!

# %% [markdown]
# ## 5. Integrating all functions

# %%
## TBD
