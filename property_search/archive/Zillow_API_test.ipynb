# %%
import requests

url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

headers = {
	"X-RapidAPI-Key": "",
	"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

# %% [markdown]
# ## Example 1

# %%
querystring = {"location":"chicago, il","home_type":"Houses","bathsMin":"2","bedsMin":"3"}

response = requests.get(url, headers = headers, params = querystring)

# %%
response.json()
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5124.9647,
#    'address': '1900 W Fletcher St, Chicago, IL 60657',
#    'variableData': {'text': 'Showcase', 'type': 'SHOWCASE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/32461d5d87e73bf953888534d6343b52-p_e.jpg',
#    'price': 2000000,
#    'detailUrl': '/homedetails/1900-W-Fletcher-St-Chicago-IL-60657/3731095_zpid/',
#    'bedrooms': 6,
#    'contingentListingType': None,
#    'longitude': -87.67616,
#    'latitude': 41.938942,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3731095',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 11,
#    'bathrooms': 6,
#    'livingArea': 5000,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3746.16,
#    'address': '4132 W West End Ave, Chicago, IL 60624',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ca6a9fd1afbc3ec3187fad985fc451a4-p_e.jpg',
#    'price': 229900,
#    'detailUrl': '/homedetails/4132-W-West-End-Ave-Chicago-IL-60624/2094928361_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.729576,
#    'latitude': 41.88374,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2094928361',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1350,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3402,
#    'address': '901 N Kedvale Ave, Chicago, IL 60651',
#    'variableData': {'text': 'Open: Sat. 11am-1pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/c83bdb950a432807ab20d636c99dec1c-p_e.jpg',
#    'price': 389000,
#    'detailUrl': '/homedetails/901-N-Kedvale-Ave-Chicago-IL-60651/2062999923_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.729485,
#    'latitude': 41.897278,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2062999923',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 4,
#    'livingArea': 2850,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 466.092,
#    'address': '8538 S May St, Chicago, IL 60620',
#    'variableData': {'text': '3D Tour', 'type': '3D_HOME'},
#    'priceChange': None,
#    'zestimate': 307300,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/659e044eee77e09f407083dfceda0453-p_e.jpg',
#    'price': 309000,
#    'detailUrl': '/homedetails/8538-S-May-St-Chicago-IL-60620/4016279_zpid/',
#    'bedrooms': 6,
#    'contingentListingType': None,
#    'longitude': -87.65254,
#    'latitude': 41.73842,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4016279',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2299,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 2451,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5227.2,
#    'address': '8259 S Bishop St, Chicago, IL 60620',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 145700,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/cfff97fe7e2d2cba54b9ad7221178c0a-p_e.jpg',
#    'price': 144900,
#    'detailUrl': '/homedetails/8259-S-Bishop-St-Chicago-IL-60620/4014864_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.659256,
#    'latitude': 41.743286,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4014864',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2650,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 1858,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4200,
#    'address': '3345 N Oleander Ave, Chicago, IL 60634',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4d896399bd26929f915031f17e784ba3-p_e.jpg',
#    'price': 269900,
#    'detailUrl': '/homedetails/3345-N-Oleander-Ave-Chicago-IL-60634/3599851_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.815155,
#    'latitude': 41.94097,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3599851',
#    'listingSubType': {'is_bankOwned': True},
#    'rentZestimate': None,
#    'daysOnZillow': '4',
#    'bathrooms': 2,
#    'livingArea': 1344,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4092,
#    'address': '6731 N Odell Ave, Chicago, IL 60631',
#    'variableData': None,
#    'priceChange': -15001,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4c091b3d5321ccee99b7ec7d9ba37ec4-p_e.jpg',
#    'price': 599999,
#    'detailUrl': '/homedetails/6731-N-Odell-Ave-Chicago-IL-60631/3512365_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.810036,
#    'latitude': 42.003494,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3512365',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 2567,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3125,
#    'address': '7744 S Constance Ave, Chicago, IL 60649',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f2ea4a24052ece505c118426d08c56d1-p_e.jpg',
#    'price': 214900,
#    'detailUrl': '/homedetails/7744-S-Constance-Ave-Chicago-IL-60649/4002698_zpid/',
#    'bedrooms': 6,
#    'contingentListingType': None,
#    'longitude': -87.580055,
#    'latitude': 41.753876,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4002698',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 2744,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3810,
#    'address': '955 N Keeler Ave, Chicago, IL 60651',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 225900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3d14846afd38c43c0a1d70a9075fef59-p_e.jpg',
#    'price': 220000,
#    'detailUrl': '/homedetails/955-N-Keeler-Ave-Chicago-IL-60651/3795587_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.730736,
#    'latitude': 41.898743,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3795587',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2522,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1400,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3109,
#    'address': '1512 S Ridgeway Ave, Chicago, IL 60623',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 162900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d70b9a2b96443ca1dc2e6c5301de3c89-p_e.jpg',
#    'price': 159900,
#    'detailUrl': '/homedetails/1512-S-Ridgeway-Ave-Chicago-IL-60623/80847831_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.71925,
#    'latitude': 41.860294,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '80847831',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2321,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1436,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3750,
#    'address': '7719 S Damen Ave, Chicago, IL 60620',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d3112278184142e3d49c365b5d0f75c5-p_e.jpg',
#    'price': 225000,
#    'detailUrl': '/homedetails/7719-S-Damen-Ave-Chicago-IL-60620/4011922_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.672874,
#    'latitude': 41.753258,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4011922',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': '1',
#    'bathrooms': 2,
#    'livingArea': 1382,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3125,
#    'address': '8208 S Kenwood Ave, Chicago, IL 60619',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/cdf5ee0386aa6d242f84f7d5715ba4b7-p_e.jpg',
#    'price': 269999,
#    'detailUrl': '/homedetails/8208-S-Kenwood-Ave-Chicago-IL-60619/4021123_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.59205,
#    'latitude': 41.74561,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4021123',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 2125,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8383.4,
#    'address': '2156 W Wellington Ave, Chicago, IL 60618',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/49a47146bd4805bd3e6450b317434615-p_e.jpg',
#    'price': 1500000,
#    'detailUrl': '/homedetails/2156-W-Wellington-Ave-Chicago-IL-60618/2094007768_zpid/',
#    'bedrooms': 11,
#    'contingentListingType': None,
#    'longitude': -87.68288,
#    'latitude': 41.936127,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2094007768',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 4,
#    'livingArea': 3700,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 750,
#    'address': '5139 S Whipple St, Chicago, IL 60632',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ae3b62017ae601a3e0208403d7518a1c-p_e.jpg',
#    'price': 160000,
#    'detailUrl': '/homedetails/5139-S-Whipple-St-Chicago-IL-60632/3929518_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.699715,
#    'latitude': 41.79971,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3929518',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 3750,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3125,
#    'address': '1807 E 93rd St, Chicago, IL 60617',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a187cbe1b5e1793f480e4032c17c4fed-p_e.jpg',
#    'price': 259000,
#    'detailUrl': '/homedetails/1807-E-93rd-St-Chicago-IL-60617/4112744_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.57996,
#    'latitude': 41.72577,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4112744',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 0,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 2918.52,
#    'address': '8336 S Kerfoot Ave, Chicago, IL 60620',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/9fba0b30f1a24b79356f3da71a3a3f2a-p_e.jpg',
#    'price': 145000,
#    'detailUrl': '/homedetails/8336-S-Kerfoot-Ave-Chicago-IL-60620/4017561_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.64153,
#    'latitude': 41.74225,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4017561',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2281,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1154,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3125,
#    'address': '12319 S Union Ave, Chicago, IL 60628',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 271000,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/af97d726cbf9617b80d3d3b79b171705-p_e.jpg',
#    'price': 269900,
#    'detailUrl': '/homedetails/12319-S-Union-Ave-Chicago-IL-60628/4157668_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.63889,
#    'latitude': 41.669964,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4157668',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2500,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1233,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3100,
#    'address': '4316 S Paulina St, Chicago, IL 60609',
#    'variableData': {'text': '3D Tour', 'type': '3D_HOME'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7001bc980f8685f3eb8b86c4e30d1a67-p_e.jpg',
#    'price': 289000,
#    'detailUrl': '/homedetails/4316-S-Paulina-St-Chicago-IL-60609/65548444_zpid/',
#    'bedrooms': 6,
#    'contingentListingType': None,
#    'longitude': -87.66793,
#    'latitude': 41.815296,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '65548444',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 1928,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.5963,
#    'address': '1932 N Burling St, Chicago, IL 60614',
#    'variableData': None,
#    'priceChange': -4400000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/426683fcfae320d0d0a6099b1f504170-p_e.jpg',
#    'price': 23500000,
#    'detailUrl': '/homedetails/1932-N-Burling-St-Chicago-IL-60614/2096089558_zpid/',
#    'bedrooms': 6,
#    'contingentListingType': None,
#    'longitude': -87.64759,
#    'latitude': 41.91708,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2096089558',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': '445',
#    'bathrooms': 11,
#    'livingArea': 25000,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3824.568,
#    'address': '4959 W Hirsch St, Chicago, IL 60651',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 346800,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/55e06282469fde74feb8ec675143819d-p_e.jpg',
#    'price': 340000,
#    'detailUrl': '/homedetails/4959-W-Hirsch-St-Chicago-IL-60651/3796422_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.75077,
#    'latitude': 41.905674,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3796422',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2685,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1980,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3125,
#    'address': '2222 S Trumbull Ave, Chicago, IL 60623',
#    'variableData': {'text': 'Open: Sat. 12-3pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/49d507c394baab64011cee416bd67526-p_e.jpg',
#    'price': 349000,
#    'detailUrl': '/homedetails/2222-S-Trumbull-Ave-Chicago-IL-60623/2062847557_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.71168,
#    'latitude': 41.850983,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2062847557',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1571,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5000,
#    'address': '3720 W Giddings St, Chicago, IL 60625',
#    'variableData': None,
#    'priceChange': 70000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b7b8fbeb7cf26773bb99b5eddf8cf86d-p_e.jpg',
#    'price': 499000,
#    'detailUrl': '/homedetails/3720-W-Giddings-St-Chicago-IL-60625/3644364_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.72154,
#    'latitude': 41.96767,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3644364',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': '3',
#    'bathrooms': 2,
#    'livingArea': 2700,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3000,
#    'address': '5843 W Augusta Blvd, Chicago, IL 60651',
#    'variableData': {'text': 'Open: Sat. 12-2pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b86f6ab22cd7363c39d67159d62cb0bd-p_e.jpg',
#    'price': 349900,
#    'detailUrl': '/homedetails/5843-W-Augusta-Blvd-Chicago-IL-60651/3800299_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.77209,
#    'latitude': 41.898132,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3800299',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 1558,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.2697,
#    'address': '901 W 129th Pl, Chicago, IL 60643',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f6bc1d8a1f3971d4c07273068c2f4ef2-p_e.jpg',
#    'price': 649000,
#    'detailUrl': '/homedetails/901-W-129th-Pl-Chicago-IL-60643/4164104_zpid/',
#    'bedrooms': 7,
#    'contingentListingType': None,
#    'longitude': -87.64377,
#    'latitude': 41.658066,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4164104',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': '10',
#    'bathrooms': 5,
#    'livingArea': 6000,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7200,
#    'address': '4329 S Wood St, Chicago, IL 60609',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 202400,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f1e5952829349e70d03258513de5e681-p_e.jpg',
#    'price': 199999,
#    'detailUrl': '/homedetails/4329-S-Wood-St-Chicago-IL-60609/3981550_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.66964,
#    'latitude': 41.814922,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3981550',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3343,
#    'daysOnZillow': '34',
#    'bathrooms': 3,
#    'livingArea': 2500,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3049.2,
#    'address': '3936 W 47th St, Chicago, IL 60632',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/c33ce989bcf54d368a7c0588cf11d891-p_e.jpg',
#    'price': 310000,
#    'detailUrl': '/homedetails/3936-W-47th-St-Chicago-IL-60632/3914889_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.722626,
#    'latitude': 41.808147,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3914889',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 2189,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3125,
#    'address': '9407 S Rhodes Ave, Chicago, IL 60619',
#    'variableData': {'text': 'Open: Sun. 1-3pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/22757e1928398c9b312ad8982cd00e9c-p_e.jpg',
#    'price': 299900,
#    'detailUrl': '/homedetails/9407-S-Rhodes-Ave-Chicago-IL-60619/4118030_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.61021,
#    'latitude': 41.72351,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4118030',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1102,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3750,
#    'address': '7814 S Jeffery Blvd, Chicago, IL 60649',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/900347b2a995a08a62ae20d6ea7f8f8c-p_e.jpg',
#    'price': 385000,
#    'detailUrl': '/homedetails/7814-S-Jeffery-Blvd-Chicago-IL-60649/4002783_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.57636,
#    'latitude': 41.752956,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4002783',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 2520,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3746.16,
#    'address': '4417 N Major Ave, Chicago, IL 60630',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 366600,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a14ce616a3797bb475497ee2aff0d761-p_e.jpg',
#    'price': 359000,
#    'detailUrl': '/homedetails/4417-N-Major-Ave-Chicago-IL-60630/3651957_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.76934,
#    'latitude': 41.96106,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3651957',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2500,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1196,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3123.252,
#    'address': '5214 S Maplewood Ave, Chicago, IL 60632',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/c0c838d15060077501bc7454a23fab26-p_e.jpg',
#    'price': 300000,
#    'detailUrl': '/homedetails/5214-S-Maplewood-Ave-Chicago-IL-60632/3930453_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.68818,
#    'latitude': 41.798733,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3930453',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1000,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 10293.228,
#    'address': '2711 W Logan Blvd, Chicago, IL 60647',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/dc2abce4d4fa8a86d76e647dd6dad7b7-p_e.jpg',
#    'price': 3995000,
#    'detailUrl': '/homedetails/2711-W-Logan-Blvd-Chicago-IL-60647/337756346_zpid/',
#    'bedrooms': 6,
#    'contingentListingType': None,
#    'longitude': -87.6955,
#    'latitude': 41.927902,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '337756346',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 5,
#    'livingArea': 0,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3136.32,
#    'address': '6208 S Normandy Ave, Chicago, IL 60638',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/86b041c61b764fd745c5e12d6259603a-p_e.jpg',
#    'price': 380000,
#    'detailUrl': '/homedetails/6208-S-Normandy-Ave-Chicago-IL-60638/3946440_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.788994,
#    'latitude': 41.77903,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3946440',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 1168,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 2308.68,
#    'address': '3146 S Calumet Ave, Chicago, IL 60616',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 695000,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/af9409dd55b84d468521d58b4564de7f-p_e.jpg',
#    'price': 689000,
#    'detailUrl': '/homedetails/3146-S-Calumet-Ave-Chicago-IL-60616/3882272_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.6179,
#    'latitude': 41.837017,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3882272',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 4993,
#    'daysOnZillow': 0,
#    'bathrooms': 4,
#    'livingArea': 2500,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4192.2,
#    'address': '5628 W Grace St, Chicago, IL 60634',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/9b6668d04cb5d250a3544f17b13a1ba8-p_e.jpg',
#    'price': 415000,
#    'detailUrl': '/homedetails/5628-W-Grace-St-Chicago-IL-60634/3659942_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.76805,
#    'latitude': 41.949776,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3659942',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1650,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 10175,
#    'address': '6342 N Natoma Ave, Chicago, IL 60631',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/96e8b63110e9df5ee8e33995ef3434dc-p_e.jpg',
#    'price': 475000,
#    'detailUrl': '/homedetails/6342-N-Natoma-Ave-Chicago-IL-60631/3627769_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.79268,
#    'latitude': 41.996758,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3627769',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 3200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3497.868,
#    'address': '3229 S Carpenter St, Chicago, IL 60608',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 430900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/51f6d7073a0c5e3ec8399841f747e8ea-p_e.jpg',
#    'price': 430000,
#    'detailUrl': '/homedetails/3229-S-Carpenter-St-Chicago-IL-60608/3881006_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.65196,
#    'latitude': 41.83509,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3881006',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2664,
#    'daysOnZillow': '3',
#    'bathrooms': 2,
#    'livingArea': 2000,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.25,
#    'address': '3507 N Osceola Ave, Chicago, IL 60634',
#    'variableData': {'text': 'Open: Sat. 12-2pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/35942b6285425309da02cd066fc20a4b-p_e.jpg',
#    'price': 540000,
#    'detailUrl': '/homedetails/3507-N-Osceola-Ave-Chicago-IL-60634/3599466_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.81268,
#    'latitude': 41.943645,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3599466',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 2093,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 10148,
#    'address': '10203 S Oakley Ave, Chicago, IL 60643',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/419a997edfc27a17559d52e41a9f61e1-p_e.jpg',
#    'price': 559000,
#    'detailUrl': '/homedetails/10203-S-Oakley-Ave-Chicago-IL-60643/4126704_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.6796,
#    'latitude': 41.70805,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4126704',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 2877,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4423,
#    'address': '2800 W Greenleaf Ave, Chicago, IL 60645',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 430900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/9786d80c35712a31990640659c1d92fe-p_e.jpg',
#    'price': 425000,
#    'detailUrl': '/homedetails/2800-W-Greenleaf-Ave-Chicago-IL-60645/3560013_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.69992,
#    'latitude': 42.009624,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3560013',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2199,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1242,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4613.004,
#    'address': '(undisclosed Address), Chicago, IL 60628',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 158600,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1076dd91c16f52e2beba62e22fc6cf2c-p_e.jpg',
#    'price': 159000,
#    'detailUrl': '/homedetails/Chicago-IL-60628/4158119_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': None,
#    'latitude': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4158119',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2500,
#    'daysOnZillow': '3',
#    'bathrooms': 2,
#    'livingArea': 1300,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3123.252,
#    'address': '3307 S Leavitt St, Chicago, IL 60608',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/0b947949a4d92aaa6040c9ccafb0a3e3-p_e.jpg',
#    'price': 468800,
#    'detailUrl': '/homedetails/3307-S-Leavitt-St-Chicago-IL-60608/3879372_zpid/',
#    'bedrooms': 7,
#    'contingentListingType': None,
#    'longitude': -87.67992,
#    'latitude': 41.833656,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3879372',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1800,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True}],
#  'resultsPerPage': 41,
#  'totalPages': 20,
#  'totalResultCount': 1346,
#  'schools': {},
#  'currentPage': 1}

# %%
def extract_top_property_urls(response, n):
    """
    Extracts and prints the top 'n' property URLs from a given API response.
    
    Parameters:
    - response: The response object from an API call.
    - n: The number of top URLs to extract and print.
    
    The function assumes the response object is convertible to JSON and contains 
    a list of properties under the 'props' key. Each property should have a 'detailUrl' key.
    """
    try:
        # Convert the response to JSON format
        data = response.json()

        # Base URL of the website where the property details can be accessed
        base_url = "https://www.zillow.com"

        # Extract the top 'n' 'detailUrl' from the data
        top_urls = [base_url + prop['detailUrl'] for prop in data['props'][:n]]

        # Print the full URLs
        for url in top_urls:
            print(url)

    except Exception as e:
        print("An error occurred:", e)

# %%
extract_top_property_urls(response, 3)
# Out:
# https://www.zillow.com/homedetails/1900-W-Fletcher-St-Chicago-IL-60657/3731095_zpid/
# https://www.zillow.com/homedetails/4132-W-West-End-Ave-Chicago-IL-60624/2094928361_zpid/
# https://www.zillow.com/homedetails/901-N-Kedvale-Ave-Chicago-IL-60651/2062999923_zpid/

# %% [markdown]
# ## "location":"west loop chicago"

# %%
querystring = {"location":"west loop chicago","home_type":"Houses"}

response_2 = requests.get(url, headers = headers, params = querystring)

# %%
response_2.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/anaconda3/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /opt/anaconda3/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /opt/anaconda3/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 response_2.json()
#
# File /opt/anaconda3/lib/python3.9/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## "location":"60611"

# %%
querystring = {"location":"60611","home_type":"Houses"}

response_2 = requests.get(url, headers = headers, params = querystring)

# %%
response_2.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/anaconda3/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /opt/anaconda3/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /opt/anaconda3/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 response_2.json()
#
# File /opt/anaconda3/lib/python3.9/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## keyword='west loop'

# %%
querystring = {"location":"chicago, il","home_type":"Houses","bathsMin":"2","bedsMin":"3", "keywords":"west loop"}

response_3 = requests.get(url, headers = headers, params = querystring)

# %%
extract_top_property_urls(response_3, 3)
# Out:
# https://www.zillow.com/homedetails/1636-W-Huron-St-Chicago-IL-60622/101274317_zpid/
# https://www.zillow.com/homedetails/15-N-Ada-St-Chicago-IL-60607/2099871540_zpid/
# https://www.zillow.com/homedetails/844-W-15th-Pl-Chicago-IL-60608/65547946_zpid/

# %% [markdown]
# ## BuildYear

# %%
querystring = {"location":"chicago, il","home_type":"Houses","bathsMin":"2","bedsMin":"3", "keywords":"west loop", "buildYearMin":"2010", "buildYearMax":"2023"}
response_4 = requests.get(url, headers = headers, params = querystring)

# %%
extract_top_property_urls(response_4, 3)
# Out:
# https://www.zillow.com/homedetails/1755-W-Superior-St-Chicago-IL-60622/2058985055_zpid/
# https://www.zillow.com/homedetails/2510-W-Superior-St-Chicago-IL-60612/89933990_zpid/

# %% [markdown]
# ## "I am looking for a one-bedroom."

# %%
querystring = {"location":"chicago, il","bedsMin":"1","bedsMax":"1"}
response = requests.get(url, headers = headers, params = querystring)
extract_top_property_urls(response, 3)
# Out:
# https://www.zillow.com/homedetails/880-N-Lake-Shore-Dr-APT-22D-Chicago-IL-60611/2121434252_zpid/
# https://www.zillow.com/homedetails/3930-N-Pine-Grove-Ave-APT-512-Chicago-IL-60613/3712871_zpid/
# https://www.zillow.com/homedetails/780-S-Federal-St-APT-307-Chicago-IL-60605/87693604_zpid/

# %% [markdown]
# ## I am looking for a rental in South Loop, Chicago, with at least one bedroom and a rent of $3000 or less per month.

# %%
querystring = {
"location": "chicago, il",
"keywords": "south loop",
"status_type": "ForRent",
"rentMaxPrice": 3000,
"bedsMin": 1
}
response = requests.get(url, headers = headers, params = querystring)
extract_top_property_urls(response, 3)
# Out:
# https://www.zillow.com/apartments/chicago-il/180-north-jefferson/9PzG/
# https://www.zillow.com/apartments/chicago-il/lake-meadows/5XgYFh/
# https://www.zillow.com/homedetails/2933-35-N-Hamlin-Ave-2902-10-Chicago-IL-60618/2059092904_zpid/

# %% [markdown]
# ## I want to buy a house in West Loop with at least two bedrooms.

# %%
querystring = {"location":"chicago, il","keywords":"west loop","bedsMin":"2"}
response = requests.get(url, headers = headers, params = querystring)
extract_top_property_urls(response, 3)
# Out:
# https://www.zillow.com/homedetails/2238-W-Maypole-Ave-UNIT-102-Chicago-IL-60612/121074255_zpid/
# https://www.zillow.com/homedetails/2857-W-Congress-Pkwy-Chicago-IL-60612/158700116_zpid/
# https://www.zillow.com/homedetails/901-W-Madison-St-UNIT-407-Chicago-IL-60607/89906195_zpid/

# %% [markdown]
# ## I am looking for a rental around Wicker Park in Chicago with a gym and a pool. It should be built within the last 10 years.

# %%
querystring = {
"location": "chicago, il",
"home_type": "Apartments_Condos_Co-ops",
"status_type": "ForRent",
"buildYearMin": 2013,
"keywords": "Wicker Park, gym, pool"
}

response = requests.get(url, headers = headers, params = querystring)
extract_top_property_urls(response, 3)
# Out:
# https://www.zillow.com/apartments/chicago-il/one-six-six/9Rx6Tz/
# https://www.zillow.com/apartments/chicago-il/marquee-at-block-37/65g7KD/
# https://www.zillow.com/apartments/chicago-il/xavier/5q4SqT/
