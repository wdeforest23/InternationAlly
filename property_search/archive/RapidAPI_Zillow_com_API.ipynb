# %%
import requests

url = "https://zillow-com1.p.rapidapi.com/property"

querystring = {"zpid":"2080998890"}

headers = {
	"X-RapidAPI-Key": "...",
	"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.get(url, headers = headers, params = querystring)

print(response.json())
# Out:
# {'listingProvider': {'enhancedVideoURL': None, 'showNoContactInfoMessage': False, 'postingGroupName': None, 'isZRMSourceText': None, 'showLogos': None, 'logos': {}, 'sourceText': None, 'title': 'Listing Provided by', 'disclaimerText': None, 'postingWebsiteURL': None, 'agentLicenseNumber': None, 'postingWebsiteLinkText': 'See listing website', 'enhancedDescriptionText': None, 'agentName': None}, 'zpid': 2080998890, 'buildingPermits': None, 'propertyTaxRate': 0.77, 'contact_recipients': [{'agent_reason': 1, 'zpro': None, 'recent_sales': 0, 'review_count': 56, 'display_name': 'Jim Pullin', 'zuid': 'X1-ZU11t0lr5j8rqx5_34dhh', 'rating_average': 5, 'badge_type': 'Premier Agent', 'phone': {'prefix': '207', 'areacode': '206', 'number': '8763'}, 'image_url': 'https://photos.zillowstatic.com/h_n/ISfkgeu1boe63o1000000000.jpg'}], 'zipcode': '98109', 'openHouseSchedule': {}, 'longitude': -122.34212, 'zestimateLowPercent': '7', 'address': {'community': None, 'city': 'Seattle', 'state': 'WA', 'neighborhood': None, 'subdivision': None, 'streetAddress': '757 Hayes St', 'zipcode': '98109'}, 'cityId': 16037, 'timeOnZillow': '1165 days', 'url': '/homedetails/757-Hayes-St-Seattle-WA-98109/2080998890_zpid/', 'zestimate': 1514100, 'imgSrc': 'https://photos.zillowstatic.com/fp/306c91504435f821b222f2e5acb36d0d-p_d.jpg', 'description': "Last home left at the Westlake Collection! A boutique community where high-tech, dramatic design & luxury harmoniously meet. The double-height living room and high-end chef's kitchen featuring Thermador appliances are perfect forentertaining. Ascend the floating stairs along a sculptural wall that is sure to amaze. Enjoy the top floor penthouse foryear-round indoor and outdoor entertainment. Minutes to Facebook, Amazon, Google, DT Seattle, Fremont, Queen Anne,Westlake and SLU!", 'price': 1514100, 'livingAreaValue': 2236, 'resoFacts': {'hasAttachedProperty': False, 'frontageType': None, 'poolFeatures': None, 'flooring': ['Tile', 'Hardwood'], 'builderModel': None, 'accessibilityFeatures': None, 'hasGarage': False, 'hasPetsAllowed': None, 'bodyType': None, 'topography': None, 'landLeaseExpirationDate': None, 'hasAdditionalParcels': False, 'waterViewYN': None, 'livingQuarters': {}, 'atAGlanceFacts': [{'factValue': 'Townhouse', 'factLabel': 'Type'}, {'factValue': '2020', 'factLabel': 'Year Built'}, {'factValue': 'Heat pump', 'factLabel': 'Heating'}, {'factValue': None, 'factLabel': 'Cooling'}, {'factValue': '1 Parking space', 'factLabel': 'Parking'}, {'factValue': '$49 monthly', 'factLabel': 'HOA'}, {'factValue': '801 sqft', 'factLabel': 'Lot'}, {'factValue': None, 'factLabel': 'Offer Review Date'}], 'offerReviewDate': None, 'horseYN': None, 'view': ['City'], 'buyerAgencyCompensationType': None, 'rooms': [{'level': None, 'dimensions': None, 'features': None, 'roomAreaUnits': None, 'roomArea': None, 'roomAreaSource': None, 'roomType': 'WalkInCloset', 'roomDescription': None, 'roomWidth': None, 'roomLevel': None, 'description': None, 'roomLengthWidthUnits': None, 'roomLength': None, 'roomFeatures': None, 'roomDimensions': None, 'roomLengthWidthSource': None, 'area': None}, {'level': None, 'dimensions': None, 'features': None, 'roomAreaUnits': None, 'roomArea': None, 'roomAreaSource': None, 'roomType': 'DiningRoom', 'roomDescription': None, 'roomWidth': None, 'roomLevel': None, 'description': None, 'roomLengthWidthUnits': None, 'roomLength': None, 'roomFeatures': None, 'roomDimensions': None, 'roomLengthWidthSource': None, 'area': None}], 'belowGradeFinishedArea': None, 'feesAndDues': [{'phone': None, 'name': None, 'fee': '$49 monthly', 'type': 'HOA'}], 'cityRegion': 'Seattle', 'subAgencyCompensation': None, 'hasPrivatePool': None, 'associationFeeIncludes': None, 'waterSource': ['Public'], 'carportParkingCapacity': None, 'transactionBrokerCompensationType': None, 'hasFireplace': None, 'gas': None, 'sewer': ['Sewer Connected'], 'elevationUnits': None, 'roadSurfaceType': None, 'mainLevelBedrooms': None, 'numberOfUnitsVacant': Non ...

# %%
response.json()
# Out:
# {'listingProvider': {'enhancedVideoURL': None,
#   'showNoContactInfoMessage': False,
#   'postingGroupName': None,
#   'isZRMSourceText': None,
#   'showLogos': None,
#   'logos': {},
#   'sourceText': None,
#   'title': 'Listing Provided by',
#   'disclaimerText': None,
#   'postingWebsiteURL': None,
#   'agentLicenseNumber': None,
#   'postingWebsiteLinkText': 'See listing website',
#   'enhancedDescriptionText': None,
#   'agentName': None},
#  'zpid': 2080998890,
#  'buildingPermits': None,
#  'propertyTaxRate': 0.77,
#  'contact_recipients': [{'agent_reason': 1,
#    'zpro': None,
#    'recent_sales': 0,
#    'review_count': 56,
#    'display_name': 'Jim Pullin',
#    'zuid': 'X1-ZU11t0lr5j8rqx5_34dhh',
#    'rating_average': 5,
#    'badge_type': 'Premier Agent',
#    'phone': {'prefix': '207', 'areacode': '206', 'number': '8763'},
#    'image_url': 'https://photos.zillowstatic.com/h_n/ISfkgeu1boe63o1000000000.jpg'}],
#  'zipcode': '98109',
#  'openHouseSchedule': {},
#  'longitude': -122.34212,
#  'zestimateLowPercent': '7',
#  'address': {'community': None,
#   'city': 'Seattle',
#   'state': 'WA',
#   'neighborhood': None,
#   'subdivision': None,
#   'streetAddress': '757 Hayes St',
#   'zipcode': '98109'},
#  'cityId': 16037,
#  'timeOnZillow': '1165 days',
#  'url': '/homedetails/757-Hayes-St-Seattle-WA-98109/2080998890_zpid/',
#  'zestimate': 1514100,
#  'imgSrc': 'https://photos.zillowstatic.com/fp/306c91504435f821b222f2e5acb36d0d-p_d.jpg',
#  'description': "Last home left at the Westlake Collection! A boutique community where high-tech, dramatic design & luxury harmoniously meet. The double-height living room and high-end chef's kitchen featuring Thermador appliances are perfect forentertaining. Ascend the floating stairs along a sculptural wall that is sure to amaze. Enjoy the top floor penthouse foryear-round indoor and outdoor entertainment. Minutes to Facebook, Amazon, Google, DT Seattle, Fremont, Queen Anne,Westlake and SLU!",
#  'price': 1514100,
#  'livingAreaValue': 2236,
#  'resoFacts': {'hasAttachedProperty': False,
#   'frontageType': None,
#   'poolFeatures': None,
#   'flooring': ['Tile', 'Hardwood'],
#   'builderModel': None,
#   'accessibilityFeatures': None,
#   'hasGarage': False,
#   'hasPetsAllowed': None,
#   'bodyType': None,
#   'topography': None,
#   'landLeaseExpirationDate': None,
#   'hasAdditionalParcels': False,
#   'waterViewYN': None,
#   'livingQuarters': {},
#   'atAGlanceFacts': [{'factValue': 'Townhouse', 'factLabel': 'Type'},
#    {'factValue': '2020', 'factLabel': 'Year Built'},
#    {'factValue': 'Heat pump', 'factLabel': 'Heating'},
#    {'factValue': None, 'factLabel': 'Cooling'},
#    {'factValue': '1 Parking space', 'factLabel': 'Parking'},
#    {'factValue': '$49 monthly', 'factLabel': 'HOA'},
#    {'factValue': '801 sqft', 'factLabel': 'Lot'},
#    {'factValue': None, 'factLabel': 'Offer Review Date'}],
#   'offerReviewDate': None,
#   'horseYN': None,
#   'view': ['City'],
#   'buyerAgencyCompensationType': None,
#   'rooms': [{'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': None,
#     'roomArea': None,
#     'roomAreaSource': None,
#     'roomType': 'WalkInCloset',
#     'roomDescription': None,
#     'roomWidth': None,
#     'roomLevel': None,
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': None,
#     'roomFeatures': None,
#     'roomDimensions': None,
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': None,
#     'roomArea': None,
#     'roomAreaSource': None,
#     'roomType': 'DiningRoom',
#     'roomDescription': None,
#     'roomWidth': None,
#     'roomLevel': None,
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': None,
#     'roomFeatures': None,
#     'roomDimensions': None,
#     'roomLengthWidthSource': None,
#     'area': None}],
#   'belowGradeFinishedArea': None,
#   'feesAndDues': [{'phone': None,
#     'name': None,
#     'fee': '$49 monthly',
#     'type': 'HOA'}],
#   'cityRegion': 'Seattle',
#   'subAgencyCompensation': None,
#   'hasPrivatePool': None,
#   'associationFeeIncludes': None,
#   'waterSource': ['Public'],
#   'carportParkingCapacity': None,
#   'transactionBrokerCompensationType': None,
#   'hasFireplace': None,
#   'gas': None,
#   'sewer': ['Sewer Connected'],
#   'elevationUnits': None,
#   'roadSurfaceType': None,
#   'mainLevelBedrooms': None,
#   'numberOfUnitsVacant': None,
#   'hasWaterfrontView': None,
#   'bathroomsOneQuarter': 0,
#   'lotSize': '801 sqft',
#   'subAgencyCompensationType': None,
#   'entryLevel': None,
#   'irrigationWaterRightsAcres': None,
#   'greenWaterConservation': None,
#   'stories': None,
#   'bathrooms': 3,
#   'numberOfUnitsInCommunity': None,
#   'listingTerms': None,
#   'otherParking': None,
#   'associationFee': None,
#   'marketingType': None,
#   'greenEnergyEfficient': None,
#   'greenSustainability': None,
#   'heating': ['Heat pump'],
#   'associationPhone': None,
#   'greenBuildingVerificationType': None,
#   'hasAttachedGarage': None,
#   'bedrooms': 3,
#   'architecturalStyle': None,
#   'listingId': None,
#   'structureType': 'Modern',
#   'interiorFeatures': None,
#   'horseAmenities': None,
#   'electric': None,
#   'otherFacts': [{'value': 'Y', 'name': 'Bus line nearby'},
#    {'value': 'RESI', 'name': 'Property type'},
#    {'value': 'Natural Gas, Electric', 'name': 'Energy source'},
#    {'value': 'Cement/Concrete, Wood, Cement Planked', 'name': 'Exterior'},
#    {'value': '90%+ High Efficiency, Ductless HP-Mini Split, Hot Water Recirc Pump, Tankless Water Heater',
#     'name': 'Heating and cooling'},
#    {'value': 'Upper', 'name': 'Master bedroom location'},
#    {'value': 'Sewer Connected', 'name': 'Sewer'},
#    {'value': 'Public', 'name': 'Water source'},
#    {'value': 'Very Good', 'name': 'Building condition'},
#    {'value': 'Poured Concrete', 'name': 'Foundation'},
#    {'value': 'Closing', 'name': 'Possesion'},
#    {'value': 'CCRs', 'name': 'Community features'},
#    {'value': 'Garage-Attached', 'name': 'Parking type'},
#    {'value': 'Provided', 'name': 'Form 17'},
#    {'value': 'Main', 'name': 'Dining room location'},
#    {'value': 'Main', 'name': 'Entrance level'},
#    {'value': 'Main', 'name': 'Living room location'},
#    {'value': 'Range/Oven, Garbage Disposal, Dishwasher, Refrigerator, Microwave',
#     'name': 'Appliances that stay'},
#    {'value': 'Upper', 'name': 'Den or office'},
#    {'value': 'Main', 'name': 'Kitchen (w/ eating area) location'},
#    {'value': 'Paved Street, Sidewalk, Curbs', 'name': 'Lot details'},
#    {'value': 'Lake, Territorial, City', 'name': 'View'},
#    {'value': 'Modern', 'name': 'Architecture'},
#    {'value': 'Completed', 'name': 'New construction'},
#    {'value': 'Flat', 'name': 'Roof'},
#    {'value': 'Bath Off Master, Vaulted Ceilings, Dbl Pane/Storm Windw, Dining Room, 2nd Kitchen, Walk-in Closet, High Tech Cabling, Wet Bar, SMART Wired',
#     'name': 'Features'},
#    {'value': 'Hardwood, Ceramic Tile', 'name': 'Floor covering'},
#    {'value': 'Cash Out, Conventional', 'name': 'Potential terms'},
#    {'value': 'Cable TV, High Speed Internet, Sprinkler System, Electric Car Charging, Rooftop Deck',
#     'name': 'Site features'},
#    {'value': 'Reviewed on receipt', 'name': 'Offers'},
#    {'value': 'Attached/Zero Lot Line', 'name': 'Building info'},
#    {'value': '2.5', 'name': 'Commission'}],
#   'lotFeatures': None,
#   'roofType': None,
#   'compensationBasedOn': None,
#   'greenEnergyGeneration': None,
#   'taxAnnualAmount': 11659,
#   'daysOnZillow': 1165,
#   'listAOR': None,
#   'hasHeating': True,
#   'elementarySchool': 'John Hay Elementary',
#   'constructionMaterials': {},
#   'basementYN': None,
#   'hoaFeeTotal': '$49 monthly',
#   'appliances': ['Dishwasher',
#    'Garbage disposal',
#    'Microwave',
#    'Range / Oven',
#    'Refrigerator'],
#   'virtualTour': None,
#   'bathroomsPartial': None,
#   'fencing': None,
#   'yearBuiltEffective': None,
#   'foundationDetails': {},
#   'buildingName': None,
#   'hasAssociation': True,
#   'isSeniorCommunity': None,
#   'propertySubType': None,
#   'propertyCondition': None,
#   'hasCarport': None,
#   'canRaiseHorses': False,
#   'hasLandLease': False,
#   'communityFeatures': {},
#   'parcelNumber': None,
#   'elevation': None,
#   'lotSizeDimensions': None,
#   'buildingAreaSource': None,
#   'contingency': None,
#   'yearBuilt': 2020,
#   'otherStructures': None,
#   'livingArea': '2,236 sqft',
#   'bathroomsFull': 2,
#   'livingAreaRangeUnits': None,
#   'incomeIncludes': None,
#   'highSchool': None,
#   'aboveGradeFinishedArea': None,
#   'isNewConstruction': None,
#   'inclusions': None,
#   'hasHomeWarranty': False,
#   'additionalFeeInfo': None,
#   'windowFeatures': None,
#   'ownership': None,
#   'woodedArea': None,
#   'middleOrJuniorSchoolDistrict': 'Seattle',
#   'associationPhone2': None,
#   'exteriorFeatures': ['Wood', 'Cement / Concrete'],
#   'buildingFeatures': None,
#   'frontageLength': None,
#   'buildingArea': None,
#   'associationAmenities': None,
#   'bathroomsHalf': 0,
#   'hasCooling': False,
#   'additionalParcelsDescription': None,
#   'parkingFeatures': ['Garage - Attached'],
#   'foundationArea': None,
#   'zoning': None,
#   'hoaFee': '$49 monthly',
#   'livingAreaRange': None,
#   'zoningDescription': None,
#   'developmentStatus': None,
#   'availabilityDate': None,
#   'waterfrontFeatures': None,
#   'waterBodyName': None,
#   'utilities': None,
#   'entryLocation': None,
#   'totalActualRent': None,
#   'hasView': True,
#   'subdivisionName': None,
#   'securityFeatures': None,
#   'attic': None,
#   'fireplaceFeatures': None,
#   'mainLevelBathrooms': None,
#   'doorFeatures': None,
#   'ownershipType': None,
#   'associationName': None,
#   'associations': [{'feeFrequency': '$49 monthly',
#     'name': None,
#     'phone': None}],
#   'waterView': '',
#   'garageParkingCapacity': None,
#   'cropsIncludedYN': None,
#   'laundryFeatures': None,
#   'buyerAgencyCompensation': None,
#   'greenIndoorAirQuality': None,
#   'homeType': 'Townhouse',
#   'spaFeatures': None,
#   'municipality': None,
#   'bathroomsThreeQuarter': 1,
#   'hasSpa': False,
#   'basement': None,
#   'associationFee2': None,
#   'cooling': {},
#   'openParkingCapacity': None,
#   'associationName2': None,
#   'hasRentControl': None,
#   'elementarySchoolDistrict': 'Seattle',
#   'otherEquipment': None,
#   'commonWalls': None,
#   'specialListingConditions': None,
#   'furnished': False,
#   'vegetation': None,
#   'patioAndPorchFeatures': None,
#   'bathroomsFloat': 3,
#   'builderName': None,
#   'highSchoolDistrict': 'Seattle',
#   'transactionBrokerCompensation': None,
#   'storiesTotal': None,
#   'cumulativeDaysOnMarket': None,
#   'fireplaces': None,
#   'irrigationWaterRightsYN': None,
#   'exclusions': None,
#   'hasOpenParking': None,
#   'landLeaseAmount': None,
#   'coveredParkingCapacity': None,
#   'middleOrJuniorSchool': 'Mc Clure Mid',
#   'hasElectricOnProperty': None,
#   'onMarketDate': None,
#   'pricePerSquareFoot': 677,
#   'parkingCapacity': 1,
#   'levels': None},
#  'taxHistory': {},
#  'brokerId': None,
#  'stateId': 59,
#  'streetAddress': '757 Hayes St',
#  'listingSubType': {'is_FSBA': False,
#   'is_comingSoon': False,
#   'is_newHome': False,
#   'is_pending': False,
#   'is_forAuction': False,
#   'is_foreclosure': False,
#   'is_bankOwned': False,
#   'is_openHouse': False,
#   'is_FSBO': False},
#  'solarPotential': None,
#  'dateSold': None,
#  'countyId': 207,
#  'timeZone': 'America/Los_Angeles',
#  'homeType': 'TOWNHOUSE',
#  'livingAreaUnits': 'sqft',
#  'comingSoonOnMarketDate': None,
#  'rentZestimate': 4936,
#  'bathrooms': 3,
#  'annualHomeownersInsurance': 6359,
#  'state': 'WA',
#  'propertyTypeDimension': 'Townhouse',
#  'building': None,
#  'listed_by': {'agent_reason': None,
#   'zpro': None,
#   'recent_sales': None,
#   'review_count': None,
#   'display_name': None,
#   'badge_type': None,
#   'business_name': None,
#   'rating_average': None,
#   'phone': None,
#   'zuid': None,
#   'image_url': None},
#  'yearBuilt': 2020,
#  'brokerageName': None,
#  'pageViewCount': 10,
#  'county': 'King County',
#  'mortgageRates': {'thirtyYearFixedRate': 6.765},
#  'attributionInfo': {'buyerAgentName': None,
#   'mlsName': None,
#   'coAgentLicenseNumber': None,
#   'listingOffices': [{'associatedOfficeType': 'listOffice',
#     'officeName': None}],
#   'lastUpdated': None,
#   'buyerAgentMemberStateLicense': None,
#   'brokerName': None,
#   'listingAgreement': None,
#   'infoString10': None,
#   'trueStatus': None,
#   'infoString3': None,
#   'agentEmail': None,
#   'agentName': None,
#   'attributionTitle': None,
#   'mlsId': None,
#   'coAgentName': None,
#   'coAgentNumber': None,
#   'infoString5': None,
#   'listingAgents': {},
#   'agentPhoneNumber': None,
#   'agentLicenseNumber': None,
#   'providerLogo': None,
#   'infoString16': None,
#   'buyerBrokerageName': None,
#   'mlsDisclaimer': None,
#   'brokerPhoneNumber': None,
#   'lastChecked': None},
#  'monthlyHoaFee': 49,
#  'homeStatus': 'OTHER',
#  'homeFacts': None,
#  'latitude': 47.63394,
#  'datePosted': '',
#  'bedrooms': 3,
#  'nearbyHomes': [{'livingArea': 2247,
#    'livingAreaValue': 2247,
#    'lotAreaUnits': 'Square Feet',
#    'lotAreaValue': 866,
#    'lotSize': 866,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/48dc223c24eb5363bb062399118f8238-p_c.jpg'}],
#    'zpid': 2082346047,
#    'longitude': -122.34207,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '759 Hayes St',
#     'zipcode': '98109'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 1368600,
#    'homeType': 'TOWNHOUSE',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 47.63394},
#   {'livingArea': 2236,
#    'livingAreaValue': 2236,
#    'lotAreaUnits': 'Square Feet',
#    'lotAreaValue': 801.504,
#    'lotSize': 801,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/5db107cebe7a9cd5d12d84e4ea1c2841-p_c.jpg'}],
#    'zpid': 332976321,
#    'longitude': -122.342,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '757 Hayes St',
#     'zipcode': '98109'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 1546600,
#    'homeType': 'TOWNHOUSE',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 47.633823},
#   {'livingArea': 1191,
#    'livingAreaValue': 1191,
#    'lotAreaUnits': 'Square Feet',
#    'lotAreaValue': 1952,
#    'lotSize': 1952,
#    'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/streetview?location=1628+Dexter+Ave+N+%2C+Seattle%2C+WA+98109&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=9NEs2_mHlsP3RJkC-5K8wGFSG8I='}],
#    'zpid': 129437034,
#    'longitude': -122.341934,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '1628 Dexter Ave N',
#     'zipcode': '98109'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 2975000,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'SOLD',
#    'currency': 'USD',
#    'latitude': 47.63383},
#   {'livingArea': 2220,
#    'livingAreaValue': 2220,
#    'lotAreaUnits': 'Square Feet',
#    'lotAreaValue': 975.744,
#    'lotSize': 975,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/43f0b23304aef5c988b2d7fd49cdadd3-p_c.jpg'}],
#    'zpid': 332974086,
#    'longitude': -122.34193,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '755 Hayes St',
#     'zipcode': '98109'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 1650000,
#    'homeType': 'TOWNHOUSE',
#    'homeStatus': 'SOLD',
#    'currency': 'USD',
#    'latitude': 47.63383},
#   {'livingArea': 1260,
#    'livingAreaValue': 1260,
#    'lotAreaUnits': 'Square Feet',
#    'lotAreaValue': 1295,
#    'lotSize': 1295,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/a1dbe07156ed64592d58b714a1087d86-p_c.jpg'}],
#    'zpid': 49102198,
#    'longitude': -122.34198,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '1702 Dexter Ave N',
#     'zipcode': '98109'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 756100,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 47.63413},
#   {'livingArea': 1260,
#    'livingAreaValue': 1260,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/fd9292e1ec8c4ba16202981d161be047-p_c.jpg'}],
#    'zpid': 2137443908,
#    'longitude': -122.34198,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '1702 Dexter Ave N',
#     'zipcode': '98109'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 577800,
#    'homeType': 'TOWNHOUSE',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 47.63413},
#   {'livingArea': 1260,
#    'livingAreaValue': 1260,
#    'lotAreaUnits': 'Square Feet',
#    'lotAreaValue': 1295,
#    'lotSize': 1295,
#    'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=316x234&zoom=17&center=47.63414001464844,-122.34201049804688&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&&signature=bLYXYq1VUbK2nM00uqLIEd6AzIw='}],
#    'zpid': 84762719,
#    'longitude': -122.34201,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '1700 Dexter Ave N',
#     'zipcode': '98109'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 713800,
#    'homeType': 'TOWNHOUSE',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 47.63414},
#   {'livingArea': 1090,
#    'livingAreaValue': 1090,
#    'lotAreaUnits': 'Square Feet',
#    'lotAreaValue': 991,
#    'lotSize': 991,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/2a91f7a91f508ce03952ebd7026f0ce3-p_c.jpg'}],
#    'zpid': 84762741,
#    'longitude': -122.341835,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '1704 Dexter Ave N #A',
#     'zipcode': '98109'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 760700,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 47.63407}],
#  'livingArea': 2236,
#  'priceHistory': [{'priceChangeRate': -0.045307443365696,
#    'date': '2021-01-29',
#    'source': 'NWMLS',
#    'postingIsRental': False,
#    'time': 1611878400000,
#    'sellerAgent': {'name': 'Carlene Pride',
#     'photo': {'url': 'https://photos.zillowstatic.com/h_e/ISap5el5snthc31000000000.jpg'},
#     'profileUrl': '/profile/carlenepride/'},
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'NWMLS',
#     'infoString3': None,
#     'infoString1': '1648689'},
#    'pricePerSquareFoot': 660,
#    'buyerAgent': {'name': 'Jason Foss',
#     'photo': {'url': 'https://photos.zillowstatic.com/h_e/ISjrsbfm5hnszc0000000000.jpg'},
#     'profileUrl': '/profile/Jason-Foss/'},
#    'event': 'Sold',
#    'price': 1475000},
#   {'priceChangeRate': 0,
#    'date': '2021-01-04',
#    'source': 'COMPASS',
#    'postingIsRental': False,
#    'time': 1609718400000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'COMPASS',
#     'infoString3': None,
#     'infoString1': '1648689'},
#    'pricePerSquareFoot': 691,
#    'buyerAgent': None,
#    'event': 'Pending sale',
#    'price': 1545000},
#   {'priceChangeRate': -0.019047619047619,
#    'date': '2020-10-15',
#    'source': 'COMPASS',
#    'postingIsRental': False,
#    'time': 1602720000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'COMPASS',
#     'infoString3': None,
#     'infoString1': '1648689'},
#    'pricePerSquareFoot': 691,
#    'buyerAgent': None,
#    'event': 'Price change',
#    'price': 1545000},
#   {'priceChangeRate': -0.1,
#    'date': '2020-08-18',
#    'source': 'COMPASS',
#    'postingIsRental': False,
#    'time': 1597708800000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'COMPASS',
#     'infoString3': None,
#     'infoString1': '1648689'},
#    'pricePerSquareFoot': 704,
#    'buyerAgent': None,
#    'event': 'Listed for sale',
#    'price': 1575000},
#   {'priceChangeRate': 0,
#    'date': '2020-04-10',
#    'source': 'Compass Washington',
#    'postingIsRental': False,
#    'time': 1586476800000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Compass Washington',
#     'infoString3': None,
#     'infoString1': '1564480'},
#    'pricePerSquareFoot': 783,
#    'buyerAgent': None,
#    'event': 'Listing removed',
#    'price': 1750000},
#   {'priceChangeRate': 0,
#    'date': '2020-02-17',
#    'source': 'Compass Washington',
#    'postingIsRental': False,
#    'time': 1581897600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Compass Washington',
#     'infoString3': None,
#     'infoString1': '1564480'},
#    'pricePerSquareFoot': 783,
#    'buyerAgent': None,
#    'event': 'Listed for sale',
#    'price': 1750000}],
#  'favoriteCount': 0,
#  'schools': [{'link': 'https://www.greatschools.org/washington/seattle/1572-Hay-Elementary-School/',
#    'rating': 8,
#    'totalCount': None,
#    'distance': 0.5,
#    'assigned': None,
#    'name': 'Hay Elementary School',
#    'studentsPerTeacher': None,
#    'isAssigned': None,
#    'size': None,
#    'level': 'Elementary',
#    'grades': 'K-5',
#    'type': 'Public'},
#   {'link': 'https://www.greatschools.org/washington/seattle/1585-Mcclure-Middle-School/',
#    'rating': 7,
#    'totalCount': None,
#    'distance': 0.8,
#    'assigned': None,
#    'name': 'Mcclure Middle School',
#    'studentsPerTeacher': None,
#    'isAssigned': None,
#    'size': None,
#    'level': 'Middle',
#    'grades': '6-8',
#    'type': 'Public'},
#   {'link': 'https://www.greatschools.org/washington/seattle/7711-Lincoln-High-School/',
#    'rating': None,
#    'totalCount': None,
#    'distance': 1.8,
#    'assigned': None,
#    'name': 'Lincoln High School',
#    'studentsPerTeacher': None,
#    'isAssigned': None,
#    'size': None,
#    'level': 'High',
#    'grades': '9-12',
#    'type': 'Public'}],
#  'zestimateHighPercent': '7',
#  'mlsid': None,
#  'countyFIPS': None,
#  'city': 'Seattle',
#  'providerListingID': None,
#  'country': 'USA',
#  'currency': 'USD',
#  'isListedByOwner': None,
#  'contingentListingType': None}

# %%
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"chicago, il","home_type":"Houses","bathsMin":"2","bedsMin":"4"}

response = requests.get(url, headers = headers, params = querystring)

# %%
response.json()
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5124.9647,
#    'address': '1900 W Fletcher St, Chicago, IL 60657',
#    'variableData': {'text': 'Showcase', 'type': 'SHOWCASE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4bcbcd2bef2e2e3ed4859967a1d2b429-p_e.jpg',
#    'price': 2000000,
#    'detailUrl': '/homedetails/1900-W-Fletcher-St-Chicago-IL-60657/3731095_zpid/',
#    'bedrooms': 6,
#    'contingentListingType': None,
#    'longitude': -87.67616,
#    'latitude': 41.938942,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3731095',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 6,
#    'livingArea': 5000,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5100.876,
#    'address': '4535 N Wolcott Ave, Chicago, IL 60640',
#    'variableData': {'text': 'Showcase', 'type': 'SHOWCASE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b47b7f3231d36ff7769ccadd586468d4-p_e.jpg',
#    'price': 1250000,
#    'detailUrl': '/homedetails/4535-N-Wolcott-Ave-Chicago-IL-60640/3707801_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.67566,
#    'latitude': 41.964367,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3707801',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 4,
#    'livingArea': 5200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 2879.316,
#    'address': '2532 W Thomas St, Chicago, IL 60622',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a7c1d5b35f4d9a24b1079ffbe182c2ce-p_e.jpg',
#    'price': 450000,
#    'detailUrl': '/homedetails/2532-W-Thomas-St-Chicago-IL-60622/3793029_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.69077,
#    'latitude': 41.901417,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3793029',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 2500,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7200,
#    'address': '4329 S Wood St, Chicago, IL 60609',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 191600,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f1e5952829349e70d03258513de5e681-p_e.jpg',
#    'price': 199999,
#    'detailUrl': '/homedetails/4329-S-Wood-St-Chicago-IL-60609/3981550_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.66964,
#    'latitude': 41.814922,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3981550',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3440,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 2500,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.5963,
#    'address': '1932 N Burling St, Chicago, IL 60614',
#    'variableData': None,
#    'priceChange': -4400000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/426683fcfae320d0d0a6099b1f504170-p_e.jpg',
#    'price': 23500000,
#    'detailUrl': '/homedetails/1932-N-Burling-St-Chicago-IL-60614/2096089558_zpid/',
#    'bedrooms': 6,
#    'contingentListingType': None,
#    'longitude': -87.64759,
#    'latitude': 41.91708,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2096089558',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 11,
#    'livingArea': 25000,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3123.252,
#    'address': '4145 N Richmond St, Chicago, IL 60618',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1bc7d742ed7ea0aa8a3be245162111a4-p_e.jpg',
#    'price': 424900,
#    'detailUrl': '/homedetails/4145-N-Richmond-St-Chicago-IL-60618/3643797_zpid/',
#    'bedrooms': 6,
#    'contingentListingType': None,
#    'longitude': -87.70165,
#    'latitude': 41.957085,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3643797',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 1900,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.2697,
#    'address': '901 W 129th Pl, Chicago, IL 60643',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f6bc1d8a1f3971d4c07273068c2f4ef2-p_e.jpg',
#    'price': 649000,
#    'detailUrl': '/homedetails/901-W-129th-Pl-Chicago-IL-60643/4164104_zpid/',
#    'bedrooms': 7,
#    'contingentListingType': None,
#    'longitude': -87.64377,
#    'latitude': 41.658066,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4164104',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 5,
#    'livingArea': 6000,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.25,
#    'address': '7037 S Laflin St, Chicago, IL 60636',
#    'variableData': {'text': '$4,999 (Feb 22)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -4999,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5c1584f55ba0e307792063932262d243-p_e.jpg',
#    'price': 255000,
#    'detailUrl': '/homedetails/7037-S-Laflin-St-Chicago-IL-60636/3998088_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.661064,
#    'latitude': 41.765667,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3998088',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3440,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 2100,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5340,
#    'address': '7258 W Catalpa Ave, Chicago, IL 60656',
#    'variableData': {'text': 'Open: Fri. 4-6pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/fa0303fe22bc77d5b44a84210327e407-p_e.jpg',
#    'price': 499900,
#    'detailUrl': '/homedetails/7258-W-Catalpa-Ave-Chicago-IL-60656/3584387_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.80921,
#    'latitude': 41.979248,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3584387',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 2170,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8050,
#    'address': '4136 N Greenview Ave, Chicago, IL 60613',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/fe9e0633127304329787e1d4d8a945c9-p_e.jpg',
#    'price': 4450000,
#    'detailUrl': '/homedetails/4136-N-Greenview-Ave-Chicago-IL-60613/119098290_zpid/',
#    'bedrooms': 6,
#    'contingentListingType': None,
#    'longitude': -87.66803,
#    'latitude': 41.95725,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '119098290',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 6,
#    'livingArea': 7134,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4250,
#    'address': '3216 W Walnut St, Chicago, IL 60624',
#    'variableData': {'text': 'Open: Sat. 11am-1pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': -10000,
#    'zestimate': 571600,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a8aee352489d4d79de7243eaa630f47d-p_e.jpg',
#    'price': 565000,
#    'detailUrl': '/homedetails/3216-W-Walnut-St-Chicago-IL-60624/2122509352_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.70696,
#    'latitude': 41.885643,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2122509352',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 3557,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 2950,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4748.04,
#    'address': '6635 S Talman Ave, Chicago, IL 60629',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b8a8bb0b272a92a441dce1f0ab0767fc-p_e.jpg',
#    'price': 300000,
#    'detailUrl': '/homedetails/6635-S-Talman-Ave-Chicago-IL-60629/3956186_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.68921,
#    'latitude': 41.772636,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3956186',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 4,
#    'livingArea': 2782,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6969.6,
#    'address': '5700 N Merrimac Ave, Chicago, IL 60646',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2d4d559fc46208339bef026c0ff6bb0b-p_e.jpg',
#    'price': 459000,
#    'detailUrl': '/homedetails/5700-N-Merrimac-Ave-Chicago-IL-60646/3626137_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.78441,
#    'latitude': 41.984913,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3626137',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 1672,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4410,
#    'address': '3638 W 80th St, Chicago, IL 60652',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7d8e3a21ec2c475175b44f88aae2f0f9-p_e.jpg',
#    'price': 369900,
#    'detailUrl': '/homedetails/3638-W-80th-St-Chicago-IL-60652/3974121_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.713715,
#    'latitude': 41.748066,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3974121',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 2322,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7810.308,
#    'address': '209 N Latrobe Ave, Chicago, IL 60644',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b5cf3fe138d732d7231c5f7be9eff8f8-p_e.jpg',
#    'price': 299000,
#    'detailUrl': '/homedetails/209-N-Latrobe-Ave-Chicago-IL-60644/3809322_zpid/',
#    'bedrooms': 7,
#    'contingentListingType': None,
#    'longitude': -87.756096,
#    'latitude': 41.8846,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3809322',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 5,
#    'livingArea': 5724,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3781.008,
#    'address': '9429 S Ada St, Chicago, IL 60620',
#    'variableData': None,
#    'priceChange': 35000,
#    'zestimate': 411900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/0d077cb6c0dc7f18029552120b0845fb-p_e.jpg',
#    'price': 410000,
#    'detailUrl': '/homedetails/9429-S-Ada-St-Chicago-IL-60620/4122065_zpid/',
#    'bedrooms': 7,
#    'contingentListingType': None,
#    'longitude': -87.65627,
#    'latitude': 41.72224,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4122065',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1900,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 3200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3136.32,
#    'address': '4025 W 24th St, Chicago, IL 60623',
#    'variableData': {'text': 'Open: Sat. 12-2pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/48d14d2e161101a82711a08ba671635a-p_e.jpg',
#    'price': 265000,
#    'detailUrl': '/homedetails/4025-W-24th-St-Chicago-IL-60623/3827413_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.725685,
#    'latitude': 41.847633,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3827413',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 1500,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7600,
#    'address': '45 N Austin Blvd, Chicago, IL 60644',
#    'variableData': {'text': '$60,900 (Apr 2)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -60900,
#    'zestimate': 355200,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/72a57b5837a66cd9becedfbb92546c1a-p_e.jpg',
#    'price': 369000,
#    'detailUrl': '/homedetails/45-N-Austin-Blvd-Chicago-IL-60644/3808185_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.774284,
#    'latitude': 41.881477,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3808185',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 4080,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 6795,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3789.72,
#    'address': '3016 N Kenneth Ave, Chicago, IL 60641',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/37a8931b1313b8545cbd4c8617ee438c-p_e.jpg',
#    'price': 339000,
#    'detailUrl': '/homedetails/3016-N-Kenneth-Ave-Chicago-IL-60641/3670983_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.73852,
#    'latitude': 41.935833,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3670983',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1150,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5000,
#    'address': '8563 W Saint Joseph Ave, Chicago, IL 60656',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 494400,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/abb69ecc3d8f79b7e12163d25e435626-p_e.jpg',
#    'price': 479900,
#    'detailUrl': '/homedetails/8563-W-Saint-Joseph-Ave-Chicago-IL-60656/3582680_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.84083,
#    'latitude': 41.972836,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3582680',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2899,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 1483,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4678.344,
#    'address': '9622 S Avalon Ave, Chicago, IL 60628',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e4ad918419d64219691b6494ea5c5e22-p_e.jpg',
#    'price': 236000,
#    'detailUrl': '/homedetails/9622-S-Avalon-Ave-Chicago-IL-60628/4135555_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.59384,
#    'latitude': 41.71967,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4135555',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1651,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3125,
#    'address': '4221 W 77th Pl, Chicago, IL 60652',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 292500,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7968960773fba2b1dd96b500ca3cfd5a-p_e.jpg',
#    'price': 289900,
#    'detailUrl': '/homedetails/4221-W-77th-Pl-Chicago-IL-60652/3961936_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.72777,
#    'latitude': 41.75232,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3961936',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2361,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 5230,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5096.52,
#    'address': '5400 N Long Ave, Chicago, IL 60630',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7bc29257c0d819bb9407ff17b552e826-p_e.jpg',
#    'price': 450000,
#    'detailUrl': '/homedetails/5400-N-Long-Ave-Chicago-IL-60630/3636076_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.76379,
#    'latitude': 41.979485,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3636076',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 0,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6599.34,
#    'address': '3 W Burton Pl, Chicago, IL 60610',
#    'variableData': None,
#    'priceChange': -3000000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/85124c16460e178ba1aa05e02978bb6e-p_e.jpg',
#    'price': 15750000,
#    'detailUrl': '/homedetails/3-W-Burton-Pl-Chicago-IL-60610/2077311189_zpid/',
#    'bedrooms': 6,
#    'contingentListingType': None,
#    'longitude': -87.62925,
#    'latitude': 41.90932,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2077311189',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 13,
#    'livingArea': 20002,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5325,
#    'address': '10558 S Lawndale Ave, Chicago, IL 60655',
#    'newConstructionType': 'BUILDER_SPEC',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5e599fb4548bf53e18cc663fb037686a-p_e.jpg',
#    'price': 799000,
#    'detailUrl': '/homedetails/10558-S-Lawndale-Ave-Chicago-IL-60655/4081359_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.713745,
#    'latitude': 41.700603,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4081359',
#    'listingSubType': {'is_newHome': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 0,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3125,
#    'address': '3820 N Troy St, Chicago, IL 60618',
#    'newConstructionType': 'BUILDER_SPEC',
#    'variableData': {'text': 'Showcase', 'type': 'SHOWCASE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/444cd858c8be3b67400908a0131297f9-p_e.jpg',
#    'price': 1100000,
#    'detailUrl': '/homedetails/3820-N-Troy-St-Chicago-IL-60618/101399552_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.70706,
#    'latitude': 41.950966,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '101399552',
#    'listingSubType': {'is_newHome': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 4,
#    'livingArea': 3600,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4264.524,
#    'address': '7056 N Overhill Ave, Chicago, IL 60631',
#    'variableData': {'text': 'Open: Sat. 2-4pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/38ca7b9e7ed0a433a62752bdb5440485-p_e.jpg',
#    'price': 899000,
#    'detailUrl': '/homedetails/7056-N-Overhill-Ave-Chicago-IL-60631/3510043_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.8191,
#    'latitude': 42.009415,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3510043',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 2800,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4813.38,
#    'address': '1115 W Chestnut St, Chicago, IL 60642',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3fa06f795587be0e208ccd7e6ac1e98a-p_e.jpg',
#    'price': 2299000,
#    'detailUrl': '/homedetails/1115-W-Chestnut-St-Chicago-IL-60642/123562188_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.65601,
#    'latitude': 41.898155,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '123562188',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 5,
#    'livingArea': 0,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3772,
#    'address': '3201 W 114th St, Chicago, IL 60655',
#    'variableData': {'text': 'Open: Sat. 11am-2pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5f974620af8dcf7104f18aee4bc5e720-p_e.jpg',
#    'price': 380000,
#    'detailUrl': '/homedetails/3201-W-114th-St-Chicago-IL-60655/4097258_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.700806,
#    'latitude': 41.686337,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4097258',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1104,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3125,
#    'address': '225 W 108th St, Chicago, IL 60628',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/53a6b448f008a28fd5261b39ac959975-p_e.jpg',
#    'price': 45000,
#    'detailUrl': '/homedetails/225-W-108th-St-Chicago-IL-60628/4143084_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.62905,
#    'latitude': 41.69772,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4143084',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1600,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5000,
#    'address': '4170 W Nelson St, Chicago, IL 60641',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 638000,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/6e48bc05072730c7ab330b7a6b24f6ba-p_e.jpg',
#    'price': 629000,
#    'detailUrl': '/homedetails/4170-W-Nelson-St-Chicago-IL-60641/3671434_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.73231,
#    'latitude': 41.93655,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3671434',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2377,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 2500,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3750,
#    'address': '7538 S Winchester Ave, Chicago, IL 60620',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/50daa4e8f43efcbeda888b94c8fcf459-p_e.jpg',
#    'price': 314900,
#    'detailUrl': '/homedetails/7538-S-Winchester-Ave-Chicago-IL-60620/4011508_zpid/',
#    'bedrooms': 6,
#    'contingentListingType': None,
#    'longitude': -87.67245,
#    'latitude': 41.756332,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4011508',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1152,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3125,
#    'address': '10326 S Avenue H, Chicago, IL 60617',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4d4b318355003df81443658bbb2184c3-p_e.jpg',
#    'price': 309900,
#    'detailUrl': '/homedetails/10326-S-Avenue-H-Chicago-IL-60617/4169727_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.53322,
#    'latitude': 41.70741,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4169727',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 1881,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3780,
#    'address': '6136 S Komensky Ave, Chicago, IL 60629',
#    'variableData': {'text': 'Open: Sat. 12-2pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7c23fe3d0ee1145adefadb7128750ab3-p_e.jpg',
#    'price': 369900,
#    'detailUrl': '/homedetails/6136-S-Komensky-Ave-Chicago-IL-60629/3940133_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.7244,
#    'latitude': 41.781155,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3940133',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1050,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1912.284,
#    'address': '53 E Division St, Chicago, IL 60610',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/be9c79bd4c386a00237e85973c3a1c83-p_e.jpg',
#    'price': 4500000,
#    'detailUrl': '/homedetails/53-E-Division-St-Chicago-IL-60610/3845765_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.62663,
#    'latitude': 41.90377,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3845765',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 9,
#    'livingArea': 7500,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3842,
#    'address': '11142 S Parnell Ave, Chicago, IL 60628',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3953cc86fae6bb995afd17ace8fcaf1a-p_e.jpg',
#    'price': 259000,
#    'detailUrl': '/homedetails/11142-S-Parnell-Ave-Chicago-IL-60628/81778333_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.636635,
#    'latitude': 41.691128,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '81778333',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 1967,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1860,
#    'address': '1922 S Louie Pkwy, Chicago, IL 60616',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/86f0289ff60fd4df3343cea6ea591f1f-p_e.jpg',
#    'price': 700000,
#    'detailUrl': '/homedetails/1922-S-Louie-Pkwy-Chicago-IL-60616/65572788_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.63235,
#    'latitude': 41.855877,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '65572788',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 2185,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5183.64,
#    'address': '7229 S Wood St, Chicago, IL 60636',
#    'variableData': {'text': 'Open: 4/21 12-3pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': 318900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1185a67452d39f60c4222f83402a0625-p_e.jpg',
#    'price': 317901,
#    'detailUrl': '/homedetails/7229-S-Wood-St-Chicago-IL-60636/4010667_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.66825,
#    'latitude': 41.762108,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '4010667',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 2199,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1240,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3354,
#    'address': '52 E Bellevue Pl, Chicago, IL 60611',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 7841300,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/344ef845364d654074a0818e1aed8ef7-p_e.jpg',
#    'price': 7900000,
#    'detailUrl': '/homedetails/52-E-Bellevue-Pl-Chicago-IL-60611/3846727_zpid/',
#    'bedrooms': 6,
#    'contingentListingType': None,
#    'longitude': -87.62635,
#    'latitude': 41.90188,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3846727',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 40299,
#    'daysOnZillow': -1,
#    'bathrooms': 9,
#    'livingArea': 0,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3750.516,
#    'address': '5919 N Bernard St, Chicago, IL 60659',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 542400,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7c8dd93e3fbb9c2a7efdb3449d7042ce-p_e.jpg',
#    'price': 560000,
#    'detailUrl': '/homedetails/5919-N-Bernard-St-Chicago-IL-60659/3620953_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.70365,
#    'latitude': 41.986973,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3620953',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 4200,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 2515,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3780,
#    'address': '5636 W Warwick Ave, Chicago, IL 60634',
#    'variableData': {'text': '3D Tour', 'type': '3D_HOME'},
#    'priceChange': None,
#    'zestimate': 786000,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/0ac16d4746bbab9d685472b4517ae603-p_e.jpg',
#    'price': 779000,
#    'detailUrl': '/homedetails/5636-W-Warwick-Ave-Chicago-IL-60634/3660066_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.76836,
#    'latitude': 41.94886,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '3660066',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3499,
#    'daysOnZillow': -1,
#    'bathrooms': 4,
#    'livingArea': 2300,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True}],
#  'resultsPerPage': 41,
#  'totalPages': 20,
#  'totalResultCount': 1010,
#  'schools': {},
#  'currentPage': 1}

# %%
url = "https://zillow-com1.p.rapidapi.com/property"

querystring = {"zpid":"3731095"}

response = requests.get(url, headers = headers, params = querystring)

# %%
response.json()
# Out:
# {'listingProvider': None,
#  'zpid': 3731095,
#  'buildingPermits': None,
#  'propertyTaxRate': 1.89,
#  'contact_recipients': [{'agent_reason': 1,
#    'zpro': None,
#    'recent_sales': 0,
#    'review_count': 11,
#    'display_name': 'Jonathon Spradling',
#    'zuid': 'X1-ZUsr5a0rmfhzih_85kue',
#    'rating_average': 4.9,
#    'badge_type': 'Premier Agent',
#    'phone': {'prefix': '681', 'areacode': '312', 'number': '7596'},
#    'image_url': 'https://photos.zillowstatic.com/h_n/IS7e64051zmyod0000000000.jpg'}],
#  'zipcode': '60657',
#  'openHouseSchedule': {},
#  'longitude': -87.67616,
#  'zestimateLowPercent': None,
#  'address': {'community': None,
#   'city': 'Chicago',
#   'state': 'IL',
#   'neighborhood': None,
#   'subdivision': None,
#   'streetAddress': '1900 W Fletcher St',
#   'zipcode': '60657'},
#  'cityId': 17426,
#  'timeOnZillow': '4 days',
#  'url': '/homedetails/1900-W-Fletcher-St-Chicago-IL-60657/3731095_zpid/',
#  'zestimate': None,
#  'imgSrc': 'https://photos.zillowstatic.com/fp/4bcbcd2bef2e2e3ed4859967a1d2b429-p_d.jpg',
#  'description': "Introducing Roscoe Village's newest gem-a magnificent 6 bed, 5.1 bath single-family home! Crafted by premier builder Denny Dev and clad in James Hardie board siding for durability and timeless elegance, this residence sits on an oversized corner lot. Step onto the lovely wrap-around porch and prepare to be enchanted by the luxurious details within. Enter the formal living room and dining room, where luxury abounds with coffered ceilings, high-end millwork, rich hardwood flooring, and an abundance of natural light streaming through Pella windows adorned with custom Hunter Douglas window treatments. The living room features a wood-burning fireplace, perfect for cozy Chicago winter nights, and a bay window offering serene views of the quiet residential street. French doors lead from the dining room to the porch, seamlessly blending indoor and outdoor living. The heart of the home lies in the luxury chef's kitchen, equipped with Subzero and Wolf appliances, quartzite counters, and a butler's pantry. The oversized island serves as a focal point and is open to the family room, where another wood-burning fireplace and built-ins await. Upstairs, discover the expansive primary suite with vaulted ceilings and his & hers custom walk-in closets. The luxurious en-suite bathroom boasts an oversized rain and steam shower, soaking tub, makeup vanity, and his and hers sinks. Three additional bedrooms, two bathrooms, and a laundry room complete the second level, providing a range of layout options. The fully finished lower level is an entertainer's dream, featuring new carpet, radiant heated floors, a wet bar, Eurocave wine cellar, and another fireplace. Two bonus bedrooms and two more bathrooms provide ample space for guests, and the laundry room boasts a brand new washer and dryer March 2024.  Bonus features of this home include high-end Wi-Fi, Sonos surround sound throughout, and a home security system, ensuring convenience and peace of mind. All lighting is on a dimmer system, an expansive attic offers additional storage space, and the interior fireplaces are all gas-start, the upstairs two are wood-burning. Step outside to the gorgeous yard boasting a brick paver patio equipped with lighting, outdoor TV, a weather-proof high-end speaker system, and a stone wood-burning fireplace, creating an idyllic setting for outdoor gatherings. Access the 3-car garage directly from Wolcott-no need to navigate a Chicago alley. Sellers have lovingly invested $100-$150K in updates since their purchase in 2018! Directly across the street from Jahn Elementary and a 6 minute walk to Hamlin Park! Take a quick drive to Whole Foods, Trader Joe's, Marianos, Wild Fork, Beat Kitchen, Starbucks, yoga and fitness studios, shopping and so much more. Don't miss the opportunity to call this extraordinary residence your own-a perfect blend of luxury, comfort, and sophisticated living in the heart of Roscoe Village.",
#  'price': 2000000,
#  'livingAreaValue': 5000,
#  'resoFacts': {'hasAttachedProperty': False,
#   'frontageType': None,
#   'poolFeatures': None,
#   'flooring': ['Hardwood', 'Heated Floors'],
#   'builderModel': None,
#   'accessibilityFeatures': ['No Disability Access'],
#   'hasGarage': True,
#   'hasPetsAllowed': None,
#   'bodyType': None,
#   'topography': None,
#   'landLeaseExpirationDate': None,
#   'hasAdditionalParcels': False,
#   'waterViewYN': None,
#   'livingQuarters': {},
#   'atAGlanceFacts': [{'factValue': 'Single Family Residence',
#     'factLabel': 'Type'},
#    {'factValue': '2013', 'factLabel': 'Year Built'},
#    {'factValue': 'Natural Gas, Forced Air, Radiant, Sep Heating Systems - 2+',
#     'factLabel': 'Heating'},
#    {'factValue': 'Central Air', 'factLabel': 'Cooling'},
#    {'factValue': '3 Garage spaces', 'factLabel': 'Parking'},
#    {'factValue': '5,124 sqft', 'factLabel': 'Lot'},
#    {'factValue': '4 Days', 'factLabel': 'Days on Zillow'},
#    {'factValue': '$400', 'factLabel': 'Price/sqft'},
#    {'factValue': '2.5% -$495', 'factLabel': 'Buyers Agency Fee'},
#    {'factValue': None, 'factLabel': 'Offer Review Date'}],
#   'offerReviewDate': None,
#   'horseYN': None,
#   'view': {},
#   'buyerAgencyCompensationType': 'See Remarks: ',
#   'rooms': [{'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '494',
#     'roomAreaSource': None,
#     'roomType': 'FamilyRoom',
#     'roomDescription': None,
#     'roomWidth': '19',
#     'roomLevel': 'Main',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '26',
#     'roomFeatures': None,
#     'roomDimensions': '26X19',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '288',
#     'roomAreaSource': None,
#     'roomType': 'MasterBedroom',
#     'roomDescription': None,
#     'roomWidth': '16',
#     'roomLevel': 'Second',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '18',
#     'roomFeatures': None,
#     'roomDimensions': '18X16',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '154',
#     'roomAreaSource': None,
#     'roomType': None,
#     'roomDescription': None,
#     'roomWidth': '11',
#     'roomLevel': 'Lower',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '14',
#     'roomFeatures': None,
#     'roomDimensions': '14X11',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '140',
#     'roomAreaSource': None,
#     'roomType': None,
#     'roomDescription': None,
#     'roomWidth': '10',
#     'roomLevel': 'Main',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '14',
#     'roomFeatures': None,
#     'roomDimensions': '14X10',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '560',
#     'roomAreaSource': None,
#     'roomType': 'RecreationRoom',
#     'roomDescription': None,
#     'roomWidth': '16',
#     'roomLevel': 'Lower',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '35',
#     'roomFeatures': None,
#     'roomDimensions': '35X16',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '48',
#     'roomAreaSource': None,
#     'roomType': 'WalkInCloset',
#     'roomDescription': None,
#     'roomWidth': '6',
#     'roomLevel': 'Second',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '8',
#     'roomFeatures': None,
#     'roomDimensions': '8X6',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '176',
#     'roomAreaSource': None,
#     'roomType': 'Bedroom5',
#     'roomDescription': None,
#     'roomWidth': '11',
#     'roomLevel': 'Lower',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '16',
#     'roomFeatures': None,
#     'roomDimensions': '16X11',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '64',
#     'roomAreaSource': None,
#     'roomType': 'WalkInCloset',
#     'roomDescription': None,
#     'roomWidth': '8',
#     'roomLevel': 'Second',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '8',
#     'roomFeatures': None,
#     'roomDimensions': '8X8',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '192',
#     'roomAreaSource': None,
#     'roomType': 'Bedroom3',
#     'roomDescription': None,
#     'roomWidth': '16',
#     'roomLevel': 'Second',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '12',
#     'roomFeatures': None,
#     'roomDimensions': '12X16',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '280',
#     'roomAreaSource': None,
#     'roomType': 'Kitchen',
#     'roomDescription': None,
#     'roomWidth': '14',
#     'roomLevel': 'Main',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '20',
#     'roomFeatures': None,
#     'roomDimensions': '20X14',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '35',
#     'roomAreaSource': None,
#     'roomType': 'Laundry',
#     'roomDescription': None,
#     'roomWidth': '5',
#     'roomLevel': 'Second',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '7',
#     'roomFeatures': None,
#     'roomDimensions': '7X5',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '272',
#     'roomAreaSource': None,
#     'roomType': 'LivingRoom',
#     'roomDescription': None,
#     'roomWidth': '16',
#     'roomLevel': 'Main',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '17',
#     'roomFeatures': None,
#     'roomDimensions': '17X16',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '40',
#     'roomAreaSource': None,
#     'roomType': None,
#     'roomDescription': None,
#     'roomWidth': '5',
#     'roomLevel': 'Lower',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '8',
#     'roomFeatures': None,
#     'roomDimensions': '8X5',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '28',
#     'roomAreaSource': None,
#     'roomType': None,
#     'roomDescription': None,
#     'roomWidth': '4',
#     'roomLevel': 'Lower',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '7',
#     'roomFeatures': None,
#     'roomDimensions': '7X4',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '192',
#     'roomAreaSource': None,
#     'roomType': 'Bedroom2',
#     'roomDescription': None,
#     'roomWidth': '12',
#     'roomLevel': 'Second',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '16',
#     'roomFeatures': None,
#     'roomDimensions': '16X12',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '132',
#     'roomAreaSource': None,
#     'roomType': 'Bedroom4',
#     'roomDescription': None,
#     'roomWidth': '11',
#     'roomLevel': 'Second',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '12',
#     'roomFeatures': None,
#     'roomDimensions': '12X11',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '165',
#     'roomAreaSource': None,
#     'roomType': 'DiningRoom',
#     'roomDescription': None,
#     'roomWidth': '11',
#     'roomLevel': 'Main',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '15',
#     'roomFeatures': None,
#     'roomDimensions': '15X11',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '40',
#     'roomAreaSource': None,
#     'roomType': None,
#     'roomDescription': None,
#     'roomWidth': '4',
#     'roomLevel': 'Lower',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '10',
#     'roomFeatures': None,
#     'roomDimensions': '10X4',
#     'roomLengthWidthSource': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomAreaUnits': 'Square Feet',
#     'roomArea': '100',
#     'roomAreaSource': None,
#     'roomType': None,
#     'roomDescription': None,
#     'roomWidth': '10',
#     'roomLevel': 'Lower',
#     'description': None,
#     'roomLengthWidthUnits': None,
#     'roomLength': '10',
#     'roomFeatures': None,
#     'roomDimensions': '10X10',
#     'roomLengthWidthSource': None,
#     'area': None}],
#   'belowGradeFinishedArea': None,
#   'feesAndDues': [{'phone': None, 'name': None, 'fee': None, 'type': 'HOA'}],
#   'cityRegion': 'Chicago',
#   'subAgencyCompensation': None,
#   'hasPrivatePool': None,
#   'associationFeeIncludes': ['None'],
#   'waterSource': ['Lake Michigan'],
#   'carportParkingCapacity': None,
#   'transactionBrokerCompensationType': None,
#   'hasFireplace': True,
#   'gas': None,
#   'sewer': ['Public Sewer'],
#   'elevationUnits': None,
#   'roadSurfaceType': None,
#   'mainLevelBedrooms': None,
#   'numberOfUnitsVacant': None,
#   'hasWaterfrontView': None,
#   'bathroomsOneQuarter': None,
#   'lotSize': '5,124 sqft',
#   'subAgencyCompensationType': None,
#   'entryLevel': None,
#   'irrigationWaterRightsAcres': None,
#   'greenWaterConservation': None,
#   'stories': 2,
#   'bathrooms': 6,
#   'numberOfUnitsInCommunity': None,
#   'listingTerms': None,
#   'otherParking': ['Driveway (Concrete', 'Off Alley)'],
#   'associationFee': None,
#   'marketingType': None,
#   'greenEnergyEfficient': None,
#   'greenSustainability': None,
#   'heating': ['Natural Gas',
#    'Forced Air',
#    'Radiant',
#    'Sep Heating Systems - 2+'],
#   'associationPhone': None,
#   'greenBuildingVerificationType': None,
#   'hasAttachedGarage': False,
#   'bedrooms': 6,
#   'architecturalStyle': 'Traditional',
#   'listingId': None,
#   'structureType': None,
#   'interiorFeatures': ['Vaulted/Cathedral Ceilings', 'Wet Bar'],
#   'horseAmenities': None,
#   'electric': ['Circuit Breakers', '200+ Amp Service'],
#   'otherFacts': {},
#   'lotFeatures': ['Corner Lot', 'Landscaped'],
#   'roofType': 'Asphalt,Other',
#   'compensationBasedOn': None,
#   'greenEnergyGeneration': None,
#   'taxAnnualAmount': 37800,
#   'daysOnZillow': 4,
#   'listAOR': None,
#   'hasHeating': True,
#   'elementarySchool': 'Jahn Elementary School',
#   'constructionMaterials': ['Frame', 'Other'],
#   'basementYN': True,
#   'hoaFeeTotal': None,
#   'appliances': ['Double Oven',
#    'Range',
#    'Microwave',
#    'Dishwasher',
#    'Refrigerator',
#    'High End Refrigerator',
#    'Washer',
#    'Dryer',
#    'Disposal',
#    'Stainless Steel Appliance(s)',
#    'Wine Refrigerator',
#    'Range Hood'],
#   'virtualTour': 'https://www.zillow.com/view-imx/d013f3f6-63c3-4a13-bb0a-6c7b68b88bc5?setAttribution=mls&wl=true&initialViewType=pano&utm_source=dashboard',
#   'bathroomsPartial': None,
#   'fencing': 'Fenced',
#   'yearBuiltEffective': None,
#   'foundationDetails': ['Concrete Perimeter'],
#   'buildingName': None,
#   'hasAssociation': None,
#   'isSeniorCommunity': None,
#   'propertySubType': ['Single Family Residence'],
#   'propertyCondition': None,
#   'hasCarport': None,
#   'canRaiseHorses': False,
#   'hasLandLease': False,
#   'communityFeatures': ['Park',
#    'Curbs',
#    'Sidewalks',
#    'Street Lights',
#    'Street Paved'],
#   'parcelNumber': '14302000410000',
#   'elevation': None,
#   'lotSizeDimensions': '41X125',
#   'buildingAreaSource': None,
#   'contingency': None,
#   'yearBuilt': 2013,
#   'otherStructures': None,
#   'livingArea': '5,000 sqft',
#   'bathroomsFull': 5,
#   'livingAreaRangeUnits': None,
#   'incomeIncludes': None,
#   'highSchool': 'Lake View High School',
#   'aboveGradeFinishedArea': None,
#   'isNewConstruction': False,
#   'inclusions': None,
#   'hasHomeWarranty': False,
#   'additionalFeeInfo': None,
#   'windowFeatures': ['Skylight(s)'],
#   'ownership': 'Fee Simple',
#   'woodedArea': None,
#   'middleOrJuniorSchoolDistrict': '299',
#   'associationPhone2': None,
#   'exteriorFeatures': ['Fire Pit'],
#   'buildingFeatures': None,
#   'frontageLength': None,
#   'buildingArea': '0',
#   'associationAmenities': None,
#   'bathroomsHalf': 1,
#   'hasCooling': True,
#   'additionalParcelsDescription': None,
#   'parkingFeatures': ['Garage', 'Open'],
#   'foundationArea': None,
#   'zoning': None,
#   'hoaFee': None,
#   'livingAreaRange': None,
#   'zoningDescription': None,
#   'developmentStatus': None,
#   'availabilityDate': None,
#   'waterfrontFeatures': None,
#   'waterBodyName': None,
#   'utilities': None,
#   'entryLocation': None,
#   'totalActualRent': None,
#   'hasView': False,
#   'subdivisionName': None,
#   'securityFeatures': ['Security System'],
#   'attic': 'Pull Down Stair',
#   'fireplaceFeatures': ['Wood Burning',
#    'Gas Log',
#    'Gas Starter',
#    'Family Room',
#    'Living Room',
#    'Basement'],
#   'mainLevelBathrooms': None,
#   'doorFeatures': None,
#   'ownershipType': None,
#   'associationName': None,
#   'associations': {},
#   'waterView': None,
#   'garageParkingCapacity': 3,
#   'cropsIncludedYN': None,
#   'laundryFeatures': ['In Unit', 'Second Floor Laundry'],
#   'buyerAgencyCompensation': '2.5% -$495',
#   'greenIndoorAirQuality': None,
#   'homeType': 'SingleFamily',
#   'spaFeatures': None,
#   'municipality': None,
#   'bathroomsThreeQuarter': None,
#   'hasSpa': False,
#   'basement': 'Full,English',
#   'associationFee2': None,
#   'cooling': ['Central Air'],
#   'openParkingCapacity': None,
#   'associationName2': None,
#   'hasRentControl': None,
#   'elementarySchoolDistrict': '299',
#   'otherEquipment': ['Intercom', 'Sump Pump'],
#   'commonWalls': None,
#   'specialListingConditions': 'None',
#   'furnished': False,
#   'vegetation': None,
#   'patioAndPorchFeatures': ['Patio', 'Porch', 'Stamped Concrete Patio'],
#   'bathroomsFloat': 6,
#   'builderName': None,
#   'highSchoolDistrict': '299',
#   'transactionBrokerCompensation': None,
#   'storiesTotal': None,
#   'cumulativeDaysOnMarket': None,
#   'fireplaces': 3,
#   'irrigationWaterRightsYN': None,
#   'exclusions': None,
#   'hasOpenParking': True,
#   'landLeaseAmount': None,
#   'coveredParkingCapacity': 3,
#   'middleOrJuniorSchool': 'Jahn Elementary School',
#   'hasElectricOnProperty': None,
#   'onMarketDate': 1712265060000,
#   'pricePerSquareFoot': 400,
#   'parkingCapacity': 3,
#   'levels': None},
#  'taxHistory': [{'time': 1617982547134,
#    'valueIncreaseRate': 0.048473,
#    'taxIncreaseRate': -0.073546425,
#    'taxPaid': 31038.92,
#    'value': 157683},
#   {'time': 1586446547134,
#    'valueIncreaseRate': -0.08000196,
#    'taxIncreaseRate': 0.020083874,
#    'taxPaid': 33502.94,
#    'value': 150393},
#   {'time': 1554824147134,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.038936276,
#    'taxPaid': 32843.32,
#    'value': 163471},
#   {'time': 1523288147134,
#    'valueIncreaseRate': 0.17508662,
#    'taxIncreaseRate': 0.08186084,
#    'taxPaid': 31612.45,
#    'value': 163471},
#   {'time': 1491752147134,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.06789004,
#    'taxPaid': 29220.44,
#    'value': 139114},
#   {'time': 1460216147134,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.07338314,
#    'taxPaid': 27362.78,
#    'value': 139114},
#   {'time': 1428593747134,
#    'valueIncreaseRate': 0.0063004997,
#    'taxIncreaseRate': -0.0061334865,
#    'taxPaid': 25492.09,
#    'value': 139114},
#   {'time': 1397057747134,
#    'valueIncreaseRate': 0.6521817,
#    'taxIncreaseRate': 0.68546414,
#    'taxPaid': 25649.41,
#    'value': 138243},
#   {'time': 1365521747134,
#    'valueIncreaseRate': 1.0906751,
#    'taxIncreaseRate': 1.1189657,
#    'taxPaid': 15218.01,
#    'value': 83673},
#   {'time': 1333985747134,
#    'valueIncreaseRate': -0.22570035,
#    'taxIncreaseRate': -0.14255543,
#    'taxPaid': 7181.81,
#    'value': 40022},
#   {'time': 1302363347134,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': -0.0041588736,
#    'taxPaid': 8375.83,
#    'value': 51688},
#   {'time': 1270827347134,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.043529943,
#    'taxPaid': 8410.81,
#    'value': 51688},
#   {'time': 1239291347134,
#    'valueIncreaseRate': -0.1368646,
#    'taxIncreaseRate': -0.06173706,
#    'taxPaid': 8059.96,
#    'value': 51688},
#   {'time': 1207755347134,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.010031691,
#    'taxPaid': 8590.3,
#    'value': 59884},
#   {'time': 1176132947134,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': -0.010677158,
#    'taxPaid': 8504.98,
#    'value': 59884},
#   {'time': 1144596947134,
#    'valueIncreaseRate': 0.5209021,
#    'taxIncreaseRate': 0.33619684,
#    'taxPaid': 8596.77,
#    'value': 59884},
#   {'time': 1113060947134,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.010180665,
#    'taxPaid': 6433.76,
#    'value': 39374},
#   {'time': 1081524947134,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.022218104,
#    'taxPaid': 6368.92,
#    'value': 39374},
#   {'time': 1049902547134,
#    'valueIncreaseRate': 0.5238206,
#    'taxIncreaseRate': 0.34211567,
#    'taxPaid': 6230.49,
#    'value': 39374},
#   {'time': 1018366547134,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.037513096,
#    'taxPaid': 4642.29,
#    'value': 25839},
#   {'time': 986830547134,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.26675725,
#    'taxPaid': 4474.44,
#    'value': 25839},
#   {'time': 955294547134,
#    'valueIncreaseRate': 0.40528634,
#    'taxIncreaseRate': 0.11890367,
#    'taxPaid': 3532.2,
#    'value': 25839},
#   {'time': 923672147134,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': 3156.84,
#    'value': 18387}],
#  'brokerId': None,
#  'stateId': 21,
#  'streetAddress': '1900 W Fletcher St',
#  'listingSubType': {'is_FSBA': True,
#   'is_comingSoon': False,
#   'is_newHome': False,
#   'is_pending': False,
#   'is_forAuction': False,
#   'is_foreclosure': False,
#   'is_bankOwned': False,
#   'is_openHouse': False,
#   'is_FSBO': False},
#  'solarPotential': None,
#  'dateSold': None,
#  'countyId': 139,
#  'timeZone': 'America/Chicago',
#  'homeType': 'SINGLE_FAMILY',
#  'livingAreaUnits': 'sqft',
#  'comingSoonOnMarketDate': None,
#  'rentZestimate': None,
#  'bathrooms': 6,
#  'annualHomeownersInsurance': 8400,
#  'state': 'IL',
#  'propertyTypeDimension': 'Single Family',
#  'building': None,
#  'listed_by': {'agent_reason': 3,
#   'zpro': False,
#   'recent_sales': 2,
#   'zuid': 'X1-ZUyu9lbb5lo4cp_1fz16',
#   'review_count': 512,
#   'display_name': 'Leigh Marcus',
#   'profile_url': 'https://www.zillow.com/profile/Leigh-Marcus/',
#   'business_name': "@properties Christie's International Real Estate",
#   'rating_average': 5,
#   'phone': {'prefix': '345', 'areacode': '773', 'number': '9034'},
#   'badge_type': 'Listing Agent',
#   'image_url': 'https://photos.zillowstatic.com/h_n/IS6y59ngwrz1nu1000000000.jpg'},
#  'yearBuilt': 2013,
#  'brokerageName': "@properties Christie's International Real Estate",
#  'pageViewCount': 1430,
#  'county': 'Cook County',
#  'mortgageRates': {'thirtyYearFixedRate': 6.684},
#  'attributionInfo': {'buyerAgentName': None,
#   'mlsName': 'MRED as distributed by MLS GRID',
#   'coAgentLicenseNumber': None,
#   'listingOffices': [{'associatedOfficeType': 'listOffice',
#     'officeName': "@properties Christie's International Real Estate"}],
#   'lastUpdated': '2024-04-06 13:18:01',
#   'buyerAgentMemberStateLicense': None,
#   'brokerName': "@properties Christie's International Real Estate",
#   'listingAgreement': None,
#   'infoString10': 'Based on information submitted to the MLS GRID as of 2024-02-07 09:06:36 PST. All data is obtained from various sources and may not have been verified by broker or MLS GRID. Supplied Open House Information is subject to change without notice. All information should be independently reviewed and verified for accuracy. Properties may or may not be listed by the office/agent presenting the information. Some IDX listings have been excluded from this website. [Click here for more information](/info/mls-disclaimers/#mls_17)\n\nThe listing broker’s offer of compensation is made only to participants of the MLS where the listing is filed.',
#   'trueStatus': 'New',
#   'infoString3': 'https://photos.zillowstatic.com/fp/1b0fc53ffc89ea17e1e382976aca4421-zillow_web_95_35.jpg',
#   'agentEmail': None,
#   'agentName': 'Leigh Marcus',
#   'attributionTitle': 'Listing courtesy of:',
#   'mlsId': '12006783',
#   'coAgentName': None,
#   'coAgentNumber': None,
#   'infoString5': '773-472-0200',
#   'listingAgents': [{'memberStateLicense': None,
#     'memberFullName': 'Leigh Marcus',
#     'associatedAgentType': 'listAgent'}],
#   'agentPhoneNumber': '773-472-0200',
#   'agentLicenseNumber': None,
#   'providerLogo': 'https://photos.zillowstatic.com/fp/1b0fc53ffc89ea17e1e382976aca4421-zillow_web_95_35.jpg',
#   'infoString16': None,
#   'buyerBrokerageName': None,
#   'mlsDisclaimer': 'Based on information submitted to the MLS GRID as of 2024-02-07 09:06:36 PST. All data is obtained from various sources and may not have been verified by broker or MLS GRID. Supplied Open House Information is subject to change without notice. All information should be independently reviewed and verified for accuracy. Properties may or may not be listed by the office/agent presenting the information. Some IDX listings have been excluded from this website. [Click here for more information](/info/mls-disclaimers/#mls_17)\n\nThe listing broker’s offer of compensation is made only to participants of the MLS where the listing is filed.',
#   'brokerPhoneNumber': '773-472-0200',
#   'lastChecked': '2024-04-09 08:29:58'},
#  'monthlyHoaFee': None,
#  'homeStatus': 'FOR_SALE',
#  'homeFacts': None,
#  'latitude': 41.938942,
#  'datePosted': '2024-04-04',
#  'bedrooms': 6,
#  'nearbyHomes': [{'livingArea': 918,
#    'livingAreaValue': 918,
#    'lotAreaUnits': 'Square Feet',
#    'lotAreaValue': 541,
#    'lotSize': 541,
#    'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=316x234&zoom=17&center=41.938941955566406,-87.67616271972656&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&&signature=ZHqKDkb2lFAv8h6fhHcxqyEC16Q='}],
#    'zpid': 101416680,
#    'longitude': -87.67616,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '1900 W Fletcher St',
#     'zipcode': '60657'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 626200,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 41.938942},
#   {'livingArea': 5000,
#    'livingAreaValue': 5000,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/streetview?location=1900+W+Fletcher+St%2C+Chicago%2C+IL+60657&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=oOxCELo5p9iary-T_6KVsaEjWJ8='}],
#    'zpid': 2090987574,
#    'longitude': -87.67616,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '1900 W Fletcher St',
#     'zipcode': '60657'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 2096500,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 41.938942},
#   {'livingArea': None,
#    'livingAreaValue': None,
#    'lotAreaUnits': 'Square Feet',
#    'lotAreaValue': 3625,
#    'lotSize': 3625,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/dfb23846d5e16dcf4b5bdc7ae3fe3bb7-p_c.jpg'}],
#    'zpid': 3731094,
#    'longitude': -87.67625,
#    'livingAreaUnits': None,
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '1904 W Fletcher St',
#     'zipcode': '60657'},
#    'livingAreaUnitsShort': None,
#    'price': 813800,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 41.938946},
#   {'livingArea': 949,
#    'livingAreaValue': 949,
#    'lotAreaUnits': 'Square Feet',
#    'lotAreaValue': 3125,
#    'lotSize': 3125,
#    'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=316x234&zoom=17&center=41.93894577026367,-87.67636108398438&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&&signature=D0p2kDm-wHspqcNKJ6cbhxXXHQk='}],
#    'zpid': 3731093,
#    'longitude': -87.67636,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '1908 W Fletcher St',
#     'zipcode': '60657'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 579900,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 41.938946},
#   {'livingArea': 1291,
#    'livingAreaValue': 1291,
#    'lotAreaUnits': 'Square Feet',
#    'lotAreaValue': 3125,
#    'lotSize': 3125,
#    'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=316x234&zoom=17&center=41.938941955566406,-87.67645263671875&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&&signature=tPBkeqvipnCKUNwi40vdeYBPHSg='}],
#    'zpid': 3731092,
#    'longitude': -87.67645,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '1910 W Fletcher St',
#     'zipcode': '60657'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 631300,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 41.938942},
#   {'livingArea': 4200,
#    'livingAreaValue': 4200,
#    'lotAreaUnits': 'Square Feet',
#    'lotAreaValue': 3084.048,
#    'lotSize': 3084,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/dd4241b40562097b5bfb33a0420cd4aa-p_c.jpg'}],
#    'zpid': 3731091,
#    'longitude': -87.676544,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '1912 W Fletcher St',
#     'zipcode': '60657'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 1631500,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 41.938942},
#   {'livingArea': None,
#    'livingAreaValue': None,
#    'lotAreaUnits': 'Square Feet',
#    'lotAreaValue': 3049.2,
#    'lotSize': 3049,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/a92d2d2ff0c03791f969d28970b9fafc-p_c.jpg'}],
#    'zpid': 158596457,
#    'longitude': -87.67662,
#    'livingAreaUnits': None,
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '1916 W Fletcher St',
#     'zipcode': '60657'},
#    'livingAreaUnitsShort': None,
#    'price': 1220000,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 41.938942},
#   {'livingArea': 910,
#    'livingAreaValue': 910,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/cb26e8880c739b93a5f23c52375957c0-p_c.jpg'}],
#    'zpid': 2085798903,
#    'longitude': -87.67662,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '1916 W Fletcher St APT 2',
#     'zipcode': '60657'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 0,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 41.938942}],
#  'livingArea': 5000,
#  'priceHistory': [{'priceChangeRate': 0.2012012012012,
#    'date': '2024-04-04',
#    'source': 'MRED as distributed by MLS GRID',
#    'postingIsRental': False,
#    'time': 1712188800000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'MRED as distributed by MLS GRID',
#     'infoString3': 'https://photos.zillowstatic.com/fp/1b0fc53ffc89ea17e1e382976aca4421-zillow_web_logo_inf_11.jpg',
#     'infoString1': '12006783'},
#    'pricePerSquareFoot': 400,
#    'buyerAgent': None,
#    'event': 'Listed for sale',
#    'price': 2000000},
#   {'priceChangeRate': -0.048571428571429,
#    'date': '2018-06-01',
#    'source': 'MRED as distributed by MLS GRID',
#    'postingIsRental': False,
#    'time': 1527811200000,
#    'sellerAgent': {'name': 'Leigh Marcus',
#     'photo': {'url': 'https://photos.zillowstatic.com/h_e/IS6y59ngwrz1nu1000000000.jpg'},
#     'profileUrl': '/profile/Leigh-Marcus/'},
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'MRED as distributed by MLS GRID',
#     'infoString3': 'https://photos.zillowstatic.com/fp/1b0fc53ffc89ea17e1e382976aca4421-zillow_web_logo_inf_11.jpg',
#     'infoString1': '09861130'},
#    'pricePerSquareFoot': 333,
#    'buyerAgent': {'name': 'Ian Halpin',
#     'photo': {'url': 'https://photos.zillowstatic.com/h_e/ISrl548o2waqwa0000000000.jpg'},
#     'profileUrl': '/profile/Ian-Halpin/'},
#    'event': 'Sold',
#    'price': 1665000},
#   {'priceChangeRate': 0,
#    'date': '2018-04-20',
#    'source': '@properties',
#    'postingIsRental': False,
#    'time': 1524182400000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': '@properties',
#     'infoString3': None,
#     'infoString1': '09861130'},
#    'pricePerSquareFoot': 350,
#    'buyerAgent': None,
#    'event': 'Pending sale',
#    'price': 1750000},
#   {'priceChangeRate': 0.22004187183704,
#    'date': '2018-04-16',
#    'source': '@properties',
#    'postingIsRental': False,
#    'time': 1523836800000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': '@properties',
#     'infoString3': None,
#     'infoString1': '09861130'},
#    'pricePerSquareFoot': 350,
#    'buyerAgent': None,
#    'event': 'Listed for sale',
#    'price': 1750000},
#   {'priceChangeRate': 0,
#    'date': '2013-04-12',
#    'source': 'MRED as distributed by MLS GRID',
#    'postingIsRental': False,
#    'time': 1365724800000,
#    'sellerAgent': {'name': 'Allen Johnson',
#     'photo': None,
#     'profileUrl': '/profile/aljohn/'},
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'MRED as distributed by MLS GRID',
#     'infoString3': 'https://photos.zillowstatic.com/fp/1b0fc53ffc89ea17e1e382976aca4421-zillow_web_logo_inf_11.jpg',
#     'infoString1': '08177807'},
#    'pricePerSquareFoot': 287,
#    'buyerAgent': {'name': 'Allen Johnson',
#     'photo': None,
#     'profileUrl': '/profile/aljohn/'},
#    'event': 'Sold',
#    'price': 1434377}],
#  'favoriteCount': 74,
#  'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1162-Jahn-Elementary-School/',
#    'rating': 6,
#    'totalCount': None,
#    'distance': 0,
#    'assigned': None,
#    'name': 'Jahn Elementary School',
#    'studentsPerTeacher': None,
#    'isAssigned': None,
#    'size': None,
#    'level': 'Primary',
#    'grades': 'PK-8',
#    'type': 'Public'},
#   {'link': 'https://www.greatschools.org/illinois/chicago/1220-Lake-View-High-School/',
#    'rating': 3,
#    'totalCount': None,
#    'distance': 1.2,
#    'assigned': None,
#    'name': 'Lake View High School',
#    'studentsPerTeacher': None,
#    'isAssigned': None,
#    'size': None,
#    'level': 'High',
#    'grades': '9-12',
#    'type': 'Public'}],
#  'zestimateHighPercent': None,
#  'mlsid': '12006783',
#  'countyFIPS': '17031',
#  'city': 'Chicago',
#  'providerListingID': None,
#  'country': 'USA',
#  'currency': 'USD',
#  'isListedByOwner': None,
#  'contingentListingType': None}
