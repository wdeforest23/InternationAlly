# %% [markdown]
# # Search Property Listings
# 1. Model Setting
# 2. Create API filter from user's query
# 3. Get Property Listings from Zillow API
# 4. Generate advice with the property listings

# %% [markdown]
# ## 1. Model Setting - Gemini pro 1.0

# %%
# %pip list | grep google-cloud-aiplatform
# %pip list | grep google-api-core

# %%
# %pip install google-cloud-aiplatform==1.43.0
# %pip install google-api-core==2.17.1

# %%
import vertexai
from vertexai.preview.generative_models import GenerativeModel, ChatSession, Part
import vertexai.preview.generative_models as generative_models
# Out:
# 2024-04-30 20:19:14.169035: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-30 20:19:15.172397: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2024-04-30 20:19:15.172527: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2024-04-30 20:19:15.172537: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
vertexai.init(project="adsp-capstone-property-pilot", location="us-central1")

# %%
model = GenerativeModel("gemini-1.0-pro")
chat = model.start_chat()

def get_chat_response(chat: ChatSession, prompt: str) -> str:
    text_response = []
    responses = chat.send_message(prompt, stream=True)
    for chunk in responses:
        text_response.append(chunk.text)
    return "".join(text_response)

# %% [markdown]
# ### Test

# %%
prompt = "Hello."
print(get_chat_response(chat, prompt))
# Out:
# Hello! 👋 It's nice to meet you. What would you like to talk about today?

# %% [markdown]
# ## 2. Create API filter from user's query

# %%
def generate_prompt_apifilter(instruction, user_query):
    return instruction.replace("{USER_QUERY}", user_query)

# %%
instruction = """
### Instructions ###
I want you to act as a principal software engineer. You'll be given a task to determine the parameters of an API call based on the "User's query" below, 
please modify the conditions and create the appropriate API filter. Provide your answer only for the part within ‘{}’. 
Do not include any other explanations in your response. Read the below instructions.

— Filter Options (Optional, so not required if not specified in the User's query) —

1. location
Format: STRING(lowercase)
Example: santa monica, ca

*If not specifically mentioned, use 'chicago, il'.
*Do not alter the format from the above example. 
*If you want to search for a specific neighborhood like Chicago's West Loop, please specify it in the Filter option '16. keywords', not here.
Incorrect example: "location": "west loop, chicago, il"
Correct example: "location": "chicago, il", "keywords": "west loop"


2. status_type
For purchase or for rent
Format: STRING
Example:
ForSale
ForRent

3. home_type
Property type comma-separated or empty for all types
Format: STRING
Example(ForRent):
Townhomes
Houses
Apartments_Condos_Co-ops

Example(ForSale):
Multi-family
Apartments
Houses
Manufactured
Condos
LotsLand
Townhomes

*If it cannot be determined from the User's query, specification is not necessary.

4. minPrice
If status_type = ForSale you can filter by min price.
Format: NUMBER
Example: 200000

5. maxPrice
If status_type = ForSale you can filter by max price.
Format: NUMBER
Example: 900000

6. rentMinPrice
If status_type = ForRent you can filter by min rent price.
Format: NUMBER
Example: 2000

7. rentMaxPrice
If status_type = ForRent you can filter by max rent price.
Format: NUMBER
Example: 3000

8. bathsMin
Bathrooms min count
Format: NUMBER
Example: 2
* If a specific number of baths is specified, rather than a range, please enter the same number for both bathsMin and bathsMax.

9. bathsMax
Bathrooms max count
Format: NUMBER
Example: 3

10. bedsMin
Bedrooms min count
Format: NUMBER
Example: 1
* If a specific number of bedrooms is specified, rather than a range, please enter the same number for both bedsMin and bedsMax.

11. bedsMax
Bedrooms max count
Format: NUMBER
Example: 3

12. sqftMin
Square Feet min value
Format: NUMBER
Example: 600

13. sqftMax
Square Feet max value
Format: NUMBER
Example: 1500

14. buildYearMin
Year Built min value
Format: NUMBER
Example: 1980

15. buildYearMax
Year Built max value
Format: NUMBER
Example: 2023

16. keywords
Filter with keywords.
Format: STRING
Example1: ‘gym’
Example2: ‘West Loop’
Example3: ‘pet, pool, South Loop‘
*Not necessary if already specified in another filter or if there is no clear specification in user’s query. Specify conditions that cannot be specified in other filters by using keywords.

17. sort
Sorting criteria for the results
Always specify "Newest"


Now, use the following query to determine the appropriate parameters.

### Example query ###
I am looking for a one-bedroom.

### Example Output ###
{
"location":"chicago, il",
"bedsMin":"1",
"bedsMax":"1",
"sort":"Newest"
}

### Example query ###
I am looking for a rental in South Loop, Chicago, with at least one bedroom and a rent of $3000 or less per month.

### Example Output ###
{
"location": "chicago, il",
"status_type": "ForRent",
"rentMaxPrice": 3000,
"bedsMin": 1,
"keywords": "South Loop",
"sort":"Newest"
}

### Example query ###
I am looking for a rental in West Loop, Chicago, with one bedroom and a rent between $2000 and $2500.

### Example Output ###
{
"location": "chicago, il",
"status_type": "ForRent",
"rentMinPrice": 2500,
"rentMaxPrice": 3000,
"bedsMin": 1,
"bedsMax": 1,
"keywords": "West Loop",
"sort":"Newest"
}

### Example query ###
I want to buy a house in River North with at least two bedrooms.

### Example Output ###
{
"location":"chicago, il",
"status_type": "ForSale",
"keywords":"River North",
"bedsMin":"2",
"sort":"Newest"
}

### Example query ###
I am looking for a rental around Wicker Park in Chicago with a gym and a pool. It should be built within the last 10 years.

### Example Output ###
{
"location": "chicago, il",
"home_type": "Apartments_Condos_Co-ops",
"status_type": "ForRent",
"buildYearMin": 2014,
"keywords": "Wicker Park, gym, pool",
"sort":"Newest"
}

### Example query ###
I am looking for a rental with a balcony, over 700 sqft in size, and less than 5 years old, located near downtown.

### Example Output ###
{
"location": "chicago, il",
"status_type": "ForRent",
"sqftMin":"700",
"buildYearMin": 2019,
"keywords": "downtown, balcony",
"sort":"Newest"
}


### User’s query ###
{USER_QUERY}

### Output ###
"""

# %%
user_query = "I am looking for a two-bedroom."
print(generate_prompt_apifilter(instruction, user_query))
# Out:
# ### Instructions ###
# I want you to act as a principal software engineer. You'll be given a task to determine the parameters of an API call based on the "User's query" below,
# please modify the conditions and create the appropriate API filter. Provide your answer only for the part within ‘{}’.
# Do not include any other explanations in your response. Read the below instructions.
#
# — Filter Options (Optional, so not required if not specified in the User's query) —
#
# 1. location
# Format: STRING(lowercase)
# Example: santa monica, ca
#
# *If not specifically mentioned, use 'chicago, il'.
# *Do not alter the format from the above example.
# *If you want to search for a specific neighborhood like Chicago's West Loop, please specify it in the Filter option '16. keywords', not here.
# Incorrect example: "location": "west loop, chicago, il"
# Correct example: "location": "chicago, il", "keywords": "west loop"
#
#
# 2. status_type
# For purchase or for rent
# Format: STRING
# Example:
# ForSale
# ForRent
#
# 3. home_type
# Property type comma-separated or empty for all types
# Format: STRING
# Example(ForRent):
# Townhomes
# Houses
# Apartments_Condos_Co-ops
#
# Example(ForSale):
# Multi-family
# Apartments
# Houses
# Manufactured
# Condos
# LotsLand
# Townhomes
#
# *If it cannot be determined from the User's query, specification is not necessary.
#
# 4. minPrice
# If status_type = ForSale you can filter by min price.
# Format: NUMBER
# Example: 200000
#
# 5. maxPrice
# If status_type = ForSale you can filter by max price.
# Format: NUMBER
# Example: 900000
#
# 6. rentMinPrice
# If status_type = ForRent you can filter by min rent price.
# Format: NUMBER
# Example: 2000
#
# 7. rentMaxPrice
# If status_type = ForRent you can filter by max rent price.
# Format: NUMBER
# Example: 3000
#
# 8. bathsMin
# Bathrooms min count
# Format: NUMBER
# Example: 2
# * If a specific number of baths is specified, rather than a range, please enter the same number for both bathsMin and bathsMax.
#
# 9. bathsMax
# Bathrooms max count
# Format: NUMBER
# Example: 3
#
# 10. bedsMin
# Bedrooms min count
# Format: NUMBER
# Example: 1
# * If a specific number of bedrooms is specified, rather than a range, please enter the same number for both bedsMin and bedsMax.
#
# 11. bedsMax
# Bedrooms max count
# Format: NUMBER
# Example: 3
#
# 12. sqftMin
# Square Feet min value
# Format: NUMBER
# Example: 600
#
# 13. sqftMax
# Square Feet max value
# Format: NUMBER
# Example: 1500
#
# 14. buildYearMin
# Year Built min value
# Format: NUMBER
# Example: 1980
#
# 15. buildYearMax
# Year Built max value
# Format: NUMBER
# Example: 2023
#
# 16. keywords
# Filter with keywords.
# Format: STRING
# Example1: ‘gym’
# Example2: ‘West Loop’
# Example3: ‘pet, pool, South Loop‘
# *Not necessary if already specified in another filter or if there is no clear specification in user’s query. Specify conditions that cannot be specified in other filters by using keywords.
#
# 17. sort
# Sorting criteria for the results
# Always specify "Newest"
#
#
# Now, use the following query to determine the appropriate parameters.
#
# ### Example query ###
# I am looking for a one-bedroom.
#
# ### Example Output ###
# {
# "location":"chicago, il",
# "bedsMin":"1",
# "bedsMax":"1",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental in South Loop, Chicago, with at least one bedroom and a rent of $3000 or less per month.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "rentMaxPrice": 3000,
# "bedsMin": 1,
# "keywords": "South Loop",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental in West Loop, Chicago, with one bedroom and a rent between $2000 and $2500.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "rentMinPrice": 2500,
# "rentMaxPrice": 3000,
# "bedsMin": 1,
# "bedsMax": 1,
# "keywords": "West Loop",
# "sort":"Newest"
# }
#
# ### Example query ###
# I want to buy a house in River North with at least two bedrooms.
#
# ### Example Output ###
# {
# "location":"chicago, il",
# "status_type": "ForSale",
# "keywords":"River North",
# "bedsMin":"2",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental around Wicker Park in Chicago with a gym and a pool. It should be built within the last 10 years.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "home_type": "Apartments_Condos_Co-ops",
# "status_type": "ForRent",
# "buildYearMin": 2014,
# "keywords": "Wicker Park, gym, pool",
# "sort":"Newest"
# }
#
# ### Example query ###
# I am looking for a rental with a balcony, over 700 sqft in size, and less than 5 years old, located near downtown.
#
# ### Example Output ###
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "sqftMin":"700",
# "buildYearMin": 2019,
# "keywords": "downtown, balcony",
# "sort":"Newest"
# }
#
#
# ### User’s query ###
# I am looking for a two-bedroom.
#
# ### Output ###

# %% [markdown]
# ### Test

# %%
user_query = "I am looking for a two-bedroom."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "bedsMin":"2",
# "bedsMax":"2",
# "sort":"newest"
# }

# %%
user_query = "I am looking for a rental in Fulton Market, Chicago, with at least one bedroom and a rent of $3500 or less per month."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location": "chicago, il",
# "status_type": "ForRent",
# "rentMaxPrice": 3500,
# "bedsMin": 1,
# "keywords": "Fulton Market",
# "sort":"Newest"
# }

# %%
user_query = "I want to buy a house in Chinatown, Chicago with a minimum of 2 bathrooms and 2 bedrooms."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location":"chicago, il",
# "status_type": "ForSale",
# "keywords":"Chinatown",
# "bedsMin":"2",
# "bathsMin": "2",
# "sort":"Newest"
# }

# %%
user_query = "I am looking for a rental around Hyde Park with a gym and a pool. It should be built within the last 15 years."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location":"chicago, il",
# "home_type":"Apartments_Condos_Co-ops",
# "status_type":"ForRent",
# "buildYearMin":"2009",
# "keywords":"Hyde Park, gym, pool",
# "sort":"Newest"
# }

# %%
user_query = "I am looking for a rental in the Old Town area of Chicago with a balcony and a pool."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location":"chicago, il",
# "home_type":"Apartments_Condos_Co-ops",
# "status_type":"ForRent",
# "keywords": "Old Town, balcony, pool",
# "sort":"Newest"
# }

# %% [markdown]
# ## 3. Get Property Listings from Zillow API

# %% [markdown]
# ### Example - Extended Search endpoint

# %%
import requests

url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

headers = {
	"X-RapidAPI-Key": "YOUR_API_KEY",
	"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

# %%
querystring = {"location":"chicago, il", "status_type":"ForRent", "bathsMin":"1","bedsMin":"3", "keywords":"west", "sort":"Newest"}
response = requests.get(url, headers = headers, params = querystring)

# %%
response.json()
# Out:
# {'props': [{'units': [{'roomForRent': False, 'beds': '3', 'price': '$6,645+'},
#     {'roomForRent': False, 'beds': '4', 'price': '$12,000+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.929546--87.67204',
#    'longitude': -87.67204,
#    'buildingName': 'Norweta',
#    'address': '2611 N Hermitage Ave, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/norweta/BXQZ9R/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2412107390,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/65ca2c82486f45afdc0e1f156f6b514f-p_e.jpg',
#    'latitude': 41.929546},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': '3240 W Fulton Blvd, Chicago, IL 60624',
#    'variableData': None,
#    'zestimate': 300400,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/402d1685a0321ebbd7c3b2ceaecb3822-p_e.jpg',
#    'price': 2800,
#    'detailUrl': '/homedetails/3240-W-Fulton-Blvd-Chicago-IL-60624/158698100_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.7079,
#    'latitude': 41.886738,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '158698100',
#    'listingSubType': {},
#    'rentZestimate': 2949,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 2180,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '3251 W Evergreen Ave #2, Chicago, IL 60651',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/6253b10423f0bf3cee38170605b73c8b-p_e.jpg',
#    'price': 2300,
#    'detailUrl': '/homedetails/3251-W-Evergreen-Ave-2-Chicago-IL-60651/348824068_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.70887,
#    'latitude': 41.90529,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '348824068',
#    'listingSubType': {},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1337 W Walton St APT 1R, Chicago, IL 60642',
#    'variableData': None,
#    'unit': 'Apt 1R',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/30be956903274166767e4b0e3532b1b0-p_e.jpg',
#    'price': 3750,
#    'detailUrl': '/homedetails/1337-W-Walton-St-APT-1R-Chicago-IL-60642/2090576086_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.661026,
#    'latitude': 41.89866,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2090576086',
#    'listingSubType': {},
#    'rentZestimate': 3750,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1500,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': '9155 S Yates Blvd, Chicago, IL 60617',
#    'variableData': None,
#    'zestimate': 202900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/555ab979538dfd6334f8a2da9f351fdc-p_e.jpg',
#    'price': 2250,
#    'detailUrl': '/homedetails/9155-S-Yates-Blvd-Chicago-IL-60617/4166886_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.56542,
#    'latitude': 41.728283,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '4166886',
#    'listingSubType': {},
#    'rentZestimate': 2127,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$1,075+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.88085--87.74993',
#    'longitude': -87.74993,
#    'buildingName': '5100-04 W Madison St',
#    'address': '5100 W Madison St, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/5100.dash.04-w-madison-st/9S55MP/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2104513367,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3bcdb14b47768008832a4328cb4cf80e-p_e.jpg',
#    'latitude': 41.88085},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '4225 W Jackson Blvd #2, Chicago, IL 60624',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/796751adf3344f560259433ec07a9e1d-p_e.jpg',
#    'price': 2500,
#    'detailUrl': '/homedetails/4225-W-Jackson-Blvd-2-Chicago-IL-60624/345459552_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -87.73152,
#    'latitude': 41.87675,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '345459552',
#    'listingSubType': {},
#    'rentZestimate': 1800,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 2200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '4117 S Michigan Ave, Chicago, IL 60653',
#    'variableData': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b0b5b0ec0cabfa208d3c2c8e65ba42fc-p_e.jpg',
#    'price': 2550,
#    'detailUrl': '/homedetails/4117-S-Michigan-Ave-Chicago-IL-60653/2069905170_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.62263,
#    'latitude': 41.819584,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2069905170',
#    'listingSubType': {},
#    'rentZestimate': 2800,
#    'daysOnZillow': 0,
#    'bathrooms': 5,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': '12253 S Yale Ave, Chicago, IL 60628',
#    'variableData': None,
#    'zestimate': 160600,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/cc0faa00f19d5b6a8a135e9f60966c54-p_e.jpg',
#    'price': 2500,
#    'detailUrl': '/homedetails/12253-S-Yale-Ave-Chicago-IL-60628/4157475_zpid/',
#    'bedrooms': 6,
#    'contingentListingType': None,
#    'longitude': -87.6281,
#    'latitude': 41.67094,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '4157475',
#    'listingSubType': {},
#    'rentZestimate': 2282,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 2800,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '610 N May St #G, Chicago, IL 60642',
#    'variableData': None,
#    'unit': '# G',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ccafcc5a491e38681866b30e38c1a0d8-p_e.jpg',
#    'price': 2400,
#    'detailUrl': '/homedetails/610-N-May-St-G-Chicago-IL-60642/2072222697_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.65617,
#    'latitude': 41.892597,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2072222697',
#    'listingSubType': {},
#    'rentZestimate': 2350,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1300,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1957 W Erie St #1, Chicago, IL 60622',
#    'variableData': None,
#    'unit': '# 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f147f8c9aee65dac4ef96bc4e0d2d76f-p_e.jpg',
#    'price': 3150,
#    'detailUrl': '/homedetails/1957-W-Erie-St-1-Chicago-IL-60622/2069264763_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.67671,
#    'latitude': 41.892914,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2069264763',
#    'listingSubType': {},
#    'rentZestimate': 3800,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1800,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2250 W Adams St #2, Chicago, IL 60612',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': 577500,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/39071e1933be7e1275b7708bf5afb793-p_e.jpg',
#    'price': 4250,
#    'detailUrl': '/homedetails/2250-W-Adams-St-2-Chicago-IL-60612/2093405040_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.68346,
#    'latitude': 41.87891,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2093405040',
#    'listingSubType': {},
#    'rentZestimate': 2995,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 2400,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '3550 N Racine Ave APT 1, Chicago, IL 60657',
#    'variableData': {'text': '3D Tour', 'type': '3D_HOME'},
#    'unit': 'Apt 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/58037ee6ef9e6f215580b5baa357c405-p_e.jpg',
#    'price': 5400,
#    'detailUrl': '/homedetails/3550-N-Racine-Ave-APT-1-Chicago-IL-60657/2106959391_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.65937,
#    'latitude': 41.94683,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2106959391',
#    'listingSubType': {},
#    'rentZestimate': 4015,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 1780,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1201 W Addison St APT 3, Chicago, IL 60613',
#    'variableData': None,
#    'unit': 'Apt 3',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1e4a02480ee0f4a65e44602ce58b987b-p_e.jpg',
#    'price': 4300,
#    'detailUrl': '/homedetails/1201-W-Addison-St-APT-3-Chicago-IL-60613/2101129022_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.65939,
#    'latitude': 41.946865,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2101129022',
#    'listingSubType': {},
#    'rentZestimate': 2919,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2400 S Lawndale Ave #3, Chicago, IL 60623',
#    'variableData': None,
#    'unit': '# 3',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a18117cd6b0caa1612e579f9d9772e5e-p_e.jpg',
#    'price': 1595,
#    'detailUrl': '/homedetails/2400-S-Lawndale-Ave-3-Chicago-IL-60623/2078934332_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.717674,
#    'latitude': 41.84781,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2078934332',
#    'listingSubType': {},
#    'rentZestimate': 1575,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1100,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$4,020+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.895016--87.65372',
#    'longitude': -87.65372,
#    'buildingName': 'Avenir',
#    'address': '730 N Milwaukee Ave, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/avenir/BZ3D2d/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2421358110,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e32e8dcbeceeadf203d1890a51dd8edb-p_e.jpg',
#    'latitude': 41.895016},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1846 S Loomis St #402, Chicago, IL 60608',
#    'variableData': None,
#    'unit': '# 402',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f300e9fedc4b9ab88b7a7e32c203ee32-p_e.jpg',
#    'price': 2150,
#    'detailUrl': '/homedetails/1846-S-Loomis-St-402-Chicago-IL-60608/347194907_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.66157,
#    'latitude': 41.856377,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '347194907',
#    'listingSubType': {},
#    'rentZestimate': 2149,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1254,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2312 S Seeley Ave #2, Chicago, IL 60608',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/9a46d07c60273ebd8bd73fcc05a65462-p_e.jpg',
#    'price': 3000,
#    'detailUrl': '/homedetails/2312-S-Seeley-Ave-2-Chicago-IL-60608/2079985241_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.67746,
#    'latitude': 41.849895,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2079985241',
#    'listingSubType': {},
#    'rentZestimate': 1992,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 2450,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$7,013+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.86681--87.62358',
#    'longitude': -87.62358,
#    'buildingName': 'NEMA Chicago',
#    'address': '1210 S Indiana Ave, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/nema-chicago/9RwqTm/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2103778973,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/35f6b1437825b0cf43201316158e8000-p_e.jpg',
#    'latitude': 41.86681},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$3,995+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.882286--87.66354',
#    'longitude': -87.66354,
#    'buildingName': '25 N Bishop',
#    'address': '25 N Bishop St, Chicago, IL',
#    'detailUrl': '/b/25-n-bishop-chicago-il-Br9fq5/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2497061171,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/287a20f083fb57b4afc5aab815ec2485-p_e.jpg',
#    'latitude': 41.882286},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '612 N May St #G, Chicago, IL 60642',
#    'variableData': None,
#    'unit': '# G',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ccafcc5a491e38681866b30e38c1a0d8-p_e.jpg',
#    'price': 2400,
#    'detailUrl': '/homedetails/612-N-May-St-G-Chicago-IL-60642/2109694949_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.656166,
#    'latitude': 41.89267,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2109694949',
#    'listingSubType': {},
#    'rentZestimate': 2674,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1500,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '6729 S Ridgeland Ave APT 3, Chicago, IL 60649',
#    'variableData': None,
#    'unit': 'Apt 3',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/732d5e8e07dd9baf6ceb5ff3b57f140b-p_e.jpg',
#    'price': 1900,
#    'detailUrl': '/homedetails/6729-S-Ridgeland-Ave-APT-3-Chicago-IL-60649/348763136_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.582275,
#    'latitude': 41.772522,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '348763136',
#    'listingSubType': {},
#    'rentZestimate': None,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1800,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2131 N Leavitt St #3, Chicago, IL 60647',
#    'variableData': None,
#    'unit': '# 3',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/45f3a5464425bf16089a073cc35c29ec-p_e.jpg',
#    'price': 3100,
#    'detailUrl': '/homedetails/2131-N-Leavitt-St-3-Chicago-IL-60647/2118278187_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.68232,
#    'latitude': 41.920902,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2118278187',
#    'listingSubType': {},
#    'rentZestimate': 3240,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1600,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '6729 S Ridgeland Ave APT 1, Chicago, IL 60649',
#    'variableData': None,
#    'unit': 'Apt 1',
#    'zestimate': 597200,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/732d5e8e07dd9baf6ceb5ff3b57f140b-p_e.jpg',
#    'price': 1800,
#    'detailUrl': '/homedetails/6729-S-Ridgeland-Ave-APT-1-Chicago-IL-60649/2101396360_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.58227,
#    'latitude': 41.772514,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2101396360',
#    'listingSubType': {},
#    'rentZestimate': 1995,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1725,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '5401-5403 S. Woodlawn Avenue, 5401-5403 S Woodlawn Ave #5401-1, Chicago, IL 60615',
#    'variableData': None,
#    'unit': '# 5401-1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/813715fabe31fdd2a77ba247051eef32-p_e.jpg',
#    'price': 3495,
#    'detailUrl': '/apartments/chicago-il/5401.dash.5403-s.-woodlawn-avenue/5Xgfp9/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.59663,
#    'latitude': 41.79999,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2071670483',
#    'listingSubType': {},
#    'rentZestimate': 2949,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1420,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'CONDO',
#    'lotAreaValue': None,
#    'address': '229 S Racine Ave #2, Chicago, IL 60607',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b8e61d03028301dcbca788deab528c42-p_e.jpg',
#    'price': 3200,
#    'detailUrl': '/homedetails/229-S-Racine-Ave-2-Chicago-IL-60607/2055445595_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.656624,
#    'latitude': 41.878185,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2055445595',
#    'listingSubType': {},
#    'rentZestimate': 4500,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1500,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2855 W Palmer St UNIT 1, Chicago, IL 60647',
#    'variableData': None,
#    'unit': 'Unit 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f0df77d94f4c5e5af28f6c7966ac686d-p_e.jpg',
#    'price': 4000,
#    'detailUrl': '/homedetails/2855-W-Palmer-St-UNIT-1-Chicago-IL-60647/347975768_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.69953,
#    'latitude': 41.921467,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '347975768',
#    'listingSubType': {},
#    'rentZestimate': 2650,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1550,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1504 W Cullom Ave #A2, Chicago, IL 60613',
#    'variableData': None,
#    'unit': '# A2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/9c14a4ccffcd027ffd40d60b1266083f-p_e.jpg',
#    'price': 4275,
#    'detailUrl': '/homedetails/1504-W-Cullom-Ave-A2-Chicago-IL-60613/2073853632_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.66811,
#    'latitude': 41.959957,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2073853632',
#    'listingSubType': {},
#    'rentZestimate': 3599,
#    'daysOnZillow': 0,
#    'bathrooms': 2.5,
#    'livingArea': 1800,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '4734 S Kildare Ave #2, Chicago, IL 60632',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3e7358cce3b8100167e5293b511f0dc5-p_e.jpg',
#    'price': 1575,
#    'detailUrl': '/homedetails/4734-S-Kildare-Ave-2-Chicago-IL-60632/2058742577_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.73125,
#    'latitude': 41.806747,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2058742577',
#    'listingSubType': {},
#    'rentZestimate': 1674,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1100,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '6651 N Rockwell St #2, Chicago, IL 60645',
#    'variableData': None,
#    'unit': '# 2',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/15b92afe0366d891393d59a5866307b3-p_e.jpg',
#    'price': 2100,
#    'detailUrl': '/homedetails/6651-N-Rockwell-St-2-Chicago-IL-60645/2071905782_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.69452,
#    'latitude': 42.002796,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2071905782',
#    'listingSubType': {},
#    'rentZestimate': 1963,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1354,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '3826 W Monroe St, Chicago, IL 60624',
#    'variableData': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1628de89aa481ce8956c7328a1e016af-p_e.jpg',
#    'price': 1650,
#    'detailUrl': '/homedetails/3826-W-Monroe-St-Chicago-IL-60624/2076380588_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.72189,
#    'latitude': 41.88009,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2076380588',
#    'listingSubType': {},
#    'rentZestimate': 1462,
#    'daysOnZillow': 0,
#    'bathrooms': 1,
#    'livingArea': 1100,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$4,250+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.89068--87.67218',
#    'longitude': -87.67218,
#    'buildingName': None,
#    'address': '1801 W Grand Ave, Chicago, IL',
#    'detailUrl': '/b/1801-w-grand-ave-chicago-il-9S23bN/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2104156205,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d83fc2d985236900f7d83f13e298c3d7-p_e.jpg',
#    'latitude': 41.89068},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2518 N Mozart St #1, Chicago, IL 60647',
#    'variableData': None,
#    'unit': '# 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1b8144f8975975537c57fda58d9f0468-p_e.jpg',
#    'price': 3300,
#    'detailUrl': '/homedetails/2518-N-Mozart-St-1-Chicago-IL-60647/2083528246_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.69906,
#    'latitude': 41.927223,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2083528246',
#    'listingSubType': {},
#    'rentZestimate': 3099,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '2919 N Pine Grove Ave APT 2, Chicago, IL 60657',
#    'variableData': None,
#    'unit': 'Apt 2',
#    'zestimate': 547900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2d2800a5ec89a6197f972238a45e0f3b-p_e.jpg',
#    'price': 4295,
#    'detailUrl': '/homedetails/2919-N-Pine-Grove-Ave-APT-2-Chicago-IL-60657/3720979_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.641525,
#    'latitude': 41.93467,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '3720979',
#    'listingSubType': {},
#    'rentZestimate': 4450,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1900,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$2,395+'},
#     {'roomForRent': False, 'beds': '4', 'price': '$3,795+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.893543--87.6694',
#    'longitude': -87.6694,
#    'buildingName': None,
#    'address': '1656 W Erie St, Chicago, IL',
#    'detailUrl': '/b/1656-w-erie-st-chicago-il-9S22wC/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 2104154579,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7a1c074bcf4bc10bf043123d925748a2-p_e.jpg',
#    'latitude': 41.893543},
#   {'units': [{'roomForRent': False, 'beds': '4', 'price': '$3,600+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.897114--87.65413',
#    'longitude': -87.65413,
#    'buildingName': None,
#    'address': '1059 W Fry St, Chicago, IL',
#    'detailUrl': '/b/1059-w-fry-st-chicago-il-5XjLzn/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 1001469094,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f3daa5f50cfe0d7855623a070e8e255d-p_e.jpg',
#    'latitude': 41.897114},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '35 S Racine Ave APT 4NW, Chicago, IL 60607',
#    'variableData': None,
#    'unit': 'Apt 4NW',
#    'zestimate': 709400,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a428249f6bb761dfddf8ac5ec5d0f2b6-p_e.jpg',
#    'price': 4200,
#    'detailUrl': '/homedetails/35-S-Racine-Ave-APT-4NW-Chicago-IL-60607/80842984_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.6569,
#    'latitude': 41.88057,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '80842984',
#    'listingSubType': {},
#    'rentZestimate': 3884,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1650,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '3728 N Magnolia Ave #11, Chicago, IL 60613',
#    'variableData': None,
#    'unit': '# 11',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b63a6461f72e61d2674786d0782032c5-p_e.jpg',
#    'price': 5875,
#    'detailUrl': '/homedetails/3728-N-Magnolia-Ave-11-Chicago-IL-60613/347305376_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.660805,
#    'latitude': 41.949833,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '347305376',
#    'listingSubType': {},
#    'rentZestimate': 4662,
#    'daysOnZillow': 0,
#    'bathrooms': 4,
#    'livingArea': 2000,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'units': [{'roomForRent': False, 'beds': '3', 'price': '$3,355+'}],
#    'listingStatus': 'FOR_RENT',
#    'zpid': '41.886066--87.656',
#    'longitude': -87.656,
#    'buildingName': None,
#    'address': '216 N May St, Chicago, IL',
#    'detailUrl': '/apartments/chicago-il/216-n-may-st/DZ7r/',
#    'isBuilding': True,
#    'hasImage': True,
#    'lotId': 1244004,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e5171f5156e06eeb43afb37c0e1810e8-p_e.jpg',
#    'latitude': 41.886066},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': None,
#    'address': '238 S Ashland Ave, Chicago, IL 60607',
#    'variableData': None,
#    'zestimate': 569700,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/bc5d04cbc3034843a272f004212e561e-p_e.jpg',
#    'price': 3800,
#    'detailUrl': '/homedetails/238-S-Ashland-Ave-Chicago-IL-60607/2119049294_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -87.66707,
#    'latitude': 41.877735,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2119049294',
#    'listingSubType': {},
#    'rentZestimate': 3614,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1800,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'APARTMENT',
#    'lotAreaValue': None,
#    'address': '1717 W Roscoe St #1, Chicago, IL 60657',
#    'variableData': None,
#    'unit': '# 1',
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/03e22f82c0b577eea9878547c0b820e9-p_e.jpg',
#    'price': 4300,
#    'detailUrl': '/homedetails/1717-W-Roscoe-St-1-Chicago-IL-60657/2082717789_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -87.67195,
#    'latitude': 41.94304,
#    'listingStatus': 'FOR_RENT',
#    'zpid': '2082717789',
#    'listingSubType': {},
#    'rentZestimate': 4184,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 1750,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': None,
#    'hasImage': True}],
#  'resultsPerPage': 41,
#  'totalPages': 9,
#  'totalResultCount': 366,
#  'schools': {},
#  'currentPage': 1}

# %%
def extract_properties(response, n, fields):
    """
    Extracts and returns the top 'n' properties from a given API response
    based on the specified fields, appending the base URL to 'detailUrl'.
    
    Parameters:
    - response: The response object from an API call.
    - n: The number of top properties to extract.
    - fields: A list of strings representing the fields to extract from each property.
    
    Returns:
    - A list of dictionaries, each representing a property with only the specified fields.
    """
    base_url = "https://www.zillow.com"
    try:
        # Convert the response to JSON format if it's not already a dictionary
        if not isinstance(response, dict):
            response = response.json()

        # Extract the top 'n' properties based on the specified fields
        top_properties = []
        for prop in response['props'][:n]:
            extracted_prop = {field: (base_url + prop['detailUrl'] if field == 'detailUrl' else prop.get(field, None)) for field in fields}
            top_properties.append(extracted_prop)

        return top_properties

    except Exception as e:
        print("An error occurred:", e)
        return []  # Return an empty list in case of an error

# %%
# Define fields to extract
fields = ["propertyType", "address", "price", "bedrooms", "bathrooms", "detailUrl", "imgSrc"]

# %%
# Get top 3 properties with selected fields
top_properties = extract_properties(response, 3, fields)
top_properties
# Out:
# [{'propertyType': None,
#   'address': '2611 N Hermitage Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/apartments/chicago-il/norweta/BXQZ9R/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/65ca2c82486f45afdc0e1f156f6b514f-p_e.jpg'},
#  {'propertyType': 'SINGLE_FAMILY',
#   'address': '3240 W Fulton Blvd, Chicago, IL 60624',
#   'price': 2800,
#   'bedrooms': 5,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/3240-W-Fulton-Blvd-Chicago-IL-60624/158698100_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/402d1685a0321ebbd7c3b2ceaecb3822-p_e.jpg'},
#  {'propertyType': 'APARTMENT',
#   'address': '3251 W Evergreen Ave #2, Chicago, IL 60651',
#   'price': 2300,
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/3251-W-Evergreen-Ave-2-Chicago-IL-60651/348824068_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/6253b10423f0bf3cee38170605b73c8b-p_e.jpg'}]

# %% [markdown]
# ### Example - Property details endpoint

# %% [markdown]
# #### Description

# %%
top_properties[1]['detailUrl']
# Out:
# 'https://www.zillow.com/homedetails/3240-W-Fulton-Blvd-Chicago-IL-60624/158698100_zpid/'

# %%
# Endpoint
url_details = "https://zillow-com1.p.rapidapi.com/property"

# URL example
property_url = top_properties[1]['detailUrl']

querystring = {"property_url":property_url}
response = requests.get(url_details, headers = headers, params = querystring)

# %%
response.json()
# Out:
# {'listingProvider': {'enhancedVideoURL': None,
#   'showNoContactInfoMessage': False,
#   'postingGroupName': None,
#   'isZRMSourceText': None,
#   'showLogos': None,
#   'logos': {},
#   'sourceText': 'Source: Zillow Rentals',
#   'title': 'Listing Provided by',
#   'disclaimerText': None,
#   'postingWebsiteURL': None,
#   'agentLicenseNumber': None,
#   'postingWebsiteLinkText': 'See listing website',
#   'enhancedDescriptionText': None,
#   'agentName': None},
#  'zpid': 158698100,
#  'buildingPermits': None,
#  'propertyTaxRate': 1.89,
#  'contact_recipients': {},
#  'zipcode': '60624',
#  'openHouseSchedule': {},
#  'longitude': -87.7079,
#  'zestimateLowPercent': '11',
#  'address': {'community': None,
#   'city': 'Chicago',
#   'state': 'IL',
#   'neighborhood': None,
#   'subdivision': None,
#   'streetAddress': '3240 W Fulton Blvd',
#   'zipcode': '60624'},
#  'cityId': 17426,
#  'timeOnZillow': '1 hour',
#  'url': '/homedetails/3240-W-Fulton-Blvd-Chicago-IL-60624/158698100_zpid/',
#  'zestimate': 300400,
#  'imgSrc': 'https://photos.zillowstatic.com/fp/402d1685a0321ebbd7c3b2ceaecb3822-p_d.jpg',
#  'description': "Hello!\n\nThis rehabbed house has central heat & air, exposed bricks, dark hardwood floors, new stainless steel kitchen appliances, in-unit washer and dryer, and plenty of storage space in the basement. It also has a firepit in the backyard for bonfires. \n\nAbout the neighborhood:\nThis unfurnished house is in the heart of East Garfield Park, less than a five-minute walk from the Kedzie Green line and Metra stations, as well as the nearest 52 Kedzie, 82 Homan and 94 California bus stops. There is plenty of space downstairs for your bikes, so you can get around very easily from here without a car. If you do have a car though, you can have a spot out back for $25/month each, or use one of the parking spots on the street out front. \n\nThis house is within a few blocks of cool neighborhood spots like Passion House Coffee, Breakthrough Community Center, Inspiration Kitchens, and the Garfield Park Conservatory, and just a short bike ride away from everything in Humboldt Park, Ukranian Village and West Loop. \n\nAbout the dollar bills/paperwork:\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent. \n\nIf all that sounds good to you, send us a message so we can share details with you about our open house this Sunday, May 5.\n\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent.",
#  'price': 2800,
#  'livingAreaValue': 2180,
#  'resoFacts': {'hasAttachedProperty': False,
#   'frontageType': None,
#   'poolFeatures': None,
#   'flooring': ['Hardwood'],
#   'builderModel': None,
#   'accessibilityFeatures': None,
#   'hasGarage': False,
#   'hasPetsAllowed': True,
#   'bodyType': None,
#   'topography': None,
#   'landLeaseExpirationDate': None,
#   'hasAdditionalParcels': False,
#   'waterViewYN': None,
#   'livingQuarters': {},
#   'atAGlanceFacts': [{'factValue': 'Sat Jun 1 2024',
#     'factLabel': 'Date available'},
#    {'factValue': 'Single Family Residence', 'factLabel': 'Type'},
#    {'factValue': 'Central Air', 'factLabel': 'Cooling'},
#    {'factValue': None, 'factLabel': 'Heating'},
#    {'factValue': 'Cats, Small Dogs', 'factLabel': 'Pets'},
#    {'factValue': 'Off Street', 'factLabel': 'Parking'},
#    {'factValue': 'In Unit', 'factLabel': 'Laundry'},
#    {'factValue': '$1,250', 'factLabel': 'Deposit & fees'},
#    {'factValue': '$1,250', 'factLabel': 'One-time fees'}],
#   'offerReviewDate': None,
#   'horseYN': None,
#   'view': {},
#   'buyerAgencyCompensationType': None,
#   'rooms': {},
#   'belowGradeFinishedArea': None,
#   'feesAndDues': [{'phone': None,
#     'name': None,
#     'fee': '$1,250',
#     'type': 'Deposit'}],
#   'cityRegion': 'Chicago',
#   'subAgencyCompensation': None,
#   'hasPrivatePool': None,
#   'associationFeeIncludes': None,
#   'waterSource': None,
#   'carportParkingCapacity': None,
#   'transactionBrokerCompensationType': None,
#   'hasFireplace': None,
#   'gas': None,
#   'sewer': None,
#   'elevationUnits': None,
#   'roadSurfaceType': None,
#   'mainLevelBedrooms': None,
#   'numberOfUnitsVacant': None,
#   'hasWaterfrontView': None,
#   'bathroomsOneQuarter': None,
#   'lotSize': None,
#   'subAgencyCompensationType': None,
#   'entryLevel': None,
#   'irrigationWaterRightsAcres': None,
#   'greenWaterConservation': None,
#   'stories': None,
#   'bathrooms': 2,
#   'numberOfUnitsInCommunity': None,
#   'listingTerms': None,
#   'otherParking': ['Contact manager'],
#   'associationFee': None,
#   'marketingType': None,
#   'greenEnergyEfficient': None,
#   'greenSustainability': None,
#   'heating': None,
#   'associationPhone': None,
#   'greenBuildingVerificationType': None,
#   'hasAttachedGarage': False,
#   'bedrooms': 5,
#   'architecturalStyle': None,
#   'listingId': None,
#   'structureType': None,
#   'interiorFeatures': None,
#   'horseAmenities': None,
#   'electric': None,
#   'otherFacts': {},
#   'lotFeatures': None,
#   'roofType': None,
#   'compensationBasedOn': None,
#   'greenEnergyGeneration': None,
#   'taxAnnualAmount': 53,
#   'daysOnZillow': 0,
#   'listAOR': None,
#   'hasHeating': None,
#   'elementarySchool': None,
#   'constructionMaterials': {},
#   'basementYN': None,
#   'hoaFeeTotal': None,
#   'appliances': ['Dishwasher', 'Dryer', 'Washer'],
#   'virtualTour': None,
#   'bathroomsPartial': None,
#   'fencing': None,
#   'yearBuiltEffective': None,
#   'foundationDetails': {},
#   'buildingName': None,
#   'hasAssociation': None,
#   'isSeniorCommunity': None,
#   'propertySubType': ['Single Family Residence'],
#   'propertyCondition': None,
#   'hasCarport': False,
#   'canRaiseHorses': False,
#   'hasLandLease': False,
#   'communityFeatures': None,
#   'parcelNumber': '1611405075',
#   'elevation': None,
#   'lotSizeDimensions': None,
#   'buildingAreaSource': None,
#   'contingency': None,
#   'yearBuilt': None,
#   'otherStructures': None,
#   'livingArea': '2,180 sqft',
#   'bathroomsFull': 2,
#   'livingAreaRangeUnits': None,
#   'incomeIncludes': None,
#   'highSchool': None,
#   'aboveGradeFinishedArea': None,
#   'isNewConstruction': None,
#   'inclusions': None,
#   'hasHomeWarranty': False,
#   'additionalFeeInfo': None,
#   'windowFeatures': None,
#   'ownership': None,
#   'woodedArea': None,
#   'middleOrJuniorSchoolDistrict': None,
#   'associationPhone2': None,
#   'exteriorFeatures': ['Bicycle storage'],
#   'buildingFeatures': None,
#   'frontageLength': None,
#   'buildingArea': None,
#   'associationAmenities': None,
#   'bathroomsHalf': None,
#   'hasCooling': True,
#   'additionalParcelsDescription': None,
#   'parkingFeatures': ['Off Street'],
#   'foundationArea': None,
#   'zoning': None,
#   'hoaFee': None,
#   'livingAreaRange': None,
#   'zoningDescription': None,
#   'developmentStatus': None,
#   'availabilityDate': 1717200000000,
#   'waterfrontFeatures': None,
#   'waterBodyName': None,
#   'utilities': None,
#   'entryLocation': None,
#   'totalActualRent': None,
#   'hasView': False,
#   'subdivisionName': None,
#   'securityFeatures': None,
#   'attic': None,
#   'fireplaceFeatures': None,
#   'mainLevelBathrooms': None,
#   'doorFeatures': None,
#   'ownershipType': None,
#   'associationName': None,
#   'associations': {},
#   'waterView': None,
#   'garageParkingCapacity': None,
#   'cropsIncludedYN': None,
#   'laundryFeatures': ['In Unit'],
#   'buyerAgencyCompensation': None,
#   'greenIndoorAirQuality': None,
#   'homeType': 'SingleFamily',
#   'spaFeatures': None,
#   'municipality': None,
#   'bathroomsThreeQuarter': None,
#   'hasSpa': False,
#   'basement': None,
#   'associationFee2': None,
#   'cooling': ['Central Air'],
#   'openParkingCapacity': None,
#   'associationName2': None,
#   'hasRentControl': None,
#   'elementarySchoolDistrict': None,
#   'otherEquipment': None,
#   'commonWalls': None,
#   'specialListingConditions': None,
#   'furnished': False,
#   'vegetation': None,
#   'patioAndPorchFeatures': None,
#   'bathroomsFloat': 2,
#   'builderName': None,
#   'highSchoolDistrict': None,
#   'transactionBrokerCompensation': None,
#   'storiesTotal': None,
#   'cumulativeDaysOnMarket': None,
#   'fireplaces': None,
#   'irrigationWaterRightsYN': None,
#   'exclusions': None,
#   'hasOpenParking': False,
#   'landLeaseAmount': None,
#   'coveredParkingCapacity': None,
#   'middleOrJuniorSchool': None,
#   'hasElectricOnProperty': None,
#   'onMarketDate': 1714435200000,
#   'pricePerSquareFoot': 1,
#   'parkingCapacity': 0,
#   'levels': None},
#  'taxHistory': [{'time': 1619814338013,
#    'valueIncreaseRate': 0.29099074,
#    'taxIncreaseRate': 0.165305,
#    'taxPaid': 4640.07,
#    'value': 22999},
#   {'time': 1588278338013,
#    'valueIncreaseRate': -0.10002526,
#    'taxIncreaseRate': -0.0021226294,
#    'taxPaid': 3981.85,
#    'value': 17815},
#   {'time': 1556655938013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.017201819,
#    'taxPaid': 3990.32,
#    'value': 19795},
#   {'time': 1525119938013,
#    'valueIncreaseRate': 0.18405312,
#    'taxIncreaseRate': 0.08628919,
#    'taxPaid': 3922.84,
#    'value': 19795},
#   {'time': 1493583938013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.07848456,
#    'taxPaid': 3611.23,
#    'value': 16718},
#   {'time': 1462047938013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.093004405,
#    'taxPaid': 3348.43,
#    'value': 16718},
#   {'time': 1430425538013,
#    'valueIncreaseRate': 0.04168484,
#    'taxIncreaseRate': 0.02882448,
#    'taxPaid': 3063.51,
#    'value': 16718},
#   {'time': 1398889538013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.020137735,
#    'taxPaid': 2977.68,
#    'value': 16049},
#   {'time': 1367353538013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.013531569,
#    'taxPaid': 2918.9,
#    'value': 16049},
#   {'time': 1335817538013,
#    'valueIncreaseRate': -0.20364214,
#    'taxIncreaseRate': -0.11813863,
#    'taxPaid': 2879.93,
#    'value': 16049},
#   {'time': 1304195138013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': -0.004153285,
#    'taxPaid': 3265.74,
#    'value': 20153},
#   {'time': 1272659138013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.04352808,
#    'taxPaid': 3279.36,
#    'value': 20153},
#   {'time': 1241123138013,
#    'valueIncreaseRate': -0.09745175,
#    'taxIncreaseRate': -0.018888129,
#    'taxPaid': 3142.57,
#    'value': 20153},
#   {'time': 1209587138013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.010037108,
#    'taxPaid': 3203.07,
#    'value': 22329},
#   {'time': 1177964738013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': -0.010681705,
#    'taxPaid': 3171.24,
#    'value': 22329},
#   {'time': 1146428738013,
#    'valueIncreaseRate': 0.45494235,
#    'taxIncreaseRate': 0.2782499,
#    'taxPaid': 3205.48,
#    'value': 22329},
#   {'time': 1114892738013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.010187656,
#    'taxPaid': 2507.71,
#    'value': 15347},
#   {'time': 1083356738013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.022194548,
#    'taxPaid': 2482.42,
#    'value': 15347},
#   {'time': 1051734338013,
#    'valueIncreaseRate': 0.7970726,
#    'taxIncreaseRate': 0.58284014,
#    'taxPaid': 2428.52,
#    'value': 15347},
#   {'time': 1020198338013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.35969514,
#    'taxPaid': 1534.28,
#    'value': 8540},
#   {'time': 988662338013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.85977525,
#    'taxPaid': 1128.4,
#    'value': 8540},
#   {'time': 957126338013,
#    'valueIncreaseRate': 0.6556805,
#    'taxIncreaseRate': 0,
#    'taxPaid': 606.74,
#    'value': 8540},
#   {'time': 925503938013,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 5158}],
#  'brokerId': None,
#  'stateId': 21,
#  'streetAddress': '3240 W Fulton Blvd',
#  'listingSubType': {'is_FSBA': False,
#   'is_comingSoon': False,
#   'is_newHome': False,
#   'is_pending': False,
#   'is_forAuction': False,
#   'is_foreclosure': False,
#   'is_bankOwned': False,
#   'is_openHouse': False,
#   'is_FSBO': False},
#  'solarPotential': None,
#  'dateSold': None,
#  'countyId': 139,
#  'timeZone': 'America/Chicago',
#  'homeType': 'SINGLE_FAMILY',
#  'livingAreaUnits': 'sqft',
#  'comingSoonOnMarketDate': None,
#  'rentZestimate': 2949,
#  'bathrooms': 2,
#  'annualHomeownersInsurance': 12,
#  'state': 'IL',
#  'propertyTypeDimension': 'Single Family',
#  'building': None,
#  'listed_by': {'agent_reason': None,
#   'zpro': None,
#   'recent_sales': None,
#   'review_count': None,
#   'display_name': None,
#   'badge_type': None,
#   'business_name': None,
#   'rating_average': None,
#   'phone': None,
#   'zuid': None,
#   'image_url': None},
#  'yearBuilt': None,
#  'brokerageName': None,
#  'pageViewCount': 33,
#  'county': 'Cook County',
#  'mortgageRates': {'thirtyYearFixedRate': 6.62},
#  'attributionInfo': {'buyerAgentName': None,
#   'mlsName': 'Zillow Rentals',
#   'coAgentLicenseNumber': None,
#   'listingOffices': {},
#   'lastUpdated': '2024-04-30 12:30:33',
#   'buyerAgentMemberStateLicense': None,
#   'brokerName': None,
#   'listingAgreement': None,
#   'infoString10': '',
#   'trueStatus': None,
#   'infoString3': None,
#   'agentEmail': None,
#   'agentName': None,
#   'attributionTitle': None,
#   'mlsId': None,
#   'coAgentName': None,
#   'coAgentNumber': None,
#   'infoString5': None,
#   'listingAgents': {},
#   'agentPhoneNumber': None,
#   'agentLicenseNumber': None,
#   'providerLogo': None,
#   'infoString16': None,
#   'buyerBrokerageName': None,
#   'mlsDisclaimer': '',
#   'brokerPhoneNumber': None,
#   'lastChecked': '2024-04-30 12:30:33'},
#  'monthlyHoaFee': None,
#  'homeStatus': 'FOR_RENT',
#  'homeFacts': None,
#  'latitude': 41.886738,
#  'datePosted': '2024-04-30',
#  'bedrooms': 5,
#  'nearbyHomes': [{'livingArea': 1100,
#    'livingAreaValue': 1100,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/e5554c105e57633af3ffe1ad656aa876-p_c.jpg'}],
#    'zpid': 343768123,
#    'longitude': -87.7082,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3248 W Fulton Blvd #1',
#     'zipcode': '60624'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 2200,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.886734},
#   {'livingArea': 1100,
#    'livingAreaValue': 1100,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/35edeaf5bc45b9c17d51abe487e987d8-p_c.jpg'}],
#    'zpid': 347968619,
#    'longitude': -87.7082,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3248 W Fulton Blvd #2',
#     'zipcode': '60624'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 2275,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.886734},
#   {'livingArea': 1100,
#    'livingAreaValue': 1100,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/4580f78a0e439644f7e90199bb2a25cd-p_c.jpg'}],
#    'zpid': 2056827324,
#    'longitude': -87.709,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3302 W Fulton Blvd UNIT 102',
#     'zipcode': '60624'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 1625,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.88673},
#   {'livingArea': 1400,
#    'livingAreaValue': 1400,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/d6a2fe9014ea7ccef23a7619bf131956-p_c.jpg'}],
#    'zpid': 340734579,
#    'longitude': -87.708595,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3261 W Fulton Blvd #1',
#     'zipcode': '60624'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 2449,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.886044},
#   {'livingArea': 700,
#    'livingAreaValue': 700,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/abd99def209046f950df93f1983273e1-p_c.jpg'}],
#    'zpid': 348787039,
#    'longitude': -87.705956,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '327 N Kedzie Ave #3',
#     'zipcode': '60612'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 2245,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.887333},
#   {'livingArea': 1500,
#    'livingAreaValue': 1500,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/231401b04665a57ba5205308cadcaf65-p_c.jpg'}],
#    'zpid': 2122061125,
#    'longitude': -87.71052,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3344 W Fulton Blvd',
#     'zipcode': '60624'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 2200,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.886703},
#   {'livingArea': 1700,
#    'livingAreaValue': 1700,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/ffce87160ba3f8e0732c410b671bbbb2-p_c.jpg'}],
#    'zpid': 2063478234,
#    'longitude': -87.70835,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3256 W Washington Blvd #G',
#     'zipcode': '60624'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 1700,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.883045},
#   {'livingArea': 800,
#    'livingAreaValue': 800,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/4e11cc23c83801bf7b7de4e490363cc2-p_c.jpg'}],
#    'zpid': 347949926,
#    'longitude': -87.70274,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3034 W Walnut St #1',
#     'zipcode': '60612'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 1675,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.8857},
#   {'livingArea': 1500,
#    'livingAreaValue': 1500,
#    'lotAreaUnits': 'sqft',
#    'lotAreaValue': None,
#    'lotSize': None,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/a706877a5044169e01d40b2cbf0889c7-p_c.jpg'}],
#    'zpid': 344569706,
#    'longitude': -87.71326,
#    'livingAreaUnits': 'Square Feet',
#    'address': {'city': 'Chicago',
#     'state': 'IL',
#     'streetAddress': '3452 W Walnut St #2',
#     'zipcode': '60624'},
#    'livingAreaUnitsShort': 'sqft',
#    'price': 2100,
#    'homeType': 'APARTMENT',
#    'homeStatus': 'FOR_RENT',
#    'currency': 'USD',
#    'latitude': 41.885708}],
#  'livingArea': 2180,
#  'priceHistory': [{'priceChangeRate': 0.21739130434783,
#    'date': '2024-04-30',
#    'source': 'Zillow Rentals',
#    'postingIsRental': True,
#    'time': 1714435200000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rentals',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 1,
#    'buyerAgent': None,
#    'event': 'Listed for rent',
#    'price': 2800},
#   {'priceChangeRate': 0,
#    'date': '2023-07-16',
#    'source': 'Zillow Rentals',
#    'postingIsRental': True,
#    'time': 1689465600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rentals',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': None,
#    'buyerAgent': None,
#    'event': 'Listing removed',
#    'price': None},
#   {'priceChangeRate': 2.5384615384615,
#    'date': '2023-07-12',
#    'source': 'Zillow Rentals',
#    'postingIsRental': True,
#    'time': 1689120000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rentals',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 1,
#    'buyerAgent': None,
#    'event': 'Listed for rent',
#    'price': 2300},
#   {'priceChangeRate': 0.083333333333333,
#    'date': '2019-05-29',
#    'source': 'Zillow Rental Network',
#    'postingIsRental': True,
#    'time': 1559088000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rental Network',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 0,
#    'buyerAgent': None,
#    'event': 'Listing removed',
#    'price': 650},
#   {'priceChangeRate': 0,
#    'date': '2019-05-14',
#    'source': 'Zillow Rental Network',
#    'postingIsRental': True,
#    'time': 1557792000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rental Network',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 0,
#    'buyerAgent': None,
#    'event': 'Listed for rent',
#    'price': 600},
#   {'priceChangeRate': 0,
#    'date': '2018-08-21',
#    'source': 'Zillow Rental Network',
#    'postingIsRental': True,
#    'time': 1534809600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rental Network',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 0,
#    'buyerAgent': None,
#    'event': 'Listing removed',
#    'price': 600},
#   {'priceChangeRate': 0,
#    'date': '2018-08-11',
#    'source': 'Zillow Rental Network',
#    'postingIsRental': True,
#    'time': 1533945600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rental Network',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 0,
#    'buyerAgent': None,
#    'event': 'Listed for rent',
#    'price': 600},
#   {'priceChangeRate': 0,
#    'date': '2018-05-05',
#    'source': 'Zillow Rental Network',
#    'postingIsRental': True,
#    'time': 1525478400000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rental Network',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 0,
#    'buyerAgent': None,
#    'event': 'Listing removed',
#    'price': 600},
#   {'priceChangeRate': 0,
#    'date': '2018-05-04',
#    'source': 'Zillow Rental Network',
#    'postingIsRental': True,
#    'time': 1525392000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Zillow Rental Network',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 0,
#    'buyerAgent': None,
#    'event': 'Listed for rent',
#    'price': 600},
#   {'priceChangeRate': 5.2967741935484,
#    'date': '2016-02-04',
#    'source': 'MRED as distributed by MLS GRID',
#    'postingIsRental': False,
#    'time': 1454544000000,
#    'sellerAgent': {'name': 'mdrommerhausen',
#     'photo': None,
#     'profileUrl': '/profile/mdrommerhausen3/'},
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'MRED as distributed by MLS GRID',
#     'infoString3': 'https://photos.zillowstatic.com/fp/1b0fc53ffc89ea17e1e382976aca4421-zillow_web_logo_inf_11.jpg',
#     'infoString1': '09068458'},
#    'pricePerSquareFoot': 90,
#    'buyerAgent': {'name': 'Daniel Close',
#     'photo': {'url': 'https://photos.zillowstatic.com/h_e/IS9h3viamvdax50000000000.jpg'},
#     'profileUrl': '/profile/Daniel-Close/'},
#    'event': 'Sold',
#    'price': 195200},
#   {'priceChangeRate': -0.92151898734177,
#    'date': '2010-01-21',
#    'source': 'MRED as distributed by MLS GRID',
#    'postingIsRental': False,
#    'time': 1264032000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'MRED as distributed by MLS GRID',
#     'infoString3': 'https://photos.zillowstatic.com/fp/1b0fc53ffc89ea17e1e382976aca4421-zillow_web_logo_inf_11.jpg',
#     'infoString1': '07395576'},
#    'pricePerSquareFoot': 14,
#    'buyerAgent': {'name': 'mdrommerhausen',
#     'photo': None,
#     'profileUrl': '/profile/mdrommerhausen3/'},
#    'event': 'Sold',
#    'price': 31000},
#   {'priceChangeRate': 1.5986842105263,
#    'date': '2006-06-07',
#    'source': 'Public Record',
#    'postingIsRental': False,
#    'time': 1149638400000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Public Record',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 181,
#    'buyerAgent': None,
#    'event': 'Sold',
#    'price': 395000},
#   {'priceChangeRate': 0,
#    'date': '2005-12-02',
#    'source': 'Public Record',
#    'postingIsRental': False,
#    'time': 1133481600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Public Record',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 70,
#    'buyerAgent': None,
#    'event': 'Sold',
#    'price': 152000}],
#  'favoriteCount': 2,
#  'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/951-Beidler-Elementary-School/',
#    'rating': 4,
#    'totalCount': None,
#    'distance': 0.2,
#    'assigned': None,
#    'name': 'Beidler Elementary School',
#    'studentsPerTeacher': None,
#    'isAssigned': None,
#    'size': None,
#    'level': 'Primary',
#    'grades': 'PK-8',
#    'type': 'Public'},
#   {'link': 'https://www.greatschools.org/illinois/chicago/1248-Marshall-Metropolitan-High-School/',
#    'rating': 1,
#    'totalCount': None,
#    'distance': 0.5,
#    'assigned': None,
#    'name': 'Marshall Metropolitan High School',
#    'studentsPerTeacher': None,
#    'isAssigned': None,
#    'size': None,
#    'level': 'High',
#    'grades': '9-12',
#    'type': 'Public'}],
#  'zestimateHighPercent': '12',
#  'mlsid': None,
#  'countyFIPS': '17031',
#  'city': 'Chicago',
#  'providerListingID': '4pm39qk0cknuv',
#  'country': 'USA',
#  'currency': 'USD',
#  'isListedByOwner': None,
#  'contingentListingType': None}

# %%
response = response.json()
response['description']
# Out:
# "Hello!\n\nThis rehabbed house has central heat & air, exposed bricks, dark hardwood floors, new stainless steel kitchen appliances, in-unit washer and dryer, and plenty of storage space in the basement. It also has a firepit in the backyard for bonfires. \n\nAbout the neighborhood:\nThis unfurnished house is in the heart of East Garfield Park, less than a five-minute walk from the Kedzie Green line and Metra stations, as well as the nearest 52 Kedzie, 82 Homan and 94 California bus stops. There is plenty of space downstairs for your bikes, so you can get around very easily from here without a car. If you do have a car though, you can have a spot out back for $25/month each, or use one of the parking spots on the street out front. \n\nThis house is within a few blocks of cool neighborhood spots like Passion House Coffee, Breakthrough Community Center, Inspiration Kitchens, and the Garfield Park Conservatory, and just a short bike ride away from everything in Humboldt Park, Ukranian Village and West Loop. \n\nAbout the dollar bills/paperwork:\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent. \n\nIf all that sounds good to you, send us a message so we can share details with you about our open house this Sunday, May 5.\n\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent."

# %%
def fetch_descriptions(properties):
    """
    Fetches the descriptions of each property and appends them to the list.

    Parameters:
    - properties: A list of dictionaries representing properties.

    Returns:
    - A list of dictionaries(the same format as input).
    """
    url_details = "https://zillow-com1.p.rapidapi.com/property"

    for prop in properties:
        # Fetch detailed information using detailUrl
        querystring = {"property_url": prop['detailUrl']}
        response = requests.get(url_details, headers=headers, params=querystring)

        # Convert to JSON and fetch description
        detail_data = response.json()
        prop['description'] = detail_data.get('description', 'No description available')

    return properties

# %%
top_properties = fetch_descriptions(top_properties)
top_properties
# Out:
# [{'propertyType': None,
#   'address': '2611 N Hermitage Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/apartments/chicago-il/norweta/BXQZ9R/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/65ca2c82486f45afdc0e1f156f6b514f-p_e.jpg',
#   'description': 'No description available'},
#  {'propertyType': 'SINGLE_FAMILY',
#   'address': '3240 W Fulton Blvd, Chicago, IL 60624',
#   'price': 2800,
#   'bedrooms': 5,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/3240-W-Fulton-Blvd-Chicago-IL-60624/158698100_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/402d1685a0321ebbd7c3b2ceaecb3822-p_e.jpg',
#   'description': "Hello!\n\nThis rehabbed house has central heat & air, exposed bricks, dark hardwood floors, new stainless steel kitchen appliances, in-unit washer and dryer, and plenty of storage space in the basement. It also has a firepit in the backyard for bonfires. \n\nAbout the neighborhood:\nThis unfurnished house is in the heart of East Garfield Park, less than a five-minute walk from the Kedzie Green line and Metra stations, as well as the nearest 52 Kedzie, 82 Homan and 94 California bus stops. There is plenty of space downstairs for your bikes, so you can get around very easily from here without a car. If you do have a car though, you can have a spot out back for $25/month each, or use one of the parking spots on the street out front. \n\nThis house is within a few blocks of cool neighborhood spots like Passion House Coffee, Breakthrough Community Center, Inspiration Kitchens, and the Garfield Park Conservatory, and just a short bike ride away from everything in Humboldt Park, Ukranian Village and West Loop. \n\nAbout the dollar bills/paperwork:\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent. \n\nIf all that sounds good to you, send us a message so we can share details with you about our open house this Sunday, May 5.\n\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent."},
#  {'propertyType': 'APARTMENT',
#   'address': '3251 W Evergreen Ave #2, Chicago, IL 60651',
#   'price': 2300,
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/3251-W-Evergreen-Ave-2-Chicago-IL-60651/348824068_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/6253b10423f0bf3cee38170605b73c8b-p_e.jpg',
#   'description': "Conveniently located just a short commute from downtown Chicago, minutes away from 606 Bloomingdale Trail. Humboldt Park/ Logan Square Edge offers the perfect balance of urban excitement and neighborhood tranquility. With its tree-lined streets, historic architecture, and welcoming atmosphere, it's no wonder why so many people are proud to call Humboldt Park home.\n\nFully remodeled unit with contemporary design, Hardwood Floors. Stainless steel appliances: Range, Over Range-Microwave, Refrigerator. In-unit Samsung Washer/Dryer. Central AC/Furnace.\n\nOne parking spot in Detached Garage included. Gas/Electric utilities paid by tenant. (1) Pet allowed upon approval.\n\nTenant is responsible for electric/gas utilities. One parking spot detached is included if requested. (1) small pet allowed upon approval if applicable. Last month rent due at signing of lease with first month's rent payment. No smoking in unit allowed. (1) year leases."}]

# %% [markdown]
# #### resoFacts

# %%
def fetch_resoFacts(properties, headers, keys_to_fetch):
    """
    Fetches specific information from the resoFacts dictionary of each property and appends it in a nested format.

    Parameters:
    - properties: A list of dictionaries representing properties.
    - headers: Headers for the API request.
    - keys_to_fetch: A list of keys to fetch from the resoFacts dictionary.

    Returns:
    - A list of dictionaries with the specified information appended in a nested format.
    """
    url_details = "https://zillow-com1.p.rapidapi.com/property"

    for prop in properties:
        # Fetch detailed information using detailUrl
        querystring = {"property_url": prop['detailUrl']}
        response = requests.get(url_details, headers=headers, params=querystring)
        detail_data = response.json()

        # Fetch information from the resoFacts dictionary
        resoFacts = detail_data.get('resoFacts', {})

        # Create a nested dictionary to store resoFacts information
        prop['resoFacts'] = {}

        for key in keys_to_fetch:
            prop['resoFacts'][key] = resoFacts.get(key, 'N/A')

    return properties

# %%
# key to fetch
keys_to_fetch_resoFacts = [
    'hasGarage', 'hasPetsAllowed', 'heating', 'cooling', 'flooring', 'appliances',
    'laundryFeatures', 'associationFee',
    'livingArea', 'taxAnnualAmount', 'parkingFeatures', 'stories'
]

top_properties = fetch_resoFacts(top_properties, headers, keys_to_fetch_resoFacts)
top_properties
# Out:
# [{'propertyType': None,
#   'address': '2611 N Hermitage Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/apartments/chicago-il/norweta/BXQZ9R/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/65ca2c82486f45afdc0e1f156f6b514f-p_e.jpg',
#   'description': 'No description available',
#   'resoFacts': {'hasGarage': 'N/A',
#    'hasPetsAllowed': 'N/A',
#    'heating': 'N/A',
#    'cooling': 'N/A',
#    'flooring': 'N/A',
#    'appliances': 'N/A',
#    'laundryFeatures': 'N/A',
#    'associationFee': 'N/A',
#    'livingArea': 'N/A',
#    'taxAnnualAmount': 'N/A',
#    'parkingFeatures': 'N/A',
#    'stories': 'N/A'}},
#  {'propertyType': 'SINGLE_FAMILY',
#   'address': '3240 W Fulton Blvd, Chicago, IL 60624',
#   'price': 2800,
#   'bedrooms': 5,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/3240-W-Fulton-Blvd-Chicago-IL-60624/158698100_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/402d1685a0321ebbd7c3b2ceaecb3822-p_e.jpg',
#   'description': "Hello!\n\nThis rehabbed house has central heat & air, exposed bricks, dark hardwood floors, new stainless steel kitchen appliances, in-unit washer and dryer, and plenty of storage space in the basement. It also has a firepit in the backyard for bonfires. \n\nAbout the neighborhood:\nThis unfurnished house is in the heart of East Garfield Park, less than a five-minute walk from the Kedzie Green line and Metra stations, as well as the nearest 52 Kedzie, 82 Homan and 94 California bus stops. There is plenty of space downstairs for your bikes, so you can get around very easily from here without a car. If you do have a car though, you can have a spot out back for $25/month each, or use one of the parking spots on the street out front. \n\nThis house is within a few blocks of cool neighborhood spots like Passion House Coffee, Breakthrough Community Center, Inspiration Kitchens, and the Garfield Park Conservatory, and just a short bike ride away from everything in Humboldt Park, Ukranian Village and West Loop. \n\nAbout the dollar bills/paperwork:\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent. \n\nIf all that sounds good to you, send us a message so we can share details with you about our open house this Sunday, May 5.\n\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent.",
#   'resoFacts': {'hasGarage': False,
#    'hasPetsAllowed': True,
#    'heating': None,
#    'cooling': ['Central Air'],
#    'flooring': ['Hardwood'],
#    'appliances': ['Dishwasher', 'Dryer', 'Washer'],
#    'laundryFeatures': ['In Unit'],
#    'associationFee': None,
#    'livingArea': '2,180 sqft',
#    'taxAnnualAmount': 53,
#    'parkingFeatures': ['Off Street'],
#    'stories': None}},
#  {'propertyType': 'APARTMENT',
#   'address': '3251 W Evergreen Ave #2, Chicago, IL 60651',
#   'price': 2300,
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/3251-W-Evergreen-Ave-2-Chicago-IL-60651/348824068_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/6253b10423f0bf3cee38170605b73c8b-p_e.jpg',
#   'description': "Conveniently located just a short commute from downtown Chicago, minutes away from 606 Bloomingdale Trail. Humboldt Park/ Logan Square Edge offers the perfect balance of urban excitement and neighborhood tranquility. With its tree-lined streets, historic architecture, and welcoming atmosphere, it's no wonder why so many people are proud to call Humboldt Park home.\n\nFully remodeled unit with contemporary design, Hardwood Floors. Stainless steel appliances: Range, Over Range-Microwave, Refrigerator. In-unit Samsung Washer/Dryer. Central AC/Furnace.\n\nOne parking spot in Detached Garage included. Gas/Electric utilities paid by tenant. (1) Pet allowed upon approval.\n\nTenant is responsible for electric/gas utilities. One parking spot detached is included if requested. (1) small pet allowed upon approval if applicable. Last month rent due at signing of lease with first month's rent payment. No smoking in unit allowed. (1) year leases.",
#   'resoFacts': {'hasGarage': False,
#    'hasPetsAllowed': True,
#    'heating': ['Forced Air'],
#    'cooling': ['Central Air'],
#    'flooring': ['Hardwood'],
#    'appliances': ['Dishwasher', 'Dryer', 'Washer'],
#    'laundryFeatures': ['In Unit'],
#    'associationFee': None,
#    'livingArea': None,
#    'taxAnnualAmount': 43,
#    'parkingFeatures': ['Detached'],
#    'stories': None}}]

# %% [markdown]
# #### Schools

# %%
def fetch_schools(properties, headers):
    """
    Fetches information about nearby schools and appends it in a nested format.

    Parameters:
    - properties: A list of dictionaries representing properties.
    - headers: Headers for the API request.

    Returns:
    - A list of dictionaries with school information appended in a nested format.
    """
    url_details = "https://zillow-com1.p.rapidapi.com/property"

    for prop in properties:
        # Fetch detailed information using detailUrl
        querystring = {"property_url": prop['detailUrl']}
        response = requests.get(url_details, headers=headers, params=querystring)
        detail_data = response.json()

        # Fetch schools information
        schools = detail_data.get('schools', [])

        # Create a nested dictionary to store school information
        prop['schools'] = schools

    return properties

# %%
top_properties = fetch_schools(top_properties, headers)
top_properties
# Out:
# [{'propertyType': None,
#   'address': '2611 N Hermitage Ave, Chicago, IL',
#   'price': None,
#   'bedrooms': None,
#   'bathrooms': None,
#   'detailUrl': 'https://www.zillow.com/apartments/chicago-il/norweta/BXQZ9R/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/65ca2c82486f45afdc0e1f156f6b514f-p_e.jpg',
#   'description': 'No description available',
#   'resoFacts': {'hasGarage': 'N/A',
#    'hasPetsAllowed': 'N/A',
#    'heating': 'N/A',
#    'cooling': 'N/A',
#    'flooring': 'N/A',
#    'appliances': 'N/A',
#    'laundryFeatures': 'N/A',
#    'associationFee': 'N/A',
#    'livingArea': 'N/A',
#    'taxAnnualAmount': 'N/A',
#    'parkingFeatures': 'N/A',
#    'stories': 'N/A'},
#   'schools': []},
#  {'propertyType': 'SINGLE_FAMILY',
#   'address': '3240 W Fulton Blvd, Chicago, IL 60624',
#   'price': 2800,
#   'bedrooms': 5,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/3240-W-Fulton-Blvd-Chicago-IL-60624/158698100_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/402d1685a0321ebbd7c3b2ceaecb3822-p_e.jpg',
#   'description': "Hello!\n\nThis rehabbed house has central heat & air, exposed bricks, dark hardwood floors, new stainless steel kitchen appliances, in-unit washer and dryer, and plenty of storage space in the basement. It also has a firepit in the backyard for bonfires. \n\nAbout the neighborhood:\nThis unfurnished house is in the heart of East Garfield Park, less than a five-minute walk from the Kedzie Green line and Metra stations, as well as the nearest 52 Kedzie, 82 Homan and 94 California bus stops. There is plenty of space downstairs for your bikes, so you can get around very easily from here without a car. If you do have a car though, you can have a spot out back for $25/month each, or use one of the parking spots on the street out front. \n\nThis house is within a few blocks of cool neighborhood spots like Passion House Coffee, Breakthrough Community Center, Inspiration Kitchens, and the Garfield Park Conservatory, and just a short bike ride away from everything in Humboldt Park, Ukranian Village and West Loop. \n\nAbout the dollar bills/paperwork:\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent. \n\nIf all that sounds good to you, send us a message so we can share details with you about our open house this Sunday, May 5.\n\nThis lease will start June 1 and go until June 30, 2025, with a chance to renew for a full year. If you see the place and like it, you will complete an application that includes a background check and credit check for each person on the lease. Once you've been approved, you will pay a non-refundable $250 move-in fee for reach person on the lease, plus first month's rent.",
#   'resoFacts': {'hasGarage': False,
#    'hasPetsAllowed': True,
#    'heating': None,
#    'cooling': ['Central Air'],
#    'flooring': ['Hardwood'],
#    'appliances': ['Dishwasher', 'Dryer', 'Washer'],
#    'laundryFeatures': ['In Unit'],
#    'associationFee': None,
#    'livingArea': '2,180 sqft',
#    'taxAnnualAmount': 53,
#    'parkingFeatures': ['Off Street'],
#    'stories': None},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/951-Beidler-Elementary-School/',
#     'rating': 4,
#     'totalCount': None,
#     'distance': 0.2,
#     'assigned': None,
#     'name': 'Beidler Elementary School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1248-Marshall-Metropolitan-High-School/',
#     'rating': 1,
#     'totalCount': None,
#     'distance': 0.5,
#     'assigned': None,
#     'name': 'Marshall Metropolitan High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'High',
#     'grades': '9-12',
#     'type': 'Public'}]},
#  {'propertyType': 'APARTMENT',
#   'address': '3251 W Evergreen Ave #2, Chicago, IL 60651',
#   'price': 2300,
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/3251-W-Evergreen-Ave-2-Chicago-IL-60651/348824068_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/6253b10423f0bf3cee38170605b73c8b-p_e.jpg',
#   'description': "Conveniently located just a short commute from downtown Chicago, minutes away from 606 Bloomingdale Trail. Humboldt Park/ Logan Square Edge offers the perfect balance of urban excitement and neighborhood tranquility. With its tree-lined streets, historic architecture, and welcoming atmosphere, it's no wonder why so many people are proud to call Humboldt Park home.\n\nFully remodeled unit with contemporary design, Hardwood Floors. Stainless steel appliances: Range, Over Range-Microwave, Refrigerator. In-unit Samsung Washer/Dryer. Central AC/Furnace.\n\nOne parking spot in Detached Garage included. Gas/Electric utilities paid by tenant. (1) Pet allowed upon approval.\n\nTenant is responsible for electric/gas utilities. One parking spot detached is included if requested. (1) small pet allowed upon approval if applicable. Last month rent due at signing of lease with first month's rent payment. No smoking in unit allowed. (1) year leases.",
#   'resoFacts': {'hasGarage': False,
#    'hasPetsAllowed': True,
#    'heating': ['Forced Air'],
#    'cooling': ['Central Air'],
#    'flooring': ['Hardwood'],
#    'appliances': ['Dishwasher', 'Dryer', 'Washer'],
#    'laundryFeatures': ['In Unit'],
#    'associationFee': None,
#    'livingArea': None,
#    'taxAnnualAmount': 43,
#    'parkingFeatures': ['Detached'],
#    'stories': None},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1210-Lowell-Elementary-School/',
#     'rating': 3,
#     'totalCount': None,
#     'distance': 0.1,
#     'assigned': None,
#     'name': 'Lowell Elementary School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/9773-Orr-Academy-High-School/',
#     'rating': 1,
#     'totalCount': None,
#     'distance': 1.2,
#     'assigned': None,
#     'name': 'Orr Academy High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'High',
#     'grades': '9-12',
#     'type': 'Public'}]}]

# %% [markdown]
# ### For main use case

# %%
import json

# %%
user_query = "I am looking for a two-bedroom."
prompt = generate_prompt_apifilter(instruction, user_query)
print(get_chat_response(chat, prompt))
# Out:
# {
# "location":"chicago, il",
# "bedsMin":"2",
# "bedsMax":"2",
# "sort":"Newest"
# }

# %%
# get an api filter through Gemini
querystring = get_chat_response(chat, prompt)

# from str to dict
querystring = json.loads(querystring)

# get listings from zillow api
response = requests.get(url, headers = headers, params = querystring)

# %%
# Define fields to extract
fields = ["propertyType", "address", "price", "bedrooms", "bathrooms", "detailUrl", "imgSrc"]

# Get top 3 properties with selected fields
top_properties = extract_properties(response, 3, fields)
top_properties
# Out:
# [{'propertyType': 'CONDO',
#   'address': '5757 N Sheridan Rd APT 11J, Chicago, IL 60660',
#   'price': 179950,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/5757-N-Sheridan-Rd-APT-11J-Chicago-IL-60660/3694665_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/c98d7bd8a3727edb87e8418c0fc527c1-p_e.jpg'},
#  {'propertyType': 'CONDO',
#   'address': '926 N Winchester Ave #2, Chicago, IL 60622',
#   'price': 475000,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/926-N-Winchester-Ave-2-Chicago-IL-60622/87711579_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/4f4c50d2ac83652a0ad54148bb44168e-p_e.jpg'},
#  {'propertyType': 'CONDO',
#   'address': '3555 W Lyndale St #3B, Chicago, IL 60647',
#   'price': 269999,
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/3555-W-Lyndale-St-3B-Chicago-IL-60647/87693371_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/c5ed15a0556264616ab6a781839bab88-p_e.jpg'}]

# %%
# get description
top_properties = fetch_descriptions(top_properties)

# get detail info from resoFacts
keys_to_fetch_resoFacts = [
    'hasGarage', 'hasPetsAllowed', 'heating', 'cooling', 'flooring', 'appliances',
    'laundryFeatures', 'associationFee',
    'livingArea', 'taxAnnualAmount', 'parkingFeatures', 'stories'
]
top_properties = fetch_resoFacts(top_properties, headers, keys_to_fetch_resoFacts)
# get school info
top_properties = fetch_schools(top_properties, headers)
top_properties
# Out:
# [{'propertyType': 'CONDO',
#   'address': '5757 N Sheridan Rd APT 11J, Chicago, IL 60660',
#   'price': 179950,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/5757-N-Sheridan-Rd-APT-11J-Chicago-IL-60660/3694665_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/c98d7bd8a3727edb87e8418c0fc527c1-p_e.jpg',
#   'description': 'Open Concept Corner 2 Bedroom, 2 Bathroom steps from the beach! This spacious north west unit features updated kitchen with stainless steal appliances, granite counter tops with breakfast bar & 42" white cabinets. Hardwood floors throughout. King size master suite with walk-in closet & queen size secondary bedroom. Laundry in the building, bike room. Steps from Kathy Osterman Beach with fenced patio and gas grills. Walk-out access to the bike trail and park. Leased heated garage parking, easy public transportation.',
#   'resoFacts': {'hasGarage': True,
#    'hasPetsAllowed': False,
#    'heating': ['Radiator(s)'],
#    'cooling': ['Window/Wall Units - 3+'],
#    'flooring': ['Hardwood'],
#    'appliances': ['Range', 'Microwave', 'Dishwasher', 'Refrigerator'],
#    'laundryFeatures': ['Common Area'],
#    'associationFee': '$994 monthly',
#    'livingArea': None,
#    'taxAnnualAmount': 3401,
#    'parkingFeatures': ['Garage - Attached', 'Open'],
#    'stories': None},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1370-Swift-Elementary-Specialty-School/',
#     'rating': 4,
#     'totalCount': None,
#     'distance': 0.3,
#     'assigned': None,
#     'name': 'Swift Elementary Specialty School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1366-Senn-High-School/',
#     'rating': 4,
#     'totalCount': None,
#     'distance': 0.7,
#     'assigned': None,
#     'name': 'Senn High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'High',
#     'grades': '9-12',
#     'type': 'Public'}]},
#  {'propertyType': 'CONDO',
#   'address': '926 N Winchester Ave #2, Chicago, IL 60622',
#   'price': 475000,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'detailUrl': 'https://www.zillow.com/homedetails/926-N-Winchester-Ave-2-Chicago-IL-60622/87711579_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/4f4c50d2ac83652a0ad54148bb44168e-p_e.jpg',
#   'description': "This is a wonderful light, airy condo, located on a tree lined street, in best part of East Ukanian Village! When I say there is nothing to do but move in, I mean just that! The entire condo has been painted and the hardwood floor throughout, have just been restained and refinished. The unit boasts an open concept living area in the front of the home. The island is perfect for a couple of bar stools and there is room for a dining table too. Tucked away by the window, is a nice space for a reading nook or home office. Enjoy the breeze from your front juliet balcony, where you can plant your favorite planter box greenery. The living room has a fireplace, which is great for cuddling or warming up on those chilly Chicago winter days and nights.  There is a split bedroom floor plan, which is great for privacy for both you, your children or your guests. The second bedroom has a full bathroom with a soaking bathtub right next door.  Walk down the hallway to the primary suite. The walk-in closet has professionally organized. The primary bathroom was updated a few years ago. The vanity features dual sinks with a lovely carrera marble counter top. You can soak in your jetted tub, or use the separate shower. There is a private balcony off the primary suite for when you want to wear you pajamas while drinking your morning coffee. The roof top garage deck was rebuilt a few years ago. That space is shared by this unit and the first floor unit owners, and is accessible by walking out the back door to your condo. To complete is awesome property, is a garage space.  There is a Mariano's grocery store a few blocks away, as well as tasty local sushi, pizza and breweries in walking distance. The Blue line is about five blocks northeast and 90-94 is close too. Lots of updates, so come visit soon!",
#   'resoFacts': {'hasGarage': True,
#    'hasPetsAllowed': None,
#    'heating': ['Natural Gas', 'Forced Air'],
#    'cooling': ['Central Air'],
#    'flooring': ['Hardwood'],
#    'appliances': None,
#    'laundryFeatures': ['In Unit', 'Laundry Hook-Up in Unit'],
#    'associationFee': '$99 monthly',
#    'livingArea': '1,200 sqft',
#    'taxAnnualAmount': 8978,
#    'parkingFeatures': ['Garage'],
#    'stories': None},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1010-Columbus-Elementary-School/',
#     'rating': 6,
#     'totalCount': None,
#     'distance': 0.3,
#     'assigned': None,
#     'name': 'Columbus Elementary School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1425-Wells-Community-Academy-High-School/',
#     'rating': 1,
#     'totalCount': None,
#     'distance': 0.4,
#     'assigned': None,
#     'name': 'Wells Community Academy High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'High',
#     'grades': '9-12',
#     'type': 'Public'}]},
#  {'propertyType': 'CONDO',
#   'address': '3555 W Lyndale St #3B, Chicago, IL 60647',
#   'price': 269999,
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'detailUrl': 'https://www.zillow.com/homedetails/3555-W-Lyndale-St-3B-Chicago-IL-60647/87693371_zpid/',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/c5ed15a0556264616ab6a781839bab88-p_e.jpg',
#   'description': 'Light filled TOP FLOOR condo in hot Logan Square with East facing views and a peek of downtown skyscrapers! NEWLY RENOVATED - Renovations completed in 2022 include:  New hardwood floors (not just refinished, complete replaced down to the subfloor, not a SQUEAKY board around), the tall ceilings are freshly painted in a show stopping bright white with new baseboards, renovated bathroom with tile to the ceiling, new vanity and fixtures, stylish light fixtures and fans and an entry way with exposed brick.  Kitchen features new cabinetry, including a rare pantry cabinet and quartz countertops. Range, microwave, fridge, dishwasher and stackable washer dryer are all less than 2 years old.  The condo offers a large open floor plan with living room, similar sized bedrooms (one being used as an office currently) and a bathroom with room for extra storage. What more could you want in a great part of Logan Square! Easy, non permit, street parking. Great location close to the 606, Palmer Square, restaurants (Wyler Road!) and transportation. Professionally managed building, dog & investor friendly. New construction all around! Broker Owned. Room sizes are estimates to be verified by buyer.',
#   'resoFacts': {'hasGarage': False,
#    'hasPetsAllowed': True,
#    'heating': ['Natural Gas', 'Forced Air'],
#    'cooling': ['Central Air'],
#    'flooring': ['Hardwood'],
#    'appliances': ['Range',
#     'Microwave',
#     'Dishwasher',
#     'Refrigerator',
#     'Washer',
#     'Dryer',
#     'Stainless Steel Appliance(s)',
#     'Gas Cooktop',
#     'Gas Oven'],
#    'laundryFeatures': ['In Unit', 'Laundry Hook-Up in Unit'],
#    'associationFee': '$300 monthly',
#    'livingArea': '1,000 sqft',
#    'taxAnnualAmount': 5103,
#    'parkingFeatures': {},
#    'stories': None},
#   'schools': [{'link': 'https://www.greatschools.org/illinois/chicago/1253-Mozart-Elementary-School/',
#     'rating': 4,
#     'totalCount': None,
#     'distance': 0.3,
#     'assigned': None,
#     'name': 'Mozart Elementary School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Primary',
#     'grades': 'PK-8',
#     'type': 'Public'},
#    {'link': 'https://www.greatschools.org/illinois/chicago/1203-Kelvyn-Park-High-School/',
#     'rating': 1,
#     'totalCount': None,
#     'distance': 1.1,
#     'assigned': None,
#     'name': 'Kelvyn Park High School',
#     'studentsPerTeacher': None,
#     'isAssigned': None,
#     'size': None,
#     'level': 'Middle',
#     'grades': '7-12',
#     'type': 'Public'}]}]

# %% [markdown]
# ## 4. Generate advice with the property listings

# %%
def generate_prompt_property(instruction, user_query, property_info, fields):
    updated_instruction = instruction.replace("{USER_QUERY}", user_query)
    updated_instruction = updated_instruction.replace("{PROPERTY_INFO}", property_info)
    updated_instruction = updated_instruction.replace("{KEY_FIELDS}", fields)
    return updated_instruction

# %%
instruction = """
### Instructions ###
I want you to act as a real estate advisor. Please recommend properties to the customer. 
'User’s query' represents the questions you are asked by the customer. 
'Real estate properties to present to the user' are the properties you will introduce to the customer. 

Note1: Include all information from {KEY_FIELDS}, including links. 
Note2: The "Resofacts" and "Schools" fields are in JSON format. You do not need to include all the information from "Resofacts" and "Schools" in your initial response. 
However, if the user asks specific questions about "Resofacts" and "Schools", include relevant information in your answer.

### User’s query ###
{USER_QUERY}

### Real estate properties to present to the user ###
{PROPERTY_INFO}

### Output ###
"""

# %%
def format_properties(properties, fields):
    formatted_properties = []
    for prop in properties:
        # Format and concatenate each field of each property
        formatted_prop = ', '.join(f"{field.capitalize().replace('_', ' ')}: {prop.get(field, 'N/A')}" for field in fields)
        formatted_properties.append(formatted_prop)
    return '\n\n'.join(formatted_properties)

# %%
# Change format
fields_desc = fields + ['description', 'resoFacts', 'schools']
property_info = format_properties(top_properties, fields_desc)
print(property_info)
# Out:
# Propertytype: CONDO, Address: 5757 N Sheridan Rd APT 11J, Chicago, IL 60660, Price: 179950, Bedrooms: 2, Bathrooms: 2, Detailurl: https://www.zillow.com/homedetails/5757-N-Sheridan-Rd-APT-11J-Chicago-IL-60660/3694665_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/c98d7bd8a3727edb87e8418c0fc527c1-p_e.jpg, Description: Open Concept Corner 2 Bedroom, 2 Bathroom steps from the beach! This spacious north west unit features updated kitchen with stainless steal appliances, granite counter tops with breakfast bar & 42" white cabinets. Hardwood floors throughout. King size master suite with walk-in closet & queen size secondary bedroom. Laundry in the building, bike room. Steps from Kathy Osterman Beach with fenced patio and gas grills. Walk-out access to the bike trail and park. Leased heated garage parking, easy public transportation., Resofacts: {'hasGarage': True, 'hasPetsAllowed': False, 'heating': ['Radiator(s)'], 'cooling': ['Window/Wall Units - 3+'], 'flooring': ['Hardwood'], 'appliances': ['Range', 'Microwave', 'Dishwasher', 'Refrigerator'], 'laundryFeatures': ['Common Area'], 'associationFee': '$994 monthly', 'livingArea': None, 'taxAnnualAmount': 3401, 'parkingFeatures': ['Garage - Attached', 'Open'], 'stories': None}, Schools: [{'link': 'https://www.greatschools.org/illinois/chicago/1370-Swift-Elementary-Specialty-School/', 'rating': 4, 'totalCount': None, 'distance': 0.3, 'assigned': None, 'name': 'Swift Elementary Specialty School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'Primary', 'grades': 'PK-8', 'type': 'Public'}, {'link': 'https://www.greatschools.org/illinois/chicago/1366-Senn-High-School/', 'rating': 4, 'totalCount': None, 'distance': 0.7, 'assigned': None, 'name': 'Senn High School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'High', 'grades': '9-12', 'type': 'Public'}]
#
# Propertytype: CONDO, Address: 926 N Winchester Ave #2, Chicago, IL 60622, Price: 475000, Bedrooms: 2, Bathrooms: 2, Detailurl: https://www.zillow.com/homedetails/926-N-Winchester-Ave-2-Chicago-IL-60622/87711579_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/4f4c50d2ac83652a0ad54148bb44168e-p_e.jpg, Description: This is a wonderful light, airy condo, located on a tree lined street, in best part of East Ukanian Village! When I say there is nothing to do but move in, I mean just that! The entire condo has been painted and the hardwood floor throughout, have just been restained and refinished. The unit boasts an open concept living area in the front of the home. The island is perfect for a couple of bar stools and there is room for a dining table too. Tucked away by the window, is a nice space for a reading nook or home office. Enjoy the breeze from your front juliet balcony, where you can plant your favorite planter box greenery. The living room has a fireplace, which is great for cuddling or warming up on those chilly Chicago winter days and nights.  There is a split bedroom floor plan, which is great for privacy for both you, your children or your guests. The second bedroom has a full bathroom with a soaking bathtub right next door.  Walk down the hallway to the primary suite. The walk-in closet has professionally organized. The primary bathroom was updated a few years ago. The vanity features dual sinks with a lovely carrera marble counter top. You can soak in your jetted tub, or use the separate shower. There is a private balcony off the primary suite for when you want to wear you pajamas while drinking your morning coffee. The roof top garage deck was rebuilt a few years ago. That space is shared by this unit and the first floor unit owners, and is accessible by walking out the back door to your condo. To complete is awesome property, is a garage space.  There is a Mariano's grocery store a few blocks away, as well as tasty local sushi, pizza and breweries in walking distance. The Blue line is about five blocks northeast and 90-94 is close too. Lots of updates, so come visit soon!, Resofacts: {'hasGarage': True, 'hasPetsAllowed': None, 'heating': ['Natural Gas', 'Forced Air'], 'cooling': ['Central Air'], 'flooring': ['Hardwood'], 'appliances': None, 'laundryFeatures': ['In Unit', 'Laundry Hook-Up in Unit'], 'associationFee': '$99 monthly', 'livingArea': '1,200 sqft', 'taxAnnualAmount': 8978, 'parkingFeatures': ['Garage'], 'stories': None}, Schools: [{'link': 'https://www.greatschools.org/illinois/chicago/1010-Columbus-Elementary-School/', 'rating': 6, 'totalCount': None, 'distance': 0.3, 'assigned': None, 'name': 'Columbus Elementary School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'Primary', 'grades': 'PK-8', 'type': 'Public'}, {'link': 'https://www.greatschools.org/illinois/chicago/1425-Wells-Community-Academy-High-School/', 'rating': 1, 'totalCount': None, 'distance': 0.4, 'assigned': None, 'name': 'Wells Community Academy High School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'High', 'grades': '9-12', 'type': 'Public'}]
#
# Propertytype: CONDO, Address: 3555 W Lyndale St #3B, Chicago, IL 60647, Price: 269999, Bedrooms: 2, Bathrooms: 1, Detailurl: https://www.zillow.com/homedetails/3555-W-Lyndale-St-3B-Chicago-IL-60647/87693371_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/c5ed15a0556264616ab6a781839bab88-p_e.jpg, Description: Light filled TOP FLOOR condo in hot Logan Square with East facing views and a peek of downtown skyscrapers! NEWLY RENOVATED - Renovations completed in 2022 include:  New hardwood floors (not just refinished, complete replaced down to the subfloor, not a SQUEAKY board around), the tall ceilings are freshly painted in a show stopping bright white with new baseboards, renovated bathroom with tile to the ceiling, new vanity and fixtures, stylish light fixtures and fans and an entry way with exposed brick.  Kitchen features new cabinetry, including a rare pantry cabinet and quartz countertops. Range, microwave, fridge, dishwasher and stackable washer dryer are all less than 2 years old.  The condo offers a large open floor plan with living room, similar sized bedrooms (one being used as an office currently) and a bathroom with room for extra storage. What more could you want in a great part of Logan Square! Easy, non permit, street parking. Great location close to the 606, Palmer Square, restaurants (Wyler Road!) and transportation. Professionally managed building, dog & investor friendly. New construction all around! Broker Owned. Room sizes are estimates to be verified by buyer., Resofacts: {'hasGarage': False, 'hasPetsAllowed': True, 'heating': ['Natural Gas', 'Forced Air'], 'cooling': ['Central Air'], 'flooring': ['Hardwood'], 'appliances': ['Range', 'Microwave', 'Dishwasher', 'Refrigerator', 'Washer', 'Dryer', 'Stainless Steel Appliance(s)', 'Gas Cooktop', 'Gas Oven'], 'laundryFeatures': ['In Unit', 'Laundry Hook-Up in Unit'], 'associationFee': '$300 monthly', 'livingArea': '1,000 sqft', 'taxAnnualAmount': 5103, 'parkingFeatures': {}, 'stories': None}, Schools: [{'link': 'https://www.greatschools.org/illinois/chicago/1253-Mozart-Elementary-School/', 'rating': 4, 'totalCount': None, 'distance': 0.3, 'assigned': None, 'name': 'Mozart Elementary School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'Primary', 'grades': 'PK-8', 'type': 'Public'}, {'link': 'https://www.greatschools.org/illinois/chicago/1203-Kelvyn-Park-High-School/', 'rating': 1, 'totalCount': None, 'distance': 1.1, 'assigned': None, 'name': 'Kelvyn Park High School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'Middle', 'grades': '7-12', 'type': 'Public'}]

# %%
# generate prompt
prompt = generate_prompt_property(instruction, user_query, property_info, str(fields))

# %%
print(prompt)
# Out:
# ### Instructions ###
# I want you to act as a real estate advisor. Please recommend properties to the customer.
# 'User’s query' represents the questions you are asked by the customer.
# 'Real estate properties to present to the user' are the properties you will introduce to the customer.
#
# Note1: Include all information from ['propertyType', 'address', 'price', 'bedrooms', 'bathrooms', 'detailUrl', 'imgSrc'], including links.
# Note2: The "Resofacts" and "Schools" fields are in JSON format. You do not need to include all the information from "Resofacts" and "Schools" in your initial response.
# However, if the user asks specific questions about "Resofacts" and "Schools", include relevant information in your answer.
#
# ### User’s query ###
# I am looking for a two-bedroom.
#
# ### Real estate properties to present to the user ###
# Propertytype: CONDO, Address: 5757 N Sheridan Rd APT 11J, Chicago, IL 60660, Price: 179950, Bedrooms: 2, Bathrooms: 2, Detailurl: https://www.zillow.com/homedetails/5757-N-Sheridan-Rd-APT-11J-Chicago-IL-60660/3694665_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/c98d7bd8a3727edb87e8418c0fc527c1-p_e.jpg, Description: Open Concept Corner 2 Bedroom, 2 Bathroom steps from the beach! This spacious north west unit features updated kitchen with stainless steal appliances, granite counter tops with breakfast bar & 42" white cabinets. Hardwood floors throughout. King size master suite with walk-in closet & queen size secondary bedroom. Laundry in the building, bike room. Steps from Kathy Osterman Beach with fenced patio and gas grills. Walk-out access to the bike trail and park. Leased heated garage parking, easy public transportation., Resofacts: {'hasGarage': True, 'hasPetsAllowed': False, 'heating': ['Radiator(s)'], 'cooling': ['Window/Wall Units - 3+'], 'flooring': ['Hardwood'], 'appliances': ['Range', 'Microwave', 'Dishwasher', 'Refrigerator'], 'laundryFeatures': ['Common Area'], 'associationFee': '$994 monthly', 'livingArea': None, 'taxAnnualAmount': 3401, 'parkingFeatures': ['Garage - Attached', 'Open'], 'stories': None}, Schools: [{'link': 'https://www.greatschools.org/illinois/chicago/1370-Swift-Elementary-Specialty-School/', 'rating': 4, 'totalCount': None, 'distance': 0.3, 'assigned': None, 'name': 'Swift Elementary Specialty School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'Primary', 'grades': 'PK-8', 'type': 'Public'}, {'link': 'https://www.greatschools.org/illinois/chicago/1366-Senn-High-School/', 'rating': 4, 'totalCount': None, 'distance': 0.7, 'assigned': None, 'name': 'Senn High School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'High', 'grades': '9-12', 'type': 'Public'}]
#
# Propertytype: CONDO, Address: 926 N Winchester Ave #2, Chicago, IL 60622, Price: 475000, Bedrooms: 2, Bathrooms: 2, Detailurl: https://www.zillow.com/homedetails/926-N-Winchester-Ave-2-Chicago-IL-60622/87711579_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/4f4c50d2ac83652a0ad54148bb44168e-p_e.jpg, Description: This is a wonderful light, airy condo, located on a tree lined street, in best part of East Ukanian Village! When I say there is nothing to do but move in, I mean just that! The entire condo has been painted and the hardwood floor throughout, have just been restained and refinished. The unit boasts an open concept living area in the front of the home. The island is perfect for a couple of bar stools and there is room for a dining table too. Tucked away by the window, is a nice space for a reading nook or home office. Enjoy the breeze from your front juliet balcony, where you can plant your favorite planter box greenery. The living room has a fireplace, which is great for cuddling or warming up on those chilly Chicago winter days and nights.  There is a split bedroom floor plan, which is great for privacy for both you, your children or your guests. The second bedroom has a full bathroom with a soaking bathtub right next door.  Walk down the hallway to the primary suite. The walk-in closet has professionally organized. The primary bathroom was updated a few years ago. The vanity features dual sinks with a lovely carrera marble counter top. You can soak in your jetted tub, or use the separate shower. There is a private balcony off the primary suite for when you want to wear you pajamas while drinking your morning coffee. The roof top garage deck was rebuilt a few years ago. That space is shared by this unit and the first floor unit owners, and is accessible by walking out the back door to your condo. To complete is awesome property, is a garage space.  There is a Mariano's grocery store a few blocks away, as well as tasty local sushi, pizza and breweries in walking distance. The Blue line is about five blocks northeast and 90-94 is close too. Lots of updates, so come visit soon!, Resofacts: {'hasGarage': True, 'hasPetsAllowed': None, 'heating': ['Natural Gas', 'Forced Air'], 'cooling': ['Central Air'], 'flooring': ['Hardwood'], 'appliances': None, 'laundryFeatures': ['In Unit', 'Laundry Hook-Up in Unit'], 'associationFee': '$99 monthly', 'livingArea': '1,200 sqft', 'taxAnnualAmount': 8978, 'parkingFeatures': ['Garage'], 'stories': None}, Schools: [{'link': 'https://www.greatschools.org/illinois/chicago/1010-Columbus-Elementary-School/', 'rating': 6, 'totalCount': None, 'distance': 0.3, 'assigned': None, 'name': 'Columbus Elementary School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'Primary', 'grades': 'PK-8', 'type': 'Public'}, {'link': 'https://www.greatschools.org/illinois/chicago/1425-Wells-Community-Academy-High-School/', 'rating': 1, 'totalCount': None, 'distance': 0.4, 'assigned': None, 'name': 'Wells Community Academy High School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'High', 'grades': '9-12', 'type': 'Public'}]
#
# Propertytype: CONDO, Address: 3555 W Lyndale St #3B, Chicago, IL 60647, Price: 269999, Bedrooms: 2, Bathrooms: 1, Detailurl: https://www.zillow.com/homedetails/3555-W-Lyndale-St-3B-Chicago-IL-60647/87693371_zpid/, Imgsrc: https://photos.zillowstatic.com/fp/c5ed15a0556264616ab6a781839bab88-p_e.jpg, Description: Light filled TOP FLOOR condo in hot Logan Square with East facing views and a peek of downtown skyscrapers! NEWLY RENOVATED - Renovations completed in 2022 include:  New hardwood floors (not just refinished, complete replaced down to the subfloor, not a SQUEAKY board around), the tall ceilings are freshly painted in a show stopping bright white with new baseboards, renovated bathroom with tile to the ceiling, new vanity and fixtures, stylish light fixtures and fans and an entry way with exposed brick.  Kitchen features new cabinetry, including a rare pantry cabinet and quartz countertops. Range, microwave, fridge, dishwasher and stackable washer dryer are all less than 2 years old.  The condo offers a large open floor plan with living room, similar sized bedrooms (one being used as an office currently) and a bathroom with room for extra storage. What more could you want in a great part of Logan Square! Easy, non permit, street parking. Great location close to the 606, Palmer Square, restaurants (Wyler Road!) and transportation. Professionally managed building, dog & investor friendly. New construction all around! Broker Owned. Room sizes are estimates to be verified by buyer., Resofacts: {'hasGarage': False, 'hasPetsAllowed': True, 'heating': ['Natural Gas', 'Forced Air'], 'cooling': ['Central Air'], 'flooring': ['Hardwood'], 'appliances': ['Range', 'Microwave', 'Dishwasher', 'Refrigerator', 'Washer', 'Dryer', 'Stainless Steel Appliance(s)', 'Gas Cooktop', 'Gas Oven'], 'laundryFeatures': ['In Unit', 'Laundry Hook-Up in Unit'], 'associationFee': '$300 monthly', 'livingArea': '1,000 sqft', 'taxAnnualAmount': 5103, 'parkingFeatures': {}, 'stories': None}, Schools: [{'link': 'https://www.greatschools.org/illinois/chicago/1253-Mozart-Elementary-School/', 'rating': 4, 'totalCount': None, 'distance': 0.3, 'assigned': None, 'name': 'Mozart Elementary School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'Primary', 'grades': 'PK-8', 'type': 'Public'}, {'link': 'https://www.greatschools.org/illinois/chicago/1203-Kelvyn-Park-High-School/', 'rating': 1, 'totalCount': None, 'distance': 1.1, 'assigned': None, 'name': 'Kelvyn Park High School', 'studentsPerTeacher': None, 'isAssigned': None, 'size': None, 'level': 'Middle', 'grades': '7-12', 'type': 'Public'}]
#
# ### Output ###

# %%
# get final response from Gemini
print(get_chat_response(chat, prompt))
# Out:
# ## Two-Bedroom Apartment Recommendations:
#
# Based on your request for a two-bedroom apartment in Chicago, I've selected three options that might interest you:
#
# **1. Spacious 2-Bedroom Condo in East Lakeview:**
#
# * **Address:** 5757 N Sheridan Rd APT 11J, Chicago, IL 60660
# * **Price:** $179,950
# * **Details:** https://www.zillow.com/homedetails/5757-N-Sheridan-Rd-APT-11J-Chicago-IL-60660/3694665_zpid/
# * **Image:** https://photos.zillowstatic.com/fp/c98d7bd8a3727edb87e8418c0fc527c-p_e.jpg
# * **Description:** This corner unit boasts an open-concept living area, two bedrooms, granite countertops, stainless steel appliances, and hardwood floors. It also includes in-building laundry and bike storage, along with access to a fenced patio, gas grills, and the bike trail. Leased heated garage parking is available.
# * **School Information:** Swift Elementary Specialty School (K-8, rated 4 stars) and Senn High School (9-12, rated 4 stars) are nearby.
# * **Note:** This condo does not allow pets.
#
# **2. Modern 2-Bedroom Condo in East Ukrainian Village:**
#
# * **Address:** 926 N Winchester Ave #2, Chicago, IL 60622
# * **Price:** $475,000
# * **Details:** https://www.zillow.com/homedetails/926-N-Winchester-Ave-2-Chicago-IL-60622/87711579_zpid/
# * **Image:** https://photos.zillowstatic.com/fp/4f4c50d2ac83652a0ad54148bb44168e-p_e.jpg
# * **Description:** This light-filled condo features an open-concept living area, two bedrooms, a private balcony off the primary suite, fireplace, upgraded finishes, and an updated bathroom with a jetted tub. The unit includes in-unit laundry and access to a shared rooftop garage deck.
# * **School Information:** Columbus Elementary School (PK-8, rated 6 stars) and Wells Community Academy High School (9-12, rated 1 star) are nearby.
# * **Note:** This condo comes with a garage parking space.
#
# **3. Top-Floor 2-Bedroom Condo in Logan Square:**
#
# * **Address:** 3555 W Lyndale St #3B, Chicago, IL 60647
# * **Price:** $269,999
# * **Details:** https://www.zillow.com/homedetails/3555-W-Lyndale-St-3B-Chicago-IL-60647/87693371_zpid/
# * **Image:** https://photos.zillowstatic.com/fp/c5ed15a0556264616ab6a781839bab88-p_e.jpg
# * **Description:** This top-floor condo features an open floor plan, two bedrooms, a fully renovated bathroom, new hardwood floors, and a remodeled kitchen with new cabinetry and quartz countertops. The unit includes in-unit laundry and is pet-friendly. The building is professionally managed and located near the 606 trail, Palmer Square, restaurants, and public transportation.
# * **School Information:** Mozart Elementary School (PK-8, rated 4 stars) and Kelvyn Park High School (7-12, rated 1 star) are nearby.
# * **Note:** This condo includes easy non-permit street parking.
#
# ##Additional Information:
#
# Please let me know if you have any specific questions about these options, including details on the "Resofacts" and "Schools" information. I'm happy to provide further clarification or suggest additional properties based on your refined search criteria.
#
# Additionally, you may consider factoring in other aspects beyond the number of bedrooms, such as:
#
# * **Budget:** Your preferred price range.
# * **Desired Neighborhood:** Specific areas in Chicago that you are interested in living.
# * **Amenities:** Parking, in-unit laundry, pet-friendliness, balcony/patio, etc.
# * **Building Features:** Gym, pool, elevator, doorman, etc.
# * **Commute:** Your typical mode of transportation and desired proximity to work, school, or other destinations.

# %%
prompt_2 = 'I want more details about the second property'
print(get_chat_response(chat, prompt_2))
# Out:
# ## Expanded Details on the East Ukrainian Village Condo:
#
# Since you're interested in learning more about the second property, let's delve deeper into the details:
#
# **Location:** 926 N Winchester Ave #2, Chicago, IL 60622. This places you in the heart of East Ukrainian Village, known for its trendy atmosphere, diverse restaurants, and vibrant nightlife.
#
# **Price:** $475,000. Keep in mind that this is the listing price, and the actual purchase price may vary depending on negotiation and market conditions.
#
# **Features:**
#
# * **Bedrooms:** 2
# * **Bathrooms:** 2
# * **Living Area:** 1,200 square feet
# * **Open concept living area with fireplace**
# * **Split bedroom floor plan for privacy**
# * **Primary suite with walk-in closet and private balcony**
# * **Updated bathroom with jetted tub and separate shower**
# * **In-unit laundry**
# * **Shared rooftop garage deck**
# * **Garage parking space included**
# * **Mariano's grocery store and local restaurants within walking distance**
# * **Easy access to Blue Line and major highways**
#
# **Additional Information:**
#
# * **Built in 2006**
# * **Monthly association fee: $99**
# * **Annual property taxes: $8,978**
# * **New construction all around the building**
#
# **Resofacts:**
#
# * **Has Garage:** Yes
# * **Pets Allowed:** Information not provided in the listing. It's recommended to contact the listing agent or property management company for clarification.
# * **Heating:** Natural Gas, Forced Air
# * **Cooling:** Central Air
# * **Flooring:** Hardwood
# * **Appliances:** Information not provided in the listing. You may need to inquire further about specific appliances included.
# * **Laundry Features:** In-unit laundry, laundry hook-up in unit
# * **Parking Features:** Garage
#
# **Schools:**
#
# * **Columbus Elementary School (PK-8, rated 6 stars)**
# * **Wells Community Academy High School (9-12, rated 1 star)**
#
# **Please note:** School information is based on the listing and may not be entirely accurate. It's always recommended to confirm school assignments with the Chicago Public Schools directly.
#
# **Additional Considerations:**
#
# * The fact that the unit is newly renovated and has a private balcony may be significant selling points.
# * The location in East Ukrainian Village offers a lively atmosphere and convenient access to amenities.
# * The association fee and property taxes are factors to consider within your budget.
#
# **Next Steps:**
#
# * If you're interested in learning more about this property, I recommend contacting the listing agent or property management company for a showing.
# * You may also want to consider researching the neighborhood and nearby amenities to ensure it aligns with your lifestyle preferences.
# * Don't hesitate to ask any additional questions you may have, and I'll be happy to assist you further.
#
# I hope this expanded information provides a clearer picture of the East Ukrainian Village condo and helps you determine if it's the right fit for your needs.

# %%
prompt_3 = 'Is this property close to public transportation facilities?'
print(get_chat_response(chat, prompt_3))
# Out:
# ## Public Transportation Accessibility of the East Ukrainian Village Condo:
#
# Yes, the East Ukrainian Village condo at 926 N Winchester Ave #2 is conveniently located near several public transportation options:
#
# **Bus Lines:**
#
# * **Route 70 Division:** The Division bus stop is just a 3-minute walk away, offering frequent service to downtown Chicago and other parts of the city.
# * **Route 56 Milwaukee:** The Milwaukee bus stop is a 5-minute walk away, providing access to the O'Hare Airport Blue Line station and the western suburbs.
# * **Route 94 California:** The California bus stop is a 7-minute walk away, connecting you to Lincoln Park, Lakeview, and the north side of the city.
#
# **Train Stations:**
#
# * **Blue Line Damen Station:** This station is located approximately a 15-minute walk from the condo. The Blue Line provides fast and direct access to downtown Chicago, O'Hare Airport, and several other neighborhoods.
#
# **Additional Information:**
#
# * The condo's walk score is 95, indicating exceptional walkability and easy access to nearby amenities and public transportation.
# * Real-time public transit information can be readily accessed through apps like Google Maps or the Chicago Transit Authority (CTA) website.
# * You can also use the CTA Trip Planner tool to determine the best routes and travel times to reach your desired destinations.
#
# **Conclusion:**
#
# Based on its proximity to bus stops and the Blue Line Damen Station, the East Ukrainian Village condo offers convenient access to public transportation for commuting, exploring the city, and running errands.

# %% [markdown]
# ## 5. Integrating all functions

# %%
## TBD
